# %%
# Boilerplate from Randy cheatsheet at https://docs.google.com/document/d/1utZuLHcKQEZNXTQLOysTNCxTHrqxczAUymmtplpn27Q/edit#
import pandas as pd
import geopandas as gpd
import numpy as np
from geopandas import GeoSeries, GeoDataFrame
import re
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# Wide display
from IPython.core.display import display, HTML
display(HTML("<style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>"))
# Out:
# <style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>

# %%
import pandas as pd
import csv, json, os, math, numbers, pandas, re, scipy, scipy.sparse, shutil
import struct, subprocess, sys, threading, time, urllib2
import sqlite3, thread, urllib

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

# %%
def get_segments_from_ring(r):
    ret = set()
    for i in range(0, len(r)):
        ret.add((r[i - 1][0], r[i - 1][1], r[i][0], r[i][1]))
    return ret

def get_segments_from_polygon(p):
    return set.union(*[get_segments_from_ring(r) for r in p])

def get_segments_from_multipolygon(mp):
    return set.union(*[get_segments_from_polygon(p) for p in mp])

def get_segments(g):
    if 'features' in g:
        return set.union(*[get_segments(f) for f in g['features']])
    elif 'geometry' in g:
        if g['geometry']['type'] == 'Polygon':
            return get_segments_from_polygon(g['geometry']['coordinates'])
        elif g['geometry']['type'] == 'MultiPolygon':
            return get_segments_from_multipolygon(g['geometry']['coordinates'])
        else:
            raise Exception('unrecognized geometry type %s' % g['geometry']['type'])
    else:
        raise 'unrecognized type'
        
def LonLatToWebMercator(lon, lat):
    x = (lon + 180.0) * 256.0 / 360.0
    y = 128.0 - math.log(math.tan((lat + 90.0) * math.pi / 360.0)) * 128.0 / math.pi
    return [x, y]

def WebMercatorToLonLat(x,y):
    lat = math.atan(math.exp((128.0 - y) * math.pi / 128.0)) * 360.0 / math.pi - 90.0
    lon = x * 360.0 / 256.0 - 180.0
    return [lon, lat]

def project_and_binarize_segment(segment, dest):
    (x1, y1) = LonLatToWebMercator(segment[0], segment[1])
    (x2, y2) = LonLatToWebMercator(segment[2], segment[3])
    dest.write(struct.pack('<ffff', x1, y1, x2, y2))

def binarize_geojson_outlines(src, dest):
    gj = json.load(open(src))
    print 'Read %d features from %s' % (len(gj['features']), src)
    segments = get_segments(gj)
    print '%d segments' % len(segments)

    try:
        os.makedirs(os.path.dirname(dest))
    except OSError:
        pass
        
    out = open(dest + '.tmp', 'w')
    for segment in segments:
        project_and_binarize_segment(segment, out)
    out.close()
    os.rename(dest + '.tmp', dest)
    print 'Created %s (%d segments)' % (dest, os.stat(dest).st_size / 16)

# %%
pandas.options.display.max_colwidth = 300
pandas.set_option('display.max_columns', 500)

# %% [markdown]
# # Read in 2018 US House boundaries

# %%
ush_2018 = gpd.read_file('voting/Remedial Plan Shapefile.shp').to_crs(epsg=4326)

# %%
ush_2018.plot()

# %%
ush_2018

# %%
# Create a GeoDataFrame that just has DISTRICT and geometry
ush_out_2018 = gpd.GeoDataFrame(ush_2018[['DISTRICT']], geometry=ush_2018.geometry,crs={'init': 'epsg:4326'})

# %%
ush_out_2018

# %%
# Write out the 2018 US House geometry as a geojson file
ush_out_2018.to_file('voting/pa_us_house_boundaries_2018.geojson', driver="GeoJSON")

# %%
binarize_geojson_outlines('voting/pa_us_house_boundaries_2018.geojson', 
                          'voting/pa_us_house_boundaries_2018.bin')
# Out:
# Read 18 features from voting/pa_us_house_boundaries_2018.geojson
# 112242 segments
# Created voting/pa_us_house_boundaries_2018.bin (112242 segments)

# %% [markdown]
# # Polling places

# %%
# Get old polling place locations
pp_2017 = gpd.read_file('voting/Polling_Place_Locations_May_2017.shp').to_crs(epsg=4326)

# %%
pp_2017.plot()

# %%
pp_2017
# Out:
#       OBJECTID_1  OBJECTID  Muni  Ward  District  \
# 0           1001    1004.0   223     0         6
# 1           1002    1005.0   223     0         7
# 2           1003    1006.0   225     0         1
# 3           1004    1007.0   225     0         2
# 4           1005    1008.0   225     0         3
# 5           1006    1009.0   225     0         4
# 6           1007    1010.0   225     0         5
# 7           1008    1011.0   225     0         6
# 8           1009    1012.0   225     0         7
# 9           1010    1013.0   225     0         8
# 10          1011    1014.0   225     0         9
# 11          1012    1015.0   225     0        10
# 12          1013    1016.0   228     3         3
# 13          1014    1017.0   228     3         4
# 14          1015    1018.0   228     3         5
# 15          1016    1019.0   228     3         6
# 16          1017    1020.0   229     0         1
# 17          1018    1021.0   229     0         2
# 18          1019    1022.0   188    28        10
# 19          1020    1023.0   188    28        11
# 20          1021    1024.0   188    29         1
# 21          1022    1025.0   188    29         2
# 22          1023    1026.0   188    29         3
# 23          1024    1027.0   188    29         4
# 24          1025    1028.0   188    29         5
# 25          1026    1029.0   188    29         7
# 26          1027    1030.0   188    29         9
# 27          1028    1031.0   188    29        10
# 28          1029    1032.0   188    29        12
# 29          1030    1033.0   188    30         1
# 30          1031    1034.0   188    30         3
# 31          1032    1035.0   188    30         4
# 32          1033    1036.0   188    30         5
# 33          1034    1037.0   188    31         3
# 34          1035    1038.0   188    31         4
# 35          1036    1039.0   188    31         5
# 36          1037    1040.0   188    31         6
# 37          1038    1041.0   188    32         1
# 38          1039    1042.0   188    32         2
# 39          1040    1043.0   188    32         3
# 40          1041    1044.0   188    32         4
# 41          1042    1045.0   188    32         5
# 42          1043    1046.0   188    32         6
# 43          1044    1047.0   188    32         7
# 44          1045    1048.0   189     0         4
# 45          1046    1049.0   189     0         5
# 46          1047    1050.0   189     0         6
# 47          1048    1051.0   189     0         7
# 48          1049    1052.0   189     0         8
# 49          1050    1053.0   189     0         9
# ...          ...       ...   ...   ...       ...
# 1273         951     954.0   188    24         6
# 1274         952     955.0   188    25         2
# 1275         953     956.0   188    25         3
# 1276         954     957.0   188    25         4
# 1277         955     958.0   188    25         5
# 1278         956     959.0   188    25         6
# 1279         957     960.0   188    26         1
# 1280         958     961.0   188    26         2
# 1281         959     962.0   188    26         4
# 1282         960     963.0   188    26         5
# 1283         961     964.0   188    26         6
# 1284         962     965.0   188    26         7
# 1285         963     966.0   188    26         8
# 1286         964     967.0   188    26         9
# 1287         965     968.0   188    26        10
# 1288         966     969.0   188    26        11
# 1289         967     970.0   188    26        12
# 1290         968     971.0   188    26        13
# 1291         969     972.0   188    26        15
# 1292         970     973.0   188    26        16
# 1293         971     974.0   188    26        17
# 1294         972     975.0   188    27         1
# 1295         973     976.0   188    27         2
# 1296         974     977.0   188    27         3
# 1297         975     978.0   188    27         4
# 1298         976     979.0   188    27         5
# 1299         977     980.0   188    27         6
# 1300         978     981.0   188    27         8
# 1301         979     982.0   188    27         9
# 1302         980     983.0   188    27        10
# 1303         981     984.0   188    27        11
# 1304         982     985.0   188    27        12
# 1305         983     986.0   188    27        13
# 1306         984     987.0   188    28         1
# 1307         985     988.0   188    28         2
# 1308         986     989.0   188    28         5
# 1309         987     990.0   188    28         6
# 1310         988     991.0   188    28         7
# 1311         989     992.0   188    28         8
# 1312         990     993.0   188    28         9
# 1313         991     994.0   222     0        16
# 1314         992     995.0   222     0        17
# 1315         993     996.0   222     0        18
# 1316         994     997.0   222     0        19
# 1317         995     998.0   222     0        20
# 1318         996     999.0   222     0        21
# 1319         997    1000.0   223     0         1
# 1320         998    1001.0   223     0         2
# 1321         999    1002.0   223     0         4
# 1322        1000    1003.0   223     0         5
#
#                                           LocName Prefix House Fraction  \
# 0                                 #2 ENGINE HOUSE   None    24     None
# 1                 WEST VIEW ELEMENTARY SCHOOL GYM   None    47     None
# 2             BALDWIN COMM. U M CHURCH-WESLEY HL.   None  5001     None
# 3               ST. GABRIEL OF THE SORROW VIR SCH   None  5200     None
# 4                                       BORO BLDG   None   100     None
# 5                                       BORO BLDG   None   100     None
# 6                    BALDWIN HIGH SCHOOL GYM HALL   None  4653     None
# 7                   BALDWIN HIGH SCHOOL  GYM HALL   None  4653     None
# 8                         CANONGATE APT-PARTY RM.   None   200     None
# 9                     WHITEHALL ELEMENTARY SCHOOL   None  4900     None
# 10                  BALDWIN HIGH SCHOOL  GYM HALL   None  4653     None
# 11           BALDWIN COMM. U M CHURCH-ASBURY HALL   None  5001     None
# 12         WILKINSBURG SCHOOL ADMINISTRATION BLDG   None   718     None
# 13                    ST STEPHEN EPISCOPAL CHURCH   None   600     None
# 14                    ST STEPHEN EPISCOPAL CHURCH   None   600     None
# 15                  WILKINSBURG SCHOOL ADMIN BLDG   None   718     None
# 16                BORO BLDG 1ST FL FIREMEN'S ROOM   None   301     None
# 17                       BORO BLDG STATION ST ENT   None   301     None
# 18                                 SALVATION ARMY   None  1821     None
# 19                                 SALVATION ARMY   None  1821     None
# 20                                   ENGINE HOUSE   None  1704     None
# 21                          CONCORD PRESBY CHURCH   None  1907     None
# 22                                CARRICK REGENCY   None  2129     None
# 23                SPENCER UNITED METHODIST CHURCH   None   117     None
# 1293            SPRING GARDEN EARLY GHILDHOOD CTR   None  1501     None
# 1294                    LYNN WILLIAMS APTS COM RM   None  3710     None
# 1295                      DESTINY OF FAITH CHURCH   None  3737     None
# 1296                      DESTINY OF FAITH CHURCH   None  3737     None
# 1297                  GREATER ALLEN A.M.E. CHURCH   None  3600     None
# 1298                    LYNN WILLIAMS APTS COM RM   None  3710     None
# 1299                     MORROW SCHOOL, 1ST FLOOR   None  1611     None
# 1300                            #34 TRUCK STATION   None  3284     None
# 1301            CARNEGIE LIBRARY WOODS RUN BRANCH   None  1201     None
# 1302                                PRESLEY RIDGE   None  2611     None
# 1303              PITTSBURGH PARAMEDIC STATION 10   None  2800     None
# 1304               RISEN LORD PARISH YOUTH REC CT   None  3250     None
# 1305                                PRESLEY RIDGE   None  2611     None
# 1306                    ST ANDREW LUTHERAN CHURCH   None   218     None
# 1307                                 NOBLE TOWERS   None  2440     None
# 1308           1ST UNITED PRESBY CH OF CRAFTON HT   None    50     None
# 1309               MIDDLETOWN ROAD BAPTIST CHURCH   None  2660     None
# 1310               MIDDLETOWN ROAD BAPTIST CHURCH   None  2660     None
# 1311                  ACENSION CHURCH SOCIAL HALL   None   114     None
# 1312                             CHARTIERS SCHOOL   None  3799     None
# 1313         LEBANON PRESBYTERIAN CHURCH SIDE ENT   None   280     None
# 1314                   SKY VIEW W. MIFFLIN VFC #4   None   660     None
# 1315               NEW EMERSON ELEMENTARY SCH GYM   None  1922     None
# 1316                        CLARA E BARTON SCHOOL   None   764     None
# 1317               W MIFFLIN HI SCH AUD LOBBY ENT   None    91     None
# 1318                        CLARA E BARTON SCHOOL   None   764     None
# 1319                                #1 FIRE HOUSE   None   338     None
# 1320          ST LUKES EV CH REAR PARKING LOT ENT   None   305     None
# 1321                              #3 ENGINE HOUSE   None   481     None
# 1322                             WEST VIEW TOWERS   None   808     None
#
#                  Street Suffix1 Suffix2            City UnitDesc UnitNumber  \
# 0               AMHERST     AVE    None       WEST VIEW     None       None
# 1              CHALFANT      ST    None       WEST VIEW     None       None
# 2               BAPTIST      RD    None      PITTSBURGH     None       None
# 3            GREENRIDGE      DR    None      PITTSBURGH     None       None
# 4          BOROUGH PARK      DR    None      PITTSBURGH     None       None
# 5          BOROUGH PARK      DR    None      PITTSBURGH     None       None
# 6              CLAIRTON    BLVD    None      PITTSBURGH     None       None
# 7              CLAIRTON    BLVD    None      PITTSBURGH     None       None
# 8         WHITE HAMPTON      LN    None      PITTSBURGH     None       None
# 9                 CURRY      RD    None      PITTSBURGH     None       None
# 10             CLAIRTON    BLVD    None      PITTSBURGH     None       None
# 11              BAPTIST      RD    None      PITTSBURGH     None       None
# 12              WALLACE     AVE    None     WILKINSBURG     None       None
# 13                 PITT      ST    None     WILKINSBURG     None       None
# 14                 PITT      ST    None     WILKINSBURG     None       None
# 15              WALLACE     AVE    None     WILKINSBURG     None       None
# 16              STATION      ST    None      WILMERDING     None       None
# 17              STATION      ST    None      WILMERDING     None       None
# 18    BROADHEAD FORDING      RD    None      PITTSBURGH     None       None
# 19    BROADHEAD FORDING      RD    None      PITTSBURGH     None       None
# 20          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 21          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 22          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 23              SPENCER     AVE    None      PITTSBURGH     None       None
# 24          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 25          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 26          BROWNSVILLE      RD    None      PITTSBURGH     None       None
# 27            PARKFIELD      ST    None      PITTSBURGH     None       None
# 28           BROWNSILLE      RD    None      PITTSBURGH     None       None
# 29                 KNOX     AVE    None      PITTSBURGH     None       None
# 30              CHARLES      ST    None      PITTSBURGH     None       None
# 31             ROCHELLE      ST    None      PITTSBURGH     None       None
# 32             ROCHELLE      ST    None      PITTSBURGH     None       None
# 33            MULDOWNEY     AVE    None      PITTSBURGH     None       None
# 34              MIFFLIN      RD    None      PITTSBURGH     None       None
# 35              MIFFLIN      RD    None      PITTSBURGH     None       None
# 36              MIFFLIN      RD    None      PITTSBURGH     None       None
# 37         SAW MILL RUN    BLVD    None      PITTSBURGH     None       None
# 38         SAW MILL RUN    BLVD    None      PITTSBURGH     None       None
# 39         SAW MILL RUN    BLVD    None      PITTSBURGH     None       None
# 40             OAKRIDGE      ST    None      PITTSBURGH     None       None
# 41             OAKRIDGE      ST    None      PITTSBURGH     None       None
# 42             OAKRIDGE      ST    None      PITTSBURGH     None       None
# 43             OAKRIDGE      ST    None      PITTSBURGH     None       None
# 44         OLD CLAIRTON      RD    None  PLEASANT HILLS     None       None
# 45             BRUCETON      RD    None  PLEASANT HILLS     None       None
# 46             BRUCETON      RD    None  PLEASANT HILLS     None       None
# 47             BRUCETON      RD    None  PLEASANT HILLS     None       None
# 48         OLD CLAIRTON      RD    None  PLEASANT HILLS     None       None
# 49         OLD CLAIRTON      RD    None  PLEASANT HILLS     None       None
# ...                 ...     ...     ...             ...      ...        ...
# 1273           TINSBURY      ST    None      PITTSBURGH     None       None
# 1274        BUENA VISTA      ST    None      PITTSBURGH     None       None
# 1275        BUENA VISTA      ST    None      PITTSBURGH     None       None
# 1276         CALIFORNIA     AVE    None      PITTSBURGH     None       None
# 1277            CLAYTON     AVE    None      PITTSBURGH     None       None
# 1278            CLAYTON     AVE    None      PITTSBURGH     None       None
# 1279            NORWOOD     AVE    None      PITTSBURGH     None       None
# 1280            NORWOOD     AVE    None      PITTSBURGH     None       None
# 1281              MAPLE     AVE    None      PITTSBURGH     None       None
# 1282     MOUNT PLEASANT      RD    None      PITTSBURGH     None       None
# 1283     MOUNT PLEASANT      RD    None      PITTSBURGH     None       None
# 1284            NORWOOD     AVE    None      PITTSBURGH     None       None
# 1285              DAMAS      ST    None      PITTSBURGH     None       None
# 1286              DAMAS      ST    None      PITTSBURGH     None       None
# 1287        PERRYSVILLE     AVE    None      PITTSBURGH     None       None
# 1288        PERRYSVILLE     AVE    None      PITTSBURGH     None       None
# 1289           FRANKLIN      RD    None      PITTSBURGH     None       None
# 1290           FRANKLIN      RD    None      PITTSBURGH     None       None
# 1291           FRANKLIN      RD    None      PITTSBURGH     None       None
# 1292          RIVERVIEW     AVE    None      PITTSBURGH     None       None
# 1293      SPRING GARDEN     AVE    None      PITTSBURGH     None       None
# 1298  POINT (-80.03498815688667 40.48361286672273)
# 1299  POINT (-80.03968839015874 40.48017986114791)
# 1300  POINT (-80.02956374785335 40.47663376163798)
# 1301   POINT (-80.0300950301923 40.47621556341201)
# 1302  POINT (-80.02742539089915 40.46791832475735)
# 1303  POINT (-80.03017817483173 40.46993900216097)
# 1304   POINT (-80.03892825671524 40.4748449942429)
# 1305  POINT (-80.02725517764658 40.46796000050905)
# 1306  POINT (-80.07522381978944 40.41495292155984)
# 1307  POINT (-80.05999654704017 40.42735336595673)
# 1308  POINT (-80.05550383336666 40.43868750703055)
# 1309  POINT (-80.05919075807664 40.44567894219043)
# 1310   POINT (-80.05889154075633 40.4458408493437)
# 1311  POINT (-80.06834454831395 40.44896106509521)
# 1312  POINT (-80.07591313752982 40.45774814196955)
# 1313  POINT (-79.93106905738372 40.34758811399941)
# 1314  POINT (-79.92962262720333 40.36080261500119)
# 1315  POINT (-79.86564065046302 40.36275261417807)
# 1316   POINT (-79.9212556241753 40.34249209234198)
# 1317  POINT (-79.87355767958728 40.38194492640493)
# 1318   POINT (-79.92133029459795 40.3423476357179)
# 1319  POINT (-80.02792574748445 40.51637463307875)
# 1320  POINT (-80.02338729985651 40.51527497622167)
# 1321  POINT (-80.03373132562082 40.52103512575727)
# 1322  POINT (-80.03354164955898 40.51717713387636)
#
# [1323 rows x 34 columns]

# %%
pp_2017[pp_2017.MWD2.duplicated()]
# Out:
#       OBJECTID_1  OBJECTID  Muni  Ward  District            LocName Prefix  \
# 1235         913     916.0   188    19        26  BROOKLINE TERRACE   None
#
#      House Fraction     Street Suffix1 Suffix2        City UnitDesc  \
# 1235   920     None  BROOKLINE    BLVD    None  PITTSBURGH     None
#
#      UnitNumber         Zip            Parcel Accessible Leadman Region  \
# 1235       None  15226-2148  0097D00067000S00       None      12      7
#
#         Coordinate    Coordina_1  DistrictCO  DistrictSE  DistrictLE EditDate  \
# 1235  1.336626e+06  393957.81808        14.0        42.0        22.0     None
#
#         MuniName          OrigAddres      MWD       POINT_X       POINT_Y  \
# 1235  PITTSBURGH  920 BROOKLINE BLVD  1881926  1.336626e+06  393957.81808
#
#          MWD2          NewAddress  \
# 1235  1881926  920 BROOKLINE BLVD
#
#                                           geometry
# 1235  POINT (-80.01876370240662 40.39250864644669)

# %%
pp_2017[pp_2017.MWD2==1881926]
# Out:
#      OBJECTID_1  OBJECTID  Muni  Ward  District                     LocName  \
# 618         296     296.0   188    19        26  BROOKLINE U.P. CHURCH HALL
#
#     Prefix House Fraction     Street Suffix1 Suffix2        City UnitDesc  \
# 618   None  1036     None  BROOKLINE    BLVD    None  PITTSBURGH     None
#
#     UnitNumber         Zip            Parcel Accessible Leadman Region  \
# 618       None  15226-2148  0097H00001000000       None      12      7
#
#        Coordinate     Coordina_1  DistrictCO  DistrictSE  DistrictLE EditDate  \
# 618  1.337211e+06  393627.765169        14.0        42.0        22.0     None
#
#        MuniName           OrigAddres      MWD       POINT_X        POINT_Y  \
# 618  PITTSBURGH  1036 BROOKLINE BLVD  1881926  1.337211e+06  393627.765169
#
#         MWD2           NewAddress  \
# 618  1881926  1036 BROOKLINE BLVD
#
#                                          geometry
# 618  POINT (-80.01663330913114 40.39164418362884)

# %%
# Get rid of Brookline terrace based on discussion with David Hoyt
# on 10/25/18
pp_2017 = pp_2017[~(pp_2017.MWD2.duplicated())]

# %%
# Get intermediate polling place locations
pp_2018_05 = gpd.read_file('voting/PollingPlaces2018_May.shp').to_crs(epsg=4326)

# %%
pp_2018_05[pp_2018_05.MWD2.duplicated()]
# Out:
#       OBJECTID_1  OBJECTID  Muni  Ward  District            LocName Prefix  \
# 1235         913     916.0   188    19        26  BROOKLINE TERRACE   None
#
#      House Fraction     Street Suffix1 Suffix2        City UnitDesc  \
# 1235   920     None  BROOKLINE    BLVD    None  PITTSBURGH     None
#
#      UnitNumber         Zip            Parcel Accessible Leadman Region  \
# 1235       None  15226-2148  0097D00067000S00       None      12      7
#
#         Coordinate     Coordina_1  DistrictCO  DistrictSE  DistrictLE  \
# 1235  1.336626e+06  393957.818078        14.0        42.0        22.0
#
#      EditDate    MuniName          OrigAddres      MWD       POINT_X  \
# 1235     None  PITTSBURGH  920 BROOKLINE BLVD  1881926  1.336626e+06
#
#             POINT_Y     MWD2          NewAddress  \
# 1235  393957.818078  1881926  920 BROOKLINE BLVD
#
#                                           geometry
# 1235  POINT (-80.01876370240662 40.39250864644669)

# %%
pp_2018_05 = pp_2018_05[~pp_2018_05.MWD2.duplicated()]

# %%
# Get new polling place locations
pp_2018_11 = gpd.read_file('voting/Allegheny_County_Polling_Place_Locations_November_2018.shp').to_crs(epsg=4326)

# %%
pp_2018_11[pp_2018_11.MWD2.duplicated()]
# Out:
#       OBJECTID_1  OBJECTID  Muni  Ward  District            LocName Prefix  \
# 1235         913     916.0   188    19        26  BROOKLINE TERRACE   None
#
#      House Fraction     Street Suffix1 Suffix2        City UnitDesc  \
# 1235   920     None  BROOKLINE    BLVD    None  PITTSBURGH     None
#
#      UnitNumber         Zip            Parcel Accessible Leadman Region  \
# 1235       None  15226-2148  0097D00067000S00       None      12      7
#
#         Coordinate     Coordina_1  DistrictCO  DistrictSE  DistrictLE  \
# 1235  1.336626e+06  393957.818078        14.0        42.0        22.0
#
#      EditDate    MuniName          OrigAddres      MWD       POINT_X  \
# 1235     None  PITTSBURGH  920 BROOKLINE BLVD  1881926  1.336626e+06
#
#             POINT_Y     MWD2          NewAddress  \
# 1235  393957.818078  1881926  920 BROOKLINE BLVD
#
#                                           geometry
# 1235  POINT (-80.01876370240662 40.39250864644669)

# %%
pp_2018_11 = pp_2018_11[~pp_2018_11.MWD2.duplicated()]

# %%
pp_2018_m = pd.merge(pp_2018_11,pp_2018_05[['MWD2','NewAddress']], on='MWD2', suffixes=('_18_11', '_18_05'),left_index=False, right_index=False, sort=False,copy=True, indicator=False,
                         validate=None)

# %%
pp_2018_2017_m = pd.merge(pp_2018_m,pp_2017[['MWD2','NewAddress']], on='MWD2', suffixes=('_18_m', '_17_05'),left_index=False, right_index=False, sort=False,copy=True, indicator=False,
                         validate=None)

# %%
# Rename NewAddress to NewAddress_17_05
pp_2018_2017_m=pp_2018_2017_m.rename(columns={'NewAddress':'NewAddress_17_05'})

# %%
pp_2018_2017_m[pp_2018_2017_m.MWD2==1881926]
# Out:
#      OBJECTID_1  OBJECTID  Muni  Ward  District              LocName Prefix  \
# 618         296     296.0   188    19        26  TREE OF LIFE CHURCH   None
#
#     House Fraction     Street Suffix1 Suffix2        City UnitDesc UnitNumber  \
# 618  1036     None  BROOKLINE    BLVD    None  PITTSBURGH     None       None
#
#             Zip            Parcel Accessible Leadman Region    Coordinate  \
# 618  15226-2148  0097H00001000000       None      12      7  1.337211e+06
#
#         Coordina_1  DistrictCO  DistrictSE  DistrictLE EditDate    MuniName  \
# 618  393627.765169        14.0        42.0        22.0     None  PITTSBURGH
#
#               OrigAddres      MWD       POINT_X        POINT_Y     MWD2  \
# 618  1036 BROOKLINE BLVD  1881926  1.337211e+06  393627.765169  1881926
#
#         NewAddress_18_11                                      geometry  \
# 618  1036 BROOKLINE BLVD  POINT (-80.01663330913114 40.39164418362884)
#
#         NewAddress_18_05           NewAddress
# 618  1036 BROOKLINE BLVD  1036 BROOKLINE BLVD

# %%
# Changed since 2017_05
len(pp_2018_2017_m[pp_2018_2017_m.NewAddress_18_11!=pp_2018_2017_m.NewAddress_17_05])
# Out:
# 59

# %%
pp_2018_2017_m['addr_changed_17'] = pp_2018_2017_m.NewAddress_18_11!=pp_2018_2017_m.NewAddress_17_05

# %%
# Changed since 2018_05
len(pp_2018_2017_m[pp_2018_2017_m.NewAddress_18_11!=pp_2018_2017_m.NewAddress_18_05])
# Out:
# 31

# %%
pp_2018_2017_m['addr_changed_18'] = pp_2018_2017_m.NewAddress_18_11!=pp_2018_2017_m.NewAddress_18_05

# %%
pp_2018_2017_m[pp_2018_2017_m.addr_changed_18].sort_values(['MuniName','MWD2'])[['MuniName','MWD2','LocName','NewAddress_18_11','NewAddress_18_05','addr_changed_17','addr_changed_18','geometry']]
# Out:
#          MuniName     MWD2                               LocName  \
# 332    BALDWIN BR  1040001                   ST ALBERT THE GREAT
# 333    BALDWIN BR  1040002                   ST ALBERT THE GREAT
# 756    BALDWIN BR  1040007           NORTH ZION LUTHERIAN CHURCH
# 758    BALDWIN BR  1040010           NORTH ZION LUTHERIAN CHURCH
# 759    BALDWIN BR  1040011    BALDWIN UNITED PRESBYTERIAN CHURCH
# 380      CARNEGIE  1180101             CARNEGIE BOROUGH BUILDING
# 381      CARNEGIE  1180104             CARNEGIE BOROUGH BUILDING
# 962    MCCANDLESS  1660202              INGOMAR ELEMENTRY SCHOOL
# 1024   MT LEBANON  1730503            MT LEBANON LUTHERAN CHURCH
# 1025   MT LEBANON  1730505            MT LEBANON LUTHERAN CHURCH
# 1026   MT LEBANON  1730508            MT LEBANON LUTHERAN CHURCH
# 1077   PENN HILLS  1850201                        VICTORY TEMPLE
# 820    PENN HILLS  1850305                    HEBRON U.P. CHURCH
# 1087   PENN HILLS  1850705        MT HOPE COMMUMITY PRESBYTERIAN
# 1108   PITTSBURGH  1880201        CARNEGIE LIBRARY OF PITTSBURGH
# 1115   PITTSBURGH  1880403            OAK HILL MANAGEMENT OFFICE
# 1181   PITTSBURGH  1881102                       LAURENTIAN HALL
# 1183   PITTSBURGH  1881104                       LAURENTIAN HALL
# 1185   PITTSBURGH  1881106            MT ARARAT COMMUMITY CENTER
# 1188   PITTSBURGH  1881111            MT ARARAT COMMUMITY CENTER
# 1191   PITTSBURGH  1881117            MT ARARAT COMMUMITY CENTER
# 622    PITTSBURGH  1881506                          MAGEE CENTER
# 1291   PITTSBURGH  1882616         RIVERVIEW PARK VISITOR CENTER
# 55           PLUM  1900008         HOLIDAY PARK CHURCH OF CHRIST
# 56           PLUM  1900009         HOLIDAY PARK CHURCH OF CHRIST
# 151        SHALER  2020104              CHERRY CITY VOL. FIRE CO
# 202         STOWE  2090202                       OHIOVIEW TOWERS
# 204         STOWE  2090401                               ROCKY'S
# 244   UP ST CLAIR  2150301  USC TWP BLDG LOWER LEVEL TRAINING RM
# 246   UP ST CLAIR  2150303  USC TWP BLDG LOWER LEVEL TRAINING RM
# 857   WILKINSBURG  2280106        COMMUNITY FORGE/JOHNSON SCHOOL
#
#             NewAddress_18_11        NewAddress_18_05  addr_changed_17  \
# 332          3198 SCHIECK ST           330 JOSEPH ST             True
# 333          3198 SCHIECK ST           330 JOSEPH ST             True
# 756      5100 BROWNSVILLE RD         374 KNOEDLER RD             True
# 758      5100 BROWNSVILLE RD         374 KNOEDLER RD             True
# 759          201 KNOEDLER RD         374 KNOEDLER RD             True
# 380           1 VETERANS WAY             201 MAIN ST             True
# 381           1 VETERANS WAY             201 MAIN ST             True
# 962         602 W INGOMAR RD         10375 PERRY HWY             True
# 1024       975 WASHINGTON RD      1100 WASHINGTON RD             True
# 1025       975 WASHINGTON RD      1100 WASHINGTON RD             True
# 1026       975 WASHINGTON RD      1100 WASHINGTON RD             True
# 1077        2824 GRAHAM BLVD      9601 FRANKSTOWN RD             True
# 820      10460 FRANKSTOWN RD      9601 FRANKSTOWN RD             True
# 1087     12106 FRANKSTOWN RD     12245 FRANKSTOWN RD             True
# 1108       612 SMITHFIELD ST            609 PENN AVE             True
# 1115          280 BURROWS ST      2415 ALLEQUIPPA ST             True
# 1181           5321 PENN AVE       113 N PACIFIC AVE             True
# 1183           5321 PENN AVE       113 N PACIFIC AVE             True
# 1185        751 N NEGLEY AVE         5799 HAMPTON ST             True
# 1188        751 N NEGLEY AVE         5799 HAMPTON ST             True
# 1191        751 N NEGLEY AVE         5801 HAMPTON ST             True
# 622       745 GREENFIELD AVE     4156 WINTERBURN AVE            False
# 1291       158 RIVERVIEW AVE           RIVERVIEW AVE             True
# 55       1510 ABERS CREEK RD          4795 HAVANA DR             True
# 56       1510 ABERS CREEK RD          4795 HAVANA DR             True
# 151            309 DAVIS AVE        146 HAWTHORNE RD             True
# 202         250 JEFFERSON DR        251 JEFFERSON DR             True
# 204          1562 ISLAND AVE        1400 FLEMING AVE             True
# 244   1820 MCLAUGHLIN RUN RD  1770 MCLAUGHLIN RUN RD             True
# 246   1820 MCLAUGHLIN RUN RD  1770 MCLAUGHLIN RUN RD             True
# 857        1256 FRANKLIN AVE     1125 PRINCETON BLVD             True
#
#       addr_changed_18                                      geometry
# 332              True  POINT (-79.96146665668988 40.38668419098998)
# 333              True  POINT (-79.96146665668988 40.38668419098998)
# 756              True  POINT (-79.98767936038728 40.34522021969623)
# 758              True  POINT (-79.98766615923428 40.34538341612095)
# 759              True  POINT (-79.98265275423823 40.34220958344338)
# 380              True  POINT (-80.09248622354187 40.40437348496651)
# 381              True  POINT (-80.09248622354187 40.40437348496651)
# 962              True  POINT (-80.05354458285946 40.58208360252215)
# 1024             True   POINT (-80.0480166542043 40.37373832898135)
# 1025             True    POINT (-80.048114107356 40.37353177333422)
# 1026             True  POINT (-80.04794318331736 40.37410404254153)
# 1077             True  POINT (-79.86269587220457 40.45991952532049)
# 820              True   POINT (-79.8454905890667 40.46071258193358)
# 1087             True  POINT (-79.82068556908331 40.47082917702095)
# 1108             True  POINT (-79.99727217730292 40.44174211677867)
# 1115             True   POINT (-79.9700215740332 40.43976640530599)
# 1181             True   POINT (-79.9378361449445 40.46491093076003)
# 1183             True  POINT (-79.93783535180172 40.46488201193655)
# 1185             True  POINT (-79.92685485117194 40.47139491990972)
# 1188             True  POINT (-79.92696945421471 40.47099342397659)
# 1191             True  POINT (-79.92697777495721 40.47116423007352)
# 622              True  POINT (-79.94018976023189 40.42340855195771)
# 1291             True  POINT (-80.01846350289074 40.48303803924744)
# 55               True   POINT (-79.7141412811708 40.48155915588463)
# 56               True  POINT (-79.71415677042182 40.48148771125202)
# 151              True  POINT (-79.95896461299489 40.49437740221057)
# 202              True  POINT (-80.07625773138786 40.48013006256672)
# 204              True  POINT (-80.07886697186828 40.48886962003505)
# 244              True  POINT (-80.07191009647731 40.33357682421526)
# 246              True  POINT (-80.07184615104653 40.33349786041523)
# 857              True   POINT (-79.87454980982193 40.4376012818225)

# %%
pp_2018_2017_m[pp_2018_2017_m.MWD2==1660201][['MuniName','MWD2','NewAddress_18_05','NewAddress_18_11','addr_changed_17','addr_changed_18','geometry']]
# Out:
#        MuniName     MWD2 NewAddress_18_05 NewAddress_18_11  addr_changed_17  \
# 961  MCCANDLESS  1660201  10375 PERRY HWY  10375 PERRY HWY            False
#
#      addr_changed_18                                      geometry
# 961            False  POINT (-80.05354114992568 40.60391226742988)

# %%
pp_2018_2017_m[pp_2018_2017_m.MWD2==2280201][['MuniName','MWD2','NewAddress_18_05','NewAddress_18_11','addr_changed_17','addr_changed_18','geometry']]
# Out:
#         MuniName     MWD2   NewAddress_18_05   NewAddress_18_11  \
# 858  WILKINSBURG  2280201  1256 FRANKLIN AVE  1256 FRANKLIN AVE
#
#      addr_changed_17  addr_changed_18  \
# 858            False            False
#
#                                          geometry
# 858  POINT (-79.87451573119165 40.43750237177388)

# %%
len(pp_2018_2017_m[(pp_2018_2017_m['addr_changed_17']) & ~(pp_2018_2017_m['addr_changed_18'])])
# Out:
# 29

# %%
# This was copied from http://localhost:8820/notebooks/projects/demographics/Voting-2018-AW3b-Polling.ipynb, 
# then modified to deal with addition of 18_05 data
def write_pp_csv(df, out_path):
    date_range = range(2017, 2019)
    out = open(out_path, 'w')
    # Write out header row.  First column doesn't have a column heading, next two are lat, lon, then each year
    out.write(",lat,lon,%s\n" % (",".join(map(str,date_range))))
    
    i=0
    for i in range(0,len(df)):
        coords = df['geometry'].iloc[i]
        lon = coords.x
        lat = coords.y
        mwd = df['MWD2'].iloc[i]
        
        # Write size row
        out_data=[mwd, lat, lon]
        for year in date_range:
            out_val = 20
            out_data.append(out_val)
        out.write('%s\n' % (",".join(map(str,out_data))))
        
        # Write color row: Color =1 for changed in 2018, .5 for changed in 2017, 0 for stable
        out_data=[mwd, lat, lon]
        color_val = 0
        if df['addr_changed_18'].iloc[i]:
            color_val=1
        elif df['addr_changed_17'].iloc[i]:
            color_val = 0.5
        
        for year in date_range:
            out_data.append(color_val)
        out.write('%s\n' % (",".join(map(str,out_data))))
    out.close()

# %%
write_pp_csv(pp_2018_2017_m, "voting/pa_ac_polling_places_2018b.csv")

# %% [markdown]
# # Deal with voting file from county

# %% [markdown]
# # Address mapping

# %%
# Key is string canonical address, value is a map: {'canonical_in_census_db': True/False,'canonical_in_google_db': True/False, 'other_addr_strings':Set, 'census_value':str, 'google_value':str
canonical_addr_map={}

# %%
def canonicalize_string(text):
    # Remove any leading or trailing whitespace, replace any internal whitespace with single spaces, upcase it all
    ret = re.sub("^\s+|\s+$", "", text)
    ret = re.sub("\s+", " ", ret)
    return ret.upper()

# %%
# Try to load canonical_addr_map originally created by 
#  http://localhost:8820/notebooks/projects/demographics/Fixup%20Address%20DB.ipynb
import pickle
pickle_file_path = 'assessments/canonical_addr_map_d.pickle'

# %%
# Load in canonical_addr_map
with open(pickle_file_path, 'rb') as handle:
    canonical_addr_map = pickle.load(handle)

# %%
# Save out canonical_addr_map
with open(pickle_file_path, 'wb') as handle:
    pickle.dump(canonical_addr_map, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
len(canonical_addr_map)
# Out:
# 3017691

# %%
# From http://localhost:8820/notebooks/projects/demographics/Allegheny%20County%20Property%20Assessments-AW9.ipynb

# assessments/cd/AC Property Assessments_10012017.xls (which is actually TDF) from Amy Gottsegen and Randy Sargent buying a CD from the county assessors office
# assessments/Allegheny_County_Parcel_Boundaries.geojson from https://data.wprdc.org/dataset/allegheny-county-parcel-boundaries
import array, csv, datetime, json, math, numpy, os, random, re 
from dateutil.parser import parse
from shapely.geometry import mapping, shape
from PIL import Image
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import pandas,numbers
from operator import itemgetter, attrgetter
import string
import calendar,time
from IPython.core.display import HTML

# Use geopandas.  Boilerplate from https://docs.google.com/document/d/1utZuLHcKQEZNXTQLOysTNCxTHrqxczAUymmtplpn27Q/edit#heading=h.f50xoxwmcir
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
# %matplotlib inline

pd.options.display.max_colwidth = 300
pd.options.display.max_rows = 100
pd.set_option('display.max_columns', 500)

# Built-in time handling fails for times before 1900.  Use arrow instead.  
# See https://arrow.readthedocs.io/en/latest/ for info
import arrow
import dateparser

def LonLatToPixelXY(lonlat):
    (lon, lat) = lonlat
    x = (lon + 180.0) * 256.0 / 360.0
    y = 128.0 - math.log(math.tan((lat + 90.0) * math.pi / 360.0)) * 128.0 / math.pi
    return [x, y]

# This does the same as above, but takes a GeoJSON point (which is what centroid returns)
def PointToPixelXY(point):
    lon=point.x
    lat=point.y
    x = (lon + 180.0) * 256.0 / 360.0
    y = 128.0 - math.log(math.tan((lat + 90.0) * math.pi / 360.0)) * 128.0 / math.pi
    return [x, y]

def GetCentroid(geometry):
    s = shape(geometry)
    return (s.centroid.x, s.centroid.y)   

def GetEpoch(date):
    return (date - datetime.datetime(1970, 1, 1)).total_seconds()

def HexToRgb(hex_string):
    rgb = colors.hex2color(hex_string)
    r,g,b = tuple([int(255*x) for x in rgb])
    return (r,g,b)

# %%
# Google addresses with the addition of using canonical_addr_map as cache
# Original version was from 
#  http://localhost:8820/notebooks/projects/demographics/Allegheny%20County%20Property%20Assessments-AW9.ipynb#
from shapely.geometry import Point
import collections


# Google geocoding API to geocode an address
# Assumes key is in google_api_key.txt
# Use as second level lookup only for those which fail census lookup

re_noalnum = re.compile('^([^\w]+)$')

def geocode_address_google(address):
    if(pandas.isnull(address) or re_noalnum.match(address)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(address)
        return None

    # String canonicalize the address
    caddr = canonicalize_string(address)

    # Check if we already have a value in canonical_addr_map, if so return it
    result=None
    if(caddr in canonical_addr_map and canonical_addr_map[caddr]['google_value']):
        result = json.loads(canonical_addr_map[caddr]['google_value'])
    else:
        # Not yet in canonical_addr_map, fetch from sqlite DB or google address lookup service
        try:
            geocode_address_google.conn
        except:
            geocode_address_google.conn = sqlite3.connect('geocoding_cache')
            geocode_address_google.cur = geocode_address_google.conn.cursor()
            geocode_address_google.cur.execute(('CREATE TABLE IF NOT EXISTS kvs'
                                         ' (key PRIMARY KEY, value)'
                                         ' WITHOUT ROWID;'))
            geocode_address_google.conn.commit()

        geocode_address_google.cur.execute('SELECT value FROM kvs WHERE key=?', (caddr,))
        rows = geocode_address_google.cur.fetchall()
        if rows:
            #print "Google: Found %r in cache" % (caddr)
            gval = rows[0][0]
            result = json.loads(gval)
        else:
            # Not in sqlite, ask google address service
            #print "Google: %r not found in cache, fetching" % (address)

            api_key = open('google-api-key-do-not-commit.txt').read()
            payload = {'address':caddr, 'key':api_key}
            result = json.load(urllib2.urlopen('https://maps.googleapis.com/maps/api/geocode/json?%s' % urllib.urlencode(payload)))
            # Keep the stringified version for the DB/canonical_addr_map
            gval = json.dumps(result)
            geocode_address_google.cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                                         ' VALUES (?, ?);'),
                                         (caddr, gval))
            geocode_address_google.conn.commit()
            
            # If the result succeeded and generated a formatted address, cache under that key too
            try:
                if(result['status']=='OK'):
                    if(len(result['results'])== 1):
                        canonical = result['results'][0]['formatted_address']
                        #print "Google: Storing canonical addr of %r for %r" % (canonical, address)
                        geocode_address_google.cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                                                             ' VALUES (?, ?);'),
                                                             (canonical, gval))
                        geocode_address_google.conn.commit()
                    else:
                        print "Google: Fetch %r seemed to succeed, but results empty or non-unique" % (address)

                else:
                    print "Google: Fetch %r failed" % (address)
                
            except:
                #pass
                raise
                
        # We had to resort to sqlite/google address service.  Add gval to canonical_addr_map
        if(caddr not in canonical_addr_map):
            canonical_addr_map[caddr]={'canonical_in_census_db':False,'canonical_in_google_db': True, 
                                       'census_value':None, 'google_value':gval}
        else:
            # Already there, presumably for census.  Add google value 
            canonical_addr_map[caddr]['canonical_in_google_db']=True
            canonical_addr_map[caddr]['google_value']=gval
 
    
    return result

def get_canonical_address_google(raw_addr):
    if(pandas.isnull(raw_addr) or re_noalnum.match(raw_addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(raw_addr)
        return None

    try:
        result=geocode_address_google(raw_addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            return(result['results'][0]['formatted_address'])
        else:
            return None
    except:
        return None

def get_canonical_zip_google(addr):
    if(pandas.isnull(addr) or re_noalnum.match(addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None

    try:
        result=geocode_address_google(addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            addr_comps = result['results'][0]['address_components']
            for i in range(0, len(addr_comps)):
                if('postal_code' in addr_comps[i]['types']):
                    return addr_comps[i]['short_name']
        
        return None
    except:
        return None
    
def get_canonical_coords_google(addr):
    if(pandas.isnull(addr) or re_noalnum.match(addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None

    try:
        result=geocode_address_google(addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            latlon = result['results'][0]['geometry']['location']
            if(latlon):
                return(Point(latlon['lng'], latlon['lat']))
        return None
    except Exception as e:
        print "Exception processing get_canonical_coords_google(%s): %s" % (addr, e)
        return None

# %%
# Census addresses with the addition of using canonical_addr_map as cache
# Original version was from 
#  http://localhost:8820/notebooks/projects/demographics/Allegheny%20County%20Property%20Assessments-AW9.ipynb#

# Uses Census geocoding API to geocode an address

import sqlite3
import urllib,urllib2
import json
from shapely.geometry import Point
import collections

# Match if the string contains no alphanumerics
re_noalnum = re.compile('^([^\w]+)$')

def geocode_address_census(address):
    if(pandas.isnull(address) or re_noalnum.match(address)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(address)
        return None

    # String canonicalize the address
    caddr = canonicalize_string(address)

    # Check if we already have a value in canonical_addr_map, if so return it
    if(caddr in canonical_addr_map and canonical_addr_map[caddr]['census_value']):
        result = json.loads(canonical_addr_map[caddr]['census_value'])
    else:
        # Not yet in canonical_addr_map, fetch from sqlite DB or census address lookup service
        try:
            geocode_address_census.sqlite
        except:
            geocode_address_census.sqlite = {}

        tpid = '%d.%s' % (os.getpid(), thread.get_ident())
        if not tpid in geocode_address_census.sqlite:
            conn = sqlite3.connect('geocoding_cache_census')
            cur = conn.cursor()
            geocode_address_census.sqlite[tpid] = { 'conn': conn, 'cur': cur }

            cur.execute(('CREATE TABLE IF NOT EXISTS kvs'
                         ' (key PRIMARY KEY, value)'
                         ' WITHOUT ROWID;'))
            conn.commit()
        else:
            conn = geocode_address_census.sqlite[tpid]['conn']
            cur = geocode_address_census.sqlite[tpid]['cur']

        cur.execute('SELECT value FROM kvs WHERE key=?', (caddr,))
        rows = cur.fetchall()
        if rows:
            cval = rows[0][0]
        else:
            payload = {'address':caddr, 'benchmark':4, 'format':'json'}
            result = json.load(urllib2.urlopen('https://geocoding.geo.census.gov/geocoder/locations/onelineaddress?%s' % urllib.urlencode(payload)))
            cval = json.dumps(result)

            cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                         ' VALUES (?, ?);'),
                        (caddr, cval))
            conn.commit()

            if len(result['result']['addressMatches']) == 1:
                canonical = result['result']['addressMatches'][0]['matchedAddress']
                cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                             ' VALUES (?, ?);'),
                             (canonical, cval))
                conn.commit()
            
        # We had to resort to sqlite/google address service.  Add cval to canonical_addr_map
        if(caddr not in canonical_addr_map):
            canonical_addr_map[caddr]={'canonical_in_census_db':True,'canonical_in_google_db': False, 
                                       'census_value':cval, 'google_value':None}
        else:
            # Already there, presumably for google.  Add census value 
            canonical_addr_map[caddr]['canonical_in_census_db']=True
            canonical_addr_map[caddr]['census_value']=cval

    
    return result

def cache_canonical_addresses(addrs):
    t = SimpleThreadPoolExecutor(25)
    for addr in addrs:
        if(not (pandas.isnull(addr) or re_noalnum.match(addr))):
            t.submit(geocode_address_census, addr)
        else:
            #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
            pass
    t.shutdown()

def get_canonical_address_census(raw_addr):
    if(pandas.isnull(raw_addr) or re_noalnum.match(raw_addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(raw_addr)
        return None

    try:
        result=geocode_address_census(raw_addr)
        if len(result['result']['addressMatches']) == 1:
            return(result['result']['addressMatches'][0]['matchedAddress'])
        else:
            return None
    except:
        return None

def get_canonical_zip_census(addr):
    try:
        result=geocode_address_census(addr)
        if len(result['result']['addressMatches']) == 1:
            return(result['result']['addressMatches'][0]['addressComponents']['zip'])
        else:
            return None
    except:
        return None

    
def get_canonical_coords_census(addr):
    try:
        result=geocode_address_census(addr)
        if len(result['result']['addressMatches']) == 1:
            coords = result['result']['addressMatches'][0]['coordinates']
            return(Point(coords['x'], coords['y']))
        else:
            return None
    except:
        return None

################################################################################################################
# These can handle being passed a map with either census or google in it and dispatch to the right service

# TODO: Think if this is the right behavior: If handed a regular string do census lookup
# If handed a map, return census if non-null, then google if non-null
def get_canonical_address(addr):
    if(pandas.isnull(addr) or ((not isinstance(addr, collections.Mapping) and re_noalnum.match(addr)))):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None

    if(isinstance(addr, collections.Mapping)):
        if('census' in addr and not pd.isnull(addr['census'])):
            return addr['census']
        elif('google' in addr and not pd.isnull(addr['google'])):
            return addr['google']
    else:
        return(get_canonical_address_census(addr))

def get_canonical_zip(addr):
    if(pandas.isnull(addr) or ((not isinstance(addr, collections.Mapping) and re_noalnum.match(addr)))):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None
    if(isinstance(addr, collections.Mapping)):
        if('census' in addr and not pd.isnull(addr['census'])):
            return get_canonical_zip_census(addr['census'])
        elif('google' in addr and not pd.isnull(addr['google'])):
            return get_canonical_zip_google(addr['google'])
    else:
        return(get_canonical_zip_census(addr))

def get_canonical_coords(addr):
    if(pandas.isnull(addr) or ((not isinstance(addr, collections.Mapping) and re_noalnum.match(addr)))):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None
    
    if(isinstance(addr, collections.Mapping)):
        if('census' in addr and not pd.isnull(addr['census'])):
            return get_canonical_coords_census(addr['census'])
        elif('google' in addr and not pd.isnull(addr['google'])):
            return get_canonical_coords_google(addr['google'])
    else:
        return(get_canonical_coords_census(addr))

def canonicalize_addr_colset(df, col_arr, out_colname):
    for  col_name in col_arr:
        df[col_name]=df[col_name].astype(basestring)
        df[col_name].fillna('', inplace=True)

    df[out_colname] = df[col_arr].apply(lambda x: get_canonical_address_census(' '.join(x)), axis=1)

# %%
# Create 'property_address_raw' and 'owner_address_raw' columns.  Call once per dataframe before calling
# canonicalize_addrs
def merge_addr_colset(df, col_arr, out_colname):
    for  col_name in col_arr:
        df[col_name]=df[col_name].astype(basestring)
        df[col_name].fillna('', inplace=True)

    df[out_colname] = df[col_arr].apply(lambda x: canonicalize_string(' '.join(x)), axis=1)
    # Fix up PGH to be PITTSBURGH
    df[out_colname] = df[out_colname].str.replace('\s*PGH\s*,', ' PITTSBURGH,', regex=True)

# %% [markdown]
# # Deal with various versions of the voter DB

# %%
voters_addr_cols=['House__', 'HouseNoSuffix', 'StreetNameComplete' ,'City', 'State','Zip_Code']
voters_dtype={'House__':numpy.str, 'HouseNoSuffix':numpy.str, 'StreetNameComplete':numpy.str ,'City':numpy.str, 
              'State':numpy.str,'Zip_Code':numpy.str,'Dist1':numpy.str}

# 2009-07 is a special case. It was generated by 
#   http://localhost:8820/notebooks/projects/demographics/Import%20Fixed%20Width%20Voter%20Files.ipynb
# from a fixed width file.  City and state were together in a single field.
voters_addr_cols_2009=['House__', 'HouseNoSuffix', 'StreetNameComplete' ,'City','Zip_Code']
voters_dtype_2009={'House__':numpy.str, 'HouseNoSuffix':numpy.str, 
                   'StreetNameComplete':numpy.str ,'City':numpy.str,'Zip_Code':numpy.str,
                   'Dist1':numpy.str
                  }

voters_info = {
    '2018-10': {'path': 'voters/2018-10-cd/10_16_18VOTERS.TXT', 
                'addr_cols': voters_addr_cols,
                'dtype': voters_dtype
               },
    '2018-08': {'path': 'voters/2018-08-cd/VOTERS8_14_18.TXT', 
                'addr_cols': voters_addr_cols,
                'dtype': voters_dtype
               },
    '2018-03': {'path': 'voters/2018-03-cd/VOTERS3_5_18.TXT', 
                'addr_cols': voters_addr_cols,
                'dtype': voters_dtype
               },
    '2017-11': {'path': 'voters/2017-11-cd/VOTERS11_30_2017.TXT', 
                'addr_cols': voters_addr_cols,
                'dtype': voters_dtype
               },
    '2009-07': {'path': "voters/2009-07-cd/VOTERS07_22_2009.TXT", 
                'addr_cols': voters_addr_cols_2009,
                'dtype': voters_dtype_2009
               }
}

# %%
# Map month strings used on import of datasets to parsed dates
monthstr_to_date_map={'2009-07':dateparser.parse("7/22/2009"),
                      '2017-11':dateparser.parse("11/30/2017"),
                      '2018-03':dateparser.parse("3/5/2018"),
                      '2018-08':dateparser.parse("8/14/2018"), 
                      '2018-10':dateparser.parse("10/16/2018")
                     }

# %%
# Hold on to the dataframes associated with each month_str in a map
vdf_map={}

# %%
# Do fixup on Pitt addresses
def fixup_pitt_addresses(df):
    df['address_raw'] = df['address_raw'].str.replace('(^.*((PITT TOWERS)|(5TH AVE-MCCORMICK HALL)|(HOLLAND HALL)) PITTSBURGH PA 15213$)', '3990 FIFTH AVE PITTSBURGH PA 15213', regex=True)
    df['address_raw'] = df['address_raw'].str.replace('(^.*AMOS HALL PITTSBURGH PA 15213$)', '3959 FIFTH AVE PITTSBURGH PA 15260', regex=True)
    df['address_raw'] = df['address_raw'].str.replace('(^.*SUTHERLAND HALL PITTSBURGH PA 15213$)', '3725 SUTHERLAND DR PITTSBURGH PA 15213', regex=True)

# %%
def load_voters_info(month_str):
    if(not month_str in voters_info):
        print "No entry for %s in voters_info" % (month_str)
    path = voters_info[month_str]['path']
    vdf_map[month_str] = pandas.read_csv(path,sep='\t',dtype=voters_info[month_str]['dtype']).set_index('ID_Number')
    r
    fixup_pitt_addresses(vdf_map[month_str])
    return vdf_map[month_str]

# %%
# Key is voter ID, DOB:str, reg_date:str, reg_info:{month_str: {status: , party: }}, addresses:{month_str:address}}
voter_map = {}

# %%
# Keep track of what month_strs are in the current voter_map
active_month_str_set=set(['2018-10','2018-08','2018-03','2017-11','2009-07'])
active_month_str_arr=sorted(list(active_month_str_set))

# %%
# Keep track of the Municipality/Ward/District seen for each address
# Key is address, value is a map from month_str to MWD value seen in that data set
addr_to_mwd_map = {}

# %%
def process_voting_record(apd, i, month_str):
    global voter_map

    # Generate set of interesting colnames we have in this data frame
    interesting_colnames=set(['address_raw','Voter_Status','Political_Party','Last_Date_Voted','Date_Last_Changed','Date_Of_Birth','Date_Registered','Dist1'])
    colnames = set(apd.columns) & interesting_colnames

    voter_id = apd.iloc[i].name
        
    if(not voter_id in voter_map):
        # Make sure 'Date_Registered' is legit
        reg_date = None
        try:
            if(apd['Date_Registered'].iloc[i]!='nan'):
                reg_date = dateparser.parse(apd['Date_Registered'].iloc[i])
        except:
            reg_date = None

        if(not reg_date):
            print "Skipping %s, unparsable registration date %s" % (voter_id, apd['Date_Registered'].iloc[i])
            return

        # reg_date is fine, add an entry
        voter_map[voter_id]={'DOB':apd['Date_Of_Birth'].iloc[i], 'reg_date':reg_date, 'reg_info':{}, 'addresses':{}}
    
    this_addr = apd['address_raw'].iloc[i]
    
    voter_map[voter_id]['reg_info'][month_str] = {'status':apd['Voter_Status'].iloc[i],'party':apd['Political_Party'].iloc[i]}
    voter_map[voter_id]['addresses'][month_str] = this_addr
    
    # If Dist1 is set, update addr_to_mwd_map
    if('Dist1' in apd.columns):
        mwd = apd['Dist1'].iloc[i]
        if(not this_addr in addr_to_mwd_map):
            # New address, create entry
            addr_to_mwd_map[this_addr]={}
        addr_to_mwd_map[this_addr][month_str]=mwd
    
def process_all_voting_records(apd,month_str):
    active_month_str_set.add(month_str)
    active_month_str_arr=sorted(list(active_month_str_set))
    for i in range(0,len(apd)):
        process_voting_record(apd, i, month_str)

# %%
vdf_2018_10 = load_voters_info('2018-10')
# Out:
# /home/rsargent/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2818: DtypeWarning: Columns (1,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
vdf_2018_08 = load_voters_info('2018-08')

# %%
vdf_2018_03 = load_voters_info('2018-03')

# %%
vdf_2017_11 = load_voters_info('2017-11')
# Out:
# /home/rsargent/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2818: DtypeWarning: Columns (1,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
vdf_2009_07 = load_voters_info('2009-07')

# %%
# Check we have everything
for month_str in (active_month_str_arr):
    print "%s: %s" % (month_str, voters_info[month_str].keys())
# Out:
# 2009-07: ['path', 'addr_cols', 'dtype']
# 2017-11: ['path', 'addr_cols', 'dtype']
# 2018-03: ['path', 'addr_cols', 'dtype']
# 2018-08: ['path', 'addr_cols', 'dtype']
# 2018-10: ['path', 'addr_cols', 'dtype']

# %%
# Process voting records
#for month_str in (['2018-03','2017-11']):
#for month_str in (['2018-08']):
#for month_str in (['2018-10']):
for month_str in (['2009-07']):
    process_all_voting_records(vdf_map[month_str],month_str)

# %%
len(addr_to_mwd_map)
# Out:
# 415548

# %% [markdown]
# # Resolve Polling places

# %%
vdf_2018_10
# Out:
#              Title        Last_Name    First_Name Middle_Name Suffix  Sex  \
# ID_Number
# 108927574-02   NaN            AABAN          ZAIN           A    NaN    M
# 103133442-02   NaN          AAGAARD         MARIT         NaN    NaN  NaN
# 102892955-02   NaN            AAMIR         TALHA         NaN    NaN    F
# 020340986-02   NaN            AARON        ANDREA         NaN    NaN    F
# 003007111-02   NaN            AARON       BARBARA           A    NaN    F
# 020029602-02   NaN            AARON       CHARLES           F    NaN    M
# 002171843-02   NaN            AARON         DAVID           G    NaN    M
# 002184557-02   NaN            AARON       DEBORAH           S    NaN    F
# 107205165-02   NaN            AARON      DOMINIKA       LARAE    NaN  NaN
# 102729360-02   NaN            AARON      DONIELLE     CATRICE    NaN    F
# 106158840-02   NaN            AARON         ELISE           R    NaN    U
# 002112797-02   NaN            AARON        EUGENE           L    NaN    M
# 002940556-02   NaN            AARON       JEFFREY      DANIEL    NaN    M
# 103082320-02   NaN            AARON      JENNIFER        HOPE    NaN  NaN
# 021116999-02   NaN            AARON        JEREMY           W    NaN    M
# 002155059-02   NaN            AARON          JOHN           H    NaN    M
# 108217836-02   NaN            AARON        JORDAN         NaN     JR  NaN
# 002132515-02   NaN            AARON        LONNIE           R    NaN    M
# 103736752-02   NaN            AARON          LUKE           A    NaN  NaN
# 020825642-02   NaN            AARON     MACKENZIE         NaN    NaN    U
# 002667958-02   NaN            AARON      MARGARET           A    NaN    F
# 002422180-02   NaN            AARON    MARGHERITA           A    NaN    F
# 002007095-02   NaN            AARON      MARY ANN         NaN    NaN    F
# 020825648-02   NaN            AARON       MICHAEL        SETH    NaN    M
# 001937184-02   NaN            AARON         NANCY           W    NaN    F
# 021065286-02   NaN            AARON        NATHAN           A    NaN    M
# 108060738-02   NaN            AARON       PATRICE           L    NaN  NaN
# 002678251-02   NaN            AARON       PATRICK         NaN    NaN    M
# 002949672-02   NaN            AARON          PAUL           A    NaN    M
# 107139266-02   NaN            AARON          PAUL           A     JR    M
# 002055003-02   NaN            AARON          PAUL           W    NaN    M
# 002517949-02   NaN            AARON       ROSALIE         NaN    NaN    F
# 002913958-02   NaN            AARON          RYAN           D    NaN    M
# 002505923-02   NaN            AARON        SAMUEL           J    NaN    M
# 020227625-02   NaN            AARON         SARAH           B    NaN    F
# 102650770-02   NaN            AARON         SCOTT     TURBERG    NaN    M
# 107920773-02   NaN            AARON          SETH         NaN    NaN    M
# 103753603-02   NaN            AARON          SETH           B    NaN  NaN
# 004307190-02   NaN            AARON       THERESA        LYNN    NaN    F
# 002683734-02   NaN            AARON        THOMAS           K    NaN    M
# 002316659-02   NaN            AARON        TRACEY           L    NaN    F
# 103904657-02   NaN            AARON       XAVAIER      GERALD    NaN  NaN
# 021610007-02   NaN            AARON       ZACHARY           A    NaN    M
# 109336250-02   NaN           AARON7       MATTHEW           S    NaN    M
# 002306508-02   NaN           AARONS        JEROME           H    NaN    M
# 108090120-02   NaN           AARONS        MARSHA           E    NaN    M
# 002771227-02   NaN           AARONS        ROBERT           D    NaN    M
# 021496853-02   NaN         AARONSON         BRYCE       JAMES    NaN    M
# 002636749-02   NaN         AARONSON          JOEL           P    NaN    M
# 013936279-02   NaN         AARONSON       MICHAEL       LOUIS    NaN    M
# ...            ...              ...           ...         ...    ...  ...
# 104391164-02   NaN             ZYSK      SHANDLER       JAMES    NaN    F
# 021412761-02   NaN             ZYSK         SHANE           M    NaN    U
# 002205912-02   NaN             ZYSK        SHARON           E    NaN    F
# 002451788-02   NaN             ZYSK         SHAWN           M    NaN    M
# 002228015-02   NaN             ZYSK       THERESA           L    NaN    F
# 002109946-02   NaN      ZYSK-MCHUGH      KIMBERLY           A    NaN    F
# 002835751-02   NaN        ZYSKOWSKI         BRIAN           J    NaN    M
# 002645635-02   NaN        ZYSKOWSKI        DENISE           S    NaN    F
# 001928259-02   NaN        ZYSKOWSKI        GLADYS         NaN    NaN    F
# 002639428-02   NaN        ZYSKOWSKI          JOHN           M    NaN    M
# 002968551-02   NaN        ZYSKOWSKI       LUCILLE         NaN    NaN    F
# 003012374-02   NaN        ZYSKOWSKI       WILLIAM           M    NaN    M
# 002133944-02   NaN        ZYSKOWSKI       ZACHARY        ZANE    NaN    M
# 021079916-02   NaN            ZYTKA        ANDREW      THOMAS    NaN    U
# 002536925-02   NaN            ZYTKA       BERNARD        JOHN     JR    M
# 002770709-02   NaN            ZYTKA         CASEY           L    NaN    F
# 021650776-02   NaN            ZYTKA       KATHRYN           C    NaN    F
# 103729096-02   NaN            ZYTKA           SAM         NaN    NaN  NaN
# 002302023-02   NaN            ZYTKA        THOMAS      ANDREW    NaN    M
# 104689806-02   NaN          ZYTNICK         ALEXA      MORGAN    NaN  NaN
# 002975445-02   NaN          ZYTNICK         ALLAN         NaN    NaN    M
# 002591538-02   NaN          ZYTNICK           BEN         NaN    NaN    M
# 002999361-02   NaN          ZYTNICK        ESTHER         NaN    NaN    F
# 002171268-02   NaN          ZYTNICK           JAY           M    NaN    M
# 001936993-02   NaN          ZYTNICK          JOEL           H    NaN    M
# 002073626-02   NaN          ZYTNICK          JONI         NaN    NaN    F
# 002345767-02   NaN          ZYTNICK      KIMBERLY           B    NaN    F
# 003013928-02   NaN          ZYTNICK       SHELDON     FARRELL    NaN    M
# 002340435-02   NaN          ZYTNICK         SUSAN       LENNE    NaN    F
# 108756858-02   NaN          ZYTNICK       WILLIAM      TAYLOR    NaN  NaN
# 109015007-02   NaN          ZYTNICK       ZACHARY         NaN    NaN  NaN
# 002060965-02   NaN            ZYWAN          PAUL           J    NaN    M
# 002751622-02   NaN            ZYWAR         HELEN         NaN    NaN    F
# 001941224-02   NaN            ZYWAR          MARK           A    NaN    M
# 001936993-02               R     100                           CERASI DR
# 002073626-02               R    3231                       NOTTINGHAM DR
# 002345767-02               R     305                         EASTERN AVE
# 003013928-02               R    3013                  GRANDVIEW FARMS PL
# 002340435-02              NO    3013                  GRANDVIEW FARMS PL
# 108756858-02               R     305                         EASTERN AVE
# 109015007-02               R     305                         EASTERN AVE
# 002060965-02               R   10090                       OLD PERRY HWY
# 002751622-02               D     510                          STATION ST
# 001941224-02               D     510                          STATION ST
# 102446703-02               D     102                        HAWTHORNE RD
# 102441885-02               D     102                        HAWTHORNE RD
# 002633118-02               D     451                          DILLER AVE
# 102632757-02               D    5009                         ORCHARD AVE
# 001936853-02               R    5009                         ORCHARD AVE
# 002841540-02               D    5009                         ORCHARD AVE
# 002166354-02               D     152                         CENTRAL AVE
# 002567475-02               D     116                          FRAZIER DR
# 002212256-02               D    3000                     SWALLOW HILL RD
# 021870143-02               D     124                          DUPONT CIR
# 109354720-02              NF    1220                         CRESCENT PL
# 104600941-02              NF     124                          DUPONT CIR
# 002900662-02              NO     121                        STILLWELL CT
# 001963827-02              NO     121                        STILLWELL CT
# 021870145-02               D     121                        STILLWELL CT
# 020288002-02               D     855                       MAC ARTHUR DR
#
#              Apt__ Address_Line_2              City State Zip_Code  \
# ID_Number
# 108927574-02   NaN            NaN              MARS    PA    16046
# 103133442-02   NaN            NaN        PITTSBURGH    PA    15221
# 102892955-02   NaN            NaN        PITTSBURGH    PA    15213
# 020340986-02   NaN            NaN        PITTSBURGH    PA    15201
# 003007111-02   NaN            NaN        PITTSBURGH    PA    15211
# 020029602-02   NaN            NaN        PITTSBURGH    PA    15241
# 002171843-02   NaN            NaN       MONROEVILLE    PA    15146
# 002184557-02   NaN            NaN         HOMESTEAD    PA    15120
# 107205165-02     A            NaN        PITTSBURGH    PA    15206
# 102729360-02   NaN            NaN        PITTSBURGH    PA    15232
# 106158840-02   NaN            NaN        PITTSBURGH    PA    15219
# 002112797-02   NaN            NaN          CLAIRTON    PA    15025
# 002940556-02   NaN            NaN        PITTSBURGH    PA    15211
# 103082320-02   NaN            NaN        PITTSBURGH    PA    15243
# 021116999-02   NaN            NaN        PITTSBURGH    PA    15236
# 002155059-02   NaN            NaN        PITTSBURGH    PA    15208
# 108217836-02  4689            NaN        PITTSBURGH    PA    15289
# 002132515-02   NaN            NaN          IMPERIAL    PA    15126
# 103736752-02   NaN            NaN        PITTSBURGH    PA    15236
# 020825642-02   NaN            NaN         HOMESTEAD    PA    15120
# 002667958-02   NaN            NaN      WEST MIFFLIN    PA    15122
# 002422180-02   NaN            NaN        PITTSBURGH    PA    15236
# 002007095-02     A            NaN      TURTLE CREEK    PA    15145
# 020825648-02   NaN            NaN         HOMESTEAD    PA    15120
# 001937184-02   NaN            NaN       MONROEVILLE    PA    15146
# 021065286-02   NaN            NaN        PITTSBURGH    PA    15236
# 108060738-02     2            NaN         SWISSVALE    PA    15218
# 002678251-02   NaN            NaN      TURTLE CREEK    PA    15145
# 002949672-02   NaN            NaN        PITTSBURGH    PA    15219
# 107139266-02   NaN            NaN        PITTSBURGH    PA    15219
# 002055003-02   NaN            NaN        PITTSBURGH    PA    15236
# 002517949-02   NaN            NaN        PITTSBURGH    PA    15217
# 002913958-02   NaN            NaN       MONROEVILLE    PA    15146
# 002505923-02   209            NaN        PITTSBURGH    PA    15208
# 020227625-02   NaN            NaN       MONROEVILLE    PA    15146
# 102650770-02   NaN            NaN        PITTSBURGH    PA    15232
# 107920773-02   NaN            NaN         HOMESTEAD    PA    15120
# 103753603-02    10            NaN        PITTSBURGH    PA    15206
# 004307190-02   NaN            NaN        PITTSBURGH    PA    15236
# 002683734-02   NaN            NaN        PITTSBURGH    PA    15234
# 002316659-02   NaN            NaN        PITTSBURGH    PA    15218
# 103904657-02   211            NaN       MONROEVILLE    PA    15146
# 021610007-02   NaN            NaN        PITTSBURGH    PA    15203
# 109336250-02   NaN            NaN        PITTSBURGH    PA    15211
# 002306508-02   NaN            NaN        PITTSBURGH    PA    15206
# 108090120-02   NaN            NaN        PITTSBURGH    PA    15206
# 002771227-02   NaN        APT 410        PITTSBURGH    PA    15235
# 021496853-02   NaN            NaN        PITTSBURGH    PA    15217
# 002636749-02   NaN            NaN        PITTSBURGH    PA    15208
# 013936279-02   308            NaN        PITTSBURGH    PA    15201
# ...            ...            ...               ...   ...      ...
# 104391164-02   NaN            NaN           OAKDALE    PA    15071
# 021412761-02   NaN            NaN           OAKDALE    PA    15071
# 002205912-02   NaN            NaN           OAKDALE    PA    15071
# 002451788-02   NaN            NaN           OAKDALE    PA    15071
# 002228015-02   NaN            NaN        PITTSBURGH    PA    15211
# 002109946-02   NaN            NaN       BETHEL PARK    PA    15102
# 002835751-02   NaN            NaN        PITTSBURGH    PA    15214
# 002645635-02   NaN            NaN        CORAOPOLIS    PA    15108
# 001928259-02   NaN            NaN        PITTSBURGH    PA    15209
# 002639428-02   NaN            NaN        CORAOPOLIS    PA    15108
# 002968551-02   NaN            NaN         SEWICKLEY    PA    15143
# 003012374-02   NaN            NaN         SEWICKLEY    PA    15143
# 002133944-02   NaN            NaN         GLASSPORT    PA    15045
# 021079916-02   NaN            NaN        PITTSBURGH    PA    15228
# 002536925-02   NaN            NaN       MC KEESPORT    PA    15135
# 002770709-02   NaN            NaN        PITTSBURGH    PA    15228
# 021650776-02   NaN            NaN        PITTSBURGH    PA    15228
# 103729096-02   113            NaN        PITTSBURGH    PA    15228
# 002302023-02   NaN            NaN        PITTSBURGH    PA    15234
# 104689806-02   NaN            NaN        PITTSBURGH    PA    15235
# 002975445-02   NaN            NaN        PITTSBURGH    PA    15238
# 002591538-02   NaN            NaN          CHESWICK    PA    15024
# 002999361-02     9            NaN        PITTSBURGH    PA    15217
# 002171268-02   NaN            NaN         ASPINWALL    PA    15215
# 001936993-02   PH9            NaN      WEST MIFFLIN    PA    15122
# 002073626-02   NaN            NaN        PITTSBURGH    PA    15235
# 002345767-02   NaN            NaN         ASPINWALL    PA    15215
# 003013928-02    PL            NaN       BETHEL PARK    PA    15102
# 002340435-02    PL            NaN       BETHEL PARK    PA    15102
# 108756858-02   NaN            NaN         ASPINWALL    PA    15215
# 109015007-02   NaN            NaN         ASPINWALL    PA    15215
# 002060965-02   NaN            NaN           WEXFORD    PA    15090
# 002751622-02   NaN            NaN        WILMERDING    PA    15148
# 001941224-02   104        APT 104        WILMERDING    PA    15148
# 102446703-02   NaN            NaN        PITTSBURGH    PA    15221
# 102441885-02   NaN            NaN        PITTSBURGH    PA    15221
# 002633118-02   NaN            NaN      WEST MIFFLIN    PA    15122
# 102632757-02   NaN            NaN       BETHEL PARK    PA    15102
# 001936853-02   NaN            NaN       BETHEL PARK    PA    15102
# 002841540-02   NaN            NaN       BETHEL PARK    PA    15102
# 002166354-02   NaN            NaN  NORTH VERSAILLES    PA    15137
# 002567475-02   NaN            NaN        PITTSBURGH    PA    15235
# 002212256-02   417            NaN        PITTSBURGH    PA    15220
# 021870143-02   NaN            NaN        PITTSBURGH    PA    15243
# 109354720-02    1J            NaN        PITTSBURGH    PA    15217
# 104600941-02   NaN            NaN        PITTSBURGH    PA    15243
# 002900662-02   NaN            NaN        PITTSBURGH    PA    15228
# 001963827-02   NaN            NaN        PITTSBURGH    PA    15228
# 021870145-02   NaN            NaN        PITTSBURGH    PA    15228
# 020288002-02   NaN            NaN        PITTSBURGH    PA    15228
#
#                               MAddress_Line_1 MAddress_Line_2       MCity  \
# ID_Number
# 108927574-02                              NaN             NaN         NaN
# 103133442-02                              NaN             NaN         NaN
# 102892955-02                              NaN             NaN         NaN
# 020340986-02                              NaN             NaN         NaN
# 003007111-02                              NaN             NaN         NaN
# 020029602-02                              NaN             NaN         NaN
# 002171843-02                              NaN             NaN         NaN
# 002184557-02                              NaN             NaN         NaN
# 107205165-02                              NaN             NaN         NaN
# 102729360-02                              NaN             NaN         NaN
# 106158840-02                              NaN             NaN         NaN
# 002112797-02                              NaN             NaN         NaN
# 002940556-02              17 LAURELWOOD DRIVE             NaN     MEDFORD
# 103082320-02                              NaN             NaN         NaN
# 021116999-02                              NaN             NaN         NaN
# 002155059-02                              NaN             NaN         NaN
# 108217836-02                              NaN             NaN         NaN
# 002132515-02                              NaN             NaN         NaN
# 103736752-02                4512 SHANNON ROAD             NaN        ERIE
# 020825642-02                              NaN             NaN         NaN
# 002667958-02                              NaN             NaN         NaN
# 002422180-02                              NaN             NaN         NaN
# 002007095-02                              NaN             NaN         NaN
# 020825648-02                              NaN             NaN         NaN
# 001937184-02                              NaN             NaN         NaN
# 021065286-02                              NaN             NaN         NaN
# 108060738-02                              NaN             NaN         NaN
# 002678251-02                              NaN             NaN         NaN
# 002949672-02                              NaN             NaN         NaN
# 107139266-02                              NaN             NaN         NaN
# 002055003-02                              NaN             NaN         NaN
# 002517949-02                              NaN             NaN         NaN
# 002913958-02                   23124 ALDER LN             NaN  CALIFORNIA
# 002505923-02                              NaN             NaN         NaN
# 020227625-02                   23124 ALDER LN             NaN  CALIFORNIA
# 102650770-02                              NaN             NaN         NaN
# 107920773-02                              NaN             NaN         NaN
# 103753603-02                              NaN             NaN         NaN
# 004307190-02                              NaN             NaN         NaN
# 002683734-02                              NaN             NaN         NaN
# 002316659-02                              NaN             NaN         NaN
# 103904657-02                              NaN             NaN         NaN
# 021610007-02                              NaN             NaN         NaN
# 109336250-02                              NaN             NaN         NaN
# 002306508-02                              NaN             NaN         NaN
# 108090120-02                1068 TIVOLI DRIVE             NaN      NAPLES
# 002771227-02                              NaN             NaN         NaN
# 021496853-02                              NaN             NaN         NaN
# 002636749-02                              NaN             NaN         NaN
# 013936279-02                              NaN             NaN         NaN
# ...                                       ...             ...         ...
# 104391164-02                              NaN             NaN         NaN
# 021412761-02                              NaN             NaN         NaN
# 002205912-02                              NaN             NaN         NaN
# 002451788-02                              NaN             NaN         NaN
# 002228015-02                              NaN             NaN         NaN
# 002109946-02                              NaN             NaN         NaN
# 002835751-02                              NaN             NaN         NaN
# 002645635-02                              NaN             NaN         NaN
# 001928259-02                              NaN             NaN         NaN
# 002639428-02                              NaN             NaN         NaN
# 002968551-02                              NaN             NaN         NaN
# 003012374-02                              NaN             NaN         NaN
# 002133944-02                              NaN             NaN         NaN
# 021079916-02                              NaN             NaN         NaN
# 002536925-02                              NaN             NaN         NaN
# 002770709-02                              NaN             NaN         NaN
# 021650776-02                              NaN             NaN         NaN
# 103729096-02                              NaN             NaN         NaN
# 002302023-02                              NaN             NaN         NaN
# 104689806-02  PMB #358320 2301 VANDERBILT PL.             NaN   NASHVILLE
# 002975445-02                              NaN             NaN         NaN
# 002591538-02                              NaN             NaN         NaN
# 002999361-02                              NaN             NaN         NaN
# 002171268-02                              NaN             NaN         NaN
# 001936993-02                              NaN             NaN         NaN
# 002073626-02                              NaN             NaN         NaN
# 002345767-02                              NaN             NaN         NaN
# 003013928-02                              NaN             NaN         NaN
# 002340435-02                              NaN             NaN         NaN
# 108756858-02                              NaN             NaN         NaN
# 109015007-02                              NaN             NaN         NaN
# 002060965-02                              NaN             NaN         NaN
# 002751622-02                              NaN             NaN         NaN
# 001941224-02                              NaN             NaN         NaN
# 102446703-02                              NaN             NaN         NaN
# 102441885-02                              NaN             NaN         NaN
# 002633118-02                              NaN             NaN         NaN
# 102632757-02                              NaN             NaN         NaN
# 001936853-02                              NaN             NaN         NaN
# 002841540-02                              NaN             NaN         NaN
# 002166354-02                              NaN             NaN         NaN
# 002567475-02                              NaN             NaN         NaN
# 002212256-02                              NaN             NaN         NaN
# 021870143-02                              NaN             NaN         NaN
# 109354720-02                              NaN             NaN         NaN
# 104600941-02                              NaN             NaN         NaN
# 002900662-02                              NaN             NaN         NaN
# 001963827-02                              NaN             NaN         NaN
# 021870145-02                              NaN             NaN         NaN
# 020288002-02                              NaN             NaN         NaN
#
#              MState   MZip_Code                        PollingPlaceDescript  \
# ID_Number
# 108927574-02    NaN         NaN                  REGIONAL LEARNING ALLIANCE
# 103133442-02    NaN         NaN             SISTER THEA BOWMAN SCHOOL LOBBY
# 102892955-02    NaN         NaN                   WILLIAM PITT UNION 1ST FL
# 020340986-02    NaN         NaN                             ENGINE HOUSE #7
# 102632757-02    NaN         NaN             MUNICIPAL BLDG COUNCIL CHAMBERS
# 001936853-02    NaN         NaN             MUNICIPAL BLDG COUNCIL CHAMBERS
# 002841540-02    NaN         NaN             MUNICIPAL BLDG COUNCIL CHAMBERS
# 002166354-02    NaN         NaN                         SENIOR CITIZEN BLDG
# 002567475-02    NaN         NaN           BRICKLAYERS & ALLIED CRAFTWORKERS
# 002212256-02    NaN         NaN             SCOTT TWP MUNICIPAL BLDG (POOL)
# 021870143-02    NaN         NaN         HOOVER SCH GROUND FLOOR ENT LWR LVL
# 109354720-02    NaN         NaN  SUMMERSET COMMUNITY CENTER AT SALES OFFICE
# 104600941-02    NaN         NaN         HOOVER SCH GROUND FLOOR ENT LWR LVL
# 002900662-02    NaN         NaN                    FOSTER SCHOOL LUNCH ROOM
# 001963827-02    NaN         NaN                    FOSTER SCHOOL LUNCH ROOM
# 021870145-02    NaN         NaN                    FOSTER SCHOOL LUNCH ROOM
# 020288002-02    NaN         NaN                    FOSTER SCHOOL LUNCH ROOM
#
#                              PollPlaceAdd  \
# ID_Number
# 108927574-02      850 CRANBERRY WOODS RD
# 103133442-02             721 REBECCA AVE
# 102892955-02             3959 FORBES AVE
# 020340986-02            4603 STANTON AVE
# 003007111-02                80 WABASH ST
# 020029602-02             245 JOHNSTON RD
# 002171843-02                 320 NOEL DR
# 002184557-02               441 E 8TH AVE
# 107205165-02            745 N NEGLEY AVE
# 102729360-02             106 WOODLAND RD
# 106158840-02           184 WASHINGTON PL
# 002112797-02            500 THOMPSON AVE
# 002940556-02                80 WABASH ST
# ...
# 002949672-02         NaN            NaN         NaN            NaN
# 107139266-02         NaN            NaN         NaN            NaN
# 002055003-02           R             AP         NaN            NaN
# 002517949-02         NaN            NaN         NaN            NaN
# 002913958-02         NaN            NaN         NaN            NaN
# 002505923-02           D             AP           D             AP
# 020227625-02         NaN            NaN         NaN            NaN
# 102650770-02         NaN            NaN         NaN            NaN
# 107920773-02         NaN            NaN         NaN            NaN
# 103753603-02         NaN            NaN         NaN            NaN
# 004307190-02         NaN            NaN         NaN            NaN
# 002683734-02         NaN            NaN         NaN            NaN
# 002316659-02         NaN            NaN         NaN            NaN
# 103904657-02         NaN            NaN         NaN            NaN
# 021610007-02         NaN            NaN         NaN            NaN
# 109336250-02         NaN            NaN         NaN            NaN
# 002306508-02           D             AP         NaN            NaN
# 108090120-02         NaN            NaN         NaN            NaN
# 002771227-02         NaN            NaN         NaN            NaN
# 021496853-02         NaN            NaN         NaN            NaN
# 002636749-02         NaN            NaN         NaN            NaN
# 013936279-02         NaN            NaN         NaN            NaN
# ...                  ...            ...         ...            ...
# 104391164-02         NaN            NaN         NaN            NaN
# 021412761-02          NF             AP         NaN            NaN
# 002205912-02          NF             AP         NaN            NaN
# 002451788-02         NaN            NaN         NaN            NaN
# 002228015-02         NaN            NaN         NaN            NaN
# 002109946-02         NaN            NaN         NaN            NaN
# 002835751-02           D             AP           D             AP
# 002645635-02           D             AP           D             AP
# 001928259-02           D             AP           D             AP
# 002639428-02           D             AP           D             AP
# 002968551-02           D             AP         NaN            NaN
# 003012374-02           D             AP         NaN            NaN
# 002133944-02         NaN            NaN         NaN            NaN
# 021079916-02         NaN            NaN         NaN            NaN
# 002536925-02           D             AP         NaN            NaN
# 002770709-02         NaN            NaN         NaN            NaN
# 021650776-02         NaN            NaN         NaN            NaN
# 103729096-02         NaN            NaN         NaN            NaN
# 002302023-02         NaN            NaN         NaN            NaN
# 104689806-02         NaN            NaN         NaN            NaN
# 002975445-02           R             AP         NaN            NaN
# 002591538-02         NaN            NaN         NaN            NaN
# 002999361-02          NO             AP         NaN            NaN
# 002171268-02         NaN            NaN         NaN            NaN
# 001936993-02         NaN            NaN         NaN            NaN
# 002073626-02         NaN            NaN           R             AP
# 002345767-02         NaN            NaN         NaN            NaN
# 003013928-02           R             AP           R             AP
# 002340435-02          NO             AP         NaN            NaN
# 108756858-02         NaN            NaN         NaN            NaN
# 109015007-02         NaN            NaN         NaN            NaN
# 002060965-02           R             AP         NaN            NaN
# 002751622-02         NaN            NaN         NaN            NaN
# 001941224-02           D             AP           D             AP
# 102446703-02         NaN            NaN         NaN            NaN
# 102441885-02         NaN            NaN         NaN            NaN
# 002633118-02         NaN            NaN         NaN            NaN
# 102632757-02         NaN            NaN         NaN            NaN
# 001936853-02         NaN            NaN         NaN            NaN
# 002841540-02         NaN            NaN         NaN            NaN
# 002166354-02           D             AP         NaN            NaN
# 002567475-02           D             AP         NaN            NaN
# 002212256-02         NaN            NaN         NaN            NaN
# 021870143-02         NaN            NaN         NaN            NaN
# 109354720-02         NaN            NaN         NaN            NaN
# 104600941-02         NaN            NaN         NaN            NaN
# 002900662-02         NaN            NaN         NaN            NaN
# 001963827-02         NaN            NaN         NaN            NaN
# 021870145-02         NaN            NaN         NaN            NaN
# 020288002-02         NaN            NaN         NaN            NaN
#
#              GN_11_02_10 GN_11_02_10_VM  \
# ID_Number
# 108927574-02         NaN            NaN
# 103133442-02         NaN            NaN
# 102892955-02          NF             AP
# 020340986-02         NaN            NaN
# 003007111-02           R             AP
# 020029602-02          NO             AP
# 002171843-02           R             AP
# 002184557-02         NaN            NaN
# 107205165-02         NaN            NaN
# 102729360-02         NaN            NaN
# 106158840-02         NaN            NaN
# 002112797-02           D             AP
# 002940556-02         NaN            NaN
# 103082320-02         NaN            NaN
# 021116999-02           R             AP
# 002155059-02           D             AP
# 108217836-02         NaN            NaN
# 002132515-02           R             AP
# 103736752-02         NaN            NaN
# 020825642-02         NaN            NaN
# 002667958-02         NaN            NaN
# 002422180-02           R             AP
# 002007095-02           R             AP
# 020825648-02         NaN            NaN
# 001937184-02           R             AP
# 021065286-02         NaN            NaN
# 108060738-02         NaN            NaN
# 002678251-02           D             AP
# 002949672-02         NaN            NaN
# 107139266-02         NaN            NaN
# 002055003-02           R             AP
# 002517949-02         NaN            NaN
# 002913958-02         NaN            NaN
# 002505923-02           D             AP
# 020227625-02         NaN            NaN
# 102650770-02           D             AP
# 107920773-02         NaN            NaN
# 103753603-02         NaN            NaN
# 002770709-02               300 HAZEL DR PITTSBURGH PA 15228
# 021650776-02               300 HAZEL DR PITTSBURGH PA 15228
# 103729096-02               300 HAZEL DR PITTSBURGH PA 15228
# 002302023-02           3912 LYNDELL AVE PITTSBURGH PA 15234
# 104689806-02         3231 NOTTINGHAM DR PITTSBURGH PA 15235
# 002975445-02          300 FOX CHAPEL RD PITTSBURGH PA 15238
# 002591538-02             111 BLACK OAK DR CHESWICK PA 15024
# 002999361-02           5845 ALDERSON ST PITTSBURGH PA 15217
# 002171268-02             305 EASTERN AVE ASPINWALL PA 15215
# 001936993-02            100 CERASI DR WEST MIFFLIN PA 15122
# 002073626-02         3231 NOTTINGHAM DR PITTSBURGH PA 15235
# 002345767-02             305 EASTERN AVE ASPINWALL PA 15215
# 003013928-02   3013 GRANDVIEW FARMS PL BETHEL PARK PA 15102
# 002340435-02   3013 GRANDVIEW FARMS PL BETHEL PARK PA 15102
# 108756858-02             305 EASTERN AVE ASPINWALL PA 15215
# 109015007-02             305 EASTERN AVE ASPINWALL PA 15215
# 002060965-02           10090 OLD PERRY HWY WEXFORD PA 15090
# 002751622-02             510 STATION ST WILMERDING PA 15148
# 001941224-02             510 STATION ST WILMERDING PA 15148
# 102446703-02           102 HAWTHORNE RD PITTSBURGH PA 15221
# 102441885-02           102 HAWTHORNE RD PITTSBURGH PA 15221
# 002633118-02           451 DILLER AVE WEST MIFFLIN PA 15122
# 102632757-02          5009 ORCHARD AVE BETHEL PARK PA 15102
# 001936853-02          5009 ORCHARD AVE BETHEL PARK PA 15102
# 002841540-02          5009 ORCHARD AVE BETHEL PARK PA 15102
# 002166354-02      152 CENTRAL AVE NORTH VERSAILLES PA 15137
# 002567475-02             116 FRAZIER DR PITTSBURGH PA 15235
# 002212256-02       3000 SWALLOW HILL RD PITTSBURGH PA 15220
# 021870143-02             124 DUPONT CIR PITTSBURGH PA 15243
# 109354720-02           1220 CRESCENT PL PITTSBURGH PA 15217
# 104600941-02             124 DUPONT CIR PITTSBURGH PA 15243
# 002900662-02           121 STILLWELL CT PITTSBURGH PA 15228
# 001963827-02           121 STILLWELL CT PITTSBURGH PA 15228
# 021870145-02           121 STILLWELL CT PITTSBURGH PA 15228
# 020288002-02          855 MAC ARTHUR DR PITTSBURGH PA 15228
#
# [941020 rows x 87 columns]

# %%
# Get rid of entries from vdf_2018_10 where 'Dist1' is null
vdf_2018_10 = vdf_2018_10[~pd.isna(vdf_2018_10['Dist1'])].copy()

# %%
# Create a version of vdf_2018_10 which has one entry per 'Dist1' value
pp_vdf_2018_10 = vdf_2018_10[~vdf_2018_10['Dist1'].duplicated()].copy()

# %%
pp_vdf_2018_10['MWD_vdf'] = pp_vdf_2018_10['Dist1'].astype('int')

# %%
len(pp_vdf_2018_10)
# Out:
# 1322

# %%
# Strip white space from ends of 'PollingPlaceDescript'
pp_vdf_2018_10['PollingPlaceDescript']=pp_vdf_2018_10['PollingPlaceDescript'].str.strip()

# %%
pp_vdf_2018_10.sort_values(['City','Dist1'])[0:2]
# Out:
#              Title Last_Name First_Name Middle_Name Suffix Sex Date_Of_Birth  \
# ID_Number
# 020059680-02   NaN  ABAROTIN     MARGOT           L    NaN   F     9/27/1920
# 002327125-02   NaN   ABRIOLA  CHRISTINA           A    NaN   F    12/29/1964
#
#              Date_Registered Voter_Status   StatusChangeDate Political_Party  \
# ID_Number
# 020059680-02        3/5/2004            A    2/22/2007 6:0:2               R
# 002327125-02       12/1/1991            A  1/6/2011 11:30:29               R
#
#              House__ HouseNoSuffix StreetNameComplete Apt__ Address_Line_2  \
# ID_Number
# 020059680-02    4053                       LE TORT LN   NaN            NaN
# 002327125-02    4954                  MEADOW CREST DR   NaN            NaN
#
#                       City State Zip_Code MAddress_Line_1 MAddress_Line_2  \
# ID_Number
# 020059680-02  ALLISON PARK    PA    15101             NaN             NaN
# 002327125-02  ALLISON PARK    PA    15101             NaN             NaN
#
#              MCity MState MZip_Code       PollingPlaceDescript  \
# ID_Number
# 020059680-02   NaN    NaN       NaN           ST URSULA CHURCH
# 002327125-02   NaN    NaN       NaN  HAMPTON PRESBY CHURCH GYM
#
#                        PollPlaceAdd           PollPlaceCSZ Last_Date_Voted  \
# ID_Number
# 020059680-02         3937 KIRK AVE   PITTSBURGH, PA  15101       11/3/2015
# 002327125-02  2942 EAST HARDIES RD     GIBSONIA, PA  15044       11/8/2016
#
#                   Dist1  Dist2 Dist3  Dist4  Dist5 Dist6 Dist7 Dist8  Dist9  \
# ID_Number
# 020059680-02  1500001.0    NaN  SC30  MN150  MD304  LG30  SN38  CD17  CPC00
# 002327125-02  1500002.0    NaN  SC30  MN150  MD304  LG30  SN38  CD17  CPC00
#
#              Dist10  Dist11  Dist12     Dist13  Dist14  Dist15 CustomData1  \
# ID_Number
# 020059680-02  CAC03     2.0     NaN  1500001-1     NaN     NaN         NaN
# 002327125-02  CAC03     2.0     NaN  1500002-1     NaN     NaN   118468743
#
#               Date_Last_Changed PhoneNumHome PR_05_15_18 PR_05_15_18_VM  \
# ID_Number
# 020059680-02    6/3/2015 8:45:1   7244490096         NaN            NaN
# 002327125-02  1/6/2011 11:30:29   7244432567         NaN            NaN
#
#              SP_03_13_18 SP_03_13_18_VM SP_03_06_18 SP_03_06_18_VM  \
# ID_Number
# 020059680-02         NaN            NaN         NaN            NaN
# 002327125-02         NaN            NaN         NaN            NaN
#
#              SP_01_23_18 SP_01_23_18_VM GN_11_07_17 GN_11_07_17_VM  \
# ID_Number
# 020059680-02         NaN            NaN         NaN            NaN
# 002327125-02         NaN            NaN         NaN            NaN
#
#              PR_05_16_17 PR_05_16_17_VM GN_11_08_16 GN_11_08_16_VM  \
# ID_Number
# 020059680-02         NaN            NaN         NaN            NaN
# 002327125-02         NaN            NaN           R             AP
#
#              PR_04_26_16 PR_04_26_16_VM GN_11_03_15 GN_11_03_15_VM  \
# ID_Number
# 020059680-02         NaN            NaN           R             AP
# 002327125-02         NaN            NaN         NaN            NaN
#
#              PR_05_19_15 PR_05_19_15_VM GN_11_04_14 GN_11_04_14_VM  \
# ID_Number
# 020059680-02           R             AP           R             AP
# 002327125-02         NaN            NaN         NaN            NaN
#
#              PR_05_20_14 PR_05_20_14_VM GN_11_05_13 GN_11_05_13_VM  \
# ID_Number
# 020059680-02         NaN            NaN         NaN            NaN
# 002327125-02         NaN            NaN         NaN            NaN
#
#              PR_05_21_13 PR_05_21_13_VM GN_11_06_12 GN_11_06_12_VM  \
# ID_Number
# 020059680-02         NaN            NaN           R             AP
# 002327125-02         NaN            NaN           R             AP
#
#              SP_08_07_12 SP_08_07_12_VM PR_04_24_12 PR_04_24_12_VM  \
# ID_Number
# 020059680-02           R             AP         NaN            NaN
# 002327125-02         NaN            NaN         NaN            NaN
#
#              GN_11_08_11 GN_11_08_11_VM PR_05_17_11 PR_05_17_11_VM  \
# ID_Number
# 020059680-02           R             AP           R             AP
# 002327125-02         NaN            NaN         NaN            NaN
#
#              GN_11_02_10 GN_11_02_10_VM  \
# ID_Number
# 020059680-02           R             AP
# 002327125-02         NaN            NaN
#
#                                              address_raw
# ID_Number
# 020059680-02       4053 LE TORT LN ALLISON PARK PA 15101
# 002327125-02  4954 MEADOW CREST DR ALLISON PARK PA 15101

# %%
# Create a subset of pp_2018_2017_m which only keeps one entry per LocName
pp_2018_2017_um = pp_2018_2017_m[~pp_2018_2017_m.LocName.str.strip().duplicated()].copy()

# %%
# Strip white space from ends of 'LocName'
pp_2018_2017_um['LocName']=pp_2018_2017_um['LocName'].str.strip()

# %%
pp_2018_2017_um.sort_values(['City','LocName'])[0:2]
# Out:
#      OBJECTID_1  OBJECTID  Muni  Ward  District  \
# 158        1159    1162.0   202     3         1
# 918         596     597.0   150     0         8
#
#                             LocName Prefix House Fraction      Street Suffix1  \
# 158  BURCHFIELD SCH-UPPER LEVEL GYM   None  1500     None  BURCHFIELD      RD
# 918   HAMPTON TWP. COMMUNITY CENTER   None  3101     None     MCCULLY      RD
#
#     Suffix2          City UnitDesc UnitNumber         Zip            Parcel  \
# 158    None  ALLISON PARK     None       None  15101-4000  0522B00280000000
# 918    None  ALLISON PARK     None       None       15101  0950S00244000000
#
#     Accessible Leadman Region    Coordinate     Coordina_1  DistrictCO  \
# 158       None      41      3  1.359077e+06  449837.715134         4.0
# 918       None      41      3  1.358629e+06  464788.012606         4.0
#
#      DistrictSE  DistrictLE EditDate MuniName          OrigAddres      MWD  \
# 158        40.0        30.0     None   SHALER  1500 BURCHFIELD RD  2020301
# 918        40.0        30.0     None  HAMPTON      4589 SCHOOL DR  1500008
#
#           POINT_X        POINT_Y     MWD2    NewAddress_18_11  \
# 158  1.359077e+06  449837.715134  2020301  1500 BURCHFIELD RD
# 918  1.358629e+06  464788.012606  1500008     3101 MCCULLY RD
#
#                                          geometry    NewAddress_18_05  \
# 158    POINT (-79.943167976415 40.54740573937607)  1500 BURCHFIELD RD
# 918  POINT (-79.93435755673711 40.58193219038682)     3101 MCCULLY RD
#
#        NewAddress_17_05  addr_changed_17  addr_changed_18
# 158  1500 BURCHFIELD RD            False            False
# 918     3101 MCCULLY RD            False            False

# %%
pp_2018_2017_um[pp_2018_2017_um.NewAddress_18_11.str.contains("MCKEE")]
# Out:
#      OBJECTID_1  OBJECTID  Muni  Ward  District                LocName Prefix  \
# 568         246     246.0   188     4         5  Engine Company No. 14   None
#
#     House Fraction Street Suffix1 Suffix2        City UnitDesc UnitNumber  \
# 568   259     None  MCKEE      PL    None  PITTSBURGH     None       None
#
#             Zip            Parcel Accessible Leadman Region    Coordinate  \
# 568  15213-3902  0028G00025000000       None      02      2  1.354085e+06
#
#         Coordina_1  DistrictCO  DistrictSE  DistrictLE EditDate    MuniName  \
# 568  410369.000485        14.0        42.0        23.0     None  PITTSBURGH
#
#        OrigAddres      MWD       POINT_X        POINT_Y     MWD2  \
# 568  259 MCKEE PL  1880405  1.354085e+06  410369.000485  1880405
#
#     NewAddress_18_11                                     geometry  \
# 568     259 MCKEE PL  POINT (-79.9575775827585 40.43875746943852)
#
#     NewAddress_18_05 NewAddress_17_05  addr_changed_17  addr_changed_18
# 568     259 MCKEE PL     259 MCKEE PL            False            False

# %%
len(pp_2018_2017_m.LocName.unique())
# Out:
# 943

# %%
pp_2018_2017_m[pp_2018_2017_m.MWD2==1370700]
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID_1, OBJECTID, Muni, Ward, District, LocName, Prefix, House, Fraction, Street, Suffix1, Suffix2, City, UnitDesc, UnitNumber, Zip, Parcel, Accessible, Leadman, Region, Coordinate, Coordina_1, DistrictCO, DistrictSE, DistrictLE, EditDate, MuniName, OrigAddres, MWD, POINT_X, POINT_Y, MWD2, NewAddress_18_11, geometry, NewAddress_18_05, NewAddress_17_05, addr_changed_17, addr_changed_18]
# Index: []

# %%
pp_vdf_2018_10[pp_vdf_2018_10.MWD_vdf==1370700]
# Out:
#              Title Last_Name First_Name Middle_Name Suffix Sex Date_Of_Birth  \
# ID_Number
# 002894558-02   NaN     ABELS      LYNDA           M    NaN   F    12/10/1955
#
#              Date_Registered Voter_Status StatusChangeDate Political_Party  \
# ID_Number
# 002894558-02       12/1/1984            A  12/1/1984 0:0:0               R
#
#              House__ HouseNoSuffix StreetNameComplete Apt__ Address_Line_2  \
# ID_Number
# 002894558-02     510                          OAK AVE   NaN            NaN
#
#                    City State Zip_Code MAddress_Line_1 MAddress_Line_2 MCity  \
# ID_Number
# 002894558-02  ELIZABETH    PA    15037             NaN             NaN   NaN
#
#              MState MZip_Code     PollingPlaceDescript     PollPlaceAdd  \
# ID_Number
# 002894558-02    NaN       NaN  BLAINE HILL VOL FIRE CO  409 OXFORD AVE
#
#                       PollPlaceCSZ Last_Date_Voted      Dist1  Dist2 Dist3  \
# ID_Number
# 002894558-02  ELIZABETH, PA  15037       3/13/2018  1370700.0    NaN  SC24
#
#               Dist4  Dist5 Dist6 Dist7 Dist8  Dist9 Dist10  Dist11  Dist12  \
# ID_Number
# 002894558-02  MN137  MD226  LG39  SN45  CG18  CPC00  CAC09     2.0     NaN
#
#                  Dist13  Dist14  Dist15 CustomData1 Date_Last_Changed  \
# ID_Number
# 002894558-02  1370700-1     NaN     NaN   116109448    2/7/2003 0:0:0
#
#              PhoneNumHome PR_05_15_18 PR_05_15_18_VM SP_03_13_18  \
# ID_Number
# 002894558-02          NaN         NaN            NaN           R
#
#              SP_03_13_18_VM SP_03_06_18 SP_03_06_18_VM SP_01_23_18  \
# ID_Number
# 002894558-02             AP         NaN            NaN         NaN
#
#              SP_01_23_18_VM GN_11_07_17 GN_11_07_17_VM PR_05_16_17  \
# ID_Number
# 002894558-02            NaN         NaN            NaN         NaN
#
#              PR_05_16_17_VM GN_11_08_16 GN_11_08_16_VM PR_04_26_16  \
# ID_Number
# 002894558-02            NaN           R             AP           R
#
#              PR_04_26_16_VM GN_11_03_15 GN_11_03_15_VM PR_05_19_15  \
# ID_Number
# 002894558-02             AP         NaN            NaN         NaN
#
#              PR_05_19_15_VM GN_11_04_14 GN_11_04_14_VM PR_05_20_14  \
# ID_Number
# 002894558-02            NaN           R             AP         NaN
#
#              PR_05_20_14_VM GN_11_05_13 GN_11_05_13_VM PR_05_21_13  \
# ID_Number
# 002894558-02            NaN         NaN            NaN         NaN
#
#              PR_05_21_13_VM GN_11_06_12 GN_11_06_12_VM SP_08_07_12  \
# ID_Number
# 002894558-02            NaN           R             AP         NaN
#
#              SP_08_07_12_VM PR_04_24_12 PR_04_24_12_VM GN_11_08_11  \
# ID_Number
# 002894558-02            NaN         NaN            NaN         NaN
#
#              GN_11_08_11_VM PR_05_17_11 PR_05_17_11_VM GN_11_02_10  \
# ID_Number
# 002894558-02            NaN           R             AP         NaN
#
#              GN_11_02_10_VM                     address_raw  MWD_vdf
# ID_Number
# 002894558-02            NaN  510 OAK AVE ELIZABETH PA 15037  1370700

# %%
pp_vdf_2018_um = pd.merge(pp_vdf_2018_10.reset_index(), pp_2018_2017_um, left_on='PollingPlaceDescript', right_on='LocName',
                          left_index=False, right_index=False, sort=False,
                          suffixes=('_vdf', '_pp'), copy=True, indicator=False,
                          validate=None, how='outer')

# %%
pp_vdf_2018_um = pd.merge(pp_vdf_2018_10.reset_index(), pp_2018_2017_m, left_on='MWD_vdf', right_on='MWD2',
                          left_index=False, right_index=False, sort=False,
                          suffixes=('_vdf', '_pp'), copy=True, indicator=False,
                          validate=None, how='outer')

# %%
pp_vdf_2018_um
# Out:
#          ID_Number Title       Last_Name   First_Name    Middle_Name Suffix  \
# 0     108927574-02   NaN           AABAN         ZAIN              A    NaN
# 1     103133442-02   NaN         AAGAARD        MARIT            NaN    NaN
# 2     102892955-02   NaN           AAMIR        TALHA            NaN    NaN
# 3     020340986-02   NaN           AARON       ANDREA            NaN    NaN
# 4     003007111-02   NaN           AARON      BARBARA              A    NaN
# 5     020029602-02   NaN           AARON      CHARLES              F    NaN
# 6     002171843-02   NaN           AARON        DAVID              G    NaN
# 7     002184557-02   NaN           AARON      DEBORAH              S    NaN
# 8     107205165-02   NaN           AARON     DOMINIKA          LARAE    NaN
# 9     102729360-02   NaN           AARON     DONIELLE        CATRICE    NaN
# 10    106158840-02   NaN           AARON        ELISE              R    NaN
# 11    002112797-02   NaN           AARON       EUGENE              L    NaN
# 12    103082320-02   NaN           AARON     JENNIFER           HOPE    NaN
# 13    021116999-02   NaN           AARON       JEREMY              W    NaN
# 14    002155059-02   NaN           AARON         JOHN              H    NaN
# 15    108217836-02   NaN           AARON       JORDAN            NaN     JR
# 16    002132515-02   NaN           AARON       LONNIE              R    NaN
# 17    103736752-02   NaN           AARON         LUKE              A    NaN
# 18    002667958-02   NaN           AARON     MARGARET              A    NaN
# 19    002007095-02   NaN           AARON     MARY ANN            NaN    NaN
# 20    108060738-02   NaN           AARON      PATRICE              L    NaN
# 21    002678251-02   NaN           AARON      PATRICK            NaN    NaN
# 22    002949672-02   NaN           AARON         PAUL              A    NaN
# 23    107139266-02   NaN           AARON         PAUL              A     JR
# 24    002517949-02   NaN           AARON      ROSALIE            NaN    NaN
# 25    002505923-02   NaN           AARON       SAMUEL              J    NaN
# 26    103753603-02   NaN           AARON         SETH              B    NaN
# 27    002683734-02   NaN           AARON       THOMAS              K    NaN
# 28    002316659-02   NaN           AARON       TRACEY              L    NaN
# 29    103904657-02   NaN           AARON      XAVAIER         GERALD    NaN
# 30    021610007-02   NaN           AARON      ZACHARY              A    NaN
# 31    109336250-02   NaN          AARON7      MATTHEW              S    NaN
# 32    002306508-02   NaN          AARONS       JEROME              H    NaN
# 33    002771227-02   NaN          AARONS       ROBERT              D    NaN
# 34    002636749-02   NaN        AARONSON         JOEL              P    NaN
# 35    013936279-02   NaN        AARONSON      MICHAEL          LOUIS    NaN
# 36    102909191-02   NaN        AARONSON    STEPHANIE            NaN    NaN
# 37    103505209-02   NaN         AARSETH      MARYANN         BISHOP    NaN
# 38    020756041-02   NaN           AASEN       WESLEY         ANDERS    NaN
# 39    002559154-02   NaN           AASMO        ALLEN            NaN    NaN
# 40    102846908-02   NaN           AATIK       OTMANE            NaN    NaN
# 41    104472794-02   NaN          ABABIO         AMMA         NYARKO    NaN
# 42    021644108-02   NaN            ABAD      BETHANY         NICOLE    NaN
# 43    021111716-02   NaN            ABAD      BRANDON          SCOTT    NaN
# 44    109121877-02   NaN            ABAD    LAWERENCE              S    NaN
# 45    021113385-02   NaN          ABADIE       MAGALI      CHRISTELE    NaN
# 46    104159309-02   NaN        ABADILLA       ANGELA            NaN    NaN
# 47    020166116-02   NaN         ABAHAZI        MARIA              T    NaN
# 48    002065557-02   NaN         ABAJIAN      BEVERLY              A    NaN
# 49    002685163-02   NaN         ABAJIAN     CAMBERLY              M    NaN
# ...            ...   ...             ...          ...            ...    ...
# 1274  020999885-02   NaN           ALLAN       DENNIS        PATRICK    NaN
# 1275  103546202-02   NaN           ALLAN        TRACY            LIN    NaN
# 1276  014129513-02   NaN        ALLBAUGH       JOSEPH        MICHAEL    NaN
# 1277  002759398-02   NaN           ALLEN       ALVINO              J    NaN
# 1278  002646307-02   NaN           ALLEN        BETTY              J    NaN
# 1279  020286650-02   NaN           ALLEN     CLARISSA              F    NaN
# 1280  002902069-02   NaN           ALLEN        DAVID              M    NaN
# 1281  002898717-02   NaN           ALLEN        DONNA            NaN    NaN
# 1310    M      4/5/1980        9/1/1998            A     3/24/2007 6:0:2
# 1311  NaN     1/21/1996       10/9/2014            A     10/9/2014 6:0:9
# 1312    F     3/31/1956        9/1/1990            A      9/1/1990 0:0:0
# 1313    F      6/1/1968        8/1/2003            A      8/1/2003 0:0:0
# 1314    M     8/16/1992       9/10/2010            A     7/26/2016 3:0:6
# 1315    F     4/22/1936        3/1/1958            A      3/1/1958 0:0:0
# 1316    F     2/25/1961       10/1/1992            A     10/1/1992 0:0:0
# 1317    M    11/22/1979        1/1/2001            I  1/20/2017 10:40:31
# 1318    F     2/19/1966        1/1/1996            A      1/1/1996 0:0:0
# 1319    F     2/11/1961        4/1/2003            A      4/1/2003 0:0:0
# 1320    F     5/22/1978       6/18/2009            A     6/18/2009 6:0:1
# 1321    F      2/4/1966        6/1/1991            A      6/1/1991 0:0:0
# 1322  NaN           NaN             NaN          NaN                 NaN
# 1323  NaN           NaN             NaN          NaN                 NaN
#
#      Political_Party House__ HouseNoSuffix    StreetNameComplete  Apt__  \
# 0                  D     155                           SENECA PL    NaN
# 1                  D     427                           CENTER ST    NaN
# 2                 NF    3990             A   5TH AVE PITT TOWERS    NaN
# 3                 NF    5602                           DUNCAN ST    NaN
# 4                  R     520                          HALLOCK ST    NaN
# 5                 NO     100                 SOUTHERN HILANDS DR    NaN
# 6                  R     137                       WILTSHIRE CIR    NaN
# 7                  D     328                           9TH AVE E    NaN
# 8                  D     507                           MELLON ST      A
# 9                  D      21                       WOODLAND RD W    NaN
# 10                NF    1345                          VICKROY ST    NaN
# 11                 D    1312                          MARION CIR    NaN
# 12                 R    1283                         ARROWOOD DR    NaN
# 13                 R     506                        NANTUCKET DR    NaN
# 14                 D     563                       RICHLAND ST N    NaN
# 15                 D    5032                FORBES (CMU SMC) AVE   4689
# 16                 R    2003                          TIMBER TRL    NaN
# 17                 R     317                         SOUTHVUE DR    NaN
# 18                 D    4010                          OUTLOOK DR    NaN
# 19                 R      24                        CAROTHERS DR      A
# 20                 D    7606                         CHEYENNE ST      2
# 21                 R     159                           BROWN AVE    NaN
# 22                 D     410                            GROVE ST    NaN
# 23                 D    3160                           AVALON ST    NaN
# 24                 D     952                           MIRROR ST    NaN
# 25                 D    7130                      FRANKSTOWN AVE    209
# 26                 D    6328                             HOWE ST     10
# 27                 R     838                       LINDENWOOD DR    NaN
# 28                 D     130                         OAKVIEW AVE    NaN
# 29                 D    4185                          IVANHOE DR    211
# 30               NON    2523                             JANE ST    NaN
# 31                 D      81                         WESTWOOD ST    NaN
# 32                 D    1437                      HIGHLAND AVE N    NaN
# 33                 D   10918                       FRANKSTOWN RD    NaN
# 34                 D     408                       GLEN ARDEN DR    NaN
# 35                NF    5240                         STANTON AVE    308
# 36                 D    5620                           HOBART ST      4
# 37                 D    4308                        BARLIND DR E    NaN
# 38                 R     320                  FORT DUQUESNE BLVD     7N
# 39                 D     577                    HICKORY GRADE RD    NaN
# 40                 R     700                    PENN CENTER BLVD    305
# 41                 D     848                         HEBERTON ST    NaN
# 42                 D     171                         BALPH AVE N    NaN
# 43                 D     163                         LINCOLN AVE      2
# 44                 D    3825                       UNIVERSITY DR  705-A
# 45               UND     198                       BUCKINGHAM DR    NaN
# 46                 D    1836                         FOXCROFT LN    501
# 47                 D     215                           MOFFAT ST    NaN
# 48                 R    5841                         FORWARD AVE    631
# 49                 R    2840                       MIDDLETOWN RD    NaN
# ...              ...     ...           ...                   ...    ...
# 1274               D    2212                           OSGOOD ST    NaN
# 1275              NF       7                       DORCHESTER DR    310
# 1276               D     823                          CONCORD ST    NaN
# 1277               D    1085                       BLACKADORE ST    NaN
# 1278               D     621                             7TH AVE    NaN
# 1279               D     929                           LOCUST ST    NaN
# 1280               R    2100                           WHITED ST    NaN
# 1281               D    1820                         BEDFORD AVE      2
# 1282               D     313                       SHENANDOAH DR    NaN
# 1283               D     718                         BROADWAY ST    NaN
# 1284               D     215                          EUCLID AVE    NaN
# 1285               D    7318                           CHURCH ST    NaN
# 1286               D     745                          ANAHEIM ST    NaN
# 1287               D    2333                          CENTRE AVE    NaN
# 1288              NF    3941                      BROWNSVILLE RD    NaN
# 1289             OTH     516                         SINCLAIR ST    602
# 1290              NF     438                           RUXTON ST    NaN
# 1291               D    1949                         SAN JUAN ST    NaN
# 1292               D    1629                            LAPPE LN    NaN
# 1293               D    7325                             RACE ST    NaN
# 1294               D     945                     WASHINGTON BLVD    E-1
# 1295               D     214                         PARKLANE DR    NaN
# 1296               D     744                         DAYS RUN RD    NaN
# 1297              NF     422                         ROBINSON CT    NaN
# 1298               R      30                          BANBURY LN    NaN
# 1299               R    4117                           IMPALA DR    NaN
# 1300               D    1833                        GREENLEAF ST    NaN
# 1301              NF    1334                         MARGARET ST    NaN
# 1302               R       4                            RIVER RD    NaN
# 1303               D     326                         BELLWOOD RD    NaN
# 1304              NF    4703                        MAPLEDALE DR    NaN
# 1305              NF    2135                     FOREST GROVE RD    NaN
# 1306               R    7033                           GRAND AVE    NaN
# 1307               D     929                            GARY AVE    NaN
# 1308               D     507                         LACEBARK CT    NaN
# 1309               D    1018                    WARRINGTON AVE E    NaN
# 1310               D    1142                  PEACHTREE DR OR RD    NaN
# 1311               D     518                         INDUSTRY ST    NaN
# 1312               D    1052                       MCALLISTER DR    NaN
# 1313               D    8518                           DERSAM ST    NaN
# 1314               R    1435                         OVERDALE DR    NaN
# 1315               R      38                          TERRACE RD    NaN
# 1316               R     198                         BEAVER ST E    NaN
# 1317               D     401                           ELBOW WAY    NaN
# 1318           ITENT     210                          COULTER RD    NaN
# 1319               D    4520                      MONONGAHELA ST    NaN
# 1320               D      26                      WINDOM HILL PL    NaN
# 1321               R       6                            MAPLE ST    NaN
# 1322             NaN     NaN           NaN                   NaN    NaN
# 1323             NaN     NaN           NaN                   NaN    NaN
#
#      Address_Line_2          City_vdf State Zip_Code  \
# 0               NaN              MARS    PA    16046
# 1               NaN        PITTSBURGH    PA    15221
# 2               NaN        PITTSBURGH    PA    15213
# 3               NaN        PITTSBURGH    PA    15201
# 4               NaN        PITTSBURGH    PA    15211
# 5               NaN        PITTSBURGH    PA    15241
# 6               NaN       MONROEVILLE    PA    15146
# 7               NaN         HOMESTEAD    PA    15120
# 8               NaN        PITTSBURGH    PA    15206
# 9               NaN        PITTSBURGH    PA    15232
# 10              NaN        PITTSBURGH    PA    15219
# 11              NaN          CLAIRTON    PA    15025
# 12              NaN        PITTSBURGH    PA    15243
# 13              NaN        PITTSBURGH    PA    15236
# 14              NaN        PITTSBURGH    PA    15208
# 15              NaN        PITTSBURGH    PA    15289
# 16              NaN          IMPERIAL    PA    15126
# 17              NaN        PITTSBURGH    PA    15236
# 18              NaN      WEST MIFFLIN    PA    15122
# 19              NaN      TURTLE CREEK    PA    15145
# 20              NaN         SWISSVALE    PA    15218
# 21              NaN      TURTLE CREEK    PA    15145
# 22              NaN        PITTSBURGH    PA    15219
# 23              NaN        PITTSBURGH    PA    15219
# 24              NaN        PITTSBURGH    PA    15217
# 25              NaN        PITTSBURGH    PA    15208
# 26              NaN        PITTSBURGH    PA    15206
# 27              NaN        PITTSBURGH    PA    15234
# 28              NaN        PITTSBURGH    PA    15218
# 29              NaN       MONROEVILLE    PA    15146
# 30              NaN        PITTSBURGH    PA    15203
# 31              NaN        PITTSBURGH    PA    15211
# 32              NaN        PITTSBURGH    PA    15206
# 33          APT 410        PITTSBURGH    PA    15235
# 34              NaN        PITTSBURGH    PA    15208
# 35              NaN        PITTSBURGH    PA    15201
# 36              NaN        PITTSBURGH    PA    15217
# 37              NaN        PITTSBURGH    PA    15227
# 38              NaN        PITTSBURGH    PA    15222
# 39              NaN       BRIDGEVILLE    PA    15017
# 40              NaN        PITTSBURGH    PA    15235
# 41              NaN        PITTSBURGH    PA    15206
# 42              NaN        PITTSBURGH    PA    15202
# 43              NaN        PITTSBURGH    PA    15202
# 44              NaN        PITTSBURGH    PA    15213
# 45              NaN        PITTSBURGH    PA    15237
# 46              NaN      ALLISON PARK    PA    15101
# 47              NaN          CARNEGIE    PA    15106
# 48              NaN        PITTSBURGH    PA    15217
# 49              NaN        PITTSBURGH    PA    15204
# ...             ...               ...   ...      ...
# 1274            NaN        PITTSBURGH    PA    15214
# 1275            NaN        PITTSBURGH    PA    15241
# 1276            NaN        PITTSBURGH    PA    15212
# 1277            NaN        PITTSBURGH    PA    15221
# 1278            NaN        CORAOPOLIS    PA    15108
# 1279            NaN       MC KEESPORT    PA    15132
# 1280            NaN        PITTSBURGH    PA    15210
# 1281            NaN        PITTSBURGH    PA    15219
# 1282            NaN        PITTSBURGH    PA    15235
# 1283            NaN  EAST MC KEESPORT    PA    15035
# 1284            NaN         GLASSPORT    PA    15045
# 1285            NaN         SWISSVALE    PA    15218
# 1286            NaN        PITTSBURGH    PA    15219
# 1287            NaN        PITTSBURGH    PA    15219
# 1288            NaN        PITTSBURGH    PA    15227
# 1289            NaN       MC KEESPORT    PA    15132
# 1290            NaN        PITTSBURGH    PA    15211
# 1291            NaN        PITTSBURGH    PA    15235
# 1292            NaN        PITTSBURGH    PA    15212
# 1293            NaN        PITTSBURGH    PA    15208
# 1294            NaN        PITTSBURGH    PA    15206
# 1295            NaN          BRADDOCK    PA    15104
# 1296            NaN          TARENTUM    PA    15084
# 1297            NaN        PITTSBURGH    PA    15213
# 1298            NaN        PITTSBURGH    PA    15202
# 1299            NaN        PITTSBURGH    PA    15239
# 1300            NaN        PITTSBURGH    PA    15211
# 1301            NaN           MUNHALL    PA    15120
# 1302            NaN         SEWICKLEY    PA    15143
# 1303            NaN      WEST MIFFLIN    PA    15122
# 1304            NaN         HOMESTEAD    PA    15120
# 1305            NaN        CORAOPOLIS    PA    15108
# 1306            NaN        PITTSBURGH    PA    15225
# 1307            NaN          CLAIRTON    PA    15025
# 1308            NaN          GIBSONIA    PA    15044
# 1309            NaN        PITTSBURGH    PA    15210
# 1310            NaN          CARNEGIE    PA    15106
# 1311            NaN        PITTSBURGH    PA    15210
# 1312            NaN    NEW KENSINGTON    PA    15068
# 1313            NaN        PITTSBURGH    PA    15235
# 1314            NaN         HOMESTEAD    PA    15120
# 1315            NaN          CARNEGIE    PA    15106
# 1316            NaN         SEWICKLEY    PA    15143
# 1317            NaN          CLAIRTON    PA    15025
# 1318            NaN       MC KEESPORT    PA    15131
# 1319            NaN        PITTSBURGH    PA    15207
# 1320            NaN        PITTSBURGH    PA    15203
# 1321            NaN          TRAFFORD    PA    15085
# 1322            NaN               NaN   NaN      NaN
# 1323            NaN               NaN   NaN      NaN
#
#                               MAddress_Line_1 MAddress_Line_2      MCity  \
# 0                                         NaN             NaN        NaN
# 1                                         NaN             NaN        NaN
# 2                                         NaN             NaN        NaN
# 3                                         NaN             NaN        NaN
# 4                                         NaN             NaN        NaN
# 5                                         NaN             NaN        NaN
# 6                                         NaN             NaN        NaN
# 7                                         NaN             NaN        NaN
# 8                                         NaN             NaN        NaN
# 9                                         NaN             NaN        NaN
# 10                                        NaN             NaN        NaN
# 11                                        NaN             NaN        NaN
# 12                                        NaN             NaN        NaN
# 13                                        NaN             NaN        NaN
# 14                                        NaN             NaN        NaN
# 15                                        NaN             NaN        NaN
# 16                                        NaN             NaN        NaN
# 17                          4512 SHANNON ROAD             NaN       ERIE
# 18                                        NaN             NaN        NaN
# 19                                        NaN             NaN        NaN
# 20                                        NaN             NaN        NaN
# 21                                        NaN             NaN        NaN
# 22                                        NaN             NaN        NaN
# 23                                        NaN             NaN        NaN
# 24                                        NaN             NaN        NaN
# 25                                        NaN             NaN        NaN
# 26                                        NaN             NaN        NaN
# 27                                        NaN             NaN        NaN
# 28                                        NaN             NaN        NaN
# 29                                        NaN             NaN        NaN
# 30                                        NaN             NaN        NaN
# 31                                        NaN             NaN        NaN
# 32                                        NaN             NaN        NaN
# 33                                        NaN             NaN        NaN
# 34                                        NaN             NaN        NaN
# 35                                        NaN             NaN        NaN
# 36                                        NaN             NaN        NaN
# 37                                        NaN             NaN        NaN
# 38                                        NaN             NaN        NaN
# 39                                 PO BOX 301             NaN      CUDDY
# 40                                        NaN             NaN        NaN
# 41    28 LEVERETT MAIL CENTER, 28 DEWOLFE ST.             NaN  CAMBRIDGE
# 42                                        NaN             NaN        NaN
# 43                                        NaN             NaN        NaN
# 44                                        NaN             NaN        NaN
# 45                                        NaN             NaN        NaN
# 46                                        NaN             NaN        NaN
# 47                                        NaN             NaN        NaN
# 48                                        NaN             NaN        NaN
# 49                                        NaN             NaN        NaN
# ...                                       ...             ...        ...
# 1274                                      NaN             NaN        NaN
# 1275                                      NaN             NaN        NaN
# 1276                                      NaN             NaN        NaN
# 1277                                      NaN             NaN        NaN
# 1278                                      NaN             NaN        NaN
# 1279                                      NaN             NaN        NaN
# 1280                                      NaN             NaN        NaN
# 1281                                      NaN             NaN        NaN
# 1282                                      NaN             NaN        NaN
# 1283                                      NaN             NaN        NaN
# 1284                                      NaN             NaN        NaN
# 1285                                      NaN             NaN        NaN
# 1286                                      NaN             NaN        NaN
# 1287                                      NaN             NaN        NaN
# 1288                                      NaN             NaN        NaN
# 1289                                      NaN             NaN        NaN
# 1290                                      NaN             NaN        NaN
# 1291                                      NaN             NaN        NaN
# 1292                                      NaN             NaN        NaN
# 1293                                      NaN             NaN        NaN
# 1294                                      NaN             NaN        NaN
# 1295                                      NaN             NaN        NaN
# 1296                                      NaN             NaN        NaN
# 1297                                      NaN             NaN        NaN
# 1298                                      NaN             NaN        NaN
# 1299                                      NaN             NaN        NaN
# 1300                                      NaN             NaN        NaN
# 1301                                      NaN             NaN        NaN
# 1302                                      NaN             NaN        NaN
# 1303                                      NaN             NaN        NaN
# 1304                                      NaN             NaN        NaN
# 1305                                      NaN             NaN        NaN
# 1306                                      NaN             NaN        NaN
# 1307                                      NaN             NaN        NaN
# 1308                                      NaN             NaN        NaN
# 1309                                      NaN             NaN        NaN
# 1310                                      NaN             NaN        NaN
# 1311                                      NaN             NaN        NaN
# 1312                                      NaN             NaN        NaN
# 1313                                      NaN             NaN        NaN
# 1314                                      NaN             NaN        NaN
# 1315                                      NaN             NaN        NaN
# 1316                                      NaN             NaN        NaN
# 1317                                      NaN             NaN        NaN
# 1318                                      NaN             NaN        NaN
# 1319                                      NaN             NaN        NaN
# 1320                                      NaN             NaN        NaN
# 1321                                      NaN             NaN        NaN
# 1322                                      NaN             NaN        NaN
# 1323                                      NaN             NaN        NaN
#
#      MState MZip_Code                        PollingPlaceDescript  \
# 0       NaN       NaN                  REGIONAL LEARNING ALLIANCE
# 1       NaN       NaN             SISTER THEA BOWMAN SCHOOL LOBBY
# 2       NaN       NaN                   WILLIAM PITT UNION 1ST FL
# 3       NaN       NaN                             ENGINE HOUSE #7
# 4       NaN       NaN                  WEST END SR COM CTR 1ST FL
# 5       NaN       NaN                            WESLEY INSTITUTE
# 6       NaN       NaN           UNIVERSITY PARK ELEMENTARY SCHOOL
# 7       NaN       NaN          HOMESTEAD APTS COMMUNITY RM BLDG C
# 8       NaN       NaN                  MT ARARAT COMMUNITY CENTER
# 9       NaN       NaN  CHATHAM UNIVERSITY LAUGHLIN HALL WELKER RM
# 10      NaN       NaN                             EPIPHANY CHURCH
# 11      NaN       NaN                  1ST UNITED METH CH RAMP DR
# 12      NaN       NaN                              TEMPLE EMANUEL
# 13      NaN       NaN                                   BORO BLDG
# 14      NaN       NaN             HELEN S FAISON ARTS ACADEMY GYM
# 15      NaN       NaN              CARNEGIE MELLON UNIVERSITY GYM
# 16      NaN       NaN                 NEW COMMUNITY CENTER-LOUNGE
# 17       PA     16510                                   BORO BLDG
# 18      NaN       NaN                        HOMEVILLE SCHOOL GYM
# 19      NaN       NaN        ELECTRIC HEIGHTS UNITED METHODIST CH
# 20      NaN       NaN                   SWISSVALE MUNICIPAL  BLDG
# 21      NaN       NaN                            JOHN FRASER HALL
# 22      NaN       NaN           HILLMAN CENTER AT SKYLINE TERRACE
# 23      NaN       NaN                   Y M C A  ALL PURPOSE ROOM
# 24      NaN       NaN             PALISADE PLAYHOUSE ALGER ST ENT
# 25      NaN       NaN              HOMEWOOD HOUSE COM RM SIDE ENT
# 26      NaN       NaN        CALVARY EPISCOPAL CHURCH PARISH HALL
# 27      NaN       NaN                           MYRTLE SCHOOL GYM
# 28      NaN       NaN            EDGEWOOD PRIMARY SCHOOL REAR ENT
# 29      NaN       NaN                  BORO BLDG COUNCIL CHAMBERS
# 30      NaN       NaN            MORSE HI RISE COM RM 24TH ST ENT
# 31      NaN       NaN                    ST JUSTIN PLAZA REC ROOM
# 32      NaN       NaN                 ST ANDREWS EPISCOPAL CHURCH
# 33      NaN       NaN                   ST BARTHOLOMEW CHURCH GYM
# 34      NaN       NaN                 LINDEN SCHOOL LEFT SIDE GYM
# 35      NaN       NaN                 SUNNYSIDE SCHOOL AUDITORIUM
# 36      NaN       NaN                      SHAARE TORAH SYNAGOGUE
# 37      NaN       NaN           BALDWIN COM U M CHURCH WESLEY HL.
# 38      NaN       NaN              CARNEGIE LIBRARY OF PITTSBURGH
# 39      NaN     15031                        FAIRVIEW VOL FIRE CO
# 40      NaN       NaN          LAUREL VILLAGE APTS LEASING OFFICE
# 41       MA     02138                        DILLWORTH SCHOOL-GYM
# 42      NaN       NaN                     BELLEVUE BORO FIRE HALL
# 43      NaN       NaN                  NEW LIFE COMMUNITY  CHURCH
# 44      NaN       NaN            SOLDIERS & SAILORS MEMORIAL HALL
# 45      NaN       NaN                           OHIO FIRE STATION
# 46      NaN       NaN                        MEMORIAL PARK CHURCH
# 47      NaN       NaN                   ST ANDREW LUTHERAN CHURCH
# 48      NaN       NaN                         FORWARD SHADY APTS.
# 49      NaN       NaN                 ACENSION CHURCH SOCIAL HALL
# ...     ...       ...                                         ...
# 1274    NaN       NaN                            MCNAUGHER SCHOOL
# 1275    NaN       NaN                           PATHFINDER SCHOOL
# 1276    NaN       NaN                             SCHILLER SCHOOL
# 1277    NaN       NaN                              SALVATION ARMY
# 1278    NaN       NaN                             ARMORY BUILDING
# 1279    NaN       NaN                         ISBIR MANOR 17 BLDG
# 1280    NaN       NaN                  BROOKLINE COM CTR GAMEROOM
# 1281    NaN       NaN                      MCKELVY SCHOOL ROOM 12
# 1282    NaN       NaN                  LINTON INTERMEDIATE SCHOOL
# 1283    NaN       NaN              UNITED VOLUNTEER FIRE & RESCUE
# 1284    NaN       NaN                              MUNICIPAL BLDG
# 1285    NaN       NaN                         NEW SWISSVALE V F C
# 1286    NaN       NaN      ROBERT WILLIAMS MEMORIAL PARK REC CENT
# 1287    NaN       NaN                           A LEO WEIL SCHOOL
# 1288    NaN       NaN                 MOORE ELEMENTARY SCHOOL GYM
# 1289    NaN       NaN                 MCKEESPORT DOWNTOWN HOUSING
# 1290    NaN       NaN                       WARRINGTON REC CENTER
# 1291    NaN       NaN             PENN HILLS MULTI PURPOSE CENTER
# 1292    NaN       NaN                  SPRINGHILL SCHOOL CAFE ENT
# 1293    NaN       NaN              BAPTIST TEMPLE CHURCH BASEMENT
# 1294    NaN       NaN              KINGSLEY HOUSE, PAULSON AVE EN
# 1295    NaN       NaN                          NORTH BRADDOCK VFD
# 1296    NaN       NaN                EAST DEER MUNICIPAL BUILDING
# 1297    NaN       NaN                              WADSWORTH HALL
# 1298    NaN       NaN         SHANNOPIN COUNTRY CLUB MEETING ROOM
# 1299    NaN       NaN                         SAMPSON FAMILY YMCA
# 1300    NaN       NaN                       SWEETBRIAR PLACE APTS
# 1301    NaN       NaN                            #1  ENGINE HOUSE
# 1302    NaN       NaN                        SEWICKLEY SPEAK EASY
# 1303    NaN       NaN                HOMEVILLE VOL FIRE CO 1ST FL
# 1304    NaN       NaN                              RESIDENCE HOME
# 1305    NaN       NaN                            FOREST GROVE VFD
# 1306    NaN       NaN                 NEVILLE ISLAND V F D 1ST FL
# 1307    NaN       NaN                     CLAIRTON MUNICIPAL BLDG
# 1308    NaN       NaN          NORTH PARK SKATING RINK MAIN FLOOR
# 1309    NaN       NaN                       ST PAUL CROSS RETREAT
# 1310    NaN       NaN             SCOTT TWP MUNICIPAL BLDG (POOL)
# 1311    NaN       NaN                       WARRINGTON REC CENTER
# 1312    NaN       NaN                        NEW PIVIK SCHOOL GYM
# 1313    NaN       NaN                   FAISON ARTS ACADEMY ANNEX
# 1314    NaN       NaN                          WEST HOMESTEAD VFD
# 1315    NaN       NaN              ROSSLYN FARMS COMMUNITY CENTER
# 1316    NaN       NaN               GLENFIELD PARK BLDG 1ST FLOOR
# 1317    NaN       NaN          WILSON PRESBYTERIAN CH SOCIAL HALL
# 1318    NaN       NaN               COULTER VOL FIRE CO 1ST FLOOR
# 1319    NaN       NaN                             KEYSTONE CHURCH
# 1320    NaN       NaN              CALIGUIRI PLAZA COMMUNITY ROOM
# 1321    NaN       NaN           STUDENT TRANSPORTATOIN OF AMERICA
# 1322    NaN       NaN                                         NaN
# 1323    NaN       NaN                                         NaN
#
#                           PollPlaceAdd                          PollPlaceCSZ  \
# 0              850 CRANBERRY WOODS RD                  WARRENDALE, PA  16066
# 1                     721 REBECCA AVE                  PITTSBURGH, PA  15221
# 2                     3959 FORBES AVE                  PITTSBURGH, PA  15213
# 3                    4603 STANTON AVE                  PITTSBURGH, PA  15201
# 4                        80 WABASH ST        PITTSBURGH               , PA
# 5                     245 JOHNSTON RD                  PITTSBURGH, PA  15241
# 1304  POINT (-79.92136642009903 40.38756318118796)
# 1305  POINT (-80.13866893819545 40.48368055629295)
# 1306  POINT (-80.12939473426918 40.51266190644771)
# 1307  POINT (-79.89474501060536 40.29627866715069)
# 1308  POINT (-80.02346771810288 40.61576014987896)
# 1309   POINT (-79.98422487470411 40.4230484968548)
# 1310   POINT (-80.08411087942628 40.3867933866778)
# 1311  POINT (-80.00096470687066 40.42135919909157)
# 1312  POINT (-79.75370476177039 40.49409295957891)
# 1313  POINT (-79.88098765134518 40.45378267580434)
# 1314  POINT (-79.91798540028839 40.40210868919787)
# 1315  POINT (-80.09156618744898 40.42316626140092)
# 1316  POINT (-80.13986966490782 40.51953381181873)
# 1317    POINT (-79.8898216412145 40.3057896316361)
# 1318  POINT (-79.80401090679604 40.29753014075285)
# 1319  POINT (-79.94210635954045 40.41195922967108)
# 1320  POINT (-79.99360421905315 40.42212624425518)
# 1321   POINT (-79.7672973028905 40.38741476491056)
# 1322   POINT (-79.8750730038095 40.27299969413713)
# 1323  POINT (-79.85614578101273 40.25456344555691)
#
#                     NewAddress_18_05                NewAddress_17_05  \
# 0                   1170 FREEPORT RD                1170 FREEPORT RD
# 1                    725 REBECCA AVE                 725 REBECCA AVE
# 2                      3959 5TH  AVE                   3959 5TH  AVE
# 3                   4603 STANTON AVE                4603 STANTON AVE
# 4                       80 WABASH ST                    80 WABASH ST
# 5                    243 JOHNSTON RD                 243 JOHNSTON RD
# 6                        320 NOEL DR                     320 NOEL DR
# 7                        481 8TH AVE                     481 8TH AVE
# 8                    5801 HAMPTON ST                 5801 HAMPTON ST
# 9                    106 WOODLAND RD                 106 WOODLAND RD
# 10                   1018 CENTRE AVE                 1018 CENTRE AVE
# 11                  500 THOMPSON AVE                500 THOMPSON AVE
# 12                 37 ROBB HOLLOW RD               37 ROBB HOLLOW RD
# 13                   410 BRUCETON RD                 410 BRUCETON RD
# 14                     7430 TIOGA ST                   7430 TIOGA ST
# 15                   5000 FORBES AVE                 5000 FORBES AVE
# 16                  580 DONALDSON RD                580 DONALDSON RD
# 17               100 BOROUGH PARK DR             100 BOROUGH PARK DR
# 18                     4315 ELIZA ST                   4315 ELIZA ST
# 19                      601 JAMES ST                    601 JAMES ST
# 20                    7560 ROSLYN ST                  7560 ROSLYN ST
# 21                     500 HUNTER ST                   500 HUNTER ST
# 22                   2114 CENTRE AVE                 2114 CENTRE AVE
# 23                   2621 CENTRE AVE                 2621 CENTRE AVE
# 24                745 GREENFIELD AVE              745 GREENFIELD AVE
# 25               7130 FRANKSTOWN AVE             7130 FRANKSTOWN AVE
# 26                     315 SHADY AVE                   315 SHADY AVE
# 27                   3724 MYRTLE AVE                 3724 MYRTLE AVE
# 28                     241 MAPLE AVE                   241 MAPLE AVE
# 29             2700 MONROEVILLE BLVD           2700 MONROEVILLE BLVD
# 30                     2416 SARAH ST                   2416 SARAH ST
# 31                     120 BOGGS AVE                   120 BOGGS AVE
# 32                   5801 HAMPTON ST                 5801 HAMPTON ST
# 134                D     727                     BROADWAY AVE     7
# 143                D     555                     FAIR OAKS ST    ST
# 147                R      65                        GRANT AVE   NaN
# 170                R     111                      DAGGETTE DR   NaN
# 180                D     548                       HOPKINS ST   NaN
# 271                R     327                       HOFFMAN RD   NaN
# 359               NF     146                         VILLA DR   NaN
# 386                D     210                     ELECTRIC AVE   NaN
# 392                R     604                           4TH ST   NaN
# 393                D    2209                      CRESTAS AVE   NaN
# 395                D     304                        MILLS AVE   NaN
# 397                D    1148                       DOHRMAN ST   NaN
# 414                D     700                         GRANT ST     8
# 429                D     746                        SCHOOL ST     4
# 455                R     115                        MARIE AVE   NaN
# 556                R    1951                       MT TROY RD   NaN
# 605                D     112                       STANLEY ST   NaN
# 611                D     601                           6TH ST   NaN
# 627                D      31                      HAWKINS VLG     E
# 648                D     301                     BESSEMER AVE     4
# 769               NO    1119                    CLEVELAND AVE   NaN
# 779                D     645                         MAPLE LN   NaN
# 810                D     416                        RIDGE AVE     2
# 844                R    1309                      PENHURST DR   NaN
# 869                D    1347                        STATE AVE   111
# 888                R    1003                 BRACKENRIDGE AVE   NaN
# 891                D     293                        BUTLER ST     3
# 925                D    1103                     WOODWARD AVE   NaN
# 934                D    4911                        GRAND AVE    1A
# 976                R     703                        2ND AVE E   NaN
# 984               NO    6811                   FRONT RIVER RD   NaN
# 1026              NF     116                          5TH AVE     3
# 1050              NF     864                          8TH AVE   NaN
# 1063               D     716                        RIDGE AVE   NaN
# 1169               D     815                           8TH ST   NaN
# 1170               D      21                     HIGHLAND AVE   NaN
# 1181               R    2403                       MT TROY RD   NaN
# 1182               D      46                          OHIO ST   NaN
# 1205               D      34                    CHARTIERS AVE   NaN
# 1216               D     129                          OAK WAY   NaN
# 1250              NO    1081                         STARR RD   NaN
# 1253               D     715                       PARKER AVE     2
# 1289             OTH     516                      SINCLAIR ST   602
# 1296               D     744                      DAYS RUN RD   NaN
# 1306               R    7033                        GRAND AVE   NaN
#
#      Address_Line_2          City_vdf State Zip_Code MAddress_Line_1  \
# 134             NaN     MC KEES ROCKS    PA    15136             NaN
# 143             NaN     MC KEES ROCKS    PA    15136             NaN
# 147             NaN        PITTSBURGH    PA    15223             NaN
# 170             NaN       BUENA VISTA    PA    15018             NaN
# 180             NaN         SEWICKLEY    PA    15143             NaN
# 271             NaN        PITTSBURGH    PA    15212             NaN
# 359             NaN        PITTSBURGH    PA    15214             NaN
# 386             NaN   EAST PITTSBURGH    PA    15112             NaN
# 392             NaN          BRADDOCK    PA    15104             NaN
# 393             NaN  NORTH VERSAILLES    PA    15137             NaN
# 395             NaN          BRADDOCK    PA    15104             NaN
# 397             NaN     MC KEES ROCKS    PA    15136             NaN
# 414             NaN       MC KEESPORT    PA    15132             NaN
# 429             NaN          CRESCENT    PA    15046             NaN
# 455             NaN        PITTSBURGH    PA    15202             NaN
# 556             NaN        PITTSBURGH    PA    15212             NaN
# 605             NaN         CREIGHTON    PA    15030             NaN
# 611             NaN       MC KEESPORT    PA    15132             NaN
# 627             NaN            RANKIN    PA    15104             NaN
# 648             NaN   EAST PITTSBURGH    PA    15112             NaN
# 769             NaN      BRACKENRIDGE    PA    15014             NaN
# 779             NaN         SEWICKLEY    PA    15143             NaN
# 810             NaN   EAST PITTSBURGH    PA    15112             NaN
# 844             NaN       MC KEESPORT    PA    15135             NaN
# 869             NaN        CORAOPOLIS    PA    15108             NaN
# 888             NaN      BRACKENRIDGE    PA    15014             NaN
# 891             NaN        PITTSBURGH    PA    15223             NaN
# 925             NaN     MC KEES ROCKS    PA    15136             NaN
# 934             NaN        PITTSBURGH    PA    15225             NaN
# 976             NaN          TARENTUM    PA    15084             NaN
# 984             NaN        PITTSBURGH    PA    15225             NaN
# 1026            NaN       MC KEESPORT    PA    15132             NaN
# 1050            NaN      BRACKENRIDGE    PA    15014             NaN
# 1063            NaN     MC KEES ROCKS    PA    15136             NaN
# 1169            NaN     MC KEES ROCKS    PA    15136             NaN
# 1170            NaN        PITTSBURGH    PA    15223             NaN
# 1181            NaN        PITTSBURGH    PA    15212             NaN
# 1182            NaN     MC KEES ROCKS    PA    15136             NaN
# 1205            NaN            RANKIN    PA    15104             NaN
# 1216            NaN            RANKIN    PA    15104             NaN
# 1250            NaN          CRESCENT    PA    15046             NaN
# 1253            NaN          BRADDOCK    PA    15104             NaN
# 1289            NaN       MC KEESPORT    PA    15132             NaN
# 1296            NaN          TARENTUM    PA    15084             NaN
# 1306            NaN        PITTSBURGH    PA    15225             NaN
#
#      MAddress_Line_2 MCity MState MZip_Code  \
# 134              NaN   NaN    NaN       NaN
# 143              NaN   NaN    NaN       NaN
# 147              NaN   NaN    NaN       NaN
# 170              NaN   NaN    NaN       NaN
# 180              NaN   NaN    NaN       NaN
# 271              NaN   NaN    NaN       NaN
# 359              NaN   NaN    NaN       NaN
# 386              NaN   NaN    NaN       NaN
# 392              NaN   NaN    NaN       NaN
# 393              NaN   NaN    NaN       NaN
# 395              NaN   NaN    NaN       NaN
# 397              NaN   NaN    NaN       NaN
# 414              NaN   NaN    NaN       NaN
# 429              NaN   NaN    NaN       NaN
# 455              NaN   NaN    NaN       NaN
# 556              NaN   NaN    NaN       NaN
# 605              NaN   NaN    NaN       NaN
# 611              NaN   NaN    NaN       NaN
# 627              NaN   NaN    NaN       NaN
# 648              NaN   NaN    NaN       NaN
# 769              NaN   NaN    NaN       NaN
# 779              NaN   NaN    NaN       NaN
# 810              NaN   NaN    NaN       NaN
# 844              NaN   NaN    NaN       NaN
# 869              NaN   NaN    NaN       NaN
# 888              NaN   NaN    NaN       NaN
# 891              NaN   NaN    NaN       NaN
# 925              NaN   NaN    NaN       NaN
# 934              NaN   NaN    NaN       NaN
# 976              NaN   NaN    NaN       NaN
# 984              NaN   NaN    NaN       NaN
# 1026             NaN   NaN    NaN       NaN
# 1050             NaN   NaN    NaN       NaN
# 1063             NaN   NaN    NaN       NaN
# 1169             NaN   NaN    NaN       NaN
# 1170             NaN   NaN    NaN       NaN
# 1181             NaN   NaN    NaN       NaN
# 1182             NaN   NaN    NaN       NaN
# 1205             NaN   NaN    NaN       NaN
# 1216             NaN   NaN    NaN       NaN
# 1250             NaN   NaN    NaN       NaN
# 1253             NaN   NaN    NaN       NaN
# 1289             NaN   NaN    NaN       NaN
# 1296             NaN   NaN    NaN       NaN
# 1306             NaN   NaN    NaN       NaN
#
#                      PollingPlaceDescript                 PollPlaceAdd  \
# 134            STO-ROX SENIOR HIGH SCHOOL              1105 VALLEY ST
# 143     MOTHER SORROW SOC HL LL KITCH ENT            10 DESIDERIO WAY
# 147              ALL SAINTS ACTIVITY BLDG                19 WILSON ST
# 170               BUENA VISTA VOL FIRE CO        3333 FIRE STATION ST
# 180                    ST STEPHENS CHURCH            405 FREDERICK ST
# 271          MT TROY VOL FIRE CO BALLROOM              33 LONSDALE ST
# 359          MT TROY VOL FIRE CO BALLROOM              33 LONSDALE ST
# 386     E PITTSBURGH COM CTR GYM REAR ENT            506 BESSEMER AVE
# 392               LUNDINE APARTMENT LOBBY                   125 COREY
# 393       MT CARMEL BAPTIST CHURCH 1ST FL            90 PORT PERRY RD
# 395   BRADDOCK BORO BLDG COUNCIL CHAMBERS                  415 6TH ST
# 397                             STOWE VFD            548 BROADWAY AVE
# 414                   ST MARTIN DE PORRES            803 MARKET ST EX
# 429                 CRESCENT TWP BUILDING           225 SPRING RUN RD
# 455             AVALON MUNICIPAL BUILDING          640 CALIFORNIA AVE
# 556          MT TROY VOL FIRE CO BALLROOM              33 LONSDALE ST
# 605    HOLY FAMILY R C CHURCH SOCIAL HALL             787 FREEPORT RD
# 611            MCKEESPORT TOWERS COM ROOM                601 SIXTH ST
# 627                            RANKIN VFD             320 HAWKINS AVE
# 648     E PITTSBURGH COM CTR GYM REAR ENT             506 BESSEMER ST
# 769                       PIONEER HOSE CO                  124 MORGAN
# 779                    ST STEPHENS CHURCH            405 FREDERICK ST
# 810    E. PITTSBURGH COM CTR GYM REAR ENT             506 BESSEMER ST
# 844                   GREENOCK ELEMENTARY  1101 GREENOCK BUENA VIS RD
# 869                     CORAOPOLIS TOWERS                951 FIRST ST
# 888                       PIONEER HOSE CO               124 MORGAN ST
# 891           CALVERT MEMORIAL U P CHURCH                94 LOCUST ST
# 925                             STOWE VFD            548 BROADWAY AVE
# 934                  NEVILLE ISLAND V F D              5300 GRAND AVE
# 976             TARENTUM BOROUGH BUILDING                 318 2ND AVE
# 984           NEVILLE ISLAND V F D 1ST FL              5300 GRAND AVE
# 1026                  ST MARTIN DE PORRES               803 MARKET ST
# 1050                     PIONEER HOSE CO.               124 MORGAN ST
# 1063                  STOWE TWP MUNI BLDG            555 BROADWAY AVE
# 1169                            STOWE VFD            548 BROADWAY AVE
# 1170                ETNA BOROUGH BUILDING               437 BUTLER ST
# 1181         MT TROY VOL FIRE CO BALLROOM              33 LONSDALE ST
# 1182                          PRESTON VFD                369 HELEN ST
# 1205   APOSTOLIC FAITH CHURCH DINING HALL               44 MILLER AVE
# 1216                     RANKIN BORO BLDG             320 HAWKINS AVE
# 1250                CRESCENT TWP BUILDING           225 SPRING RUN RD
# 386          NaN            NaN         NaN            NaN         NaN
# 392          NaN            NaN         NaN            NaN         NaN
# 393            D             AP           D             AP           D
# 395            D             AP           D             AP           D
# 397          NaN            NaN         NaN            NaN           D
# 414          NaN            NaN         NaN            NaN           D
# 429          NaN            NaN         NaN            NaN         NaN
# 455          NaN            NaN         NaN            NaN           R
# 556          NaN            NaN         NaN            NaN           R
# 605          NaN            NaN         NaN            NaN         NaN
# ...
# 779   1.291849e+06  448125.031033         4.0        37.0        44.0
# 810   1.386126e+06  393463.989919        14.0        45.0        35.0
# 844   1.396201e+06  363122.386079        18.0        45.0        35.0
# 869   1.297873e+06  441835.782284        14.0        42.0        45.0
# 888   1.416292e+06  469250.386545         4.0        45.0        33.0
# 891   1.358232e+06  431849.345175        14.0        40.0        21.0
# 925   1.321458e+06  423758.200439        14.0        42.0        45.0
# 934   1.307001e+06  438524.626025        14.0        42.0        27.0
# 976   1.412674e+06  468037.042081        12.0        45.0        33.0
# 984   1.307001e+06  438524.626025        14.0        42.0        27.0
# 1026  1.378641e+06  376908.278815        14.0        45.0        35.0
# 1050  1.415011e+06  472418.131121         4.0        45.0        33.0
# 1063  1.322641e+06  423061.839044        14.0        42.0        45.0
# 1169  1.321453e+06  423777.570990        14.0        42.0        45.0
# 1170  1.358383e+06  432464.831278        14.0        40.0        21.0
# 1181  1.347453e+06  423457.308550        14.0        38.0        20.0
# 1182  1.325560e+06  427664.386106        14.0        42.0        27.0
# 1205  1.374231e+06  401627.858756        14.0        45.0        34.0
# 1216  1.378794e+06  399323.420136        14.0        45.0        34.0
# 1250  1.281726e+06  454792.099715        18.0        47.0        16.0
# 1253  1.379595e+06  395826.523221        14.0        45.0        34.0
# 1289  1.380020e+06  377575.998382        14.0        45.0        35.0
# 1296  1.405184e+06  461828.310698         4.0        45.0        33.0
# 1306  1.307001e+06  438524.626025        14.0        42.0        27.0
#
#      EditDate      MuniName                    OrigAddres      MWD  \
# 134      None         STOWE              1105 N VALLEY RD  2090900
# 143      None         STOWE              10 DESIDERIO WAY  2090100
# 147      None          ETNA                  19 WILSON ST  1390300
# 170      None  ELIZABETH TP         3333  FIRE STATION ST  1370300
# 180      None     SEWICKLEY                 200 WALNUT ST  1990100
# 271      None       RESERVE            3441 MOUNT TROY RD  1930300
# 359      None       RESERVE         3367 SPRING GARDEN RD  1930400
# 386      None  E PITTSBURGH              506 BESSEMER AVE  1330300
# 392      None      BRADDOCK                 125 COREY AVE  1130100
# 393      None  N VERSAILLES            90 PORT PERRY ROAD  1790700
# 395      None      BRADDOCK              415 SIXTH STREET  1130200
# 397      None         STOWE              831 BROADWAY AVE  2090600
# 414      None    MCKEESPORT                 704 MARKET ST  1680200
# 429      None      CRESCENT             225 SPRING RUN RD  1270100
# 455      None        AVALON            640 CALIFORNIA AVE  1030100
# 556      None       RESERVE                33 LONSDALE ST  1930100
# 605      None     EAST DEER               787 FREEPORT RD  1310200
# 611      None    MCKEESPORT                    601 6TH ST  1680500
# 627      None        RANKIN                27 HAMILTON ST  1920300
# 1181                33 LONSDALE ST                33 LONSDALE ST
# 1182                  369 HELEN ST                  369 HELEN ST
# 1205                 44 MILLER AVE                 44 MILLER AVE
# 1216               320 HAWKINS AVE               320 HAWKINS AVE
# 1250             225 SPRING RUN RD             225 SPRING RUN RD
# 1253                    445 6TH ST                    445 6TH ST
# 1289               523 SINCLAIR ST               523 SINCLAIR ST
# 1296               927 FREEPORT RD               927 FREEPORT RD
# 1306                5300 GRAND AVE                5300 GRAND AVE
#
#      addr_changed_17 addr_changed_18
# 134            False           False
# 143            False           False
# 147            False           False
# 170            False           False
# 180            False           False
# 271            False           False
# 359            False           False
# 386            False           False
# 392            False           False
# 393            False           False
# 395            False           False
# 397            False           False
# 414            False           False
# 429            False           False
# 455            False           False
# 556            False           False
# 605            False           False
# 611            False           False
# 627            False           False
# 648            False           False
# 769            False           False
# 779            False           False
# 810            False           False
# 844            False           False
# 869            False           False
# 888            False           False
# 891            False           False
# 925            False           False
# 934            False           False
# 976            False           False
# 984            False           False
# 1026           False           False
# 1050           False           False
# 1063           False           False
# 1169           False           False
# 1170           False           False
# 1181           False           False
# 1182           False           False
# 1205           False           False
# 1216           False           False
# 1250           False           False
# 1253           False           False
# 1289           False           False
# 1296           False           False
# 1306           False           False

# %%
pp_vdf_2018_um[['ID_Number','City_vdf','StreetNameComplete','House__','MWD_vdf','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript')
# Out:
#          ID_Number         City_vdf   StreetNameComplete House__    MWD_vdf  \
# 694   002308286-02        ASPINWALL               9TH ST     202  1020002.0
# 1301  102786984-02          MUNHALL          MARGARET ST    1334  1750003.0
# 1149  104048142-02       PITTSBURGH         MARTSOLF AVE     232  2230001.0
# 305   002086265-02       PITTSBURGH             GREER ST     608  1881507.0
# 647   002656899-02       PITTSBURGH        CHURCHLAND ST    6946  1881212.0
# 965   002314381-02       PITTSBURGH        LEMINGTON AVE    6962  1881211.0
# 1271  002417316-02       PITTSBURGH        LEMINGTON AVE    7274  1881213.0
# 926   002867727-02       PITTSBURGH        PRINCETON AVE     234  2230006.0
# 210   002197547-02      MC KEESPORT              PARK ST    1236  1680703.0
# 912   108216372-02      MC KEESPORT             IRWIN ST    2500  1680707.0
# 258   102440876-02       PITTSBURGH        CHALFONTE AVE     129  2230004.0
# 802   021281118-02       PITTSBURGH         ROTHPLETZ ST    1022  1882708.0
# 1267  020878800-02          MUNHALL              HILL ST    3410  1750007.0
# 466   002681614-02       PITTSBURGH              GIST ST      42  1880102.0
# 64    001984448-02          MUNHALL       VIRGINIA AVE W     202  1750006.0
# 584   002449185-02          OAKMONT          COLLEGE AVE     810  1810001.0
# 505   002918735-02          OAKMONT              11TH ST     724  1810002.0
# 1130  021400436-02         CLAIRTON          VAN KIRK ST     861  1230302.0
# 11    002112797-02         CLAIRTON           MARION CIR    1312  1230203.0
# 201   102733041-02       PITTSBURGH        CLAIRHAVEN ST    1209  1882805.0
# 1184  103564396-02       PITTSBURGH           WINSLOW ST    6412  1881202.0
# 306   001978060-02       PITTSBURGH           MANTON WAY     933  1881811.0
# 161                              WEST RIDGE CHURCH
# 1162               WEST VIEW ELEMENTARY SCHOOL GYM
# 939                  WEST VIEW ELEMENTARY SCHL GYM
# 781                               WEST VIEW TOWERS
# 822                        THE WESTERN PA HOSPITAL
# 744                        WESTINGHOUSE PARK BLDG.
# 1116               WESTMINSTER PRESBYTERIAN CHURCH
# 1101  WESTSIDE UNITED METHODIST CHURCH SOCIAL HALL
# 725   WESTSIDE UNITED METHODIST CHURCH SOCIAL HALL
# 529           WESTWOOD ELEMENTARY SCHOOL STAGE ENT
# 184                                WESTWOOD SCHOOL
# 63                            WHITAKER VOL FIRE CO
# 1210                          WHITAKER VOL FIRE CO
# 575               WHITE OAK MUNIC BLDG-COUNCIL CH.
# 1150                   WHITEHALL ELEMENTARY SCHOOL
# 409                    WHITEHALL ELEMENTARY SCHOOL
# 756                        WHITTIER SCHOOL RM. B-2
# 172                       WHITTIER SCHOOL-ROOM B-2
# 1104                               WIGHTMAN SCHOOL
# 664                                 WIGHTMAN ANNEX
# 211                      WILKINS SCHOOL 1ST FL ENT
# 1009                                TOWNSHIP BLDG.
# 682                   WILKINS TWP MUNI BLDG 1ST FL
# 905                WILKINSBURG BORO OWNED BUILDING
# 882                  WILKINSBURG SCHOOL ADMIN BLDG
# 128         WILKINSBURG SCHOOL ADMINISTRATION BLDG
# 2                    WILLIAM PITT UNION MAIN FLOOR
# 1317            WILSON PRESBYTERIAN CH SOCIAL HALL
# 609             WILSON PRESBYTERIAN CH SOCIAL HALL
# 72                  WM. MCKINLEY CITIZENS CTR. INC
# 1080                        WM PENN SCHOOL LIBRARY
# 326                WM S MOREHEAD TOWERS MAIN LOBBY
# 1141         WOLVARENA STADIUM VISITOR LOCKER ROOM
# 901                    WOODLAND HILLS JR HIGH WEST
# 422                    WOODLAND HILLS JR HIGH WEST
# 910         CHRISTIAN WAY ENTRANCE - WOOLSLAIR GYM
# 752            WQED FM ENT OFF 5TH HILLMAN CONF RM
# 887                                WWJD ASSOCIATES
# 23                    Y. M. C. A. ALL PURPOSE ROOM
# 969                   Y. M. C. A. MEMBERSHIP LOBBY
# 344                Allegheny Dwellings - BLDG. #15
# 902              ZION EVANGELICAL LUTHERIAN CHURCH
# 137              ZION EVANGELICAL LUTHERIAN CHURCH
# 470                              ZION LUTHERAN CH.
# 376                      ZION LUTHERAN CHURCH HALL
# 1322                       BLAINE HILL VOL FIRE CO
# 1323                     ELIZABETH FORWARD SR HIGH
#
#                             PollingPlaceDescript  \
# 694                       # 2 FIRE HOUSE STATION
# 1301                            #1  ENGINE HOUSE
# 1149                               #1 FIRE HOUSE
# 305                             #12 ENGINE HOUSE
# 647                             #15 ENGINE HOUSE
# 965                             #15 ENGINE HOUSE
# 1271                            #15 ENGINE HOUSE
# 926                              #2 ENGINE HOUSE
# 210                              #3 ENGINE HOUSE
# 912                              #3 ENGINE HOUSE
# 258                              #3 ENGINE HOUSE
# 802                            #34 TRUCK STATION
# 1267                 #4  FIRE HOUSE - DOWNSTAIRS
# 466                              #4 ENGINE HOUSE
# 331                   835 FIFTH AVE
# 831              217 COMMERCIAL AVE
# 1230             721 CALIFORNIA AVE
# 455              640 CALIFORNIA AVE
# ...                             ...
# 380             91 COMMONWEALTH AVE
# 336                   710 NORTH AVE
# 687                   710 NORTH AVE
# 161                  100 GORWOOD DR
# 1162                 47 CHALFANT ST
# 939                47 CHALFONTE AVE
# 781           808 WEST VIEW PARK DR
# 822             4800 FRIENDSHIP AVE
# 744               MURTLAND & THOMAS
# 1116  2040 WASHINGTON ROAD UPPER ST
# 1101               307 ATLANTIC AVE
# 725                307 ATLANTIC AVE
# 529                508 SHADYHILL RD
# 184                508 SHADYHILL RD
# 63                    239 CHURCH ST
# 1210                  239 CHURCH ST
# 575                2280 LINCOLN WAY
# 1150                  4900 CURRY RD
# 409                   4900 CURRY RD
# 756                  150 MERIDAN ST
# 172                  150 MERIDAN ST
# 1104                 5604 SOLWAY ST
# 664                  5604 SOLWAY ST
# 211             7604 CHARLESTON AVE
# 1009                  110 PEFFER RD
# 682                   110 PEFFER RD
# 905                    716 ROSS AVE
# 882                 718 WALLACE AVE
# 128                 718 WALLACE AVE
# 2                     3959 5TH  AVE
# 1317                     400 4TH ST
# 609                      400 4TH ST
# 72            SEVENTH & CENTER STS.
# 1080                 110 WOODLET LN
# 326                    375 CRAIG ST
# 1141                  1025 LYNN AVE
# 901                   7600 EVANS ST
# 422                   7600 EVANS ST
# 910                     501 40TH ST
# 752                    4802 5TH AVE
# 887                1329 FREEPORT RD
# 23                  2621 CENTRE AVE
# 969                 2621 CENTRE AVE
# 344                1610 SANDUSKY CT
# 902                     220 37TH ST
# 137                     220 37TH ST
# 470             11609 FRANKSTOWN RD
# 376             11609 FRANKSTOWN RD
# 1322                 409 OXFORD AVE
# 1323           1000 WEIGLES HILL RD
#
# [1324 rows x 14 columns]

# %%
pp_vdf_2018_um[pd.isna(pp_vdf_2018_um.MWD_vdf) | pd.isna(pp_vdf_2018_um.MWD2)][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MWD_vdf','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript')
# Out:
#          ID_Number    City_vdf StreetNameComplete House__ Zip_Code    MWD_vdf  \
# 493   002894558-02   ELIZABETH            OAK AVE     510    15037  1370700.0
# 110   104321361-02  PITTSBURGH       CHADWORTH CT    1408    15237  1450203.0
# 1322           NaN         NaN                NaN     NaN      NaN        NaN
# 1323           NaN         NaN                NaN     NaN      NaN        NaN
#
#           MuniName       MWD2 addr_changed_18                    LocName  \
# 493            NaN        NaN             NaN                        NaN
# 110            NaN        NaN             NaN                        NaN
# 1322  ELIZABETH TP  1370702.0           False    BLAINE HILL VOL FIRE CO
# 1323  ELIZABETH TP  1370701.0           False  ELIZABETH FORWARD SR HIGH
#
#          PollingPlaceDescript           PollPlaceCSZ          PollPlaceAdd  \
# 493   BLAINE HILL VOL FIRE CO   ELIZABETH, PA  15037       409 OXFORD AVE
# 110           ST JOHN NEUMANN  PITTSBURGH, PA  15237  2230 ROCHESTER ROAD
# 1322                      NaN                    NaN                   NaN
# 1323                      NaN                    NaN                   NaN
#
#           NewAddress_18_11      NewAddress_18_05
# 493                    NaN                   NaN
# 110                    NaN                   NaN
# 1322        409 OXFORD AVE        409 OXFORD AVE
# 1323  1000 WEIGLES HILL RD  1000 WEIGLES HILL RD

# %%
pp_vdf_2018_um[pd.isna(pp_vdf_2018_um.MWD_vdf) | pd.isna(pp_vdf_2018_um.MWD2)][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MWD_vdf','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript')

# %%
pp_vdf_2018_um[(pp_vdf_2018_um['addr_changed_18'].fillna(False))&~(pd.isna(pp_vdf_2018_um.StreetNameComplete))&(pp_vdf_2018_um.PollPlaceAdd.str.strip()!=pp_vdf_2018_um.NewAddress_18_11.str.strip())][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript').sort_values(['MuniName','MWD2'])
# Out:
#         ID_Number       City_vdf StreetNameComplete House__ Zip_Code  \
# 61   002232432-02         VERONA       MT CARMEL RD    8010    15147
# 577  001934343-02     PITTSBURGH         BEEHNER RD    4164    15217
# 252  108446264-02     PITTSBURGH          DUNLAP ST     431    15214
# 608  109157590-02  MC KEES ROCKS  PLEASANT RIDGE RD     403    15136
#
#        MuniName       MWD2 addr_changed_18                        LocName  \
# 61   PENN HILLS  1850201.0            True                 VICTORY TEMPLE
# 577  PITTSBURGH  1881506.0            True                   MAGEE CENTER
# 252  PITTSBURGH  1882616.0            True  RIVERVIEW PARK VISITOR CENTER
# 608       STOWE  2090202.0            True                OHIOVIEW TOWERS
#
#               PollingPlaceDescript           PollPlaceCSZ  \
# 61                  VICTORY TEMPLE  PITTSBURGH, PA  15235
# 577                   MAGEE CENTER  PITTSBURGH, PA  15217
# 252  RIVERVIEW PARK VISITOR CENTER  PITTSBURGH, PA  15214
# 608                OHIOVIEW TOWERS  PITTSBURGH, PA  15136
#
#               PollPlaceAdd    NewAddress_18_11     NewAddress_18_05
# 61       2024 GRAHAM BLVD     2824 GRAHAM BLVD   9601 FRANKSTOWN RD
# 577   745 GREENGFIELD AVE   745 GREENFIELD AVE  4156 WINTERBURN AVE
# 252      158 RIVERVIEW DR    158 RIVERVIEW AVE        RIVERVIEW AVE
# 608  92 PLEASANT RIDGE DR     250 JEFFERSON DR     251 JEFFERSON DR

# %%
pp_vdf_2018_um[(pp_vdf_2018_um['PollingPlaceDescript'].fillna('').str.contains('ARARAT')) | (pp_vdf_2018_um['LocName'].fillna('').str.contains('ARARAT'))][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript').sort_values(['MuniName','MWD2'])
# Out:
#          ID_Number    City_vdf StreetNameComplete House__ Zip_Code  \
# 1329           NaN         NaN                NaN     NaN      NaN
# 8     107205165-02  PITTSBURGH          MELLON ST     507    15206
#
#         MuniName       MWD2 addr_changed_18                     LocName  \
# 1329  PITTSBURGH  1881106.0            True  MT ARARAT COMMUMITY CENTER
# 8            NaN        NaN             NaN                         NaN
#
#             PollingPlaceDescript           PollPlaceCSZ       PollPlaceAdd  \
# 1329                         NaN                    NaN                NaN
# 8     MT ARARAT COMMUNITY CENTER  PITTSBURGH, PA  15206  745 N NEGLEY AVE
#
#       NewAddress_18_11 NewAddress_18_05
# 1329  751 N NEGLEY AVE  5799 HAMPTON ST
# 8                  NaN              NaN

# %%
pp_vdf_2018_um[(pp_vdf_2018_um['PollingPlaceDescript'].fillna('').str.contains('ARARAT')) | (pp_vdf_2018_um['LocName'].fillna('').str.contains('ARARAT'))]
# Out:
#          ID_Number Title Last_Name First_Name Middle_Name Suffix  Sex  \
# 8     107205165-02   NaN     AARON   DOMINIKA       LARAE    NaN  NaN
# 1329           NaN   NaN       NaN        NaN         NaN    NaN  NaN
#
#      Date_Of_Birth Date_Registered Voter_Status StatusChangeDate  \
# 8        3/13/1991       3/31/2016            A  3/31/2016 3:0:8
# 1329           NaN             NaN          NaN              NaN
#
#      Political_Party House__ HouseNoSuffix StreetNameComplete Apt__  \
# 8                  D     507                        MELLON ST     A
# 1329             NaN     NaN           NaN                NaN   NaN
#
#      Address_Line_2    City_vdf State Zip_Code MAddress_Line_1  \
# 8               NaN  PITTSBURGH    PA    15206             NaN
# 1329            NaN         NaN   NaN      NaN             NaN
#
#      MAddress_Line_2 MCity MState MZip_Code        PollingPlaceDescript  \
# 8                NaN   NaN    NaN       NaN  MT ARARAT COMMUNITY CENTER
# 1329             NaN   NaN    NaN       NaN                         NaN
#
#            PollPlaceAdd           PollPlaceCSZ Last_Date_Voted      Dist1  \
# 8     745 N NEGLEY AVE   PITTSBURGH, PA  15206       5/15/2018  1881117.0
# 1329                NaN                    NaN             NaN        NaN
#
#      Dist2 Dist3  Dist4  Dist5 Dist6 Dist7 Dist8  Dist9 Dist10  Dist11 Dist12  \
# 8      NaN  SC57  MN188  MD231  LG24  SN38  CG18  CPC09  CAC10     2.0    NaN
# 1329   NaN   NaN    NaN    NaN   NaN   NaN   NaN    NaN    NaN     NaN    NaN
#
#          Dist13  Dist14  Dist15 CustomData1   Date_Last_Changed PhoneNumHome  \
# 8     1881117-1     NaN     NaN         NaN  3/21/2016 11:14:46   4126380012
# 1329        NaN     NaN     NaN         NaN                 NaN          NaN
#
#      PR_05_15_18 PR_05_15_18_VM SP_03_13_18 SP_03_13_18_VM SP_03_06_18  \
# 8              D             AP         NaN            NaN         NaN
# 1329         NaN            NaN         NaN            NaN         NaN
#
#      SP_03_06_18_VM SP_01_23_18 SP_01_23_18_VM GN_11_07_17 GN_11_07_17_VM  \
# 8               NaN         NaN            NaN           D             AP
# 1329            NaN         NaN            NaN         NaN            NaN
#
#      PR_05_16_17 PR_05_16_17_VM GN_11_08_16 GN_11_08_16_VM PR_04_26_16  \
# 8              D             AP           D             AP         NaN
# 1329         NaN            NaN         NaN            NaN         NaN
#
#      PR_04_26_16_VM GN_11_03_15 GN_11_03_15_VM PR_05_19_15 PR_05_19_15_VM  \
# 8               NaN         NaN            NaN         NaN            NaN
# 1329            NaN         NaN            NaN         NaN            NaN
#
#      GN_11_04_14 GN_11_04_14_VM PR_05_20_14 PR_05_20_14_VM GN_11_05_13  \
# 8            NaN            NaN         NaN            NaN         NaN
# 1329         NaN            NaN         NaN            NaN         NaN
#
#      GN_11_05_13_VM PR_05_21_13 PR_05_21_13_VM GN_11_06_12 GN_11_06_12_VM  \
# 8               NaN         NaN            NaN         NaN            NaN
# 1329            NaN         NaN            NaN         NaN            NaN
#
#      SP_08_07_12 SP_08_07_12_VM PR_04_24_12 PR_04_24_12_VM GN_11_08_11  \
# 8            NaN            NaN         NaN            NaN         NaN
# 1329         NaN            NaN         NaN            NaN         NaN
#
#      GN_11_08_11_VM PR_05_17_11 PR_05_17_11_VM GN_11_02_10 GN_11_02_10_VM  \
# 8               NaN         NaN            NaN         NaN            NaN
# 1329            NaN         NaN            NaN         NaN            NaN
#
#                             address_raw  OBJECTID_1  OBJECTID   Muni  Ward  \
# 8     507 MELLON ST PITTSBURGH PA 15206         NaN       NaN    NaN   NaN
# 1329                                NaN       863.0     864.0  188.0  11.0
#
#       District                     LocName Prefix House Fraction  Street  \
# 8          NaN                         NaN    NaN   NaN      NaN     NaN
# 1329       6.0  MT ARARAT COMMUMITY CENTER      N   751     None  NEGLEY
#
#      Suffix1 Suffix2     City_pp UnitDesc UnitNumber         Zip Parcel  \
# 8        NaN     NaN         NaN      NaN        NaN         NaN    NaN
# 1329     AVE    None  PITTSBURGH     None       None  15206-2059   None
#
#      Accessible Leadman Region  Coordinate  Coordina_1  DistrictCO  \
# 8           NaN     NaN    NaN         NaN         NaN         NaN
# 1329       None      06      2         NaN         NaN        14.0
#
#       DistrictSE  DistrictLE EditDate    MuniName        OrigAddres      MWD  \
# 8            NaN         NaN      NaN         NaN               NaN      NaN
# 1329        38.0        24.0     None  PITTSBURGH  751 N NEGLEY AVE  1881106
#
#       POINT_X  POINT_Y       MWD2  NewAddress_18_11  \
# 8         NaN      NaN        NaN               NaN
# 1329      NaN      NaN  1881106.0  751 N NEGLEY AVE
#
#                                           geometry NewAddress_18_05  \
# 8                                              NaN              NaN
# 1329  POINT (-79.92685485117194 40.47139491990972)  5799 HAMPTON ST
#
#      NewAddress_17_05 addr_changed_17 addr_changed_18
# 8                 NaN             NaN             NaN
# 1329  5799 HAMPTON ST            True            True

# %%
pp_vdf_2018_um[(pp_vdf_2018_um['ID_Number'].fillna('').str.contains('002177240-02')) | (pp_vdf_2018_um['LocName'].fillna('').str.contains('BURCHFIELD '))][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript').sort_values(['MuniName','MWD2'])
# Out:
#         ID_Number      City_vdf StreetNameComplete House__ Zip_Code MuniName  \
# 997           NaN           NaN                NaN     NaN      NaN   SHALER
# 604  002177240-02  ALLISON PARK       LIMESTONE DR     700    15101      NaN
#
#           MWD2 addr_changed_18                         LocName  \
# 997  2020301.0           False  BURCHFIELD SCH-UPPER LEVEL GYM
# 604        NaN             NaN                             NaN
#
#                    PollingPlaceDescript PollPlaceCSZ         PollPlaceAdd  \
# 997                                 NaN          NaN                  NaN
# 604  BURCHFIELD SCHOOL UPPER LEVEL  GYM    PA  15101  1500 BURCHFIELD RD
#
#        NewAddress_18_11    NewAddress_18_05
# 997  1500 BURCHFIELD RD  1500 BURCHFIELD RD
# 604                 NaN                 NaN

# %%
pp_vdf_2018_um[(pp_vdf_2018_um['PollingPlaceDescript'].fillna('').str.contains('#4')) | (pp_vdf_2018_um['LocName'].fillna('').str.contains('#4'))][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript').sort_values(['MuniName','MWD2'])
# Out:
#          ID_Number         City_vdf StreetNameComplete House__ Zip_Code  \
# 1096           NaN              NaN                NaN     NaN      NaN
# 1114           NaN              NaN                NaN     NaN      NaN
# 1115           NaN              NaN                NaN     NaN      NaN
# 400   002681614-02       PITTSBURGH            GIST ST      42    15219
# 1366           NaN              NaN                NaN     NaN      NaN
# 913   020878800-02          MUNHALL            HILL ST    3410    15120
# 63    001984448-02          MUNHALL     VIRGINIA AVE W     202    15120
# 239   002953521-02  NATRONA HEIGHTS       CHINKAPIN DR     241    15065
# 715   020233862-02  NATRONA HEIGHTS          MEADOW ST    2707    15065
# 420   002955479-02     WEST MIFFLIN       IRWIN RUN RD     617    15122
#
#           MuniName       MWD2 addr_changed_18                     LocName  \
# 1096      HARRISON  1520301.0           False    HARRISON HILLS V.F.C. #4
# 1114       MUNHALL  1750006.0           False   #4 FIRE HOUSE- DOWNSTAIRS
# 1115       MUNHALL  1750007.0           False   #4 FIREHOUSE (DOWNSTAIRS)
# 400     PITTSBURGH  1880102.0           False             #4 ENGINE HOUSE
# 1366  WEST MIFFLIN  2220017.0           False  SKY VIEW W. MIFFLIN VFC #4
# 913            NaN        NaN             NaN                         NaN
# 63             NaN        NaN             NaN                         NaN
# 239            NaN        NaN             NaN                         NaN
# 715            NaN        NaN             NaN                         NaN
# 420            NaN        NaN             NaN                         NaN
#
#                 PollingPlaceDescript             PollPlaceCSZ  \
# 1096                             NaN                      NaN
# 1114                             NaN                      NaN
# 1115                             NaN                      NaN
# 400                  #4 ENGINE HOUSE    PITTSBURGH, PA  15213
# 1366                             NaN                      NaN
# 913      #4  FIRE HOUSE - DOWNSTAIRS       MUNHALL, PA  15120
# 63            #4 FIRE HOUSE UPSTAIRS            MUNHALL, PA
# 239         HARRISON HILLS V F C  #4    PITTSBURGH, PA  15065
# 715          HARRISON HILLS V F C #4    PITTSBURGH, PA  15065
# 420   SKY VIEW WEST MIFFLIN V F C #4  WEST MIFFLIN, PA  15122
#
#            PollPlaceAdd  NewAddress_18_11  NewAddress_18_05
# 1096                NaN  5300 FREEPORT RD  5300 FREEPORT RD
# 1114                NaN      3401 MAIN ST      3401 MAIN ST
# 1115                NaN      3401 MAIN ST      3401 MAIN ST
# 400    1324 FORBES AVE    1324 FORBES AVE   1324 FORBES AVE
# 1366                NaN      660 NOBLE DR      660 NOBLE DR
# 913       3401 MAIN ST                NaN               NaN
# 63        3401 MAIN ST                NaN               NaN
# 239   5300 FREEPORT RD                NaN               NaN
# 715   5300 FREEPORT RD                NaN               NaN
# 420       660 NOBLE DR                NaN               NaN

# %%
len(pp_vdf_2018_um[(~pd.isna(pp_vdf_2018_um['LocName'])&~(pd.isna(pp_vdf_2018_um['PollingPlaceDescript'])))][['ID_Number','City_vdf','StreetNameComplete','House__','Zip_Code','MuniName','MWD2','addr_changed_18','LocName','PollingPlaceDescript','PollPlaceCSZ','PollPlaceAdd','NewAddress_18_11','NewAddress_18_05']].sort_values('PollingPlaceDescript').sort_values(['MuniName','MWD2']))
# Out:
# 517

# %% [markdown]
# # Debug

# %%
voter_map['021339238-02']
# Out:
# {'DOB': '7/22/1989',
#  'addresses': {'2009-07': '3725 SUTHERLAND DR PITTSBURGH PA 15213',
#   '2017-11': '3725 SUTHERLAND DR PITTSBURGH PA 15213',
#   '2018-03': '3725 SUTHERLAND DR PITTSBURGH PA 15213',
#   '2018-08': '3725 SUTHERLAND DR PITTSBURGH PA 15213'},
#  'reg_date': datetime.datetime(2008, 4, 8, 0, 0),
#  'reg_info': {'2009-07': {'party': 'D', 'status': 'A'},
#   '2017-11': {'party': 'D', 'status': 'I'},
#   '2018-03': {'party': 'D', 'status': 'I'},
#   '2018-08': {'party': 'D', 'status': 'I'}}}

# %%
voter_map['002171843-02']
# Out:
# {'DOB': '8/19/1944',
#  'addresses': {'2017-11': '137 WILTSHIRE CIR MONROEVILLE PA 15146',
#   '2018-03': '137 WILTSHIRE CIR MONROEVILLE PA 15146',
#   '2018-08': '137 WILTSHIRE CIR MONROEVILLE PA 15146'},
#  'reg_date': '10/1/1974',
#  'reg_info': {'2017-11': {'party': 'R', 'status': 'A'},
#   '2018-03': {'party': 'R', 'status': 'A'},
#   '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
# Find voters who changed affilliation
changed_vids = []
for vid in voter_map:
    vrec = voter_map[vid]
    if('2018-08' in vrec['addresses'] and not '15213' in vrec['addresses']['2018-08']):
        continue
    affil_changed = False
    month_strs = sorted(vrec['reg_info'].keys())
    affil_init = vrec['reg_info'][month_strs[0]]
    for i in range(1,len(month_strs)):
        if(vrec['reg_info'][month_strs[i]]!=affil_init):
            changed_vids.append(vid)
            print "%s changed: [%s]=%r -> [%s]=%r\n\t%s\n\t%s" % (vid, month_strs[0],affil_init, 
                                                                  month_strs[i],vrec['reg_info'][month_strs[i]],
                                                                  vrec['addresses'][month_strs[0]],
                                                                  vrec['addresses'][month_strs[i]])

# %%
colnames_2018 = list(vdf_2018_08)

# %%
colnames_2018
# Out:
# ['Title',
#  'Last_Name',
#  'First_Name',
#  'Middle_Name',
#  'Suffix',
#  'Sex',
#  'Date_Of_Birth',
#  'Date_Registered',
#  'Voter_Status',
#  'StatusChangeDate',
#  'Political_Party',
#  'House__',
#  'HouseNoSuffix',
#  'StreetNameComplete',
#  'Apt__',
#  'Address_Line_2',
#  'City',
#  'State',
#  'Zip_Code',
#  'MAddress_Line_1',
#  'MAddress_Line_2',
#  'MCity',
#  'MState',
#  'MZip_Code',
#  'PollingPlaceDescript',
#  'PollPlaceAdd',
#  'PollPlaceCSZ',
#  'Last_Date_Voted',
#  'Dist1',
#  'Dist2',
#  'Dist3',
#  'Dist4',
#  'Dist5',
#  'Dist6',
#  'Dist7',
#  'Dist8',
#  'Dist9',
#  'Dist10',
#  'Dist11',
#  'Dist12',
#  'Dist13',
#  'Dist14',
#  'Dist15',
#  'CustomData1',
#  'Date_Last_Changed',
#  'PhoneNumHome',
#  'PR_05_15_18',
#  'PR_05_15_18_VM',
#  'SP_03_13_18',
#  'SP_03_13_18_VM',
#  'SP_03_06_18',
#  'SP_03_06_18_VM',
#  'SP_01_23_18',
#  'SP_01_23_18_VM',
#  'GN_11_07_17',
#  'GN_11_07_17_VM',
#  'PR_05_16_17',
#  'PR_05_16_17_VM',
#  'GN_11_08_16',
#  'GN_11_08_16_VM',
#  'PR_04_26_16',
#  'PR_04_26_16_VM',
#  'GN_11_03_15',
#  'GN_11_03_15_VM',
#  'PR_05_19_15',
#  'PR_05_19_15_VM',
#  'GN_11_04_14',
#  'GN_11_04_14_VM',
#  'PR_05_20_14',
#  'PR_05_20_14_VM',
#  'GN_11_05_13',
#  'GN_11_05_13_VM',
#  'PR_05_21_13',
#  'PR_05_21_13_VM',
#  'GN_11_06_12',
#  'GN_11_06_12_VM',
#  'SP_08_07_12',
#  'SP_08_07_12_VM',
#  'PR_04_24_12',
#  'PR_04_24_12_VM',
#  'GN_11_08_11',
#  'GN_11_08_11_VM',
#  'PR_05_17_11',
#  'PR_05_17_11_VM',
#  'GN_11_02_10',
#  'GN_11_02_10_VM',
#  'address_raw']

# %%
vdf_2018_08[0:10]
# Out:
#              Title Last_Name First_Name Middle_Name Suffix  Sex Date_Of_Birth  \
# ID_Number
# 108927574-02   NaN     AABAN       ZAIN           A    NaN    M     2/16/1999
# 103133442-02   NaN   AAGAARD      MARIT         NaN    NaN  NaN    10/17/1975
# 102892955-02   NaN     AAMIR      TALHA         NaN    NaN    F    12/28/1991
# 020340986-02   NaN     AARON     ANDREA         NaN    NaN    F     8/11/1983
# 003007111-02   NaN     AARON    BARBARA           A    NaN    F     7/27/1954
# 020029602-02   NaN     AARON    CHARLES           F    NaN    M     6/15/1938
# 002171843-02   NaN     AARON      DAVID           G    NaN    M     8/19/1944
# 002184557-02   NaN     AARON    DEBORAH           S    NaN    F      5/1/1958
# 107205165-02   NaN     AARON   DOMINIKA       LARAE    NaN  NaN     3/13/1991
# 102729360-02   NaN     AARON   DONIELLE     CATRICE    NaN    F     5/24/1970
#
#              Date_Registered Voter_Status   StatusChangeDate Political_Party  \
# ID_Number
# 108927574-02       1/26/2018            A    1/26/2018 3:0:3               D
# 103133442-02       7/24/2011            A    7/24/2011 6:0:0               D
# 102892955-02       9/28/2010            I  1/21/2016 12:6:44              NF
# 020340986-02      10/14/2004            A  8/15/2011 9:32:47              NF
# 003007111-02        3/1/1984            A     3/1/1984 0:0:0               R
# 020029602-02      10/25/2003            A   10/25/2003 2:0:1              NO
# 002171843-02       10/1/1974            A    10/1/1974 0:0:0               R
# 002184557-02        4/1/1983            A    10/9/2014 6:0:9               D
# 107205165-02       3/31/2016            A    3/31/2016 3:0:8               D
# 102729360-02        3/9/2010            A     3/9/2010 6:0:2               D
#
#              House__ HouseNoSuffix   StreetNameComplete Apt__ Address_Line_2  \
# ID_Number
# 108927574-02     155                          SENECA PL   NaN            NaN
# 103133442-02     427                          CENTER ST   NaN            NaN
# 102892955-02    3990             A  5TH AVE PITT TOWERS   NaN            NaN
# 020340986-02    5602                          DUNCAN ST   NaN            NaN
# 003007111-02     520                         HALLOCK ST   NaN            NaN
# 020029602-02     100                SOUTHERN HILANDS DR   NaN            NaN
# 002171843-02     137                      WILTSHIRE CIR   NaN            NaN
# 002184557-02     328                          9TH AVE E   NaN            NaN
# 107205165-02     507                          MELLON ST     A            NaN
# 102729360-02      21                      WOODLAND RD W   NaN            NaN
#
#                      City State Zip_Code MAddress_Line_1 MAddress_Line_2  \
# ID_Number
# 108927574-02         MARS    PA    16046             NaN             NaN
# 103133442-02   PITTSBURGH    PA    15221             NaN             NaN
# 102892955-02   PITTSBURGH    PA    15213             NaN             NaN
# 020340986-02   PITTSBURGH    PA    15201             NaN             NaN
# 003007111-02   PITTSBURGH    PA    15211             NaN             NaN
# 020029602-02   PITTSBURGH    PA    15241             NaN             NaN
# 002171843-02  MONROEVILLE    PA    15146             NaN             NaN
# 002184557-02    HOMESTEAD    PA    15120             NaN             NaN
# 107205165-02   PITTSBURGH    PA    15206             NaN             NaN
# 102729360-02   PITTSBURGH    PA    15232             NaN             NaN
#
#              MCity MState MZip_Code  \
# ID_Number
# 108927574-02   NaN    NaN       NaN
# 103133442-02   NaN    NaN       NaN
# 102892955-02   NaN    NaN       NaN
# 020340986-02   NaN    NaN       NaN
# 003007111-02   NaN    NaN       NaN
# 020029602-02   NaN    NaN       NaN
# 002171843-02   NaN    NaN       NaN
# 002184557-02   NaN    NaN       NaN
# 107205165-02   NaN    NaN       NaN
# 102729360-02   NaN    NaN       NaN
#
#                                     PollingPlaceDescript  \
# ID_Number
# 108927574-02                  REGIONAL LEARNING ALLIANCE
# 103133442-02             SISTER THEA BOWMAN SCHOOL LOBBY
# 102892955-02                   WILLIAM PITT UNION 1ST FL
# 020340986-02                             ENGINE HOUSE #7
# 003007111-02                  WEST END SR COM CTR 1ST FL
# 020029602-02                            WESLEY INSTITUTE
# 002171843-02           UNIVERSITY PARK ELEMENTARY SCHOOL
# 002184557-02          HOMESTEAD APTS COMMUNITY RM BLDG C
# 107205165-02                 ST ANDREWS EPISCOPAL CHURCH
# 102729360-02  CHATHAM UNIVERSITY LAUGHLIN HALL WELKER RM
#
#                          PollPlaceAdd                          PollPlaceCSZ  \
# ID_Number
# 108927574-02  850 CRANBERRY WOODS RD                  WARRENDALE, PA  16066
# 103133442-02         721 REBECCA AVE                  PITTSBURGH, PA  15221
# 102892955-02         3959 FORBES AVE                  PITTSBURGH, PA  15213
# 020340986-02        4603 STANTON AVE                  PITTSBURGH, PA  15201
# 003007111-02            80 WABASH ST        PITTSBURGH               , PA
# 020029602-02         245 JOHNSTON RD                  PITTSBURGH, PA  15241
# 002171843-02             320 NOEL DR                      MONROEVILLE, PA
# 002184557-02           441 E 8TH AVE                   HOMESTEAD, PA  15120
# 107205165-02         5801 HAMPTON ST                  PITTSBURGH, PA  15206
# 102729360-02         106 WOODLAND RD   PITTSBURGH               , PA  15232
#
#              Last_Date_Voted      Dist1  Dist2 Dist3  Dist4  Dist5 Dist6  \
# ID_Number
# 108927574-02             NaN  1650005.0    NaN  SC50  MN165  MD212  LG28
# 103133442-02       5/15/2018  2280205.0    NaN  SC83  MN228  MD210  LG24
# 102892955-02       11/2/2010  1880408.0    NaN  SC58  MN188  MD227  LG23
# 020340986-02       11/8/2016  1881006.0    NaN  SC56  MN188  MD231  LG21
# 003007111-02       11/8/2016  1882003.0    NaN  SC63  MN188  MD313  LG27
# 020029602-02       3/13/2018  2150502.0    NaN  SC77  MN215  MD220  LG40
# 002171843-02       11/8/2016  1710304.0    NaN  SC29  MN171  MD207  LG25
# 002184557-02       11/8/2016  1550101.0    NaN  SC95  MN155  MD215  LG34
# 107205165-02       5/15/2018  1881117.0    NaN  SC57  MN188  MD231  LG24
# 102729360-02       11/6/2012  1881403.0    NaN  SC58  MN188  MD235  LG23
#
#              Dist7 Dist8  Dist9 Dist10  Dist11  Dist12     Dist13  Dist14  \
# ID_Number
# 108927574-02  SN38  CD17  CPC00  CAC02     2.0     NaN  1650005-1     NaN
# 103133442-02  SN43  CG18  CPC00  CAC10     2.0     NaN  2280205-1     NaN
# 102892955-02  SN43  CG18  CPC03  CAC10     2.0     NaN  1880408-1     NaN
# 020340986-02  SN42  CG18  CPC07  CAC13     2.0     NaN  1881006-1     NaN
# 003007111-02  SN42  CG18  CPC02  CAC12     2.0     NaN  1882003-1     NaN
# 020029602-02  SN37  CG18  CPC00  CAC05     2.0     NaN  2150502-1     NaN
# 002171843-02  SN45  CG18  CPC00  CAC08     2.0     NaN  1710304-1     NaN
# 002184557-02  SN43  CG18  CPC00  CAC11     2.0     NaN  1550101-1     NaN
# 107205165-02  SN38  CG18  CPC09  CAC10     2.0     NaN  1881117-1     NaN
# 102729360-02  SN43  CG18  CPC08  CAC11     2.0     NaN  1881403-1     NaN
#
#               Dist15 CustomData1   Date_Last_Changed PhoneNumHome PR_05_15_18  \
# ID_Number
# 108927574-02     NaN         NaN   7/10/2018 9:14:41          NaN         NaN
# 103133442-02     NaN         NaN   7/14/2011 8:45:27          NaN           D
# 102892955-02     NaN         NaN   9/19/2010 8:43:36          NaN         NaN
# 020340986-02     NaN   123820540   8/15/2011 9:32:47   4126091988         NaN
# 003007111-02     NaN   115112799     9/20/2000 0:0:0          NaN         NaN
# 020029602-02     NaN   123546186  10/22/2003 15:57:8          NaN         NaN
# 002171843-02     NaN   110509262     7/15/1982 0:0:0          NaN         NaN
# 002184557-02     NaN   114510332   10/8/2014 9:25:49          NaN         NaN
# 107205165-02     NaN         NaN  3/21/2016 11:14:46   4126380012           D
# 102729360-02     NaN         NaN    8/2/2011 8:59:31          NaN         NaN
#
#              PR_05_15_18_VM SP_03_13_18 SP_03_13_18_VM SP_03_06_18  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP         NaN            NaN         NaN
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02            NaN         NaN            NaN         NaN
# 020029602-02            NaN          NO             AP         NaN
# 002171843-02            NaN         NaN            NaN         NaN
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02             AP         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN         NaN
#
#              SP_03_06_18_VM SP_01_23_18 SP_01_23_18_VM GN_11_07_17  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02            NaN         NaN            NaN           D
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02            NaN         NaN            NaN         NaN
# 020029602-02            NaN         NaN            NaN          NO
# 002171843-02            NaN         NaN            NaN         NaN
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN           D
# 102729360-02            NaN         NaN            NaN         NaN
#
#              GN_11_07_17_VM PR_05_16_17 PR_05_16_17_VM GN_11_08_16  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP           D             AP           D
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN          NF
# 003007111-02            NaN         NaN            NaN           R
# 020029602-02             AP         NaN            NaN          NO
# 002171843-02            NaN         NaN            NaN           R
# 002184557-02            NaN         NaN            NaN           D
# 107205165-02             AP           D             AP           D
# 102729360-02            NaN         NaN            NaN         NaN
#
#              GN_11_08_16_VM PR_04_26_16 PR_04_26_16_VM GN_11_03_15  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP           D             AP         NaN
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02             AP         NaN            NaN         NaN
# 003007111-02             AP         NaN            NaN         NaN
# 020029602-02             AP         NaN            NaN          NO
# 002171843-02             AP         NaN            NaN         NaN
# 002184557-02             AP         NaN            NaN         NaN
# 107205165-02             AP         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN         NaN
#
#              GN_11_03_15_VM PR_05_19_15 PR_05_19_15_VM GN_11_04_14  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02            NaN           D             AP           D
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02            NaN         NaN            NaN           R
# 020029602-02             AP         NaN            NaN          NO
# 002171843-02            NaN         NaN            NaN           R
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN         NaN
#
#              GN_11_04_14_VM PR_05_20_14 PR_05_20_14_VM GN_11_05_13  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP         NaN            NaN         NaN
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02             AP         NaN            NaN         NaN
# 020029602-02             AP         NaN            NaN          NO
# 002171843-02             AP           R             AP         NaN
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN         NaN
#
#              GN_11_05_13_VM PR_05_21_13 PR_05_21_13_VM GN_11_06_12  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02            NaN           D             AP           D
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02            NaN         NaN            NaN           R
# 020029602-02             AP         NaN            NaN          NO
# 002171843-02            NaN         NaN            NaN           R
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN           D
#
#              GN_11_06_12_VM SP_08_07_12 SP_08_07_12_VM PR_04_24_12  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP         NaN            NaN           D
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02             AP         NaN            NaN         NaN
# 020029602-02             AP         NaN            NaN         NaN
# 002171843-02             AP         NaN            NaN           R
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN         NaN
# 102729360-02             AP         NaN            NaN         NaN
#
#              PR_04_24_12_VM GN_11_08_11 GN_11_08_11_VM PR_05_17_11  \
# ID_Number
# 108927574-02            NaN         NaN            NaN         NaN
# 103133442-02             AP           D             AP         NaN
# 102892955-02            NaN         NaN            NaN         NaN
# 020340986-02            NaN         NaN            NaN         NaN
# 003007111-02            NaN         NaN            NaN         NaN
# 020029602-02            NaN          NO             AP         NaN
# 002171843-02             AP         NaN            NaN         NaN
# 002184557-02            NaN         NaN            NaN         NaN
# 107205165-02            NaN         NaN            NaN         NaN
# 102729360-02            NaN         NaN            NaN         NaN
#
#              PR_05_17_11_VM GN_11_02_10 GN_11_02_10_VM  \
# ID_Number
# 108927574-02            NaN         NaN            NaN
# 103133442-02            NaN         NaN            NaN
# 102892955-02            NaN          NF             AP
# 020340986-02            NaN         NaN            NaN
# 003007111-02            NaN           R             AP
# 020029602-02            NaN          NO             AP
# 002171843-02            NaN           R             AP
# 002184557-02            NaN         NaN            NaN
# 107205165-02            NaN         NaN            NaN
# 102729360-02            NaN         NaN            NaN
#
#                                               address_raw
# ID_Number
# 108927574-02                  155 SENECA PL MARS PA 16046
# 103133442-02            427 CENTER ST PITTSBURGH PA 15221
# 102892955-02           3990 FIFTH AVE PITTSBURGH PA 15213
# 020340986-02           5602 DUNCAN ST PITTSBURGH PA 15201
# 003007111-02           520 HALLOCK ST PITTSBURGH PA 15211
# 020029602-02  100 SOUTHERN HILANDS DR PITTSBURGH PA 15241
# 002171843-02       137 WILTSHIRE CIR MONROEVILLE PA 15146
# 002184557-02             328 9TH AVE E HOMESTEAD PA 15120
# 107205165-02            507 MELLON ST PITTSBURGH PA 15206
# 102729360-02         21 WOODLAND RD W PITTSBURGH PA 15232

# %%
colnames_2017 = list(vdf_2017_11)

# %%
colnames_2017
# Out:
# ['Title',
#  'Last_Name',
#  'First_Name',
#  'Middle_Name',
#  'Suffix',
#  'Sex',
#  'Date_Of_Birth',
#  'Date_Registered',
#  'Voter_Status',
#  'StatusChangeDate',
#  'Political_Party',
#  'House__',
#  'HouseNoSuffix',
#  'StreetNameComplete',
#  'Apt__',
#  'Address_Line_2',
#  'City',
#  'State',
#  'Zip_Code',
#  'MAddress_Line_1',
#  'MAddress_Line_2',
#  'MCity',
#  'MState',
#  'MZip_Code',
#  'PollingPlaceDescript',
#  'PollPlaceAdd',
#  'PollPlaceCSZ',
#  'Last_Date_Voted',
#  'Dist1',
#  'Dist2',
#  'Dist3',
#  'Dist4',
#  'Dist5',
#  'Dist6',
#  'Dist7',
#  'Dist8',
#  'Dist9',
#  'Dist10',
#  'Dist11',
#  'Dist12',
#  'Dist13',
#  'Dist14',
#  'Dist15',
#  'CustomData1',
#  'Date_Last_Changed',
#  'PhoneNumHome',
#  'GN_11_07_17',
#  'GN_11_07_17_VM',
#  'PR_05_16_17',
#  'PR_05_16_17_VM',
#  'GN_11_08_16',
#  'GN_11_08_16_VM',
#  'PR_04_26_16',
#  'PR_04_26_16_VM',
#  'GN_11_03_15',
#  'GN_11_03_15_VM',
#  'PR_05_19_15',
#  'PR_05_19_15_VM',
#  'GN_11_04_14',
#  'GN_11_04_14_VM',
#  'PR_05_20_14',
#  'PR_05_20_14_VM',
#  'GN_11_05_13',
#  'GN_11_05_13_VM',
#  'PR_05_21_13',
#  'PR_05_21_13_VM',
#  'GN_11_06_12',
#  'GN_11_06_12_VM',
#  'SP_08_07_12',
#  'SP_08_07_12_VM',
#  'PR_04_24_12',
#  'PR_04_24_12_VM',
#  'GN_11_08_11',
#  'GN_11_08_11_VM',
#  'PR_05_17_11',
#  'PR_05_17_11_VM',
#  'GN_11_02_10',
#  'GN_11_02_10_VM',
#  'PR_05_18_10',
#  'PR_05_18_10_VM',
#  'GN_11_03_09',
#  'GN_11_03_09_VM',
#  'PR_05_19_09',
#  'PR_05_19_09_VM',
#  'GN_11_04_08',
#  'GN_11_04_08_VM',
#  'PR_04_22_08',
#  'PR_04_22_08_VM',
#  'GN_11_06_07',
#  'GN_11_06_07_VM',
#  'PR_05_15_07',
#  'PR_05_15_07_VM',
#  'GN_11_07_06',
#  'GN_11_07_06_VM',
#  'PR_05_16_06',
#  'PR_05_16_06_VM',
#  'GN_11_08_05',
#  'GN_11_08_05_VM',
#  'PR_05_17_05',
#  'PR_05_17_05_VM',
#  'GN_11_02_04',
#  'GN_11_02_04_VM',
#  'PR_04_27_04',
#  'PR_04_27_04_VM',
#  'CT_11_04_03',
#  'CT_11_04_03_VM',
#  'PR_05_20_03',
#  'PR_05_20_03_VM',
#  'GN_11_05_02',
#  'GN_11_05_02_VM',
#  'PR_05_21_02',
#  'PR_05_21_02_VM',
#  'GN_11_06_01',
#  'GN_11_06_01_VM',
#  'PR_05_15_01',
#  'PR_05_15_01_VM',
#  'GN_11_07_00',
#  'GN_11_07_00_VM',
#  'PR_04_04_00',
#  'PR_04_04_00_VM',
#  'GN_11_02_99',
#  'GN_11_02_99_VM',
#  'PR_05_18_99',
#  'PR_05_18_99_VM',
#  'GN_11_03_98',
#  'GN_11_03_98_VM',
#  'address_raw']

# %%
945667*3
# Out:
# 2837001

# %% [markdown]
# # Save/load voter_map

# %%
# Try to save voter_map 
#   voter_map_17_18_18.pickle has 'reg_date' as a string
#   voter_map_17_18_18_b.pickle has 'reg_date' converted to datetime
#   voter_map_09_17_18_18_c.pickle has data from 2009-07
#   voter_map_09_17_18_18_d.pickle has census_block info (full for 15213, partial for all, need to do TODO addresses)
#   voter_map_09_17_18_18_e.pickle has census_block info for all
#   voter_map_09_17_18_18_f.pickle has census_block latlon info for all

import pickle
voter_map_file_path = 'voters/voter_map_09_17_18_18_f.pickle'

# %%
# Save out voter_map
with open(voter_map_file_path, 'wb') as handle:
    pickle.dump(voter_map, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load in voter_map
with open(voter_map_file_path, 'rb') as handle:
    voter_map = pickle.load(handle)

# %% [markdown]
# # Census Blocks

# %%
# The following was copied from http://localhost:8820/notebooks/projects/demographics/Voting-2018-obsolete-CB-proc.ipynb
# and has not been tested here yet
def addr_to_coords(caddr):
    #caddr = canonicalize_string(addr)
    # Try coords from census first
    coords = get_canonical_coords(caddr)
    if(not coords):
        # Didn't work, try google
        coords = get_canonical_coords_google(caddr)
    #if(coords):
    #    print "%s: %s" % (caddr,coords)
    return coords

# %%
# Test
addr_to_coords('3725 SUTHERLAND DR PITTSBURGH PA 15213')

# %%
# Create a GeoDataFrame that just has voter id and raw_address and has addr_to_coords as geometry
vdf_2018_08_gj = gpd.GeoDataFrame(vdf_2018_08['address_raw'], geometry=vdf_2018_08['address_raw'].apply(addr_to_coords),crs={'init': 'epsg:4326'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-26d063dd9238> in <module>()
#       1 # Create a GeoDataFrame that just has voter id and raw_address and has addr_to_coords as geometry
# ----> 2 vdf_2018_08_gj = gpd.GeoDataFrame(vdf_2018_08['address_raw'], geometry=vdf_2018_08['address_raw'].apply(addr_to_coords),crs={'init': 'epsg:4326'})
#
# NameError: name 'vdf_2018_08' is not defined

# %%
# Load geojson for census blocks in Allegheny County, find census block for each voter
ac_cb_gj = gpd.read_file('allegheny_county/tl_2010_42003_tabblock10.geojson')

# %%
# Get just the ones that geolocate successfully and do a spatial join with the census blocks
vdf_ok_2018_08_gj = vdf_2018_08_gj[(~pd.isna(vdf_2018_08_gj.geometry))]
vdf_ok_cb_2018_08_gj = gpd.sjoin(vdf_ok_2018_08_gj, ac_cb_gj, how="inner", op='within')

# %%
# Keep only the index, 'address_raw', 'GEOID10', and geometry 
vdf_ok_cb_2018_08_out_gj = gpd.GeoDataFrame(vdf_ok_cb_2018_08_gj[['address_raw','GEOID10']], geometry=vdf_ok_cb_2018_08_gj.geometry, crs={'init': 'epsg:4326'})

# %%
# Save to file
vdf_ok_cb_2018_08_out_gj.to_file('voters/vdf_ok_cb_2018_08_out_gj.geojson', driver="GeoJSON")

# %%
# Load geojson for vdf_ok_cb_2018_08_out_gj
vdf_ok_cb_2018_08_out_gj = gpd.read_file('voters/vdf_ok_cb_2018_08_out_gj.geojson')

# %%
# Save the ones that do not geolocate successfully 
non_geolocatable_addrs = vdf_2018_08_gj[(pd.isna(vdf_2018_08_gj.geometry))].address_raw.unique()
numpy.save("voters/non_geolocatable_addrs.npy",non_geolocatable_addrs)

# %%
# Load the ones that do not geolocate successfully 
non_geolocatable_addrs = numpy.load("voters/non_geolocatable_addrs.npy")

# %%
len(non_geolocatable_addrs)
# Out:
# 9258

# %%
list(vdf_ok_cb_2018_08_out_gj)
# Out:
# [u'address_raw', u'GEOID10', 'geometry']

# %%
# Get rid of duplicates
addrs_to_cb_2018 = vdf_ok_cb_2018_08_out_gj[~vdf_ok_cb_2018_08_out_gj['address_raw'].duplicated()].reset_index().copy()

# %%
len(addrs_to_cb_2018)
# Out:
# 410370

# %%
addrs_to_cb_2018[0:10]
# Out:
#    index                          address_raw          GEOID10  \
# 0      0          155 SENECA PL MARS PA 16046  420034110001038
# 1      1           322 OSONA LN MARS PA 16046  420034110001038
# 2      2        244 VENANGO TRL MARS PA 16046  420034110001038
# 3      3        272 VENANGO TRL MARS PA 16046  420034110001038
# 4      4      647 CHILLIWACK LN MARS PA 16046  420034110001038
# 5      5        270 VENANGO TRL MARS PA 16046  420034110001038
# 6      7          119 SENECA PL MARS PA 16046  420034110001038
# 7      9           318 OSONA LN MARS PA 16046  420034110001038
# 8     11  924 PENTICON LN WARRENDALE PA 15086  420034110001038
# 9     12         828 ONEIDA CIR MARS PA 16046  420034110001038
#
#                                        geometry
# 0  POINT (-80.08404760000001 40.66922539999999)
# 1         POINT (-80.08978430000001 40.6685968)
# 2         POINT (-80.08884759999999 40.6676426)
# 3                POINT (-80.0901774 40.6685874)
# 4                 POINT (-80.0858873 40.661459)
# 5                POINT (-80.0901767 40.6684939)
# 6                POINT (-80.0862948 40.6715325)
# 7         POINT (-80.08979520000001 40.6689412)
# 8                POINT (-80.0794375 40.6617756)
# 9                POINT (-80.0859794 40.6605851)

# %%
def process_addrs_to_cb_into_cam(df):
    start=arrow.now()
    chunk_start_time=start
    chunk_size=1000

    for i in range(0,len(df)):
        addr = df['address_raw'].iloc[i]
        cb = df['GEOID10'].iloc[i]
        latlon = df.geometry[i]
        
        if(not addr in canonical_addr_map):
            # This is a new entry to this canonical_addr_map
            canonical_addr_map[addr]={'canonical_in_census_db':False,'canonical_in_google_db': False, 
                                       'census_value':None, 'google_value':None}

            
        canonical_addr_map[addr]['census_block']=cb
        canonical_addr_map[addr]['latlon']=latlon
        
        # Handle periodic debug message
        if((i%chunk_size)==0 and i>0):
            print "%d-%d: processing %r, %s time elapsed" %(i-(chunk_size-1), i, addr, arrow.now()-chunk_start_time)
            addcnt=0
            chunk_start_time=arrow.now()

    end=arrow.now()
    print "Processing took %s for %d addresses" % (str(end-start), len(df))

# %%
process_addrs_to_cb_into_cam(addrs_to_cb_2018)
# Out:
# 1-1000: processing u'3150 AVALON ST PITTSBURGH PA 15219', 0:00:00.149945 time elapsed
# 1001-2000: processing u'7058 HIGHLAND CREEK DR BRIDGEVILLE PA 15017', 0:00:00.117282 time elapsed
# 2001-3000: processing u'114 BUCKINGHAM DR PITTSBURGH PA 15237', 0:00:00.110578 time elapsed
# 3001-4000: processing u'572 ORCHARD AVE PITTSBURGH PA 15202', 0:00:00.132115 time elapsed
# 4001-5000: processing u'907 SONIE DR SEWICKLEY PA 15143', 0:00:00.121692 time elapsed
# 5001-6000: processing u'338 COBBLESTONE CIR MC KEES ROCKS PA 15136', 0:00:00.111981 time elapsed
# 6001-7000: processing u'322 VICTORIA DR MONROEVILLE PA 15146', 0:00:00.103223 time elapsed
# 7001-8000: processing u'4180 BATTLE RIDGE RD MC DONALD PA 15057', 0:00:00.115359 time elapsed
# 8001-9000: processing u'1112 CENTER AVE VERONA PA 15147', 0:00:00.121592 time elapsed
# 9001-10000: processing u'2656 WINCHESTER DR PITTSBURGH PA 15220', 0:00:00.119439 time elapsed
# 10001-11000: processing u'316 BEAR RUN DR PITTSBURGH PA 15237', 0:00:00.109639 time elapsed
# 11001-12000: processing u'2814 CLEARVIEW DR GLENSHAW PA 15116', 0:00:00.119856 time elapsed
# 12001-13000: processing u'133 BRUNNER DR PITTSBURGH PA 15214', 0:00:00.118508 time elapsed
# 13001-14000: processing u'24 DINSMORE AVE PITTSBURGH PA 15205', 0:00:00.121285 time elapsed
# 14001-15000: processing u'1928 FAIRLAND ST PITTSBURGH PA 15210', 0:00:00.107235 time elapsed
# 15001-16000: processing u'330 ABERDEEN DR PITTSBURGH PA 15239', 0:00:00.108957 time elapsed
# 16001-17000: processing u'446 ATEN RD CORAOPOLIS PA 15108', 0:00:00.119511 time elapsed
# 17001-18000: processing u'1609 VALLEY BROOKE CT WEXFORD PA 15090', 0:00:00.117802 time elapsed
# 18001-19000: processing u'2009 EAGLE RIDGE DR MONROEVILLE PA 15146', 0:00:00.110772 time elapsed
# 19001-20000: processing u'981 VALLEVISTA AVE PITTSBURGH PA 15234', 0:00:00.108480 time elapsed
# 20001-21000: processing u'1500 SQUIRE RIDGE DR SEWICKLEY PA 15143', 0:00:00.117678 time elapsed
# 21001-22000: processing u'112 LYNDHURST CIR WEXFORD PA 15090', 0:00:00.119396 time elapsed
# 22001-23000: processing u'2012 WIGHTMAN ST PITTSBURGH PA 15217', 0:00:00.106981 time elapsed
# 23001-24000: processing u'204 SCENIC HILL DR CARNEGIE PA 15106', 0:00:00.119450 time elapsed
# 24001-25000: processing u'106 JAROD DR MOON TWP PA 15108', 0:00:00.142349 time elapsed
# 53001-54000: processing u'420 DALLAS AVE S PITTSBURGH PA 15208', 0:00:00.112720 time elapsed
# 54001-55000: processing u'629 SETTER LN CLAIRTON PA 15025', 0:00:00.116369 time elapsed
# 55001-56000: processing u'1163 LINKS WAY GIBSONIA PA 15044', 0:00:00.116201 time elapsed
# 56001-57000: processing u'810 LIMESTONE DR ALLISON PARK PA 15101', 0:00:00.116639 time elapsed
# 57001-58000: processing u'525 TRENTON AVE S PITTSBURGH PA 15221', 0:00:00.118823 time elapsed
# 58001-59000: processing u'636 ROYCE AVE PITTSBURGH PA 15243', 0:00:00.104785 time elapsed
# 59001-60000: processing u'118 E RUSSETS CIR BRIDGEVILLE PA 15017', 0:00:00.118976 time elapsed
# 60001-61000: processing u'1069 OLD POST RD SOUTH PARK PA 15129', 0:00:00.098073 time elapsed
# 61001-62000: processing u'845 MAGINN ST PITTSBURGH PA 15214', 0:00:00.111792 time elapsed
# 62001-63000: processing u'2040 EWINGS MILL RD CORAOPOLIS PA 15108', 0:00:00.116991 time elapsed
# 63001-64000: processing u'1516 LAUREL RIDGE DR CRESCENT PA 15046', 0:00:00.118102 time elapsed
# 64001-65000: processing u'125 SWEETWATER DR SEWICKLEY PA 15143', 0:00:00.124063 time elapsed
# 65001-66000: processing u'707 TREFOIL CT MONROEVILLE PA 15146', 0:00:00.108030 time elapsed
# 66001-67000: processing u'510 TAYLOR ST NORTH VERSAILLES PA 15137', 0:00:00.117904 time elapsed
# 67001-68000: processing u'705 TIMBERIDGE DR BETHEL PARK PA 15102', 0:00:00.120648 time elapsed
# 68001-69000: processing u'2617 MILBURN ST MC KEESPORT PA 15132', 0:00:00.119291 time elapsed
# 69001-70000: processing u'347 TWIN OAKS RD PITTSBURGH PA 15243', 0:00:00.119011 time elapsed
# 70001-71000: processing u'6050 SPRING HOUSE PL BRIDGEVILLE PA 15017', 0:00:00.117759 time elapsed
# 71001-72000: processing u'3150 CAMBERLY DR GIBSONIA PA 15044', 0:00:00.107929 time elapsed
# 72001-73000: processing u'608 DEBALDO DR WEST MIFFLIN PA 15122', 0:00:00.106657 time elapsed
# 73001-74000: processing u'93 EARLWOOD RD PITTSBURGH PA 15235', 0:00:00.116326 time elapsed
# 74001-75000: processing u'908 DRESSEL RD ALLISON PARK PA 15101', 0:00:00.112428 time elapsed
# 75001-76000: processing u'1110 RAYMOND DR OAKDALE PA 15071', 0:00:00.117840 time elapsed
# 76001-77000: processing u'115 LOCUST LN PITTSBURGH PA 15241', 0:00:00.117584 time elapsed
# 77001-78000: processing u'102 LIGONIER CT NEW KENSINGTON PA 15068', 0:00:00.113451 time elapsed
# 78001-79000: processing u'1900 OUTLOOK DR VERONA PA 15147', 0:00:00.116867 time elapsed
# 79001-80000: processing u'626 OSAGE RD PITTSBURGH PA 15243', 0:00:00.109335 time elapsed
# 80001-81000: processing u'102 MANILLA AVE E PITTSBURGH PA 15220', 0:00:00.102861 time elapsed
# 81001-82000: processing u'1041 AUGUSTA WAY PITTSBURGH PA 15236', 0:00:00.107948 time elapsed
# 404001-405000: processing u'316 SHAW AVE MC KEESPORT PA 15132', 0:00:00.102001 time elapsed
# 405001-406000: processing u'440 MAIN ST IMPERIAL PA 15126', 0:00:00.106634 time elapsed
# 406001-407000: processing u'900 9TH ST ELIZABETH PA 15037', 0:00:00.122308 time elapsed
# 407001-408000: processing u'605 SARAH ST CARNEGIE PA 15106', 0:00:00.120573 time elapsed
# 408001-409000: processing u'853 DELAWARE AVE PITTSBURGH PA 15221', 0:00:00.121017 time elapsed
# 409001-410000: processing u'1523 4TH AVE CORAOPOLIS PA 15108', 0:00:00.119486 time elapsed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-00b864095b37> in <module>()
# ----> 1 process_addrs_to_cb_into_cam(addrs_to_cb_2018)
#
# <ipython-input-66-8607b788ee5d> in process_addrs_to_cb_into_cam(df)
#      25
#      26     end=arrow.now()
# ---> 27     print "Processing took %s for %d dots" % (str(end-start), chunk_cnt)
#
# NameError: global name 'chunk_cnt' is not defined

# %%
canonical_addr_map[canonical_addr_map.keys()[0]]

# %% [markdown]
# # Process voter address events

# %%
# Copied from http://localhost:8820/notebooks/projects/demographics/Allegheny%20County%20Property%20Assessments-AW9.ipynb#
# As of 10/23/18, this isn't used yet.

# find_event_by_date takes a list of maps containg 'date' fields and looks for one the the last one that's before
# search_date or the first which is simultaneous (in case of multiple simultaneous records).  
# Returns -1 if the search_date is earlier than any existing item.  It assumes that each map in the event list 
# contains a 'date' field and that they're in sorted order from earliest to latest.
def find_event_index_by_date(event_list, search_date):
    match_index=-1
    for i in range(0,len(event_list)):
        if(event_list[i]['date']<search_date):
            # This happened before the date we're looking for, update match_index
            match_index=i
        elif(event_list[i]['date']==search_date):
            # This is the first exact match, return i
            return(i)
        else:
            # This happened after the date we're looking for, return match_index
            return match_index
    # If we get to here, there is no event after this date.  Return match_index
    return match_index

def find_event_index_by_date_and_asofdate(event_list, search_date, asofdate):
    match_index=-1
    for i in range(0,len(event_list)):
        if(event_list[i]['date']<search_date):
            # This happened before the date we're looking for, update match_index
            match_index=i
        elif(event_list[i]['date']==search_date):
            if(event_list[i]['asofdate']==asofdate):
                # This is an exact match, return i
                return(i)
            elif(event_list[i]['asofdate']<asofdate):
                # This happened on the same search_date and before the asoifdate 
                # we're looking for, update match_index
                match_index=i

        else:
            # This happened after the date we're looking for, return match_index
            return match_index
    # If we get to here, there is no event after this date.  Return match_index
    return match_index

# This takes an existing event list and either inserts a given event_map and returns True, or 
# decides that the event is a duplicate and returns false
def insert_event(event_list, event_map):
    # Find the index of the element already in the list which precedes the date in event_map.  
    # If not found, match_index is -1, so we should insert it at the beginning of event_list and return True
    # If found, check if the record matches what we already have (TODO: see if we need something
    # more sophisticated than ==).  If it matches what we already have, return False and do not modify the list.
    # If it doesn't match what we have insert it.  Note that list.insert takes the arg of the element to insert
    # before, so we use match_index+1
    match_index = find_event_index_by_date(event_list, event_map['date'])
    if(match_index==-1):
        #print "No match, insert at beginning"
        # No match.  Insert at the beginning, return True
        event_list.insert(0, event_map)
        return True
    # We've got a matching or preceeding event, compare it with this and any other potentially 
    # simultaneous events
    #print "Time match at %d" % (match_index)
    for i in range(match_index, len(event_list)):
        if(event_map == event_list[i]):
            # This is a duplicate, ignore it
            #print "Found duplicate match at %d (%r)" % (i,event_list[i])
            return False
        elif(event_map['date'] == event_list[i]['date'] and 'asofdate' in event_map and 'asofdate' in event_list[i] and event_map['asofdate'] == event_list[i]['asofdate']):
            # This is an event from the same sale date and asofdate, but it doesn't match exactly.
            # Have the new event supercede the old one.  Return true.
            #print "Found superceded version at %d (%r -> %r)" % (i,event_list[i], event_map)
            event_list[i]=event_map
            return True
        elif(event_map['date']<event_list[i]['date'] or ((event_map['date'] == event_list[i]['date'] and 'asofdate' in event_map and 'asofdate' in event_list[i] and event_map['asofdate'] < event_list[i]['asofdate']))):
            # We're past any simultaneous events that might have matched, continue
            # Note that this version only works if the asofdates within a given sale date 
            # are always kept sorted
            #print "Hit a later item at %d (%r)" % (i,match_index)
            break
        #print "Didn't match at %d (%r), keep trying" % (i,event_list[i])
        match_index=i
    # We've got a preceeding or simultaneous event that doesnt match.  Insert this 
    # new item just past match_index
    #print "Inserting after %d" % (match_index)
    event_list.insert(match_index+1, event_map)
    return True

# This takes an existing event list and either deletes a given event_map and returns True, or 
# decides that the event is not there and returns False
def delete_event(event_list, event_map):
    # Find the index of the element already in the list which matches or precedes the date in event_map.  
    # If not found, match_index is -1, so we should return False
    # If found, check if the record matches what we already have.  If it matches, delete and return True
    match_index = find_event_index_by_date(event_list, event_map['date'])
    if(match_index==-1 or event_map['date']>event_list[match_index]['date']):
        #print "No match"        
        return False
    # We've got a matching date for this event, compare it with this and any other potentially 
    # simultaneous events
    #print "Time match at %d" % (match_index)
    for i in range(match_index, len(event_list)):
        if(event_map == event_list[i]):
            #print "Found match at %d (%r), deleting" % (i,event_list[i])
            del event_list[i]
            return True
        elif(event_map['date'] == event_list[i]['date'] and 'asofdate' in event_map and 'asofdate' in event_list[i] and event_map['asofdate'] == event_list[i]['asofdate']):
            # This is an event from the same sale date and asofdate, delete and return true.
            #print "Found matching date and asofdate at %d, deleting" % (i)
            del event_list[i]
            return True
        elif(event_map['date']<event_list[i]['date']):
            # We're past any simultaneous events that might have matched, break and return False
            break
    #print "No match"
    return True

# %%
# Keep track of what addresses are in use but don't yet have a computed blockgroup
addrs_to_blocks_todo_set=set()
# These two arrays should both be added to at the same time, and only when an address both geolocates and isn't already in addrs_to_blocks_todo_set
addrs_to_blocks=[]
coords_to_blocks=[]
# Keep track of which voter ID's need updating when a given address is mapped
# Key is address, value is set of voter ID's
addrs_to_blocks_update_map={}

# %%
# Keep track of what addresses are non-geolocatable.  Initialize this from the saved list from 
# processing all of 2018-08 if it is reset.
non_geolocatable_addrs_set=set(list(non_geolocatable_addrs))

# %%
# Keep track of what addresses are geolocatable but fail to resolve into census blocks when spatially joined with the 
# Census block geojson.  This is updated by the TODO resolution steps below
uncomputable_census_block_addrs_set=set()

# %%
# Set up paths to save/restore sets accumulating what addresses fail for 
# geolocation and/or census block computation
import pickle
pickle_failset_path_t = 'assessments/fail_addr_{}_set.pickle'

# %%
# Save out fail addr sets
with open(pickle_failset_path_t.format('geo'), 'wb') as handle:
    pickle.dump(non_geolocatable_addrs_set, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(pickle_failset_path_t.format('cb'), 'wb') as handle:
    pickle.dump(uncomputable_census_block_addrs_set, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load in fail addr sets
with open(pickle_failset_path_t.format('geo'), 'rb') as handle:
    non_geolocatable_addrs_set = pickle.load(handle)
with open(pickle_failset_path_t.format('cb'), 'rb') as handle:
    uncomputable_census_block_addrs_set = pickle.load(handle)

# %%
len(non_geolocatable_addrs_set)
# Out:
# 10752

# %%
len(uncomputable_census_block_addrs_set)
# Out:
# 271

# %%
# Only call this for addreses that are already known to be geolocatable.
# This will add the addr to be processed into census block.
def queue_todo_addr(vid, this_addr, coords):
    # Check if we really need to geolocate this address
    if(this_addr in non_geolocatable_addrs_set or this_addr in uncomputable_census_block_addrs_set or not coords):
        # We already know it can't be geolocated
        return False

    # If addr is not already in addrs_to_blocks_todo_set, 
    # add to addrs_to_blocks_todo_set, addrs_to_blocks, and coords_to_blocks
    # Either way, add vid to addrs_to_blocks_update_map
    if(not this_addr in addrs_to_blocks_todo_set):
        # Don't have this one yet
        addrs_to_blocks_todo_set.add(this_addr)
        addrs_to_blocks.append(this_addr)
        coords_to_blocks.append(coords)
        addrs_to_blocks_update_map[this_addr]=set([vid])

    # We've got this one queued up to process later, add entry in addrs_to_blocks_update_map
    addrs_to_blocks_update_map[this_addr].add(vid)
    
    return True

# Check if this voter moved away, meaning that they were present in an earlier
# version of the DB and disappeared in later versions

def check_voter_moved_away(vid):
    if(not vid in voter_map):
        print "WARNING: %s not in voter_map" % (vid)
        return None
    
    vrec = voter_map[vid]
    
    # Get the month_str values in sorted order for this voter
    month_strs = sorted(vrec['reg_info'].keys())
    last_ms = month_str[-1]
    
    # Find the index of the last month we have info on this voter
    # in the active_month_str_arr listing in order all the 
    # datasets we have incorporated into voter_map
    last_ms = month_strs[-1]
    last_idx = active_month_str_arr.index(last_ms)
    moved_ms=None
    if(last_idx<len(active_month_str_arr)-1):
        moved_ms=active_month_str_arr[last_idx+1]
    return(moved_ms)

def voter_process_address_history(vid, force_update):
    # Given a voter ID, process the adresses into an order list of start date -> addr
    # The start date for the first address is 'reg_date'.
    # The start date of subsequent addresses is monthstr_to_date_map[month_str] if the address changed
    # from before.
    # This needs to be recomputed by force after the import of a new voter DB instance.  In that case, 
    # pass in true for force_update.  For subsequent runs it can be false and just used the cached version
    if(not vid in voter_map):
        return None
    vrec = voter_map[vid]
    if(not force_update and 'addr_arr' in vrec):
        return vrec['addr_arr']

    # Need to compute addr_arr
    addr_arr=[]
    
    # Get the month_str values in sorted order for this voter
    month_strs = sorted(vrec['reg_info'].keys())
    last_addr = None
    
    # Check if this voter moved away, meaning that they were present in an earlier
    # version of the DB and disappeared in later versions
    
    
    for j in range(0,len(month_strs)):
        month_str = month_strs[j]

        # By default, use the date of the first dataset as the start date, 
        # and get the address for this month for comparing and potentially 
        # creating a new addr_arr entry
        start_date = monthstr_to_date_map[month_str]
        this_addr = vrec['addresses'][month_str]
        
        # The first address is special because it uses reg_date and the 
        # address is always used.  After that, if the address hasn't changed
        # we just skip to the next month.
        if(j==0):
            start_date = vrec['reg_date']
        else:
            if(this_addr == last_addr):
                # Address hasn't changed, skip to the next month_str
                continue
                
        # Set last_addr to this_addr for comparison next time through loop
        last_addr = this_addr
                
        # We need to create a new entry
        addr_event={'date': start_date, 'address':this_addr}
        
        # Check if we need to geolocate this address
        if(this_addr in non_geolocatable_addrs_set or this_addr in uncomputable_census_block_addrs_set):
            # We already know it can't be geolocated
            addr_event['census_block']=None
            # We're done with this address now, record and go on to the next one
            addr_arr.append(addr_event)
            continue
        elif(this_addr in addrs_to_blocks_todo_set):
            # We've already got this one queued up, add entry in addrs_to_blocks_update_map
            addrs_to_blocks_update_map[this_addr].add(vid)
            # We're done with this address now, record and go on to the next one
            addr_arr.append(addr_event)
            continue
        elif(this_addr in canonical_addr_map):
            # We have an entry in canonical_addr_map, see if we know the census block ID
            if('census_block' in canonical_addr_map[this_addr]):
                addr_event['census_block']=canonical_addr_map[this_addr]['census_block']
                # We're done with this address now, record and go on to the next one
                addr_arr.append(addr_event)
                continue
            # If we don't already know the census block ID, fall through to 
            # dealing with it after this if/else section
        else:
            # We don't have an entry in canonical_addr_map yet.  Create one and fall through
            canonical_addr_map[this_addr]={'canonical_in_census_db':False,'canonical_in_google_db': False,
                                           'census_value':None, 'google_value':None}

        # At this point, we know there is an entry in canonical_addr_map (which we may)
        # have just created, and this address doesn't have a census block recorded for 
        # it yet.  Set up to calculate the census block.
        coords = addr_to_coords(this_addr)
        if(coords):
            # It is geolocatable, add to addrs_to_blocks_todo_set, 
            # addrs_to_blocks, coords_to_blocks, and addrs_to_blocks_update_map
            addrs_to_blocks_todo_set.add(this_addr)
            addrs_to_blocks.append(this_addr)
            coords_to_blocks.append(coords)
            addrs_to_blocks_update_map[this_addr]=set([vid])
            # addr_event['census_block'] will get updated later 
        else:
            # It is not geolocatable, add to non_geolocatable_addrs_set
            # and update canonical_addr_map to have census_block = None
            non_geolocatable_addrs_set.add(this_addr)
            canonical_addr_map[this_addr]['census_block']=None
            canonical_addr_map[this_addr]['latlon']=None
            addr_event['census_block']=None
                    
        addr_arr.append(addr_event)

    # Done with month_str loop, add addr_arr to vrec and return
    vrec['addr_arr']=addr_arr
    return addr_arr

# Find entries in addr_arr and make sure ones that are missing
# 'census_block' are properly recorded in 
# addrs_to_blocks_update_map={} and friends
def voter_crosscheck_address_history_array(vid_arr):
    start=arrow.now()
    chunk_start_time=start
    chunk_size=10000
    num_added = 0
    
    for i in range(0,len(vid_arr)):
        vid = vid_arr[i]
        if(not vid in voter_map):
            print "WARNING: %s not in voter_map" % (vid)
            continue
        vrec = voter_map[vid]
        if(not 'addr_arr' in vrec):
            print "WARNING: %s missing addr_arr in voter_map, re-run voter_process_address_history_array" % (vid)
            continue
            
        
        addr_arr = vrec['addr_arr']
        for j in range(0,len(addr_arr)):
            addr_rec = vrec['addr_arr'][j]
            if(not 'census_block' in addr_rec):
                # Add this entry to the queue to compute census block
                this_addr = addr_rec['address']
                coords = addr_to_coords(this_addr)
                if(queue_todo_addr(vid, this_addr, coords)):
                    num_added=num_added + 1
                else:
                    print "WARNING %s: '%s' lacks 'census_block' but queue_todo_addr fails, setting to None" % (vid, this_addr)
                    addr_rec['census_block']=None
        
        # Handle periodic debug message
        if((i%chunk_size)==0 and i>0):
            print "%d-%d: processing %r, %d added, %s time elapsed" %(i-(chunk_size-1), i, vid, num_added, arrow.now()-chunk_start_time)
            addcnt=0
            chunk_start_time=arrow.now()

    end=arrow.now()
    print "Processing took %s for %d addresses, %d added to addrs_to_blocks_update_map" % (str(end-start), len(vid_arr), num_added)

def voter_process_address_history_array(vid_arr, force_update):
    start=arrow.now()
    chunk_start_time=start
    chunk_size=10000

    for i in range(0,len(vid_arr)):
        vid = vid_arr[i]
        voter_process_address_history(vid, force_update)
        
        # Handle periodic debug message
        if((i%chunk_size)==0 and i>0):
            print "%d-%d: processing %r, %d in todo set, %d non-geolocatable, %s time elapsed" %(i-(chunk_size-1), i, vid, 
                                                                                                 len(addrs_to_blocks_todo_set), len(non_geolocatable_addrs_set),
                                                                                                 arrow.now()-chunk_start_time)
            addcnt=0
            chunk_start_time=arrow.now()

    end=arrow.now()
    print "Processing took %s for %d addresses" % (str(end-start), len(vid_arr))

# %%
all_vids=sorted(voter_map.keys())

# %%
voter_process_address_history_array(all_vids,False)
# Out:
# 1-10000: processing '001910531-02', 12 in todo set, 10750 non-geolocatable, 0:00:09.426994 time elapsed
# 10001-20000: processing '001931879-02', 12 in todo set, 10750 non-geolocatable, 0:00:00.014654 time elapsed
# 20001-30000: processing '001946646-02', 12 in todo set, 10750 non-geolocatable, 0:00:00.013929 time elapsed
# 30001-40000: processing '001964389-02', 12 in todo set, 10750 non-geolocatable, 0:00:00.013375 time elapsed
# 40001-50000: processing '001985312-02', 13 in todo set, 10750 non-geolocatable, 0:00:00.013278 time elapsed
# 50001-60000: processing '002002989-02', 17 in todo set, 10750 non-geolocatable, 0:00:00.016294 time elapsed
# 60001-70000: processing '002018307-02', 17 in todo set, 10750 non-geolocatable, 0:00:00.012637 time elapsed
# 70001-80000: processing '002035528-02', 17 in todo set, 10750 non-geolocatable, 0:00:00.012317 time elapsed
# 80001-90000: processing '002054354-02', 19 in todo set, 10750 non-geolocatable, 0:00:00.012645 time elapsed
# 90001-100000: processing '002069700-02', 20 in todo set, 10750 non-geolocatable, 0:00:01.505738 time elapsed
# 100001-110000: processing '002089750-02', 20 in todo set, 10750 non-geolocatable, 0:00:00.012695 time elapsed
# 110001-120000: processing '002108945-02', 21 in todo set, 10750 non-geolocatable, 0:00:00.011879 time elapsed
# 120001-130000: processing '002126236-02', 21 in todo set, 10750 non-geolocatable, 0:00:00.011504 time elapsed
# 130001-140000: processing '002140140-02', 22 in todo set, 10750 non-geolocatable, 0:00:00.010597 time elapsed
# 140001-150000: processing '002160886-02', 22 in todo set, 10750 non-geolocatable, 0:00:00.013574 time elapsed
# 150001-160000: processing '002177010-02', 22 in todo set, 10750 non-geolocatable, 0:00:00.011346 time elapsed
# 160001-170000: processing '002193737-02', 23 in todo set, 10750 non-geolocatable, 0:00:00.011296 time elapsed
# 170001-180000: processing '002214913-02', 24 in todo set, 10750 non-geolocatable, 0:00:00.011337 time elapsed
# 180001-190000: processing '002233174-02', 25 in todo set, 10750 non-geolocatable, 0:00:00.825793 time elapsed
# 190001-200000: processing '002249493-02', 26 in todo set, 10750 non-geolocatable, 0:00:00.013062 time elapsed
# 200001-210000: processing '002264851-02', 26 in todo set, 10750 non-geolocatable, 0:00:00.013118 time elapsed
# 210001-220000: processing '002284992-02', 26 in todo set, 10750 non-geolocatable, 0:00:00.012934 time elapsed
# 220001-230000: processing '002299984-02', 27 in todo set, 10750 non-geolocatable, 0:00:00.699006 time elapsed
# 230001-240000: processing '002318849-02', 27 in todo set, 10750 non-geolocatable, 0:00:00.011787 time elapsed
# 240001-250000: processing '002338848-02', 27 in todo set, 10750 non-geolocatable, 0:00:00.013043 time elapsed
# 250001-260000: processing '002356508-02', 27 in todo set, 10750 non-geolocatable, 0:00:00.012128 time elapsed
# 260001-270000: processing '002371242-02', 27 in todo set, 10750 non-geolocatable, 0:00:00.013042 time elapsed
# 270001-280000: processing '002389748-02', 28 in todo set, 10750 non-geolocatable, 0:00:00.013187 time elapsed
# 280001-290000: processing '002407419-02', 28 in todo set, 10750 non-geolocatable, 0:00:00.012924 time elapsed
# 290001-300000: processing '002423355-02', 29 in todo set, 10750 non-geolocatable, 0:00:00.012108 time elapsed
# 300001-310000: processing '002443761-02', 29 in todo set, 10750 non-geolocatable, 0:00:00.012731 time elapsed
# 310001-320000: processing '002462452-02', 30 in todo set, 10750 non-geolocatable, 0:00:01.377827 time elapsed
# 320001-330000: processing '002479650-02', 31 in todo set, 10750 non-geolocatable, 0:00:00.014627 time elapsed
# 330001-340000: processing '002493599-02', 31 in todo set, 10750 non-geolocatable, 0:00:00.012506 time elapsed
# 340001-350000: processing '002514842-02', 31 in todo set, 10750 non-geolocatable, 0:00:00.012811 time elapsed
# 350001-360000: processing '002530060-02', 32 in todo set, 10750 non-geolocatable, 0:00:00.010866 time elapsed
# 360001-370000: processing '002547151-02', 33 in todo set, 10750 non-geolocatable, 0:00:00.015473 time elapsed
# 370001-380000: processing '002568214-02', 34 in todo set, 10750 non-geolocatable, 0:00:00.012226 time elapsed
# 380001-390000: processing '002586349-02', 35 in todo set, 10750 non-geolocatable, 0:00:00.012831 time elapsed
# 390001-400000: processing '002602295-02', 35 in todo set, 10750 non-geolocatable, 0:00:00.012883 time elapsed
# 400001-410000: processing '002618626-02', 35 in todo set, 10750 non-geolocatable, 0:00:00.012749 time elapsed
# 410001-420000: processing '002638141-02', 35 in todo set, 10750 non-geolocatable, 0:00:00.012713 time elapsed
# 420001-430000: processing '002653421-02', 36 in todo set, 10750 non-geolocatable, 0:00:00.013250 time elapsed
# 430001-440000: processing '002673116-02', 36 in todo set, 10750 non-geolocatable, 0:00:00.012597 time elapsed
# 440001-450000: processing '002692498-02', 38 in todo set, 10750 non-geolocatable, 0:00:00.905223 time elapsed
# 450001-460000: processing '002709721-02', 39 in todo set, 10750 non-geolocatable, 0:00:00.012105 time elapsed
# 460001-470000: processing '002724004-02', 39 in todo set, 10750 non-geolocatable, 0:00:00.012777 time elapsed
# 470001-480000: processing '002743572-02', 39 in todo set, 10750 non-geolocatable, 0:00:00.012799 time elapsed
# 480001-490000: processing '002760412-02', 41 in todo set, 10750 non-geolocatable, 0:00:00.013167 time elapsed
# 490001-500000: processing '002776667-02', 41 in todo set, 10750 non-geolocatable, 0:00:00.012803 time elapsed
# 500001-510000: processing '002797521-02', 41 in todo set, 10750 non-geolocatable, 0:00:00.012780 time elapsed
# 510001-520000: processing '002816183-02', 41 in todo set, 10750 non-geolocatable, 0:00:00.012850 time elapsed
# 520001-530000: processing '002833033-02', 44 in todo set, 10750 non-geolocatable, 0:00:01.958499 time elapsed
# 530001-540000: processing '002847418-02', 44 in todo set, 10750 non-geolocatable, 0:00:00.018123 time elapsed
# 540001-550000: processing '002868871-02', 44 in todo set, 10750 non-geolocatable, 0:00:00.013091 time elapsed
# 550001-560000: processing '002883479-02', 44 in todo set, 10750 non-geolocatable, 0:00:00.013043 time elapsed
# 560001-570000: processing '002901369-02', 46 in todo set, 10750 non-geolocatable, 0:00:00.013451 time elapsed
# 570001-580000: processing '002922116-02', 47 in todo set, 10750 non-geolocatable, 0:00:00.012731 time elapsed
# 580001-590000: processing '002939854-02', 48 in todo set, 10750 non-geolocatable, 0:00:00.012095 time elapsed
# 590001-600000: processing '002955305-02', 48 in todo set, 10750 non-geolocatable, 0:00:00.012914 time elapsed
# 600001-610000: processing '002972596-02', 49 in todo set, 10750 non-geolocatable, 0:00:00.010886 time elapsed
# 610001-620000: processing '002991199-02', 49 in todo set, 10750 non-geolocatable, 0:00:00.012849 time elapsed
# 620001-630000: processing '003006802-02', 50 in todo set, 10750 non-geolocatable, 0:00:02.831801 time elapsed
# 630001-640000: processing '003026905-02', 50 in todo set, 10750 non-geolocatable, 0:00:00.014401 time elapsed
# 640001-650000: processing '003046025-02', 51 in todo set, 10750 non-geolocatable, 0:00:00.015081 time elapsed
# 650001-660000: processing '003063318-02', 51 in todo set, 10750 non-geolocatable, 0:00:00.013104 time elapsed
# 660001-670000: processing '003077231-02', 51 in todo set, 10750 non-geolocatable, 0:00:00.013007 time elapsed
# 670001-680000: processing '004449955-02', 58 in todo set, 10750 non-geolocatable, 0:00:12.845029 time elapsed
# 680001-690000: processing '004828083-02', 65 in todo set, 10750 non-geolocatable, 0:00:03.101053 time elapsed
# 690001-700000: processing '013339997-02', 75 in todo set, 10750 non-geolocatable, 0:00:07.708383 time elapsed
# 700001-710000: processing '020025600-02', 83 in todo set, 10750 non-geolocatable, 0:00:04.518066 time elapsed
# 710001-720000: processing '020052069-02', 84 in todo set, 10750 non-geolocatable, 0:00:01.403272 time elapsed
# 720001-730000: processing '020115158-02', 84 in todo set, 10750 non-geolocatable, 0:00:00.013406 time elapsed
# 730001-740000: processing '020178233-02', 86 in todo set, 10750 non-geolocatable, 0:00:03.789400 time elapsed
# 740001-750000: processing '020220773-02', 88 in todo set, 10750 non-geolocatable, 0:00:02.300150 time elapsed
# 750001-760000: processing '020280122-02', 90 in todo set, 10750 non-geolocatable, 0:00:08.921219 time elapsed
# 760001-770000: processing '020341224-02', 92 in todo set, 10750 non-geolocatable, 0:00:00.013290 time elapsed
# 770001-780000: processing '020399120-02', 93 in todo set, 10750 non-geolocatable, 0:00:00.649746 time elapsed
# 780001-790000: processing '020426270-02', 94 in todo set, 10750 non-geolocatable, 0:00:00.014851 time elapsed
# 790001-800000: processing '020493592-02', 95 in todo set, 10750 non-geolocatable, 0:00:00.883242 time elapsed
# 800001-810000: processing '020576057-02', 97 in todo set, 10750 non-geolocatable, 0:00:00.017315 time elapsed
# 810001-820000: processing '020682818-02', 100 in todo set, 10750 non-geolocatable, 0:00:00.012729 time elapsed
# 820001-830000: processing '020762964-02', 101 in todo set, 10750 non-geolocatable, 0:00:01.915566 time elapsed
# 830001-840000: processing '020844288-02', 103 in todo set, 10750 non-geolocatable, 0:00:01.229920 time elapsed
# 840001-850000: processing '020939049-02', 103 in todo set, 10750 non-geolocatable, 0:00:00.017810 time elapsed
# 850001-860000: processing '021047106-02', 105 in todo set, 10750 non-geolocatable, 0:00:01.378573 time elapsed
# 860001-870000: processing '021141104-02', 106 in todo set, 10750 non-geolocatable, 0:00:01.521041 time elapsed
# 870001-880000: processing '021237030-02', 108 in todo set, 10750 non-geolocatable, 0:00:00.019228 time elapsed
# 880001-890000: processing '021332932-02', 111 in todo set, 10750 non-geolocatable, 0:00:02.981030 time elapsed
# 890001-900000: processing '021429023-02', 113 in todo set, 10750 non-geolocatable, 0:00:00.813432 time elapsed
# 900001-910000: processing '021497971-02', 114 in todo set, 10750 non-geolocatable, 0:00:06.340023 time elapsed
# 910001-920000: processing '021588821-02', 116 in todo set, 10750 non-geolocatable, 0:00:00.012203 time elapsed
# 920001-930000: processing '021684521-02', 119 in todo set, 10750 non-geolocatable, 0:00:04.584177 time elapsed
# 930001-940000: processing '021811798-02', 120 in todo set, 10750 non-geolocatable, 0:00:01.133024 time elapsed
# 940001-950000: processing '021888070-02', 120 in todo set, 10750 non-geolocatable, 0:00:00.013649 time elapsed
# 950001-960000: processing '102607072-02', 123 in todo set, 10750 non-geolocatable, 0:00:03.063745 time elapsed
# 960001-970000: processing '102813959-02', 129 in todo set, 10750 non-geolocatable, 0:00:14.014563 time elapsed
# 970001-980000: processing '102956541-02', 138 in todo set, 10750 non-geolocatable, 0:00:02.008537 time elapsed
# 980001-990000: processing '103141438-02', 143 in todo set, 10750 non-geolocatable, 0:00:03.020872 time elapsed
# 990001-1000000: processing '103300655-02', 151 in todo set, 10750 non-geolocatable, 0:00:06.615201 time elapsed
# 1000001-1010000: processing '103437651-02', 157 in todo set, 10750 non-geolocatable, 0:00:05.469516 time elapsed
# 1010001-1020000: processing '103565044-02', 163 in todo set, 10750 non-geolocatable, 0:00:14.758495 time elapsed
# 1020001-1030000: processing '103661037-02', 167 in todo set, 10750 non-geolocatable, 0:00:07.689014 time elapsed
# 1030001-1040000: processing '103768308-02', 173 in todo set, 10750 non-geolocatable, 0:00:04.793905 time elapsed
# 1040001-1050000: processing '103947279-02', 182 in todo set, 10750 non-geolocatable, 0:00:23.156034 time elapsed
# 1050001-1060000: processing '104117574-02', 185 in todo set, 10750 non-geolocatable, 0:00:01.322405 time elapsed
# 1060001-1070000: processing '104305873-02', 194 in todo set, 10750 non-geolocatable, 0:00:12.577765 time elapsed
# 1070001-1080000: processing '104472524-02', 202 in todo set, 10750 non-geolocatable, 0:00:05.947975 time elapsed
# 1080001-1090000: processing '105233303-02', 206 in todo set, 10750 non-geolocatable, 0:00:01.663466 time elapsed
# 1090001-1100000: processing '106509254-02', 209 in todo set, 10750 non-geolocatable, 0:00:00.019423 time elapsed
# 1100001-1110000: processing '107203224-02', 213 in todo set, 10750 non-geolocatable, 0:00:00.517675 time elapsed
# 1110001-1120000: processing '107544887-02', 220 in todo set, 10750 non-geolocatable, 0:00:05.886868 time elapsed
# 1120001-1130000: processing '107711655-02', 222 in todo set, 10750 non-geolocatable, 0:00:00.017489 time elapsed
# 1130001-1140000: processing '107877660-02', 228 in todo set, 10750 non-geolocatable, 0:00:12.824271 time elapsed
# 1140001-1150000: processing '107992745-02', 231 in todo set, 10750 non-geolocatable, 0:00:02.239309 time elapsed
# 1150001-1160000: processing '108123484-02', 235 in todo set, 10750 non-geolocatable, 0:00:12.258211 time elapsed
# 1160001-1170000: processing '108232046-02', 240 in todo set, 10750 non-geolocatable, 0:00:01.652327 time elapsed
# 1170001-1180000: processing '108731346-02', 244 in todo set, 10750 non-geolocatable, 0:00:05.787246 time elapsed
# 1180001-1190000: processing '108956204-02', 249 in todo set, 10750 non-geolocatable, 0:00:10.859801 time elapsed
# 1190001-1200000: processing '109152327-02', 252 in todo set, 10750 non-geolocatable, 0:00:03.657269 time elapsed
# Google: Fetch '1510 INGLEWOOD DR PITTSBURGH PA 15237' seemed to succeed, but results empty or non-unique
# 1200001-1210000: processing '109304328-02', 615 in todo set, 10751 non-geolocatable, 0:03:45.423481 time elapsed
# Google: Fetch '1726 STEVENSAN DR SEWICKLEY PA 15143' seemed to succeed, but results empty or non-unique
# Processing took 0:12:06.155882 for 1217523 addresses

# %%
voter_crosscheck_address_history_array(all_vids)
# Out:
# 1-10000: processing '001910531-02', 0 added, 0:00:00.062748 time elapsed
# 10001-20000: processing '001931879-02', 0 added, 0:00:00.035705 time elapsed
# 20001-30000: processing '001946646-02', 0 added, 0:00:00.035301 time elapsed
# 30001-40000: processing '001964389-02', 0 added, 0:00:00.035057 time elapsed
# 40001-50000: processing '001985312-02', 0 added, 0:00:00.029339 time elapsed
# 50001-60000: processing '002002989-02', 0 added, 0:00:00.028754 time elapsed
# 60001-70000: processing '002018307-02', 0 added, 0:00:00.027497 time elapsed
# 70001-80000: processing '002035528-02', 0 added, 0:00:00.026337 time elapsed
# 890001-900000: processing '021429023-02', 0 added, 0:00:00.021162 time elapsed
# 900001-910000: processing '021497971-02', 0 added, 0:00:00.021587 time elapsed
# 910001-920000: processing '021588821-02', 0 added, 0:00:00.020954 time elapsed
# 920001-930000: processing '021684521-02', 0 added, 0:00:00.021108 time elapsed
# 930001-940000: processing '021811798-02', 0 added, 0:00:00.020998 time elapsed
# 940001-950000: processing '021888070-02', 0 added, 0:00:00.020949 time elapsed
# 950001-960000: processing '102607072-02', 0 added, 0:00:00.021009 time elapsed
# 960001-970000: processing '102813959-02', 0 added, 0:00:00.021020 time elapsed
# 970001-980000: processing '102956541-02', 0 added, 0:00:00.019944 time elapsed
# 980001-990000: processing '103141438-02', 0 added, 0:00:00.020207 time elapsed
# 990001-1000000: processing '103300655-02', 0 added, 0:00:00.019756 time elapsed
# 1000001-1010000: processing '103437651-02', 0 added, 0:00:00.019874 time elapsed
# 1010001-1020000: processing '103565044-02', 0 added, 0:00:00.020056 time elapsed
# 1020001-1030000: processing '103661037-02', 0 added, 0:00:00.019673 time elapsed
# 1030001-1040000: processing '103768308-02', 0 added, 0:00:00.019842 time elapsed
# 1040001-1050000: processing '103947279-02', 0 added, 0:00:00.019613 time elapsed
# 1050001-1060000: processing '104117574-02', 0 added, 0:00:00.019778 time elapsed
# 1060001-1070000: processing '104305873-02', 0 added, 0:00:00.019699 time elapsed
# 1070001-1080000: processing '104472524-02', 0 added, 0:00:00.020131 time elapsed
# 1080001-1090000: processing '105233303-02', 0 added, 0:00:00.019700 time elapsed
# 1090001-1100000: processing '106509254-02', 0 added, 0:00:00.019691 time elapsed
# 1100001-1110000: processing '107203224-02', 0 added, 0:00:00.019648 time elapsed
# 1110001-1120000: processing '107544887-02', 0 added, 0:00:00.019433 time elapsed
# 1120001-1130000: processing '107711655-02', 0 added, 0:00:00.019497 time elapsed
# 1130001-1140000: processing '107877660-02', 0 added, 0:00:00.019647 time elapsed
# 1140001-1150000: processing '107992745-02', 0 added, 0:00:00.019609 time elapsed
# 1150001-1160000: processing '108123484-02', 0 added, 0:00:00.019479 time elapsed
# 1160001-1170000: processing '108232046-02', 0 added, 0:00:00.019399 time elapsed
# 1170001-1180000: processing '108731346-02', 0 added, 0:00:00.019375 time elapsed
# 1180001-1190000: processing '108956204-02', 0 added, 0:00:00.019237 time elapsed
# 1190001-1200000: processing '109152327-02', 0 added, 0:00:00.019275 time elapsed
# 1200001-1210000: processing '109304328-02', 0 added, 0:00:00.017991 time elapsed
# Processing took 0:00:02.786353 for 1217523 addresses, 0 added to addrs_to_blocks_update_map

# %%
len(addrs_to_blocks_todo_set)
# Out:
# 0

# %%
len(addrs_to_blocks)
# Out:
# 967

# %%
addrs_to_blocks
# Out:
# ['5847 MERIDIAN RD GIBSONIA PA 15044']

# %%
canonical_addr_map['5847 MERIDIAN RD GIBSONIA PA 15044']
# Out:
# {'canonical_in_census_db': True,
#  'canonical_in_google_db': True,
#  'census_block': u'420034080012051',
#  'census_value': u'{"result": {"addressMatches": [{"tigerLine": {"tigerLineId": "630042568", "side": "R"}, "coordinates": {"y": 40.65425, "x": -79.960495}, "matchedAddress": "5847 MERIDIAN RD, GIBSONIA, PA, 15044", "addressComponents": {"suffixType": "RD", "zip": "15044", "toAddress": "5829", "preQualifier": "", "preDirection": "", "city": "GIBSONIA", "preType": "", "state": "PA", "suffixQualifier": "", "fromAddress": "5849", "streetName": "MERIDIAN", "suffixDirection": ""}}], "input": {"benchmark": {"benchmarkName": "Public_AR_Current", "id": "4", "isDefault": false, "benchmarkDescription": "Public Address Ranges - Current Benchmark"}, "address": {"address": "5847 MERIDIAN RD GIBSONIA PA 15044"}}}}',
#  'google_value': u'{"status": "OK", "results": [{"geometry": {"location_type": "ROOFTOP", "bounds": {"northeast": {"lat": 40.6541931, "lng": -79.96048669999999}, "southwest": {"lat": 40.6534307, "lng": -79.9613317}}, "viewport": {"northeast": {"lat": 40.6551608802915, "lng": -79.95956021970848}, "southwest": {"lat": 40.6524629197085, "lng": -79.9622581802915}}, "location": {"lat": 40.6538573, "lng": -79.9609746}}, "address_components": [{"long_name": "5847", "types": ["street_number"], "short_name": "5847"}, {"long_name": "South Meridian Road", "types": ["route"], "short_name": "S Meridian Rd"}, {"long_name": "Gibsonia", "types": ["locality", "political"], "short_name": "Gibsonia"}, {"long_name": "Richland Township", "types": ["administrative_area_level_3", "political"], "short_name": "Richland Township"}, {"long_name": "Allegheny County", "types": ["administrative_area_level_2", "political"], "short_name": "Allegheny County"}, {"long_name": "Pennsylvania", "types": ["administrative_area_level_1", "political"], "short_name": "PA"}, {"long_name": "United States", "types": ["country", "political"], "short_name": "US"}, {"long_name": "15044", "types": ["postal_code"], "short_name": "15044"}, {"long_name": "9450", "types": ["postal_code_suffix"], "short_name": "9450"}], "place_id": "ChIJ7R3aS6aPNIgR0Azr6KHhiys", "formatted_address": "5847 S Meridian Rd, Gibsonia, PA 15044, USA", "types": ["premise"]}]}',
#  'latlon': <shapely.geometry.point.Point at 0x7f4d0d9ccb10>}

# %%
all_vids[0:1]
# Out:
# ['001002451-02']

# %%
'census_block' in voter_map['001002451-02']['addr_arr'][0]
# Out:
# True

# %%
voter_map['109188400-02']
# Out:
# {'DOB': '4/15/1986',
#  'addr_arr': [{'address': '807 BEACON CIR OAKDALE PA 15071',
#    'census_block': u'420034580002086',
#    'date': datetime.datetime(2018, 8, 24, 0, 0)}],
#  'addresses': {'2018-08': '807 BEACON CIR OAKDALE PA 15071'},
#  'reg_date': datetime.datetime(2018, 8, 24, 0, 0),
#  'reg_info': {'2018-08': {'party': 'NF', 'status': 'A'}}}

# %%
'807 BEACON CIR OAKDALE PA 15071' in non_geolocatable_addrs_set
# Out:
# True

# %%
'807 BEACON CIR OAKDALE PA 15071' in uncomputable_census_block_addrs_set
# Out:
# False

# %%
geocode_address_google('807 BEACON CIR OAKDALE PA 15071')
# Out:
# {u'results': [{u'address_components': [{u'long_name': u'807',
#      u'short_name': u'807',
#      u'types': [u'street_number']},
#     {u'long_name': u'Beacon Circle',
#      u'short_name': u'Beacon Cir',
#      u'types': [u'route']},
#     {u'long_name': u'Oakdale',
#      u'short_name': u'Oakdale',
#      u'types': [u'locality', u'political']},
#     {u'long_name': u'Collier Township',
#      u'short_name': u'Collier Township',
#      u'types': [u'administrative_area_level_3', u'political']},
#     {u'long_name': u'Allegheny County',
#      u'short_name': u'Allegheny County',
#      u'types': [u'administrative_area_level_2', u'political']},
#     {u'long_name': u'Pennsylvania',
#      u'short_name': u'PA',
#      u'types': [u'administrative_area_level_1', u'political']},
#     {u'long_name': u'United States',
#      u'short_name': u'US',
#      u'types': [u'country', u'political']},
#     {u'long_name': u'15071',
#      u'short_name': u'15071',
#      u'types': [u'postal_code']}],
#    u'formatted_address': u'807 Beacon Cir, Oakdale, PA 15071, USA',
#    u'geometry': {u'bounds': {u'northeast': {u'lat': 40.3930951,
#       u'lng': -80.1582646},
#      u'southwest': {u'lat': 40.3929375, u'lng': -80.1584087}},
#     u'location': {u'lat': 40.393051, u'lng': -80.15833959999999},
#     u'location_type': u'ROOFTOP',
#     u'viewport': {u'northeast': {u'lat': 40.39436528029149,
#       u'lng': -80.1569876697085},
#      u'southwest': {u'lat': 40.3916673197085, u'lng': -80.1596856302915}}},
#    u'place_id': u'ChIJYR1LvcZZNIgR6VSw3nXXpAo',
#    u'types': [u'premise']}],
#  u'status': u'OK'}

# %%
get_canonical_coords('807 BEACON CIR OAKDALE PA 15071')

# %%
get_canonical_coords_google('807 BEACON CIR OAKDALE PA 15071')

# %%
addr_to_coords('807 BEACON CIR OAKDALE PA 15071')

# %%
canonical_addr_map['807 BEACON CIR OAKDALE PA 15071']
# Out:
# {'canonical_in_census_db': False,
#  'canonical_in_google_db': True,
#  'census_block': u'420034580002086',
#  'census_value': None,
#  'google_value': u'{"status": "OK", "results": [{"geometry": {"location_type": "ROOFTOP", "bounds": {"northeast": {"lat": 40.3930951, "lng": -80.1582646}, "southwest": {"lat": 40.3929375, "lng": -80.1584087}}, "viewport": {"northeast": {"lat": 40.39436528029149, "lng": -80.1569876697085}, "southwest": {"lat": 40.3916673197085, "lng": -80.1596856302915}}, "location": {"lat": 40.393051, "lng": -80.15833959999999}}, "address_components": [{"long_name": "807", "types": ["street_number"], "short_name": "807"}, {"long_name": "Beacon Circle", "types": ["route"], "short_name": "Beacon Cir"}, {"long_name": "Oakdale", "types": ["locality", "political"], "short_name": "Oakdale"}, {"long_name": "Collier Township", "types": ["administrative_area_level_3", "political"], "short_name": "Collier Township"}, {"long_name": "Allegheny County", "types": ["administrative_area_level_2", "political"], "short_name": "Allegheny County"}, {"long_name": "Pennsylvania", "types": ["administrative_area_level_1", "political"], "short_name": "PA"}, {"long_name": "United States", "types": ["country", "political"], "short_name": "US"}, {"long_name": "15071", "types": ["postal_code"], "short_name": "15071"}], "place_id": "ChIJYR1LvcZZNIgR6VSw3nXXpAo", "formatted_address": "807 Beacon Cir, Oakdale, PA 15071, USA", "types": ["premise"]}]}'}

# %%
addr_to_coords('807 BEACON CIR OAKDALE PA 15071')

# %%
voter_map['109188400-02']
# Out:
# {'DOB': '4/15/1986',
#  'addr_arr': [{'address': '807 BEACON CIR OAKDALE PA 15071',
#    'census_block': u'420034580002086',
#    'date': datetime.datetime(2018, 8, 24, 0, 0)}],
#  'addresses': {'2018-08': '807 BEACON CIR OAKDALE PA 15071'},
#  'reg_date': datetime.datetime(2018, 8, 24, 0, 0),
#  'reg_info': {'2018-08': {'party': 'NF', 'status': 'A'}}}

# %%
# Reset
canonical_addr_map['807 BEACON CIR OAKDALE PA 15071']={'canonical_in_census_db': False,
 'canonical_in_google_db': False,
 'census_block': u'420034580002086',
 'census_value': None,
 'google_value': None}

# %% [markdown]
# # Process addrs_to_blocks_todo_set

# %%
# Construct GeoDataFrame from addrs_to_blocks and coords_to_blocks
todo_addrs_df = pd.DataFrame(addrs_to_blocks, columns=['address_raw'])
todo_geom_df = pd.Series(coords_to_blocks)

# %%
todo_gj = gpd.GeoDataFrame(todo_addrs_df, geometry=todo_geom_df,crs={'init': 'epsg:4326'})

# %%
todo_gj.plot()

# %%
# Do spatial join to get census block for each address 
# Example from:
#    http://localhost:8820/notebooks/projects/demographics/Census-Planning-DB-2018.ipynb
# mob_blkgroups_gj = gpd.sjoin(blkgrps_cent_gj, mob_gj, how="inner", op='within')
todo_cb_gj = gpd.sjoin(todo_gj, ac_cb_gj, how="inner", op='within')

# %%
todo_cb_gj=todo_cb_gj.reset_index()

# %%
todo_cb_gj
# Out:
#      index                                      address_raw  \
# 0        0                 137 HAMILTON DR WEXFORD PA 15090
# 1       94                  520 DOUGLAS DR WEXFORD PA 15090
# 2      198                  506 DOUGLAS DR WEXFORD PA 15090
# 3        1           136 WASHINGTON WAY PITTSBURGH PA 15237
# 4      327           188 WASHINGTON WAY PITTSBURGH PA 15237
# 5        2                 331 ROUP AVE PITTSBURGH PA 15232
# 6        3                317 PARK EDGE DR CLINTON PA 15026
# 7      869                351 PARK EDGE DR CLINTON PA 15026
# 8        4            249 BARBARA DR MC KEES ROCKS PA 15136
# 9      398            247 BARBARA DR MC KEES ROCKS PA 15136
# 10       5                  114 ROBERT ST IMPERIAL PA 15126
# 11     126                  125 ROBERT ST IMPERIAL PA 15126
# 12       6                 203 FAULK DR WAREENDALE PA 15086
# 13     569                125 WATSON DR WARRENDALE PA 15086
# 14     669                144 WATSON DR WARRENDALE PA 15086
# 15       7                 304 DUPONT DR MC DONALD PA 15057
# 16       8       124 BROOKFIELD ESTATES DR WEXFORD PA 15090
# 17     944              122 PINE HOLLOW DR WEXFORD PA 15090
# 18       9              1010 LENOX OVAL PITTSBURGH PA 15237
# 19      10             1812 WATERLEAF CT SEWICKLEY PA 15143
# 20     422             1800 WATERLEAF CT SEWICKLEY PA 15143
# 21      11            2749 STROMBERG ST PITTSBURGH PA 15203
# 22      12                 837 VISTA ST PITTSBURGH PA 15212
# 23      13                  345 RICHARD RD WEXFORD PA 15090
# 24      14                1610 NASH AVE PITTSBURGH PA 15235
# 25      15                 251 JACOB DR PITTSBURGH PA 15235
# 26      16                   126 COVE CT MC DONALD PA 15057
# 28           POINT (-79.95843000000001 40.632767)         8474        42
# 29                    POINT (-80.000305 40.39318)        24092        42
# 30                 POINT (-80.0955269 40.5367815)         8891        42
# 31                 POINT (-80.0902061 40.5347659)         8891        42
# 32                    POINT (-79.98478 40.493515)        17279        42
# 33                 POINT (-79.9208446 40.4169142)         8241        42
# 34                    POINT (-79.920525 40.41872)         8241        42
# 35                    POINT (-79.85525 40.343952)         3918        42
# 36                     POINT (-79.93889 40.54439)        15242        42
# 37                    POINT (-80.08317 40.469105)        14822        42
# 38                    POINT (-80.05242 40.492245)          901        42
# 39                    POINT (-79.81914 40.547424)        21453        42
# 40           POINT (-80.00024000000001 40.342552)         1146        42
# 41                   POINT (-79.846436 40.335865)        20662        42
# 42           POINT (-80.16289499999999 40.493781)        17008        42
# 43                   POINT (-80.029976 40.316826)        22238        42
# 44                     POINT (-80.08543 40.60436)         6354        42
# 45                    POINT (-79.83202 40.335857)         5863        42
# 46                    POINT (-79.97566 40.493847)        12825        42
# 47                   POINT (-80.062836 40.351986)        30491        42
# 48                  POINT (-79.7372819 40.622393)        26056        42
# 49   POINT (-80.22176160000001 40.50681720000001)        23984        42
# ..                                            ...          ...       ...
# 914                   POINT (-79.97682 40.366814)        11925        42
# 915                   POINT (-79.77587 40.393642)        14926        42
# 916                   POINT (-79.84187 40.671623)         7460        42
# 917         POINT (-79.81334059999999 40.4137519)         5024        42
# 918           POINT (-79.81100499999999 40.39724)         5528        42
# 919                   POINT (-80.02721 40.520473)        13925        42
# 920                  POINT (-79.991264 40.458233)         3472        42
# 921                     POINT (-79.8441 40.39999)        12048        42
# 922                   POINT (-79.91468 40.380383)        16052        42
# 923                   POINT (-80.07802 40.410717)        13624        42
# 924           POINT (-80.05652000000001 40.47148)         6495        42
# 925           POINT (-79.82577499999999 40.31095)        18294        42
# 926                   POINT (-79.821724 40.34925)         5384        42
# 927                    POINT (-79.96193 40.46403)        22969        42
# 928                   POINT (-79.90487 40.380047)         5897        42
# 929                    POINT (-79.97017 40.62039)        26617        42
# 930                   POINT (-79.98965 40.428684)         9513        42
# 931                POINT (-80.0208406 40.5715688)        14824        42
# 932            POINT (-79.96277600000001 40.3532)        10572        42
# 933                  POINT (-79.879166 40.417408)        15051        42
# 934          POINT (-79.81225999999999 40.417004)        25171        42
# 935                   POINT (-79.983284 40.38626)         3467        42
# 936                    POINT (-79.74561 40.60646)        28765        42
# 937          POINT (-79.88061999999999 40.426876)        29592        42
# 938                   POINT (-80.07504 40.440834)         4619        42
# 939          POINT (-80.04484600000001 40.430977)        24282        42
# 940                   POINT (-79.95961 40.360344)        10569        42
# 941                   POINT (-79.93187 40.457905)        25836        42
# 942         POINT (-79.90305739999999 40.4022864)         9658        42
# 943                POINT (-79.9049926 40.3180961)         7309        42
# 944                   POINT (-79.88799 40.437675)        20521        42
# 945                  POINT (-79.750275 40.602535)        21706        42
# 946                  POINT (-79.965256 40.614613)        24518        42
# 947                     POINT (-80.196335 40.559)        15292        42
# 948                 POINT (-79.812235 40.3827383)        20916        42
# 949                   POINT (-80.07468 40.394302)         6419        42
# 950          POINT (-79.95270499999999 40.463593)        25603        42
# 951                 POINT (-79.898549 40.2878204)        26246        42
# 952          POINT (-79.84341999999999 40.365265)          341        42
# 953                    POINT (-79.81135 40.38003)        19461        42
# 954           POINT (-79.78306000000001 40.54205)        30201        42
# 955                  POINT (-80.094475 40.407394)        23913        42
# 956          POINT (-79.99326000000001 40.381023)         3146        42
# 957                   POINT (-79.83923 40.517735)        14023        42
# 958          POINT (-79.78942000000001 40.479103)         3052        42
# 959                   POINT (-80.18216 40.403103)        26519        42
# 960                POINT (-79.9400211 40.4625624)         2516        42
# 961                    POINT (-80.02922 40.39225)        26200        42
# 962          POINT (-79.71057999999999 40.464962)         2118        42
# 963                   POINT (-79.87701 40.442627)        20502        42
#
#     COUNTYFP10 TRACTCE10 BLOCKCE10          GEOID10      NAME10 MTFCC10 UR10  \
# 0          003    409000      3052  420034090003052  Block 3052   G5040    R
# 1          003    409000      3052  420034090003052  Block 3052   G5040    R
# 2          003    409000      3052  420034090003052  Block 3052   G5040    R
# 3          003    429300      1014  420034293001014  Block 1014   G5040    U
# 4          003    429300      1014  420034293001014  Block 1014   G5040    U
# 5          003    080700      2002  420030807002002  Block 2002   G5040    U
# 6          003    452000      4002  420034520004002  Block 4002   G5040    R
# 7          003    452000      4002  420034520004002  Block 4002   G5040    R
# 8          003    462100      2019  420034621002019  Block 2019   G5040    U
# 9          003    462100      2019  420034621002019  Block 2019   G5040    U
# 10         003    452000      2032  420034520002032  Block 2032   G5040    R
# 11         003    452000      2032  420034520002032  Block 2032   G5040    R
# 12         003    411000      1057  420034110001057  Block 1057   G5040    U
# 13         003    411000      1057  420034110001057  Block 1057   G5040    U
# 14         003    411000      1057  420034110001057  Block 1057   G5040    U
# 15         003    564000      2010  420035640002010  Block 2010   G5040    U
# 16         003    409000      3008  420034090003008  Block 3008   G5040    U
# 17         003    409000      3008  420034090003008  Block 3008   G5040    U
# 18         003    429201      2008  420034292012008  Block 2008   G5040    U
# 19         003    412001      1004  420034120011004  Block 1004   G5040    U
# 20         003    412001      1004  420034120011004  Block 1004   G5040    U
# 21         003    160800      2008  420031608002008  Block 2008   G5040    U
# 22         003    563200      3003  420035632003003  Block 3003   G5040    U
# 23         003    413100      4010  420034131004010  Block 4010   G5040    U
# 24         003    523702      1019  420035237021019  Block 1019   G5040    U
# 25         003    523300      4008  420035233004008  Block 4008   G5040    U
# 26         003    564000      1079  420035640001079  Block 1079   G5040    R
# 27         003    564000      1079  420035640001079  Block 1079   G5040    R
# 28         003    408001      3023  420034080013023  Block 3023   G5040    U
# 29         003    320600      2006  420033206002006  Block 2006   G5040    U
# 30         003    437000      1015  420034370001015  Block 1015   G5040    U
# 31         003    437000      1015  420034370001015  Block 1015   G5040    U
# 32         003    427200      2017  420034272002017  Block 2017   G5040    U
# 33         003    141400      4014  420031414004014  Block 4014   G5040    U
# 34         003    141400      4014  420031414004014  Block 4014   G5040    U
# 35         003    552300      1008  420035523001008  Block 1008   G5040    U
# 36         003    426800      2000  420034268002000  Block 2000   G5040    U
# 37         003    460002      2001  420034600022001  Block 2001   G5040    U
# 38         003    431100      1018  420034311001018  Block 1018   G5040    U
# 39         003    419000      1051  420034190001051  Block 1051   G5040    U
# 40         003    480102      2013  420034801022013  Block 2013   G5040    U
# 41         003    552400      3003  420035524003003  Block 3003   G5040    U
# 42         003    451300      1004  420034513001004  Block 1004   G5040    U
# 43         003    475301      3014  420034753013014  Block 3014   G5040    U
# 44         003    412001      3001  420034120013001  Block 3001   G5040    U
# 45         003    552400      2001  420035524002001  Block 2001   G5040    U
# 46         003    427000      1002  420034270001002  Block 1002   G5040    U
# 47         003    474101      1027  420034741011027  Block 1027   G5040    U
# 48         003    401300      2007  420034013002007  Block 2007   G5040    U
# 49         003    451105      1011  420034511051011  Block 1011   G5040    U
# ..         ...       ...       ...              ...         ...     ...  ...
# 914        003    478200      1015  420034782001015  Block 1015   G5040    U
# 915        003    564400      4015  420035644004015  Block 4015   G5040    U
# 916        003    407001      2001  420034070012001  Block 2001   G5040    R
# 917        003    509400      2000  420035094002000  Block 2000   G5040    U
# 918        003    508000      1008  420035080001008  Block 1008   G5040    U
# 919        003    430200      2002  420034302002002  Block 2002   G5040    U
# 920        003    240600      2020  420032406002020  Block 2020   G5040    U
# 921        003    512000      1007  420035120001007  Block 1007   G5040    U
# 922        003    310200      1000  420033102001000  Block 1000   G5040    U
# 923        003    468900      1010  420034689001010  Block 1010   G5040    U
# 924        003    464400      4073  420034644004073  Block 4073   G5040    U
# 925        003    496200      4021  420034962004021  Block 4021   G5040    U
# 926        003    503002      2020  420035030022020  Block 2020   G5040    U
# 927        003    060300      1019  420030603001019  Block 1019   G5040    U
# 928        003    484500      1015  420034845001015  Block 1015   G5040    U
# 929        003    408002      2036  420034080022036  Block 2036   G5040    U
# 930        003    170200      1041  420031702001041  Block 1041   G5040    U
# 931        003    413500      2033  420034135002033  Block 2033   G5040    U
# 932        003    480200      1019  420034802001019  Block 1019   G5040    U
# 933        003    515100      1006  420035151001006  Block 1006   G5040    U
# 934        003    509400      2002  420035094002002  Block 2002   G5040    U
# 935        003    290400      2023  420032904002023  Block 2023   G5040    U
# 936        003    402000      3036  420034020003036  Block 3036   G5040    U
# 937        003    515200      1004  420035152001004  Block 1004   G5040    U
# 938        003    465600      1004  420034656001004  Block 1004   G5040    U
# 939        003    563100      1027  420035631001027  Block 1027   G5040    U
# 940        003    480200      1002  420034802001002  Block 1002   G5040    U
# 941        003    070500      3000  420030705003000  Block 3000   G5040    U
# 942        003    483800      3025  420034838003025  Block 3025   G5040    U
# 943        003    491200      1000  420034912001000  Block 1000   G5040    U
# 944        003    560500      2008  420035605002008  Block 2008   G5040    U
# 945        003    403500      4005  420034035004005  Block 4005   G5040    U
# 946        003    414102      1006  420034141021006  Block 1006   G5040    U
# 947        003    446000      1013  420034460001013  Block 1013   G5040    U
# 948        003    507000      2013  420035070002013  Block 2013   G5040    U
# 949        003    470502      2017  420034705022017  Block 2017   G5040    U
# 950        003    080200      2000  420030802002000  Block 2000   G5040    U
# 951        003    492900      2009  420034929002009  Block 2009   G5040    U
# 952        003    486900      2009  420034869002009  Block 2009   G5040    U
# 953        003    507000      2060  420035070002060  Block 2060   G5040    U
# 954        003    417100      2015  420034171002015  Block 2015   G5040    U
# 955        003    468800      3003  420034688003003  Block 3003   G5040    U
# 956        003    320400      1016  420033204001016  Block 1016   G5040    U
# 957        003    525200      1020  420035252001020  Block 1020   G5040    U
# 958        003    523702      2012  420035237022012  Block 2012   G5040    U
# 959        003    455000      1000  420034550001000  Block 1000   G5040    U
# 960        003    080600      1004  420030806001004  Block 1004   G5040    U
# 961        003    191800      4009  420031918004009  Block 4009   G5040    U
# 962        003    526302      4000  420035263024000  Block 4000   G5040    U
# 963        003    561100      1030  420035611001030  Block 1030   G5040    U
#
#     UACE10 UATYP10 FUNCSTAT10    ALAND10  AWATER10   INTPTLAT10    INTPTLON10
# 0     None    None          S   710017.0       0.0  +40.6248273  -080.0467588
# 1     None    None          S   710017.0       0.0  +40.6248273  -080.0467588
# 2     None    None          S   710017.0       0.0  +40.6248273  -080.0467588
# 3    69697       U          S    34400.0       0.0  +40.5527247  -080.0408034
# 4    69697       U          S    34400.0       0.0  +40.5527247  -080.0408034
# 5    69697       U          S    11659.0       0.0  +40.4606761  -079.9349128
# 6     None    None          S  2833561.0       0.0  +40.4803199  -080.3065768
# 7     None    None          S  2833561.0       0.0  +40.4803199  -080.3065768
# 8    69697       U          S    54910.0       0.0  +40.4836335  -080.0844713
# 9    69697       U          S    54910.0       0.0  +40.4836335  -080.0844713
# 10    None    None          S   551076.0       0.0  +40.4615713  -080.2338658
# 11    None    None          S   551076.0       0.0  +40.4615713  -080.2338658
# 12   69697       U          S   337194.0       0.0  +40.6570036  -080.0856303
# 13   69697       U          S   337194.0       0.0  +40.6570036  -080.0856303
# 14   69697       U          S   337194.0       0.0  +40.6570036  -080.0856303
# 15   69697       U          S  1055910.0       0.0  +40.3955104  -080.2090571
# 16   69697       U          S   755386.0       0.0  +40.6406210  -080.0571910
# 17   69697       U          S   755386.0       0.0  +40.6406210  -080.0571910
# 18   69697       U          S     8968.0       0.0  +40.5478333  -080.0156887
# 19   69697       U          S   475579.0       0.0  +40.5997651  -080.0969003
# 20   69697       U          S   475579.0       0.0  +40.5997651  -080.0969003
# 21   69697       U          S    74282.0       0.0  +40.4217809  -079.9672750
# 22   69697       U          S    21401.0       0.0  +40.4583119  -079.9964739
# 23   69697       U          S   148959.0       0.0  +40.6105502  -080.0652582
# 24   69697       U          S   421634.0       0.0  +40.4929595  -079.8026995
# 25   69697       U          S    14192.0       0.0  +40.4672264  -079.8409363
# 26    None    None          S  4517284.0       0.0  +40.4111647  -080.2696561
# 27    None    None          S  4517284.0       0.0  +40.4111647  -080.2696561
# 28   69697       U          S   464617.0       0.0  +40.6353657  -079.9598436
# 29   69697       U          S   290553.0       0.0  +40.3947286  -080.0044311
# 30   69697       U          S  1418860.0       0.0  +40.5319182  -080.0906058
# 31   69697       U          S  1418860.0       0.0  +40.5319182  -080.0906058
# 940  69697       U          S   940064.0       0.0  +40.3641471  -079.9563191
# 941  69697       U          S    71537.0       0.0  +40.4581435  -079.9296219
# 942  69697       U          S     8368.0       0.0  +40.4022931  -079.9031460
# 943  69697       U          S   178481.0       0.0  +40.3194638  -079.9048679
# 944  69697       U          S     7165.0       0.0  +40.4373565  -079.8875682
# 945  69697       U          S    11497.0       0.0  +40.6032716  -079.7497036
# 946  69697       U          S     8817.0       0.0  +40.6146937  -079.9664437
# 947  69697       U          S   300661.0       0.0  +40.5611296  -080.1940867
# 948  69697       U          S    14274.0       0.0  +40.3831119  -079.8125450
# 949  69697       U          S    37286.0       0.0  +40.3941690  -080.0756049
# 950  69697       U          S    21963.0       0.0  +40.4626440  -079.9529972
# 951  69697       U          S    25193.0       0.0  +40.2879779  -079.8971353
# 952  69697       U          S     6831.0       0.0  +40.3649864  -079.8439272
# 953  69697       U          S     6429.0       0.0  +40.3798877  -079.8116758
# 954  69697       U          S     6369.0       0.0  +40.5418293  -079.7833584
# 955  69697       U          S    17506.0       0.0  +40.4078180  -080.0936258
# 956  69697       U          S    12670.0       0.0  +40.3811910  -079.9928185
# 957  69697       U          S     6811.0       0.0  +40.5182308  -079.8389418
# 958  69697       U          S   292739.0       0.0  +40.4847175  -079.7831235
# 959  69697       U          S   114659.0       0.0  +40.4040889  -080.1844385
# 960  69697       U          S    12108.0       0.0  +40.4629780  -079.9398970
# 961  69697       U          S    13913.0       0.0  +40.3928294  -080.0293058
# 962  69697       U          S   477910.0       0.0  +40.4602967  -079.7109659
# 963  69697       U          S     7277.0       0.0  +40.4430131  -079.8777424
#
# [964 rows x 19 columns]

# %%
# Process all the newly processed census blocks into canonical_addr_map
process_addrs_to_cb_into_cam(todo_cb_gj)
# Out:
# Processing took 0:00:00.117206 for 964 addresses

# %%
list(todo_cb_gj.address_raw)
# Out:
# ['205 BROOK ST MC DONALD PA 15057']

# %%
# Make a copy of addrs_to_blocks_todo_set to keep track of what addresses are left
# after we process the ones that came back with valid census blocks
failed_census_block_addrs = addrs_to_blocks_todo_set

# Remove all the elements that successfully generated census blocks
map(failed_census_block_addrs.remove, list(todo_cb_gj.address_raw))

# Update the vids in addrs_to_blocks_update_map={}
for addr in addrs_to_blocks_update_map:
    census_block = None
    # Check if this is a failed address
    if addr in failed_census_block_addrs:
        # Record 'census_block'=None in canonical_addr_map if not already recorded
        if(not 'census_block' in canonical_addr_map[addr]):
            canonical_addr_map[addr]['census_block']=None
    else:
        # Make sure addr is in canonical_addr_map
        if(not addr in canonical_addr_map or not 'census_block' in canonical_addr_map[addr]):
            print "ERROR: Trying to find census block for %s, but missing from canonical_addr_map" % (addr)
            continue
        # It is in canonical_addr_map, record the census block
        census_block = canonical_addr_map[addr]['census_block']
        
    # census_block should either be None or set to a valid value, record it in the relevant voter IDs.
    for vid in addrs_to_blocks_update_map[addr]:
        # Make sure vid is in voter_map
        if(not vid in voter_map):
            print "ERROR: Trying to update %s with census block %s, but missing from voter_map " % (vid, census_block)
            continue
        vrec = voter_map[vid]
        if(not 'addr_arr' in vrec):
            print "ERROR: Trying to update %s with census block %s, but 'addr_arr' missing from voter_map " % (vid, census_block)
            continue
        # Find the entry in addr_arr matching this address
        for i in range(0,len(voter_map[vid]['addr_arr'])):
            if(addr == voter_map[vid]['addr_arr'][i]['address']):
                # Matches! Update census block
                voter_map[vid]['addr_arr'][i]['census_block'] = census_block

# %%
'1741 BRODHEAD RD MOON TWP PA 15108' in addrs_to_blocks_update_map
# Out:
# True

# %%
failed_census_block_addrs
# Out:
# {'61 OLD JACKS RUN RD IRWIN PA 15642',
#  '620 TULLAMORE TRAIL MARS PA 16046',
#  '9441 NOBLESTOWN RD MC DONALD PA 15057'}

# %%
canonical_addr_map['620 TULLAMORE TRAIL MARS PA 16046']
# Out:
# {'canonical_in_census_db': True,
#  'canonical_in_google_db': True,
#  'census_block': None,
#  'census_value': '{"result": {"addressMatches": [], "input": {"benchmark": {"benchmarkName": "Public_AR_Current", "id": "4", "isDefault": false, "benchmarkDescription": "Public Address Ranges - Current Benchmark"}, "address": {"address": "620 TULLAMORE TRAIL MARS PA 16046"}}}}',
#  'google_value': '{"status": "OK", "results": [{"geometry": {"location_type": "APPROXIMATE", "bounds": {"northeast": {"lat": 40.702338, "lng": -80.00406799999999}, "southwest": {"lat": 40.6913781, "lng": -80.0243249}}, "viewport": {"northeast": {"lat": 40.702338, "lng": -80.00406799999999}, "southwest": {"lat": 40.6913781, "lng": -80.0243249}}, "location": {"lat": 40.6958996, "lng": -80.0117254}}, "formatted_address": "Mars, PA 16046, USA", "place_id": "ChIJ_VcUBgaGNIgRYWufKCeQGg0", "address_components": [{"long_name": "Mars", "types": ["locality", "political"], "short_name": "Mars"}, {"long_name": "Adams Township", "types": ["administrative_area_level_3", "political"], "short_name": "Adams Township"}, {"long_name": "Butler County", "types": ["administrative_area_level_2", "political"], "short_name": "Butler County"}, {"long_name": "Pennsylvania", "types": ["administrative_area_level_1", "political"], "short_name": "PA"}, {"long_name": "United States", "types": ["country", "political"], "short_name": "US"}, {"long_name": "16046", "types": ["postal_code"], "short_name": "16046"}], "partial_match": true, "types": ["locality", "political"]}]}'}

# %%
coords = addr_to_coords('9441 NOBLESTOWN RD MC DONALD PA 15057')
print "%f %f" % (coords.y, coords.x)
# Out:
# 40.366776 -80.284990

# %%
# Add failed_census_block_addrs to uncomputable_census_block_addrs_set
uncomputable_census_block_addrs_set = uncomputable_census_block_addrs_set.union(failed_census_block_addrs)
print "Added %d addrs to uncomputable_census_block_addrs_set, size now %d" % (len(failed_census_block_addrs), len(uncomputable_census_block_addrs_set))
# Out:
# Added 3 addrs to uncomputable_census_block_addrs_set, size now 271

# %%
# Reset TODO related variables to be empty
addrs_to_blocks_todo_set=set()
addrs_to_blocks=[]
coords_to_blocks=[]
addrs_to_blocks_update_map={}

# %%
# From ~/education/earthtime/voting/update_vids_in_addrs_to_blocks_update_map_out.txt
# These appear to be addresses that did not match to any of the census blocks
reprocess_addrs = ['14 BEECH ST AMBRIDGE PA 15003',
'245 ERMA ST RD1 MONONGAHELA PA 15063',
'330 CENTER AVE MC DONALD PA 15057',
'10 RIDGE RD RD1 MARS PA 16046',
'123 STATE RTE 30 CLINTON PA 15026',
'44 ROBINSON RUN RD MCDONALD PA 15057',
'2 BEECH ST AMBRIDGE PA 15003',
'114 GRANT ST MCDONALD PA 15057',
'337 CENTER AVE MCDONALD PA 15057',
'232 CENTER AVE CECIL PA 15321',
'1136 US ROUTE 30 CLINTON PA 15026',
'402 SOUTHPOINT CT MCDONALD PA 15057',
'7 2ND ST PITTSBURGH PA 15215',
'535 5TH ST TRAFFORD PA 15085',
'1268 STATE RTE 30 CLINTON PA 15026',
'240 BLYTHE RD BOX MCDONALD PA 15057',
'499 CENTER AVE CECIL PA 15321',
'10 BEECH ST AMBRIDGE PA 15003',
'273 BOCKTOWN RD PO BOX CRESCENT PA 15046',
'215 STATE RTE 136 RD3 BOX MONONGAHELA PA 15063',
'201 MURRYSVILLE RD NEW KENSINGTON PA 15068',
'CHRISTY COR NEW KENSINGTON PA 15068',
'101 RIDGE RD MONONGAHELA PA 15063',
'1280 US ROUTE 30 CLINTON PA 15026']

# %%
reprocess_vids = set()

# %%
for this_addr in reprocess_addrs:
    map(reprocess_vids.add,addrs_to_blocks_update_map[this_addr])

# %%
len(reprocess_vids)
# Out:
# 474

# %%
voter_process_address_history_array(list(reprocess_vids),True)
# Out:
# Processing took 0:00:00.038317 for 474 addresses

# %% [markdown]
# # Test voter_process_address_history_array components

# %%
voter_map[voter_map.keys()[0]]={'DOB': '1/8/1944',
 'addresses': {'2009-07': '415 CHESTNUT ST SPRINGDALE PA 15144',
  '2017-11': '415 CHESTNUT ST SPRINGDALE PA 15144',
  '2018-03': '415 CHESTNUT ST SPRINGDALE PA 15144',
  '2018-08': '415 CHESTNUT ST SPRINGDALE PA 15144'},
 'reg_date': datetime.datetime(1993, 4, 1, 0, 0),
 'reg_info': {'2009-07': {'party': 'D', 'status': 'A'},
  '2017-11': {'party': 'D', 'status': 'A'},
  '2018-03': {'party': 'D', 'status': 'A'},
  '2018-08': {'party': 'D', 'status': 'A'}}}

# %%
voter_map[voter_map.keys()[3]]={'DOB': '8/29/1972',
 'addresses': {'2009-07': '1500 SUGARLOAF DR PITTSBURGH PA 15239',
  '2017-11': '3014 SETTLERS CT MURRYSVILLE PA 15668',
  '2018-03': '3014 SETTLERS CT MURRYSVILLE PA 15668',
  '2018-08': '509 OCTOBER CT PLUM PA 15239'},
 'reg_date': datetime.datetime(1990, 10, 1, 0, 0),
 'reg_info': {'2009-07': {'party': 'R', 'status': 'A'},
  '2017-11': {'party': 'R', 'status': 'A'},
  '2018-03': {'party': 'R', 'status': 'A'},
  '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
i=3
voter_map[voter_map.keys()[i]]
# Out:
# {'DOB': '8/29/1972',
#  'addresses': {'2009-07': '1500 SUGARLOAF DR PITTSBURGH PA 15239',
#   '2017-11': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#   '2018-03': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#   '2018-08': '509 OCTOBER CT PLUM PA 15239'},
#  'reg_date': datetime.datetime(1990, 10, 1, 0, 0),
#  'reg_info': {'2009-07': {'party': 'R', 'status': 'A'},
#   '2017-11': {'party': 'R', 'status': 'A'},
#   '2018-03': {'party': 'R', 'status': 'A'},
#   '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
voter_process_address_history(voter_map.keys()[i], True)
# Out:
# [{'address': '1500 SUGARLOAF DR PITTSBURGH PA 15239',
#   'census_block': u'420035263012005',
#   'date': datetime.datetime(1990, 10, 1, 0, 0)},
#  {'address': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#   'date': datetime.datetime(2017, 11, 30, 0, 0)},
#  {'address': '509 OCTOBER CT PLUM PA 15239',
#   'census_block': None,
#   'date': datetime.datetime(2018, 8, 14, 0, 0)}]

# %%
voter_map[voter_map.keys()[3]]
# Out:
# {'DOB': '8/29/1972',
#  'addr_arr': [{'address': '1500 SUGARLOAF DR PITTSBURGH PA 15239',
#    'census_block': u'420035263012005',
#    'date': datetime.datetime(1990, 10, 1, 0, 0)},
#   {'address': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#    'census_block': u'420035263011014',
#    'date': datetime.datetime(2017, 11, 30, 0, 0)},
#   {'address': '509 OCTOBER CT PLUM PA 15239',
#    'census_block': None,
#    'date': datetime.datetime(2018, 8, 14, 0, 0)}],
#  'addresses': {'2009-07': '1500 SUGARLOAF DR PITTSBURGH PA 15239',
#   '2017-11': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#   '2018-03': '3014 SETTLERS CT MURRYSVILLE PA 15668',
#   '2018-08': '509 OCTOBER CT PLUM PA 15239'},
#  'reg_date': datetime.datetime(1990, 10, 1, 0, 0),
#  'reg_info': {'2009-07': {'party': 'R', 'status': 'A'},
#   '2017-11': {'party': 'R', 'status': 'A'},
#   '2018-03': {'party': 'R', 'status': 'A'},
#   '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
addrs_to_blocks_todo_set
# Out:
# {'3014 SETTLERS CT MURRYSVILLE PA 15668'}

# %%
addrs_to_blocks
# Out:
# ['3014 SETTLERS CT MURRYSVILLE PA 15668']

# %%
coords_to_blocks

# %%
addrs_to_blocks_update_map
# Out:
# {'3014 SETTLERS CT MURRYSVILLE PA 15668': {'002323758-02'}}

# %% [markdown]
# # Generate random points in census blocks

# %%
# From http://localhost:8820/notebooks/projects/demographics/Get%20random%20census%20block%20points%20from%20prototiles.ipynb
import numpy as np
numpy_record_type = [('x','<f4'), ('y','<f4'), ('blockIdx', '<i4'), ('subIdx', '<i4')]
all_pts = np.memmap('prototiles/master-sorted-by-block.bin', dtype=numpy_record_type)

def find_point_idx(block_idx):
    min_idx = 0
    max_idx = len(all_pts) - 1
    while min_idx <= max_idx:
        test_idx = int((min_idx + max_idx) / 2)
        if block_idx > all_pts[test_idx][2]:
            min_idx = test_idx + 1
        elif block_idx < all_pts[test_idx][2] or all_pts[test_idx][3] != 0:
            max_idx = test_idx - 1
        else:
            return test_idx
    return [min_idx, max_idx]

        
def block_points(block_idx):
    ret = []
    idx = find_point_idx(block_idx)
    assert all_pts[idx][2] == block_idx and all_pts[idx][3] == 0
    while idx < len(all_pts):
        if all_pts[idx][2] == block_idx:
            ret.append({'x':all_pts[idx][0], 'y':all_pts[idx][1]})
        else:
            break
        idx += 1
    return ret

# %%
import json
block_geoids_2010 = json.load(open('block_geoids_2010.json'))

geoid2idx = {}
for i in range(0, len(block_geoids_2010)):
    geoid2idx[block_geoids_2010[i]] = i+1

# %%
# For each census block, keep track of what voter each index has been assigned to
# Top level key is census block number, secondary key is 'next' for keeping track of the next index to be assigned,
# 'points' for the value returned by block_points, and voter ID: index for other entries
block_id_use_map={}

# %%
# Keep track of which census blocks overflowed the number of points
block_id_overflow_set=set()

# %%
def block_get_voter_coords(census_block, vid):
    if(not census_block in block_id_use_map):
        # Need to create an entry, set 'next' to 0, initialize points
        # First convert from GEOID10 to the index into the block_idx
        block_idx = geoid2idx[census_block]
        point_arr = block_points(block_idx)
        block_id_use_map[census_block]={'next':0, 'points':point_arr, 'numpoints':len(point_arr)}
    # We know census_block is in block_id_use_map (which we may have just added)
    # Check if this voter ID is already registered
    if(vid in block_id_use_map[census_block]):
        # Already assigned, just use the same index as before
        point_idx=block_id_use_map[census_block][vid]
    else:
        # Not yet assigned, take the next available 
        # and increment 'next'
        point_idx = block_id_use_map[census_block]['next']
        if(point_idx>block_id_use_map[census_block]['numpoints']-1):
            # Overflow
            if(not census_block in block_id_overflow_set):
                block_id_overflow_set.add(census_block)
                print "WARNING: overflow in census block %s" % (census_block)
            # For now, just start reassigning numbers back at 0
            point_idx=0
            block_id_use_map[census_block]['next']=0
        block_id_use_map[census_block]['next'] = point_idx + 1
        block_id_use_map[census_block][vid] = point_idx
        
    # Retrieve the webmercator point from the points array.
    # Convert it to lat lon and create a Point to return.
    # Note that WebMercatorToLonLat(x,y) returns [lon, lat]
    # the args to create a Point are also (lon, lat)
    point_xy = block_id_use_map[census_block]['points'][point_idx]
    ll_arr = WebMercatorToLonLat(point_xy['x'],point_xy['y'])
    return Point(ll_arr[0], ll_arr[1])

# %%
def voter_get_coords_for_addr_history(vid, force_update):
    if(not vid in voter_map):
        print "WARNING: %s not in voter_map" % (vid)
        return
    vrec = voter_map[vid]
    if(not 'addr_arr' in vrec):
        print "WARNING: %s missing addr_arr in voter_map, re-run voter_process_address_history_array" % (vid)
        return

    addr_arr = vrec['addr_arr']
    for j in range(0,len(addr_arr)):
        addr_rec = vrec['addr_arr'][j]
        if(not 'census_block' in addr_rec):
            print "WARNING %s: '%s' lacks 'census_block', skipping" % (vid, this_addr)
            continue
        # census_block might be None, in which case don't get coords
        if(addr_rec['census_block']==None):
            continue
        try:
            coords = block_get_voter_coords(addr_rec['census_block'], vid)
            #print "Assigning %r to %s[%d]='%s'"%(coords, vid,j,addr_rec['census_block'])
            #voter_map[vid]['addr_arr'][j]['latlon'] = coords
            addr_rec['latlon'] = coords
        except Exception as e:
            print "ERROR: Exception getting coords for %s[%d]='%s': %s"%(vid,j,addr_rec['census_block'],e)

def voter_get_coords_for_addr_history_array(vid_arr, force_update):
    start=arrow.now()
    chunk_start_time=start
    chunk_size=10000

    for i in range(0,len(vid_arr)):
        vid = vid_arr[i]
        voter_get_coords_for_addr_history(vid, force_update)
        
        # Handle periodic debug message
        if((i%chunk_size)==0 and i>0):
            print "%d-%d: processing %r, %d in todo set, %d non-geolocatable, %s time elapsed" %(i-(chunk_size-1), i, vid, 
                                                                                                 len(addrs_to_blocks_todo_set), len(non_geolocatable_addrs_set),
                                                                                                 arrow.now()-chunk_start_time)
            addcnt=0
            chunk_start_time=arrow.now()

    end=arrow.now()
    print "Processing took %s for %d addresses" % (str(end-start), len(vid_arr))

# %%
voter_get_coords_for_addr_history_array(all_vids, False)
# Out:
# 1-10000: processing '001910531-02', 0 in todo set, 10752 non-geolocatable, 0:00:17.611181 time elapsed
# 10001-20000: processing '001931879-02', 0 in todo set, 10752 non-geolocatable, 0:00:08.952873 time elapsed
# 20001-30000: processing '001946646-02', 0 in todo set, 10752 non-geolocatable, 0:00:05.611544 time elapsed
# 30001-40000: processing '001964389-02', 0 in todo set, 10752 non-geolocatable, 0:00:03.956679 time elapsed
# 40001-50000: processing '001985312-02', 0 in todo set, 10752 non-geolocatable, 0:00:02.723732 time elapsed
# 50001-60000: processing '002002989-02', 0 in todo set, 10752 non-geolocatable, 0:00:02.207827 time elapsed
# 60001-70000: processing '002018307-02', 0 in todo set, 10752 non-geolocatable, 0:00:01.880395 time elapsed
# 70001-80000: processing '002035528-02', 0 in todo set, 10752 non-geolocatable, 0:00:01.262595 time elapsed
# 80001-90000: processing '002054354-02', 0 in todo set, 10752 non-geolocatable, 0:00:01.020480 time elapsed
# 90001-100000: processing '002069700-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.972449 time elapsed
# 100001-110000: processing '002089750-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.998418 time elapsed
# 110001-120000: processing '002108945-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.909638 time elapsed
# 120001-130000: processing '002126236-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.900039 time elapsed
# 130001-140000: processing '002140140-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.844326 time elapsed
# WARNING: overflow in census block 420034736024005
# 140001-150000: processing '002160886-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.651605 time elapsed
# 150001-160000: processing '002177010-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.599900 time elapsed
# 160001-170000: processing '002193737-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.664466 time elapsed
# 170001-180000: processing '002214913-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.706193 time elapsed
# 180001-190000: processing '002233174-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.680332 time elapsed
# 190001-200000: processing '002249493-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.663212 time elapsed
# WARNING: overflow in census block 420034772004020
# 200001-210000: processing '002264851-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.594131 time elapsed
# 210001-220000: processing '002284992-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.512849 time elapsed
# 220001-230000: processing '002299984-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.535287 time elapsed
# 230001-240000: processing '002318849-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.569383 time elapsed
# 240001-250000: processing '002338848-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.561718 time elapsed
# 250001-260000: processing '002356508-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.570207 time elapsed
# 260001-270000: processing '002371242-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.547149 time elapsed
# 270001-280000: processing '002389748-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.504200 time elapsed
# 280001-290000: processing '002407419-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.470827 time elapsed
# 290001-300000: processing '002423355-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.504157 time elapsed
# 300001-310000: processing '002443761-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.548592 time elapsed
# 310001-320000: processing '002462452-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.535789 time elapsed
# 320001-330000: processing '002479650-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.549543 time elapsed
# 330001-340000: processing '002493599-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.523383 time elapsed
# WARNING: overflow in census block 420034580002003
# WARNING: overflow in census block 420035252002011
# 340001-350000: processing '002514842-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.482671 time elapsed
# WARNING: overflow in census block 420035642003013
# WARNING: overflow in census block 420035627002016
# 350001-360000: processing '002530060-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.466966 time elapsed
# 360001-370000: processing '002547151-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.504479 time elapsed
# 370001-380000: processing '002568214-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.539705 time elapsed
# WARNING: overflow in census block 420034455002051
# 380001-390000: processing '002586349-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.516766 time elapsed
# 390001-400000: processing '002602295-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.507523 time elapsed
# 400001-410000: processing '002618626-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.519743 time elapsed
# 410001-420000: processing '002638141-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.442105 time elapsed
# 420001-430000: processing '002653421-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.485357 time elapsed
# 430001-440000: processing '002673116-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.495538 time elapsed
# WARNING: overflow in census block 420030201004007
# WARNING: overflow in census block 420035170002013
# 440001-450000: processing '002692498-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.546951 time elapsed
# 450001-460000: processing '002709721-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.532649 time elapsed
# 460001-470000: processing '002724004-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.509447 time elapsed
# 470001-480000: processing '002743572-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.480748 time elapsed
# 480001-490000: processing '002760412-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.462045 time elapsed
# 490001-500000: processing '002776667-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.490940 time elapsed
# WARNING: overflow in census block 420034297001021
# WARNING: overflow in census block 420031807003012
# 500001-510000: processing '002797521-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.511268 time elapsed
# 510001-520000: processing '002816183-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.517841 time elapsed
# 520001-530000: processing '002833033-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.578570 time elapsed
# WARNING: overflow in census block 420034120014006
# 530001-540000: processing '002847418-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.516399 time elapsed
# 540001-550000: processing '002868871-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.468213 time elapsed
# WARNING: overflow in census block 420031016001007
# WARNING: overflow in census block 420034706001003
# WARNING: overflow in census block 420034211003045
# WARNING: overflow in census block 420034292012001
# 550001-560000: processing '002883479-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.498296 time elapsed
# 560001-570000: processing '002901369-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.516628 time elapsed
# 570001-580000: processing '002922116-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.513281 time elapsed
# 580001-590000: processing '002939854-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.525025 time elapsed
# 590001-600000: processing '002955305-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.596339 time elapsed
# 600001-610000: processing '002972596-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.478280 time elapsed
# 610001-620000: processing '002991199-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.441315 time elapsed
# 620001-630000: processing '003006802-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.486421 time elapsed
# 630001-640000: processing '003026905-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.491448 time elapsed
# 640001-650000: processing '003046025-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.496104 time elapsed
# 650001-660000: processing '003063318-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.498013 time elapsed
# 660001-670000: processing '003077231-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.506581 time elapsed
# WARNING: overflow in census block 420034511053002
# WARNING: overflow in census block 420030103002002
# WARNING: overflow in census block 420035180012008
# WARNING: overflow in census block 420034802003009
# 670001-680000: processing '004449955-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.467300 time elapsed
# WARNING: overflow in census block 420035644004012
# WARNING: overflow in census block 420034751014005
# 680001-690000: processing '004828083-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.451455 time elapsed
# WARNING: overflow in census block 420034080011000
# 690001-700000: processing '013339997-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.453356 time elapsed
# WARNING: overflow in census block 420034721001012
# WARNING: overflow in census block 420035642003005
# 700001-710000: processing '020025600-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.473625 time elapsed
# WARNING: overflow in census block 420034843001010
# WARNING: overflow in census block 420039804001004
# 710001-720000: processing '020052069-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.503640 time elapsed
# 720001-730000: processing '020115158-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.571863 time elapsed
# WARNING: overflow in census block 420034688002021
# 730001-740000: processing '020178233-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.509764 time elapsed
# WARNING: overflow in census block 420035627002001
# WARNING: overflow in census block 420034323002000
# 740001-750000: processing '020220773-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.571777 time elapsed
# 750001-760000: processing '020280122-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.499076 time elapsed
# 760001-770000: processing '020341224-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.471555 time elapsed
# 770001-780000: processing '020399120-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.451607 time elapsed
# 780001-790000: processing '020426270-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.452725 time elapsed
# WARNING: overflow in census block 420030201002015
# 790001-800000: processing '020493592-02', 0 in todo set, 10752 non-geolocatable, 0:00:00
02', 0 in todo set, 10752 non-geolocatable, 0:00:00.376484 time elapsed
# WARNING: overflow in census block 420034580001000
# WARNING: overflow in census block 420034080013001
# 1100001-1110000: processing '107203224-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.369425 time elapsed
# WARNING: overflow in census block 420039822001016
# WARNING: overflow in census block 420034580002013
# 1110001-1120000: processing '107544887-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.376392 time elapsed
# WARNING: overflow in census block 420034090001030
# 1120001-1130000: processing '107711655-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.371297 time elapsed
# WARNING: overflow in census block 420031702001043
# WARNING: overflow in census block 420030409001000
# 1130001-1140000: processing '107877660-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.370961 time elapsed
# WARNING: overflow in census block 420030708002000
# WARNING: overflow in census block 420034560012016
# 1140001-1150000: processing '107992745-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.358191 time elapsed
# WARNING: overflow in census block 420034090003051
# WARNING: overflow in census block 420030103004005
# WARNING: overflow in census block 420030901002016
# 1150001-1160000: processing '108123484-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.363201 time elapsed
# WARNING: overflow in census block 420031609002009
# 1160001-1170000: processing '108232046-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.366866 time elapsed
# WARNING: overflow in census block 420035639002012
# 1170001-1180000: processing '108731346-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.358638 time elapsed
# WARNING: overflow in census block 420034110001065
# WARNING: overflow in census block 420034011002017
# 1180001-1190000: processing '108956204-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.358956 time elapsed
# WARNING: overflow in census block 420030203001020
# WARNING: overflow in census block 420030804001015
# WARNING: overflow in census block 420030201001006
# WARNING: overflow in census block 420032406001048
# 1190001-1200000: processing '109152327-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.343426 time elapsed
# WARNING: overflow in census block 420034120013002
# WARNING: overflow in census block 420034370001005
# 1200001-1210000: processing '109304328-02', 0 in todo set, 10752 non-geolocatable, 0:00:00.406427 time elapsed
# WARNING: overflow in census block 420030603002030
# Processing took 0:01:41.854877 for 1217523 addresses

# %%
len(block_id_overflow_set)
# Out:
# 90

# %%
overflow_block_ids=list(block_id_overflow_set)
numpoints = map(lambda x: block_id_use_map[x]['numpoints'], overflow_block_ids)
numvoters = map(lambda x: len(block_id_use_map[x])-3, overflow_block_ids)

# %%
overflow_blocks_df=pd.DataFrame(zip(overflow_block_ids,numpoints,numvoters),columns=['GEOID10','numpoints','numvoters'])

# %%
overflow_blocks_df=pd.DataFrame(zip(numpoints,numvoters),columns=['numpoints','numvoters'],index=overflow_block_ids)

# %%
overflow_blocks_df
# Out:
#                  numpoints  numvoters
# 420031702001043        112        119
# 420031609002009         76         88
# 420031702001044         60         87
# 420034742022025        375        415
# 420030201005050         75        383
# 420031414004026         60        123
# 420034090003049         60         78
# 420034323002000        157        192
# 420030103004005         70         81
# 420030201001006        122        123
# 420030201001005         60        184
# 420030201002019        202        239
# 420035140001006        199        225
# 420030201002015         60        202
# 420034291002013         67        103
# 420030201003010         60        193
# 420030201006024         60        186
# 420034011002017         79         84
# 420034772004020        124        440
# 420034292012010         60         87
# 420034690003016         76        105
# 420031115003025         60         74
# 420035644004012         90        127
# 420035252002011         99        377
# 420030901002016         66         89
# 420034110001038        336        458
# 420034560012016        390        419
# 420030510002003       1760       2391
# 420034211003045         62        233
# 420034211003044         66        134
# 420035639002025        112        149
# 420035237022014         76         80
# 420030708002000        194        239
# 420034736024005         61        255
# 420030510001016        101        117
# 420035524001028        106        132
# 420034292012001        324        489
# 420034705022011        295        328
# 420039818001010        112        428
# 420034211003051         61         79
# 420034211003052         70         93
# 420035237023009        289        329
# 420034721001012         64        167
# 420035237023001        564        625
# 420034110001065         94         96
# 420030804001015        174        182
# 420034297001021         60        113
# 420030203001022         60         96
# 420034120014006         68        140
# 420034350002027         94        118
# 420034080011000        128        251
# 420035170002013        167        345
# 420034580001000        254        292
# 420031016001007         60        152
# 420034802003009         60         64
# 420030201004007         60        224
# 420031115004012         96        102
# 420034580003044        128        158
# 420034511053002         60        129
# 420030409001000        146        209
# 420030203001054         60         69
# 420034580002013         96        100
# 420039822001016         68        334
# 420034688002021         60         80
# 420034090003034         70         88
# 420030203001020        778        790
# 420035642003013         60        123
# 420035180012008        135        227
# 420035627002016         60        358
# 420031609001010        488        570
# 420034580002003         72        339
# 420034751014019        131        145
# 420034090001030         70         77
# 420034080013001       1063       1106
# 420031401001004         60         93
# 420035627002001         60        154
# 420035642003005         62         92
# 420034843001010        160        476
# 420034751014005        692       1042
# 420034455003036        178        190
# 420035639002012         60         62
# 420031807003012         60        105
# 420031414005009        137        148
# 420030103002002        198        535
# 420034706001003         71        160
# 420034090003051         60         74
# 420034455002051         60        141
# 420034885002014         65         76
# 420035041001024         96        108
# 420039804001004        191        371

# %%
overflow_blocks_df.to_csv('voters/overflow_blocks_df.csv')

# %% [markdown]
# ## Debug census block dots

# %%
voter_map[all_vids[1]]
# Out:
# {'DOB': '9/29/1926',
#  'addr_arr': [{'address': '500 CHAPEL HARBOR DR PITTSBURGH PA 15238',
#    'census_block': None,
#    'date': datetime.datetime(1956, 1, 1, 0, 0)},
#   {'address': '1094 FOX CHAPEL RD PITTSBURGH PA 15238',
#    'census_block': u'420034220001019',
#    'date': datetime.datetime(2018, 8, 14, 0, 0),
#    'latlon': <shapely.geometry.point.Point at 0x7f4babaa1e90>}],
#  'addresses': {'2017-11': '500 CHAPEL HARBOR DR PITTSBURGH PA 15238',
#   '2018-03': '500 CHAPEL HARBOR DR PITTSBURGH PA 15238',
#   '2018-08': '1094 FOX CHAPEL RD PITTSBURGH PA 15238'},
#  'reg_date': datetime.datetime(1956, 1, 1, 0, 0),
#  'reg_info': {'2017-11': {'party': 'R', 'status': 'A'},
#   '2018-03': {'party': 'R', 'status': 'A'},
#   '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
census_block = voter_map[all_vids[1]]['addr_arr'][1]['census_block']
census_block
# Out:
# u'420034220001019'

# %%
str(block_get_voter_coords(census_block, all_vids[1]))
# Out:
# 'POINT (-79.86298799514771 40.53353520356066)'

# %%
len(block_id_use_map['420030201001005']['points'])
# Out:
# 60

# %%
block_id_use_map['420030201001005']['next']
# Out:
# 184

# %%
block_idx = geoid2idx[census_block]
block_idx
# Out:
# 8118177

# %%
block_points(block_idx)
# Out:
# [{'x': 71.20854, 'y': 96.41904},
#  {'x': 71.20453, 'y': 96.40817},
#  {'x': 71.20712, 'y': 96.419304},
#  {'x': 71.2026, 'y': 96.41814},
#  {'x': 71.20184, 'y': 96.419044},
#  {'x': 71.20506, 'y': 96.415146},
#  {'x': 71.20089, 'y': 96.41163},
#  {'x': 71.20153, 'y': 96.42017},
#  {'x': 71.199326, 'y': 96.410965},
#  {'x': 71.20281, 'y': 96.4192},
#  {'x': 71.203285, 'y': 96.40802},
#  {'x': 71.201454, 'y': 96.418945},
#  {'x': 71.203354, 'y': 96.41212},
#  {'x': 71.204056, 'y': 96.418625},
#  {'x': 71.20275, 'y': 96.410446},
#  {'x': 71.204895, 'y': 96.40982},
#  {'x': 71.2026, 'y': 96.41038},
#  {'x': 71.203415, 'y': 96.41155},
#  {'x': 71.20124, 'y': 96.42053},
#  {'x': 71.201096, 'y': 96.414375},
#  {'x': 71.20246, 'y': 96.40811},
#  {'x': 71.20192, 'y': 96.41548},
#  {'x': 71.20116, 'y': 96.42126},
#  {'x': 71.19984, 'y': 96.40555},
#  {'x': 71.20221, 'y': 96.411545},
#  {'x': 71.19937, 'y': 96.40823},
#  {'x': 71.20224, 'y': 96.40804},
#  {'x': 71.20066, 'y': 96.41177},
#  {'x': 71.20194, 'y': 96.41202},
#  {'x': 71.20285, 'y': 96.41615},
#  {'x': 71.20277, 'y': 96.41098},
#  {'x': 71.19918, 'y': 96.403625},
#  {'x': 71.20154, 'y': 96.420006},
#  {'x': 71.2061, 'y': 96.4173},
#  {'x': 71.20778, 'y': 96.41903},
#  {'x': 71.19911, 'y': 96.40881},
#  {'x': 71.201454, 'y': 96.4068},
#  {'x': 71.20797, 'y': 96.41924},
#  {'x': 71.20696, 'y': 96.41769},
#  {'x': 71.20124, 'y': 96.413445},
#  {'x': 71.201584, 'y': 96.41098},
#  {'x': 71.2079, 'y': 96.41967},
#  {'x': 71.20165, 'y': 96.41652},
#  {'x': 71.203064, 'y': 96.416695},
#  {'x': 71.2015, 'y': 96.41835},
#  {'x': 71.204956, 'y': 96.41751}]

# %% [markdown]
# # Write out dots files

# %%
def color_from_floats(r,g,b):
    return r + g * 256.0 + b * 256.0 * 256.0

def pack_color(color):
    return color['r'] + color['g'] * 256.0 + color['b'] * 256.0 * 256.0;

def parse_color(color):
    color = color.strip()
    c = color
    try:
        if c[0] == '#':
            c = c[1:]
        if len(c) == 3:
            return pack_color({'r': 17 * int(c[0:1], 16),
                               'g': 17 * int(c[1:2], 16),
                               'b': 17 * int(c[2:3], 16)})
        if len(c) == 6:
            return pack_color({'r': int(c[0:2], 16),
                               'g': int(c[2:4], 16),
                               'b': int(c[4:6], 16)})
    except:
        pass
    raise InvalidUsage('Cannot parse color <code><b>%s</b></code> from spreadsheet.<br><br>Color must be in standard web form, <code><b>#RRGGBB</b></code>, where RR, GG, and BB are each two-digit hexadecimal numbers between 00 and FF.<br><br>See <a href="https://www.w3schools.com/colors/colors_picker.asp">HTML Color Picker</a>' % color)

def parse_colors(colors):
    packed = [parse_color(color) for color in colors]
    return numpy.array(packed, dtype = numpy.float32)

# %%
out_suffix="09_17_18_18_18"

# %%
max_datetime = dateparser.parse('12/31/3000')

# %%
start=arrow.now()

dem_a_color = '#0000fb'
rep_a_color = '#db0404'
dem_i_color = '#254b87'
rep_i_color = '#821616'
#other_color = '#decc64'
other_color = '#505050'
unknown_color = '#303030'

def vid_to_color(vid, month_str):
    if (not vid in voter_map):
        return unknown_color
    vrec = voter_map[vid]
    if(month_str in vrec['reg_info']):
        rrec = vrec['reg_info'][month_str]
        if(rrec['party']=='D' and rrec['status']=='A'):
            return dem_a_color
        elif(rrec['party']=='D' and rrec['status']=='I'):
            return dem_i_color
        elif(rrec['party']=='R' and rrec['status']=='A'):
            return rep_a_color
        elif(rrec['party']=='R' and rrec['status']=='I'):
            return rep_i_color
        else:
            return other_color
    return unknown_color

def output_voter_reg_dots_d(vid_arr, suffix):
    # If vid_arr not specified, do all of the keys in voter_map
    if(len(vid_arr)==0):
        vid_arr=voter_map.keys()
        
    # Write out voter registration for each voter in vid_arr
    points = []
    start=arrow.now()
    chunk_start_time=arrow.now()
    chunk_size=1000
    dot_cnt=0
    
    for v_i in range(0,len(vid_arr)):
        try:
            vid = vid_arr[v_i]
            if(not vid in voter_map):
                continue
            vrec = voter_map[vid]

            if(not 'addr_arr' in vrec):
                continue

            # Get the month_str values in sorted order for this voter
            month_strs = sorted(vrec['reg_info'].keys())

            # Keep track of the date of the last datapoint. 
            # Initialize last_date to be the registration date for this voter

            last_date = vrec['reg_date']
            last_color=0


            # Keep track of the index of the next month_str
            next_month_str_i=0

            # Iterate over the addresses in addr_arr
            for a_i in range(0,len(vrec['addr_arr'])):
                addr_rec = vrec['addr_arr'][a_i]
                # If addr_rec is not plottable, skip it
                if(not 'latlon' in addr_rec):
                    continue

                # We have lat/lon for this address, continue
                centroid = addr_rec['latlon']
                if(not centroid):
                    continue

                # Get the start time for this address.
                addr_start_date = vrec['addr_arr'][a_i]['date']

                # Find the end time for this address.
                # If this is the last address 
                # and the voter hasn't moved away, set end_date to max
                addr_end_date=max_datetime
                if(a_i<len(vrec['addr_arr'])-1):
                    # There's another address after this one, set end_date
                    # to the start of the next address
                    addr_end_date = vrec['addr_arr'][a_i+1]['date']
                else:
                    # Check if they moved away
                    moved_ms = check_voter_moved_away(vid)
                    if(moved_ms):
                        addr_end_date = monthstr_to_date_map[moved_ms]
                        if((v_i%chunk_size)==0):
                            print "%s moved away by %s (%s)" % (vid, moved_ms,addr_end_date)

                # Loop over the month strings until we find one that's 
                # >= addr_start_date.  Typically the next one would be, but 
                # it may not be if the previous address was bad
                while(next_month_str_i<(len(month_strs)-1) and monthstr_to_date_map[month_strs[next_month_str_i]]<addr_start_date):
                    # Step forward to the next month
                    next_month_str_i=next_month_str_i+1

                if((v_i%chunk_size)==0):
                    print "%s[%d]: %s - %s [%d of %d]" % (vid, a_i, addr_start_date, addr_end_date, next_month_str_i, len(month_strs))

                # Start with the color of next_month_str_i
                # and last_date = addr_start_date
                last_date = addr_start_date
                while(next_month_str_i < len(month_strs) and monthstr_to_date_map[month_strs[next_month_str_i]]<=addr_end_date):
                    month_str = month_strs[next_month_str_i]
                    did_output_dot=False

                    # Get color for this registration event
                    color = vid_to_color(vid, month_str)

                   # Get range of dates for this color
                    startdate_epoch = GetEpoch(last_date)
                    # If this is the last month, set enddate_epoch to addr_end_date.  Otherwise set it to month_str.
                    end_date = dateparser.parse(month_str)
                    if(next_month_str_i==len(month_strs)-1):
                        end_date = addr_end_date
                    enddate_epoch = GetEpoch(end_date)
                    if(color != None):
                        points += PointToPixelXY(centroid)     
                        points.append(parse_color(color))
                        # Put epoch time for SALEDATE as start valid time, and next_date as end valid time
                        points.append(float(startdate_epoch))
                        points.append(float(enddate_epoch))
                        if((v_i%chunk_size)==0):
                            print "  %s[%d][%s]: %s - %s = %s (len %d)" % (vid, a_i, month_str,last_date, end_date, color, len(points))
                    else:
                        print "Color of %s is None"

                    # Set last_date and last_color for next loop
                    last_date = end_date
                    last_color= color
                    did_output_dot=True
                    dot_cnt=dot_cnt+1
                    # Special case when monthstr_to_date_map[month_strs[next_month_str_i]]==addr_end_date
                    # to break out of the loop without incrementing next_month_str_i.  Otherwise we 
                    # may have a gap at the end
                    if(monthstr_to_date_map[month_strs[next_month_str_i]]>=addr_end_date):
                        break
                    else:
                        next_month_str_i = next_month_str_i+1
                    # End of inner month loop
                # End of middle address_loop
            # End of try block at level of vid
        except:
            print "Unexpected error processing [%d] %s:" % (v_i, vid), sys.exc_info()[0]
            raise

        # Handle periodic debug message
        if((v_i%chunk_size)==0 and v_i>0):
            print "%d-%d: processing %r, %s time elapsed" %(v_i-(chunk_size-1), v_i, vid, arrow.now()-chunk_start_time)
            chunk_start_time=arrow.now()
                
    array.array('f', points).tofile(open(('voting/voter_reg_%s.bin'%suffix), 'wb'))

    end=arrow.now()
    print "Processing took %s for %d dots" % (str(end-start), dot_cnt)

# %%
# Output all the voter dots for Allegheny County
# 17_18_18_18_c is all census_block points with independents in yellow
# 17_18_18_18_d is all census_block points with independents in dark grey
# 09_17_18_18_18_e is all census_block points with independents in dark grey and moved away checking
output_voter_reg_dots_d(all_vids, "09_17_18_18_18_e")
# Out:
# 001002451-02 moved away by 2017-11 (2017-11-30 00:00:00)
# 001002451-02[0]: 1951-01-01 00:00:00 - 2017-11-30 00:00:00 [0 of 1]
#   001002451-02[0][2009-07]: 1951-01-01 00:00:00 - 2017-11-30 00:00:00 = #db0404 (len 5)
# 001324375-02[0]: 2000-01-31 00:00:00 - 2017-11-30 00:00:00 [0 of 5]
#   001324375-02[0][2009-07]: 2000-01-31 00:00:00 - 2009-07-27 00:00:00 = #0000fb (len 17185)
#   001324375-02[0][2017-11]: 2009-07-27 00:00:00 - 2017-11-27 00:00:00 = #0000fb (len 17190)
# 001324375-02[1]: 2017-11-30 00:00:00 - 3000-12-31 00:00:00 [1 of 5]
#   001324375-02[1][2017-11]: 2017-11-30 00:00:00 - 2017-11-27 00:00:00 = #0000fb (len 17195)
#   001324375-02[1][2018-03]: 2017-11-27 00:00:00 - 2018-03-27 00:00:00 = #0000fb (len 17200)
#   001324375-02[1][2018-08]: 2018-03-27 00:00:00 - 2018-08-27 00:00:00 = #0000fb (len 17205)
#   001324375-02[1][2018-10]: 2018-08-27 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len 17210)
# 1-1000: processing '001324375-02', 0:00:05.791827 time elapsed
# 001338012-02[0]: 2002-08-21 00:00:00 - 2017-11-30 00:00:00 [0 of 5]
#   001338012-02[0][2009-07]: 2002-08-21 00:00:00 - 2009-07-27 00:00:00 = #0000fb (len 34140)
#   001338012-02[0][2017-11]: 2009-07-27 00:00:00 - 2017-11-27 00:00:00 = #0000fb (len 34145)
# 001338012-02[1]: 2017-11-30 00:00:00 - 3000-12-31 00:00:00 [1 of 5]
#   001338012-02[1][2017-11]: 2017-11-30 00:00:00 - 2017-11-27 00:00:00 = #0000fb (len 34150)
#   001338012-02[1][2018-03]: 2017-11-27 00:00:00 - 2018-03-27 00:00:00 = #0000fb (len 34155)
#   001338012-02[1][2018-08]: 2018-03-27 00:00:00 - 2018-08-27 00:00:00 = #0000fb (len 34160)
#   001338012-02[1][2018-10]: 2018-08-27 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len 34165)
# 1001-2000: processing '001338012-02', 0:00:05.680722 time elapsed
# 001381520-02[0]: 1996-06-18 00:00:00 - 2017-11-30 00:00:00 [0 of 5]
#   001381520-02[0][2009-07]: 1996-06-18 00:00:00 - 2009-07-27 00:00:00 = #db0404 (len 51560)
#   001381520-02[0][2017-11]: 2009-07-27 00:00:00 - 2017-11-27 00:00:00 = #db0404 (len 51565)
# 001381520-02[1]: 2017-11-30 00:00:00 - 3000-12-31 00:00:00 [1 of 5]
#   001381520-02[1][2017-11]: 2017-11-30 00:00:00 - 2017-11-27 00:00:00 = #db0404 (len 51570)
#   001381520-02[1][2018-03]: 2017-11-27 00:00:00 - 2018-03-27 00:00:00 = #db0404 (len 51575)
#   001381520-02[1][2018-08]: 2018-03-27 00:00:00 - 2018-08-27 00:00:00 = #db0404 (len 51580)
#   001381520-02[1][2018-10]: 2018-08-27 00:00:00 - 3000-12-31 00:00:00 = #db0404 (len 51585)
# 2001-3000: processing '001381520-02', 0:00:05.816453 time elapsed
# 001410718-02[0]: 1997-12-12 00:00:00 - 3000-12-31 00:00:00 [0 of 4]
#   001410718-02[0][2017-11]: 1997-12-12 00:00:00 - 2017-11-27 00:00:00 = #0000fb (len 69305)
#   001410718-02[0][2018-03]: 2017-11-27 00:00:00 - 2018-03-27 00:00:00 = #0000fb (len 69310)
#   001410718-02[0][2018-08]: 2018-03-27 00:00:00 - 2018-08-27 00:00:00 = #0000fb (len 69315)
#   001410718-02[0][2018-10]: 2018-08-27 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len
00:00:00 - 3000-12-31 00:00:00 [0 of 1]
#   109344991-02[0][2018-10]: 2018-10-20 00:00:00 - 3000-12-31 00:00:00 = #db0404 (len 23922325)
# 1212001-1213000: processing '109344991-02', 0:00:05.961829 time elapsed
# 109353496-02[0]: 2018-10-20 00:00:00 - 3000-12-31 00:00:00 [0 of 1]
#   109353496-02[0][2018-10]: 2018-10-20 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len 23927085)
# 1213001-1214000: processing '109353496-02', 0:00:06.026861 time elapsed
# 109362106-02[0]: 2018-10-21 00:00:00 - 3000-12-31 00:00:00 [0 of 1]
#   109362106-02[0][2018-10]: 2018-10-21 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len 23931845)
# 1214001-1215000: processing '109362106-02', 0:00:06.028115 time elapsed
# 109370466-02[0]: 2018-10-22 00:00:00 - 3000-12-31 00:00:00 [0 of 1]
#   109370466-02[0][2018-10]: 2018-10-22 00:00:00 - 3000-12-31 00:00:00 = #0000fb (len 23936590)
# 1215001-1216000: processing '109370466-02', 0:00:05.978887 time elapsed
# 1216001-1217000: processing '109376027-02', 0:00:06.008500 time elapsed
# Processing took 4:46:58.428757 for 4788763 dots

# %%
output_voter_reg_dots_c(vids_15213[0:1000], "1810_15213_c")
# Out:
# 102892955-02[0]: 2010-09-28 00:00:00 - 3000-12-31 00:00:00 [2017-11 at 0]
#   102892955-02[0][2017-11]: 2010-09-28 00:00:00 - 2017-11-26 00:00:00 = #decc64 (len 5)
#   102892955-02[0][2018-03]: 2017-11-26 00:00:00 - 2018-03-26 00:00:00 = #decc64 (len 10)
#   102892955-02[0][2018-08]: 2018-03-26 00:00:00 - 3000-12-31 00:00:00 = #decc64 (len 15)
# Processing took 0:00:05.014690 for 3005 dots

# %%
voter_map[all_vids[26]]
# Out:
# {'DOB': '3/6/1968',
#  'addr_arr': [{'address': '206 QUAIL CT BADEN PA 15005',
#    'census_block': u'420034110003006',
#    'date': datetime.datetime(1996, 12, 30, 0, 0),
#    'latlon': <shapely.geometry.point.Point at 0x7f4bf71fdd10>}],
#  'addresses': {'2018-03': '206 QUAIL CT BADEN PA 15005',
#   '2018-08': '206 QUAIL CT BADEN PA 15005'},
#  'reg_date': datetime.datetime(1996, 12, 30, 0, 0),
#  'reg_info': {'2018-03': {'party': 'R', 'status': 'A'},
#   '2018-08': {'party': 'R', 'status': 'A'}}}

# %%
monthstr_to_date_map
# Out:
# {'2009-07': datetime.datetime(2009, 7, 22, 0, 0),
#  '2017-11': datetime.datetime(2017, 11, 30, 0, 0),
#  '2018-03': datetime.datetime(2018, 3, 5, 0, 0),
#  '2018-08': datetime.datetime(2018, 8, 14, 0, 0),
#  '2018-10': datetime.datetime(2018, 10, 16, 0, 0)}

# %%
# This is an old version before adding addr_arr and census block handling
start=arrow.now()

dem_a_color = '#0000fb'
rep_a_color = '#db0404'
dem_i_color = '#254b87'
rep_i_color = '#821616'
other_color = '#decc64'
unknown_color = '#303030'

def vid_to_color(vid, month_str):
    if (not vid in voter_map):
        return unknown_color
    vrec = voter_map[vid]
    if(month_str in vrec['reg_info']):
        rrec = vrec['reg_info'][month_str]
        if(rrec['party']=='D' and rrec['status']=='A'):
            return dem_a_color
        elif(rrec['party']=='D' and rrec['status']=='I'):
            return dem_i_color
        elif(rrec['party']=='R' and rrec['status']=='A'):
            return rep_a_color
        elif(rrec['party']=='R' and rrec['status']=='I'):
            return rep_i_color
        else:
            return other_color
    return unknown_color

def vid_to_coords(vid, month_str):
    if (not vid in voter_map):
        return None
    vrec = voter_map[vid]
    if(month_str in vrec['addresses']):
        addr = vrec['addresses'][month_str]
        # Try coords from census first
        coords = get_canonical_coords(addr)
        if(not coords):
            # Didn't work, try google
            coords = get_canonical_coords_google(addr)
    return coords

def output_voter_reg_dots(vid_arr, suffix):
    # If vid_arr not specified, do all of the keys in voter_map
    if(len(vid_arr)==0):
        vid_arr=voter_map.keys()
        
    # Write out voter registration for each voter in vid_arr
    points = []
    start=arrow.now()
    chunk_start_time=arrow.now()
    chunk_size=1000
    chunk_cnt=0
    
    for vid in vid_arr:
        if(not vid in voter_map):
            continue
        vrec = voter_map[vid]
        
        # Get the month_str values in sorted order for this voter
        month_strs = sorted(vrec['reg_info'].keys())

        # Keep track of the date of the last datapoint. 
        # Initialize last_date to be the registration date for this voter
        
        # Initially, 'reg_date' was a string.  The conversion here was taking 
        # too long, so I converted it to be output from dateparser.parse(vrec['reg_date']) 
        # at ~9am 10/22/18 (_b.pickle and later).  Double check here
        # that the stored type isn't a string and skip if it is.
        if(isinstance(vrec['reg_date'], basestring)):
            print "Unconverted reg_date for %s: %s, skipping" % (vid, vrec['reg_date'])
            continue
            
        last_date = vrec['reg_date']
        last_color=0

        for j in range(0,len(month_strs)):
            month_str = month_strs[j]
            centroid=None
            did_output_dot=False
            try:
                centroid = vid_to_coords(vid, month_str)
                if(not centroid):
                    print "Cannot compute coords for %s, %s = %r, skipping" % (vid, month_str, vrec['addresses'][month_str])
                    continue
            except:
                print "Error computing coords for %s, %s, skipping" % (vid, month_str)
                continue

            try:
                # Handle periodic debug message
                if((chunk_cnt%chunk_size)==0 and chunk_cnt>0):
                    print "%d-%d: processing %r, %s time elapsed" %(chunk_cnt-(chunk_size-1), chunk_cnt, vid, arrow.now()-chunk_start_time)
                    addcnt=0
                    chunk_start_time=arrow.now()

                # Get color for this registration event
                color = vid_to_color(vid, month_str)

                if((chunk_cnt%chunk_size)==0):
                    print "  %s: %s = %s" % (vid, month_str, color)

                # Get range of dates for this color
                startdate_epoch = GetEpoch(last_date)
                # If this is the last month, set enddate_epoch to the far future.  Otherwise set it to month_str.
                end_date = dateparser.parse(month_str)
                enddate_epoch = GetEpoch(end_date)
                if(j==len(month_strs)-1):
                    enddate_epoch = float(1e38)
                if(color != None):
                    points += PointToPixelXY(centroid)     
                    points.append(parse_color(color))
                    # Put epoch time for SALEDATE as start valid time, and next_date as end valid time
                    points.append(float(startdate_epoch))
                    points.append(float(enddate_epoch))
                    #print "  %s: %s - %s = %s (len %d)" % (parid, event_date, next_date, color, len(points))
                else:
                    print "Color of " + str(vid) + " is None"

                # Set last_date and last_color for next loop
                last_date = end_date
                last_color= color
                did_output_dot=True
            except:
                print "Unexpected error processing %s:" % (vid), sys.exc_info()[0]
                raise

            #Increment debug message counter
            if(did_output_dot):
                chunk_cnt = chunk_cnt+1

    array.array('f', points).tofile(open(('voting/voter_reg_%s.bin'%suffix), 'wb'))

    end=arrow.now()
    print "Processing took %s for %d dots" % (str(end-start), chunk_cnt)

# %%
all_vids=sorted(voter_map.keys())

# %%
len(all_vids)
# Out:
# 1196866

# %%
# Output all the voter dots for Allegheny County
output_voter_reg_dots(all_vids, "17_18_18_b")
# Out:
#   001004817-02: 2017-11 = #db0404
# Cannot compute coords for 001008094-02, 2017-11 = '2453 MASONIC DR SEWICKLEY PA 15143', skipping
# Cannot compute coords for 001022781-02, 2017-11 = '332 INDIAN RIDGE DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001039005-02, 2017-11 = '126 JACKSON AVE N PITTSBURGH PA 15202', skipping
# Cannot compute coords for 001057292-02, 2017-11 = '412 GREEN ST MUNHALL PA 15120', skipping
# Cannot compute coords for 001065524-02, 2017-11 = '1604 JEFFERSON RIDGE DR JEFFERSON HILLS PA 15025', skipping
# Cannot compute coords for 001067337-02, 2017-11 = '148 OAKVILLE DR PITTSBURGH PA 15220', skipping
# Cannot compute coords for 001233910-02, 2017-11 = '102 GRAHAM ST S PITTSBURGH PA 15206', skipping
# 1-1000: processing '001303897-02', 0:00:48.397881 time elapsed
#   001303897-02: 2018-08 = #decc64
# Cannot compute coords for 001307339-02, 2017-11 = '2031 BROAD HILL FARMS RD MOON TWP PA 15108', skipping
# Cannot compute coords for 001309404-02, 2017-11 = '1509 STAUNTON DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001310134-02, 2017-11 = '100 W CRESTRIDGE DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001310172-02, 2017-11 = '2407 MASONIC DR SEWICKLEY PA 15143', skipping
# Cannot compute coords for 001310717-02, 2018-08 = '103 LIBERTY CT MOON TWP PA 15108', skipping
# Cannot compute coords for 001311922-02, 2017-11 = '9308 CHRISTOPHER WREN DR WEXFORD PA 15090', skipping
# Cannot compute coords for 001313539-02, 2017-11 = '2141 MASONIC DR SEWICKLEY PA 15143', skipping
# Cannot compute coords for 001314033-02, 2017-11 = '2439 MASONIC DR SEWICKLEY PA 15143', skipping
# Cannot compute coords for 001315470-02, 2017-11 = '2415 MASONIC DR SEWICKLEY PA 15143', skipping
# Cannot compute coords for 001317936-02, 2017-11 = '241 FOXWOOD RD MOON TWP PA 15108', skipping
# Cannot compute coords for 001319036-02, 2017-11 = '477 8TH AVE W HOMESTEAD PA 15120', skipping
# Cannot compute coords for 001320364-02, 2017-11 = '2517 MINTON DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001320627-02, 2018-03 = '38 PARKVIEW DR JT TR CT CLINTON PA 15026', skipping
# Cannot compute coords for 001320627-02, 2018-08 = '38 PARKVIEW DR JT TR CT CLINTON PA 15026', skipping
# Cannot compute coords for 001320746-02, 2018-08 = '9310 LANDING LN MOON TWP PA 15108', skipping
# Cannot compute coords for 001321408-02, 2017-11 = '100 OLDE MANOR LN MOON TWP PA 15108', skipping
# Cannot compute coords for 001321610-02, 2017-11 = '117 WINEBIDDLE ST N PITTSBURGH PA 15224', skipping
# Cannot compute coords for 001322420-02, 2018-08 = '407 POLO CLUB DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001322518-02, 2017-11 = '334 FLAUGHERTY RUN RD RD2 MOON TWP PA 15108', skipping
# Cannot compute coords for 001322644-02, 2017-11 = '1657 CLAIRTON RD RTE 885 WEST MIFFLIN PA 15122', skipping
# 1001-2000: processing '001323172-02', 0:01:13.962620 time elapsed
#   001323172-02: 2018-08 = #821616
# Cannot compute coords for 001323232-02, 2017-11 = '324 COLLEGE PARK DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001324029-02, 2017-11 = '1232 MCKEE ST CRESCENT PA 15046', skipping
# Cannot compute coords for 001324284-02, 2017-11 = '4108 LANDING LN MOON TWP PA 15108', skipping
# Cannot compute coords for 001325924-02, 2017-11 = '400 COLONY WEST DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001326596-02, 2017-11 = '114 MCLAUGHLIN RD MOON TWP PA 15108', skipping
# Cannot compute coords for 001326929-02, 2017-11 = '238 FOXWOOD RD MOON TWP PA 15108', skipping
# Cannot compute coords for 001326946-02, 2017-11 = '321 SEAN DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001327011-02, 2017-11 = '124 RIVER CREST DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001327217-02, 2017-11 = '1294 MAPLE ST CRESCENT PA 15046', skipping
# Cannot compute coords for 001327913-02, 2017-11 = '401 VERANDA LN MOON TWP PA 15108', skipping
# Cannot compute coords for 001328425-02, 2017-11 = '359 RANCHERO DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001328441-02, 2017-11 = '1022 AUTUMN WOODS DR MOON TWP PA 15108', skipping
# Cannot compute coords for 
R MOON TWP PA 15108', skipping
# Cannot compute coords for 001938288-02, 2018-08 = '303 SEASONS CT PITTSBURGH PA 15239', skipping
# Cannot compute coords for 001938302-02, 2017-11 = '301 HAMILTON AVE HARWICK PA 15049', skipping
# Cannot compute coords for 001938340-02, 2017-11 = '407 ABBEYVILLE RD PITTSBURGH PA 15228', skipping
# Cannot compute coords for 001938522-02, 2017-11 = '113 SHADOW LN MOON TWP PA 15108', skipping
# 47001-48000: processing '001938524-02', 0:00:32.078195 time elapsed
#   001938524-02: 2018-03 = #db0404
# Cannot compute coords for 001938552-02, 2017-11 = '242 HAVENWOOD DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001938567-02, 2017-11 = '1705 GREYSTONE DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001938579-02, 2017-11 = '1883 OAKBINE AVE MOON TWP PA 15108', skipping
# Cannot compute coords for 001938608-02, 2017-11 = '389 STARZ RD W GIBSONIA PA 15044', skipping
# Cannot compute coords for 001938839-02, 2017-11 = '108 BRADLEY DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001938975-02, 2017-11 = '929 MONTCLAIR DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001939052-02, 2017-11 = '427 BRADDOCK AVE S PITTSBURGH PA 15221', skipping
# 48001-49000: processing '001939096-02', 0:00:36.968745 time elapsed
#   001939096-02: 2018-03 = #decc64
# Cannot compute coords for 001939120-02, 2017-11 = '123 SCHUCHERT ST PITTSBURGH PA 15210', skipping
# Cannot compute coords for 001939341-02, 2017-11 = '4364 BRIGHTVIEW AVE E PITTSBURGH PA 15227', skipping
# Cannot compute coords for 001939417-02, 2017-11 = '301 VINE ST JEFFERSON HILLS PA 15025', skipping
# Cannot compute coords for 001939595-02, 2017-11 = '3413 WOODWIND DR JEFFERSON HILLS PA 15025', skipping
# 49001-50000: processing '001939689-02', 0:00:27.327783 time elapsed
#   001939689-02: 2018-08 = #db0404
# Cannot compute coords for 001939697-02, 2018-08 = '2207 LINDALON DR MC KEESPORT PA 15135', skipping
# Cannot compute coords for 001940115-02, 2017-11 = '118 DARNLEY DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001940195-02, 2017-11 = '153 ROSEMONT DR MOON TWP PA 15108', skipping
# Cannot compute coords for 001940325-02, 2017-11 = '146 SHEPARD RD GIBSONIA PA 15044', skipping
# Cannot compute coords for 001940325-02, 2018-03 = '146 SHEPARD RD GIBSONIA PA 15044', skipping
# Cannot compute coords for 001940325-02, 2018-08 = '146 SHEPARD RD GIBSONIA PA 15044', skipping
# Cannot compute coords for 001940345-02, 2017-11 = '314 SUNLIGHT DR MOON TWP PA 15108', skipping
# 50001-51000: processing '001940345-02', 0:00:30.116615 time elapsed
#   001940345-02: 2018-08 = #db0404
# Cannot compute coords for 001940468-02, 2017-11 = '107 SPRINGHOUSE DR JEFFERSON HILLS PA 15025', skipping
# Cannot compute coords for 001940499-02, 2017-11 = '333 15TH AVE W HOMESTEAD PA 15120', skipping
# Cannot compute coords for 001940542-02, 2017-11 = '500 CEDAR RUN RD ALLISON PARK PA 15101', skipping
# Cannot compute coords for 001940570-02, 2017-11 = '206 LARKSPUR ST E MUNHALL PA 15120', skipping
# Cannot compute coords for 001940653-02, 2017-11 = '40 JACKSON AVE S PITTSBURGH PA 15202', skipping
# 51001-52000: processing '001940991-02', 0:01:08.295927 time elapsed
#   001940991-02: 2017-11 = #0000fb
# Cannot compute coords for 001941138-02, 2017-11 = '147 JAMESTOWN RD N MOON TWP PA 15108', skipping
# Cannot compute coords for 001941146-02, 2017-11 = '219 11TH ST ASPINWALL PA 15215', skipping
# Cannot compute coords for 001941339-02, 2017-11 = '119 LANSDOWNE DR MOON TWP PA 15108', skipping
# Cannot compute coords for 
for i in range(0,len(all_vids)):
    try:
        vid = all_vids[i]
        vrec = voter_map[vid]
        month_strs = sorted(vrec['reg_info'].keys())
        last_date = dateparser.parse(vrec['reg_date'])
    except Exception as e:
        print "%d: %s failed: %s\n\t%r" % (i,vid,e,vrec)
        failed_vids.append(i)
# Out:
# 352013: 002748431-02 failed: Input type must be str or unicode
# 	{'DOB': '2/22/1943', 'reg_date': nan, 'addresses': {'2018-08': '3080 FELIX DR SOUTH PARK PA 15129', '2018-03': '3080 FELIX DR SOUTH PARK PA 15129', '2017-11': '3080 FELIX DR SOUTH PARK PA 15129'}, 'reg_info': {'2018-08': {'status': 'A', 'party': 'D'}, '2018-03': {'status': 'A', 'party': 'D'}, '2017-11': {'status': 'A', 'party': 'D'}}}

# %%
# Manually fixup Robert Felix to not have a nan reg_date
voter_map['002748431-02']['reg_date']="09/01/1944"

# %%
# Convert all the vrec['reg_date'] to be parsed dates: This only had to be done once!
#for vid in voter_map:
#    voter_map[vid]['reg_date'] = dateparser.parse(voter_map[vid]['reg_date'])

# %%
len(voter_map)
# Out:
# 1217523

# %%
# Get the voter ids for 15213
vids_15213=list(vdf_2018_10[vdf_2018_10['Zip_Code']=='15213'].index)

# %%
len(vids_15213)
# Out:
# 28484

# %%
output_voter_reg_dots(vids_15213, "1808_15213_b")
# Out:
#   102892955-02: 2017-11 = #decc64
# Cannot compute coords for 002489479-02, 2018-08 = '1606 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 107459954-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 003075356-02, 2018-08 = '208 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 105479268-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 012357120-02, 2018-08 = '1008 XAMOS HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021514977-02, 2018-08 = '611 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021559828-02, 2018-08 = '1614 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# 1-1000: processing '104102587-02', 0:00:19.073903 time elapsed
#   104102587-02: 2018-03 = #0000fb
# Cannot compute coords for 020027833-02, 2018-08 = '1714 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 102903510-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020030507-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# 1001-2000: processing '021270770-02', 0:00:02.443980 time elapsed
#   021270770-02: 2017-11 = #254b87
# Cannot compute coords for 002255523-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002716638-02, 2018-08 = '301 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021725610-02, 2018-08 = '606 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002951228-02, 2018-08 = '612 XAMOS HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021828963-02, 2018-08 = '605 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 107394884-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021348147-02, 2018-08 = '808 XAMOS HALL PITTSBURGH PA 15213', skipping
# 2001-3000: processing '103586138-02', 0:00:02.470665 time elapsed
#   103586138-02: 2018-03 = #0000fb
# Cannot compute coords for 021285806-02, 2018-08 = '1414 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002489487-02, 2018-08 = '508 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# 3001-4000: processing '107822162-02', 0:00:03.970465 time elapsed
#   107822162-02: 2017-11 = #0000fb
# Cannot compute coords for 021665840-02, 2018-08 = '1608 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 107803091-02, 2018-08 = '3990 3990 5TH AVE AMOS HALL PITTSBURGH PA 15213', skipping
# 4001-5000: processing '108217838-02', 0:00:09.626806 time elapsed
#   108217838-02: 2017-11 = #db0404
# Cannot compute coords for 021841976-02, 2018-08 = '1206 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 102927326-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 003066572-02, 2018-08 = '1410 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021630237-02, 2018-08 = '601 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021571131-02, 2018-08 = '1214 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 003075379-02, 2018-08 = '307 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021588815-02, 2018-08 = '1717 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# 5001-6000: processing '020717403-02', 0:00:07.737250 time elapsed
#   020717403-02: 2018-03 = #0000fb
# Cannot compute coords for 002598100-02, 2018-08 = '1502 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 
B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002138125-02, 2018-08 = '614 E XSUTHERLAND HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020841577-02, 2018-08 = '1606 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021827393-02, 2018-08 = '1618 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020029919-02, 2018-08 = '1207 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# 73001-74000: processing '107799164-02', 0:00:04.468008 time elapsed
#   107799164-02: 2017-11 = #0000fb
# Cannot compute coords for 021637688-02, 2018-08 = '1103 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021636843-02, 2018-08 = '1003 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 003075345-02, 2018-08 = '1414 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 103772132-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# 74001-75000: processing '021184416-02', 0:00:04.830664 time elapsed
#   021184416-02: 2017-11 = #254b87
# Cannot compute coords for 020387711-02, 2018-08 = '209 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020675981-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021354901-02, 2018-08 = '903 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 104392181-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 106809980-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# 75001-76000: processing '021620026-02', 0:00:02.547946 time elapsed
#   021620026-02: 2017-11 = #decc64
# Cannot compute coords for 002131253-02, 2018-08 = '1501 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020071195-02, 2018-08 = '804 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# 76001-77000: processing '108086619-02', 0:00:06.500762 time elapsed
#   108086619-02: 2017-11 = #decc64
# Cannot compute coords for 002356135-02, 2018-08 = '706 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002958369-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 103769603-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 102926335-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# 77001-78000: processing '105930908-02', 0:00:07.519043 time elapsed
#   105930908-02: 2018-03 = #0000fb
# 78001-79000: processing '020891292-02', 0:00:04.388863 time elapsed
#   020891292-02: 2018-08 = #821616
# Cannot compute coords for 002594105-02, 2018-08 = '626 3 XHOLLAND HALL PITTSBURGH PA 15213', skipping
# Cannot compute coords for 002021371-02, 2018-08 = '212 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 020305845-02, 2018-08 = '804 B XPITT TOWERS PITTSBURGH PA 15213', skipping
# Cannot compute coords for 021692694-02, 2018-08 = '514 A XPITT TOWERS PITTSBURGH PA 15213', skipping
# 79001-80000: processing '107992304-02', 0:00:02.536425 time elapsed
#   107992304-02: 2017-11 = #decc64
# Cannot compute coords for 108066169-02, 2018-08 = '3990 5TH AVE-MCCORMICK HALL PITTSBURGH PA 15213', skipping
# Processing took 0:07:37.268933 for 80184 dots

# %%
voter_map['102892955-02']['addresses']['2018-08']
# Out:
# '3990 A 5TH AVE PITT TOWERS PITTSBURGH PA 15213'

# %%
vdf_2018_08.loc['002021371-02']
# Out:
# Title                                                      NaN
# Last_Name                                         ZAJUCZKOWSKI
# First_Name                                             GREGORY
# Middle_Name                                                  J
# Suffix                                                     NaN
# Sex                                                          M
# Date_Of_Birth                                         1/1/1800
# Date_Registered                                      10/1/2002
# Voter_Status                                                 I
# StatusChangeDate                             1/21/2016 12:52:6
# Political_Party                                             NO
# House__                                                    212
# HouseNoSuffix                                                A
# StreetNameComplete                                XPITT TOWERS
# Apt__                                                        2
# Address_Line_2                                             NaN
# City                                                PITTSBURGH
# State                                                       PA
# Zip_Code                                                 15213
# MAddress_Line_1                                            NaN
# MAddress_Line_2                                            NaN
# MCity                                                      NaN
# MState                                                     NaN
# MZip_Code                                                  NaN
# PollingPlaceDescript                 WILLIAM PITT UNION 1ST FL
# PollPlaceAdd                                  3959 FORBES AVE
# PollPlaceCSZ                             PITTSBURGH, PA  15213
# Last_Date_Voted                                            NaN
# Dist1                                              1.88041e+06
# Dist2                                                      NaN
# Dist3                                                     SC58
# Dist4                                                    MN188
# Dist5                                                    MD227
# Dist6                                                     LG23
# Dist7                                                     SN43
# Dist8                                                     CG18
# Dist9                                                    CPC03
# Dist10                                                   CAC10
# Dist11                                                       2
# Dist12                                                     NaN
# Dist13                                               1880408-1
# Dist14                                                     NaN
# Dist15                                                     NaN
# CustomData1                                          123261190
# Date_Last_Changed                           5/10/2010 10:20:58
# PhoneNumHome                                               NaN
# PR_05_15_18                                                NaN
# PR_05_15_18_VM                                             NaN
# SP_03_13_18                                                NaN
# SP_03_13_18_VM                                             NaN
# SP_03_06_18                                                NaN
# SP_03_06_18_VM                                             NaN
# SP_01_23_18                                                NaN
# SP_01_23_18_VM                                             NaN
# GN_11_07_17                                                NaN
# GN_11_07_17_VM                                             NaN
# PR_05_16_17                                                NaN
# PR_05_16_17_VM                                             NaN
# GN_11_08_16                                                NaN
# GN_11_08_16_VM                                             NaN
# PR_04_26_16                                                NaN
# PR_04_26_16_VM                                             NaN
# GN_11_03_15                                                NaN
# GN_11_03_15_VM                                             NaN
# PR_05_19_15                                                NaN
# PR_05_19_15_VM                                             NaN
# GN_11_04_14                                                NaN
# GN_11_04_14_VM                                             NaN
# PR_05_20_14                                                NaN
# PR_05_20_14_VM                                             NaN
# GN_11_05_13                                                NaN
# GN_11_05_13_VM                                             NaN
# PR_05_21_13                                                NaN
# PR_05_21_13_VM                                             NaN
# GN_11_06_12                                                NaN
# GN_11_06_12_VM                                             NaN
# SP_08_07_12                                                NaN
# SP_08_07_12_VM                                             NaN
# PR_04_24_12                                                NaN
# PR_04_24_12_VM                                             NaN
# GN_11_08_11                                                NaN
# GN_11_08_11_VM                                             NaN
# PR_05_17_11                                                NaN
# PR_05_17_11_VM                                             NaN
# GN_11_02_10                                                NaN
# GN_11_02_10_VM                                             NaN
# address_raw             212 A XPITT TOWERS PITTSBURGH PA 15213
# Name: 002021371-02, dtype: object

# %%
canonical_addr_map['3725 SUTHERLAND DR PITTSBURGH PA 15213']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-4d07443f8751> in <module>()
# ----> 1 canonical_addr_map['3725 SUTHERLAND DR PITTSBURGH PA 15213']
#
# KeyError: '3725 SUTHERLAND DR PITTSBURGH PA 15213'

# %%
get_canonical_coords(voter_map['102892955-02']['addresses']['2018-08'])

# %%
get_canonical_coords_google(voter_map['102892955-02']['addresses']['2018-08'])

# %%
vid_to_coords('021189057-02','2018-08')

# %% [markdown]
# # Archive

# %%
# This version predates addition of addr_arr and census_block IDs to voter map
start=arrow.now()

dem_a_color = '#0000fb'
rep_a_color = '#db0404'
dem_i_color = '#254b87'
rep_i_color = '#821616'
other_color = '#decc64'
unknown_color = '#303030'

def vid_to_color(vid, month_str):
    if (not vid in voter_map):
        return unknown_color
    vrec = voter_map[vid]
    if(month_str in vrec['reg_info']):
        rrec = vrec['reg_info'][month_str]
        if(rrec['party']=='D' and rrec['status']=='A'):
            return dem_a_color
        elif(rrec['party']=='D' and rrec['status']=='I'):
            return dem_i_color
        elif(rrec['party']=='R' and rrec['status']=='A'):
            return rep_a_color
        elif(rrec['party']=='R' and rrec['status']=='I'):
            return rep_i_color
        else:
            return other_color
    return unknown_color

def vid_to_coords(vid, month_str):
    if (not vid in voter_map):
        return None
    vrec = voter_map[vid]
    if(month_str in vrec['addresses']):
        addr = vrec['addresses'][month_str]
        # Try coords from census first
        coords = get_canonical_coords(addr)
        if(not coords):
            # Didn't work, try google
            coords = get_canonical_coords_google(addr)
    return coords

def output_voter_reg_dots(vid_arr, suffix):
    # If vid_arr not specified, do all of the keys in voter_map
    if(len(vid_arr)==0):
        vid_arr=voter_map.keys()
        
    # Write out voter registration for each voter in vid_arr
    points = []
    start=arrow.now()
    chunk_start_time=arrow.now()
    chunk_size=1000
    chunk_cnt=0
    
    for vid in vid_arr:
        if(not vid in voter_map):
            continue
        vrec = voter_map[vid]
        
        # Get the month_str values in sorted order for this voter
        month_strs = sorted(vrec['reg_info'].keys())

        # Keep track of the date of the last datapoint. 
        # Initialize last_date to be the registration date for this voter
        
        # Initially, 'reg_date' was a string.  The conversion here was taking 
        # too long, so I converted it to be output from dateparser.parse(vrec['reg_date']) 
        # at ~9am 10/22/18 (_b.pickle and later).  Double check here
        # that the stored type isn't a string and skip if it is.
        if(isinstance(vrec['reg_date'], basestring)):
            print "Unconverted reg_date for %s: %s, skipping" % (vid, vrec['reg_date'])
            continue
            
        last_date = vrec['reg_date']
        last_color=0

        for j in range(0,len(month_strs)):
            month_str = month_strs[j]
            centroid=None
            did_output_dot=False
            try:
                centroid = vid_to_coords(vid, month_str)
                if(not centroid):
                    print "Cannot compute coords for %s, %s = %r, skipping" % (vid, month_str, vrec['addresses'][month_str])
                    continue
            except:
                print "Error computing coords for %s, %s, skipping" % (vid, month_str)
                continue

            try:
                # Handle periodic debug message
                if((chunk_cnt%chunk_size)==0 and chunk_cnt>0):
                    print "%d-%d: processing %r, %s time elapsed" %(chunk_cnt-(chunk_size-1), chunk_cnt, vid, arrow.now()-chunk_start_time)
                    addcnt=0
                    chunk_start_time=arrow.now()

                # Get color for this registration event
                color = vid_to_color(vid, month_str)

                if((chunk_cnt%chunk_size)==0):
                    print "  %s: %s = %s" % (vid, month_str, color)

                # Get range of dates for this color
                startdate_epoch = GetEpoch(last_date)
                # If this is the last month, set enddate_epoch to the far future.  Otherwise set it to month_str.
                end_date = dateparser.parse(month_str)
                enddate_epoch = GetEpoch(end_date)
                if(j==len(month_strs)-1):
                    enddate_epoch = float(1e38)
                if(color != None):
                    points += PointToPixelXY(centroid)     
                    points.append(parse_color(color))
                    # Put epoch time for SALEDATE as start valid time, and next_date as end valid time
                    points.append(float(startdate_epoch))
                    points.append(float(enddate_epoch))
                    #print "  %s: %s - %s = %s (len %d)" % (parid, event_date, next_date, color, len(points))
                else:
                    print "Color of " + str(vid) + " is None"

                # Set last_date and last_color for next loop
                last_date = end_date
                last_color= color
                did_output_dot=True
            except:
                print "Unexpected error processing %s:" % (vid), sys.exc_info()[0]
                raise

            #Increment debug message counter
            if(did_output_dot):
                chunk_cnt = chunk_cnt+1

    array.array('f', points).tofile(open(('voting/voter_reg_%s.bin'%suffix), 'wb'))

    end=arrow.now()
    print "Processing took %s for %d dots" % (str(end-start), chunk_cnt)
