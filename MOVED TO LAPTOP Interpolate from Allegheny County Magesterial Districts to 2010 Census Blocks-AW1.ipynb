# %%
# Cloned from http://localhost:8815/notebooks/uwsgi/dotmaptiles/data-visualization-tools/examples/lodes/MOVED%20TO%20LAPTOP%20Interpolate%20from%20Allegheny%20County%20Magesterial%20Districts%20to%202010%20Census%20Blocks.ipynb
# on 10/2/18 to work on eviction data from Jeff Benzing at Public Source.

# %%
# Boilerplate from Randy cheatsheet at https://docs.google.com/document/d/1utZuLHcKQEZNXTQLOysTNCxTHrqxczAUymmtplpn27Q/edit#
import pandas as pd
import geopandas as gpd
import numpy as np
from geopandas import GeoSeries, GeoDataFrame
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
# Wide display
from IPython.core.display import display, HTML
display(HTML("<style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>"))
# Out:
# <style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>

# %%
import csv, json, os, numbers, pandas, re, scipy, scipy.sparse, shutil
import subprocess, sys, threading, time, urllib2

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

# %%
# !conda remove -y geos
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for package removal in environment /home/rsargent/anaconda2:
#
# The following packages will be REMOVED:
#
#     fiona:     1.7.0-py27_0
#     geopandas: 0.3.0-py27_0 conda-forge
#     geos:      3.5.1-1      conda-forge
#     libgdal:   2.1.0-0
#     shapely:   1.6.2-py27_0 conda-forge

# %%
import geopandas

#!conda install -y fiona geos psycopg2 pysal shapely 
#!conda install -y -c conda-forge geopandas
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-27-25dcd02d5db2> in <module>()
# ----> 1 import geopandas
#       2
#       3 #!conda install -y fiona geos psycopg2 pysal shapely
#       4 #!conda install -y -c conda-forge geopandas
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/geopandas/__init__.py in <module>()
#       2 from geopandas.geodataframe import GeoDataFrame
#       3
# ----> 4 from geopandas.io.file import read_file
#       5 from geopandas.io.sql import read_postgis
#       6 from geopandas.tools import sjoin
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/geopandas/io/file.py in <module>()
#       1 import os
#       2
# ----> 3 import fiona
#       4 import numpy as np
#       5
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/fiona/__init__.py in <module>()
#      70 from six import string_types
#      71
# ---> 72 from fiona.collection import Collection, BytesCollection, vsi_path
#      73 from fiona._drivers import driver_count, GDALEnv, supported_drivers
#      74 from fiona.odict import OrderedDict
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/fiona/collection.py in <module>()
#       5 import sys
#       6
# ----> 7 from fiona.ogrext import Iterator, ItemsIterator, KeysIterator
#       8 from fiona.ogrext import Session, WritingSession
#       9 from fiona.ogrext import (
#
# ImportError: libgeos-3.4.2.so: cannot open shared object file: No such file or directory

# %%
pandas.options.display.max_colwidth = 300

# %%
districts_gj = urllib2.urlopen('https://data.cmucreatelab.org/earthtime/us/districts.geojson').read()

# %%
geopandas.GeoDataFrame.from_file('evictions/tl_2010_42003_tabblock10.shp')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-c7d582733d6f> in <module>()
# ----> 1 geopandas.GeoDataFrame.from_file('evictions/tl_2010_42003_tabblock10.shp')
#
# NameError: name 'geopandas' is not defined

# %%
# !pwd
# !ls evictions/tl_2010_42003_tabblock10.shp
# Out:
# /workspace2/rsargent/uwsgi/dotmaptiles/data-visualization-tools/examples/lodes
# evictions/tl_2010_42003_tabblock10.shp

# %%
# !conda list
# Out:
# # packages in environment at /home/rsargent/anaconda2:
# #
# _license                  1.1                      py27_1
# alabaster                 0.7.10                   py27_0
# anaconda                  custom                   py27_0
# anaconda-client           1.6.3                    py27_0
# anaconda-navigator        1.6.2                    py27_0
# anaconda-project          0.6.0                    py27_0
# asn1crypto                0.22.0                   py27_0
# astroid                   1.4.9                    py27_0
# astropy                   1.3.2               np112py27_0
# babel                     2.4.0                    py27_0
# backports                 1.0                      py27_0
# backports_abc             0.5                      py27_0
# beautifulsoup4            4.6.0                    py27_0
# bitarray                  0.8.1                    py27_0
# blaze                     0.10.1                   py27_0
# bleach                    1.5.0                    py27_0
# bokeh                     0.12.5                   py27_1
# boto                      2.46.1                   py27_0
# bottleneck                1.2.1               np112py27_0
# cairo                     1.14.8                        0
# cdecimal                  2.3                      py27_2
# cffi                      1.10.0                   py27_0
# chardet                   3.0.3                    py27_0
# click                     6.7                      py27_0
# click-plugins             1.0.3                    py27_0    conda-forge
# cligj                     0.4.0                    py27_0    conda-forge
# cloudpickle               0.2.2                    py27_0
# clyent                    1.2.2                    py27_0
# colorama                  0.3.9                    py27_0
# conda                     4.3.29                   py27_0    conda-forge
# conda-env                 2.6.0                         0    conda-forge
# configparser              3.5.0                    py27_0
# contextlib2               0.5.5                    py27_0
# cryptography              1.8.1                    py27_0
# curl                      7.52.1                        0
# cycler                    0.10.0                   py27_0
# cython                    0.25.2                   py27_0
# cytoolz                   0.8.2                    py27_0
# dask                      0.14.3                   py27_1
# datashape                 0.5.4                    py27_0
# dbus                      1.10.10                       0
# decorator                 4.0.11                   py27_0
# descartes                 1.1.0                    py27_0    conda-forge
# distributed               1.16.3                   py27_0
# docutils                  0.13.1                   py27_0
# entrypoints               0.2.2                    py27_1
# enum34                    1.1.6                    py27_0
# et_xmlfile                1.0.1                    py27_0
# expat                     2.1.0                         0
# fastcache                 1.0.2                    py27_1
# fiona                     1.7.10                   py27_2    conda-forge
# flask                     0.12.2                   py27_0
# flask-cors                3.0.2                    py27_0
# fontconfig                2.12.1                        3
# freetype                  2.5.5                         2
# freexl                    1.0.2                         2    conda-forge
# funcsigs                  1.0.2                    py27_0
# functools32               3.2.3.2                  py27_0
# futures                   3.1.1                    py27_0
# gdal                      2.1.3               np112py27_0    conda-forge
# geopandas                 0.3.0                    py27_0    conda-forge
# geos                      3.5.1                         1    conda-forge
# get_terminal_size         1.0.0                    py27_0
# gevent                    1.2.1                    py27_0
# giflib                    5.1.4                         0    conda-forge
# glib                      2.50.2                        1
# greenlet                  0.4.12                   py27_0
# grin                      1.2.1                    py27_3
# gst-plugins-base          1.8.0                         0
# gstreamer                 1.8.0                         0
# h5py                      2.7.0               np112py27_0
# harfbuzz                  0.9.39                        2
# hdf4                      4.2.12                        0    conda-forge
# hdf5                      1.8.17                        1
# heapdict                  1.0.0                    py27_1
# html5lib                  0.999                    py27_0
# icu                       54.1                          0
# idna                      2.5                      py27_0
# imagesize                 0.7.1                    py27_0
# ipaddress                 1.0.18                   py27_0
# ipykernel                 4.6.1                    py27_0
# ipython                   5.3.0                    py27_0
# ipython_genutils          0.2.0                    py27_0
# ipywidgets                6.0.0                    py27_0
# isort                     4.2.5                    py27_0
# itsdangerous              0.24                     py27_0
# jbig                      2.1                           0
# jdcal                     1.3                      py27_0
# jedi                      0.10.2                   py27_2
# jinja2                    2.9.6                    py27_0
# jpeg                      9b                            0
# json-c                    0.12.1                        0    conda-forge
# jsonschema                2.6.0                    py27_0
# jupyter                   1.0.0                    py27_3
# jupyter_client            5.0.1                    py27_0
# jupyter_console           5.1.0                    py27_0
# jupyter_core              4.3.0                    py27_0
# kealib                    1.4.6                         3    conda-forge
# lazy-object-proxy         1.2.2                    py27_0
# libdap4                   3.18.3                        2    conda-forge
# libffi                    3.2.1                         1
# libgcc                    4.8.5                         2
# libgfortran               3.0.0                         1
# libiconv                  1.14                          4    conda-forge
# libnetcdf                 4.4.1                         0    conda-forge
# libpng                    1.6.27                        0
# libpq                     9.5.4                         0
# libsodium                 1.0.10                        0
# libspatialindex           1.8.5                         1    conda-forge
# libspatialite             4.3.0a                       15    conda-forge
# libtiff                   4.0.6                         3
# libtool                   2.4.2                         0
# libxcb                    1.12                          1
# libxml2                   2.9.4                         0
# libxslt                   1.1.29                        0
# llvmlite                  0.18.0                   py27_0
# locket                    0.2.0                    py27_1
# lxml                      3.7.3                    py27_0
# markupsafe                0.23                     py27_2
# matplotlib                2.0.2               np112py27_0
# mistune                   0.7.4                    py27_0
# mkl                       2017.0.1                      0
# mkl-service               1.1.2                    py27_3
# mpmath                    0.19                     py27_1
# msgpack-python            0.4.8                    py27_0
# multipledispatch          0.4.9                    py27_0
# munch                     2.2.0                    py27_0    conda-forge
# navigator-updater         0.1.0                    py27_0
# nbconvert                 5.1.1                    py27_0
# nbformat                  4.3.0                    py27_0
# networkx                  1.11                     py27_0
# nltk                      3.2.3                    py27_0
# nose                      1.3.7                    py27_1
# notebook                  5.0.0                    py27_0
# numba                     0.33.0              np112py27_0
# numexpr                   2.6.2               np112py27_0
# numpy                     1.12.1                   py27_0
# numpydoc                  0.6.0                    py27_0
# odo                       0.5.0                    py27_1
# olefile                   0.44                     py27_0
# openjpeg                  2.1.2                         2    conda-forge
# openpyxl                  2.4.7                    py27_0
# openssl                   1.0.2l                        0
# packaging                 16.8                     py27_0
# pandas                    0.20.1              np112py27_0
# pandocfilters             1.4.1                    py27_0
# pango                     1.40.3                        1
# partd                     0.3.8                    py27_0
# path.py                   10.3.1                   py27_0
# pathlib2                  2.2.1                    py27_0
# patsy                     0.4.1                    py27_0
# pcre                      8.39                          1
# pep8                      1.7.0                    py27_0
# pexpect                   4.2.1                    py27_0
# pickleshare               0.7.4                    py27_0
# pillow                    4.1.1                    py27_0
# pip                       9.0.1                    py27_1
# pixman                    0.34.0                        0
# ply                       3.10                     py27_0
# proj4                     4.9.3                         5    conda-forge
# prompt_toolkit            1.0.14                   py27_0
# psutil                    5.2.2                    py27_0
# psycopg2                  2.7.1                    py27_0
# ptyprocess                0.5.1                    py27_0
# py                        1.4.33                   py27_0
# pycairo                   1.10.0                   py27_0
# pycosat                   0.6.2                    py27_0
# pycparser                 2.17                     py27_0
# pycrypto                  2.6.1                    py27_6
# pycurl                    7.43.0                   py27_2
# pyflakes                  1.5.0                    py27_0
# pygments                  2.2.0                    py27_0
# pylint                    1.6.4                    py27_1
# pyodbc                    4.0.16                   py27_0
# pyopenssl                 17.0.0                   py27_0
# pyparsing                 2.1.4                    py27_0
# pyproj                    1.9.5.1                  py27_0    conda-forge
# pyqt                      5.6.0                    py27_2
# pysal                     1.14.3                   py27_0    conda-forge
# pytables                  3.3.0               np112py27_0
# pytest                    3.0.7                    py27_0
# python                    2.7.13                        0
# python-dateutil           2.6.0                    py27_0
# pytz                      2017.2                   py27_0
# pywavelets                0.5.2               np112py27_0
# pyyaml                    3.12                     py27_0
# pyzmq                     16.0.2                   py27_0
# qt                        5.6.2                         4
# qtawesome                 0.4.4                    py27_0
# qtconsole                 4.3.0                    py27_0
# qtpy                      1.2.1                    py27_0
# readline                  6.2                           2
# requests                  2.14.2                   py27_0
# rope                      0.9.4                    py27_1
# rtree                     0.8.3                    py27_0    conda-forge
# ruamel_yaml               0.11.14                  py27_1
# scandir                   1.5                      py27_0
# scikit-image              0.13.0              np112py27_0
# scikit-learn              0.18.1              np112py27_1
# scipy                     0.19.0              np112py27_0
# seaborn                   0.7.1                    py27_0
# setuptools                27.2.0                   py27_0
# shapely                   1.6.2                    py27_0    conda-forge
# simplegeneric             0.8.1                    py27_1
# singledispatch            3.4.0.3                  py27_0
# sip                       4.18                     py27_0
# six                       1.10.0                   py27_0
# snowballstemmer           1.2.1                    py27_0
# sortedcollections         0.5.3                    py27_0
# sortedcontainers          1.5.7                    py27_0
# sphinx                    1.5.6                    py27_0
# spyder                    3.1.4                    py27_0
# sqlalchemy                1.1.9                    py27_0
# sqlite                    3.13.0                        0
# ssl_match_hostname        3.4.0.2                  py27_1
# statsmodels               0.8.0               np112py27_0
# subprocess32              3.2.7                    py27_0
# sympy                     1.0                      py27_0
# tblib                     1.3.2                    py27_0
# terminado                 0.6                      py27_0
# testpath                  0.3                      py27_0
# tk                        8.5.18                        0
# toolz                     0.8.2                    py27_0
# tornado                   4.5.1                    py27_0
# traitlets                 4.3.2                    py27_0
# unicodecsv                0.14.1                   py27_0
# unixodbc                  2.3.4                         0
# util-linux                2.21                          0
# uwsgi                     2.0.12                   py27_0    conda-forge
# wcwidth                   0.1.7                    py27_0
# werkzeug                  0.12.2                   py27_0
# wheel                     0.29.0                   py27_0
# widgetsnbextension        2.0.0                    py27_0
# wrapt                     1.10.10                  py27_0
# xerces-c                  3.1.4                         0
# xlrd                      1.0.0                    py27_0
# xlsxwriter                0.9.6                    py27_0
# xlwt                      1.2.0                    py27_0
# xz                        5.2.2                         1
# yaml                      0.1.6                         0
# zeromq                    4.1.5                         0
# zict                      0.1.2                    py27_0
# zlib                      1.2.8                         3

# %%
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /home/rsargent/anaconda2:
#
# The following NEW packages will be INSTALLED:
#
#     click-plugins:   1.0.3-py27_0      conda-forge
#     cligj:           0.4.0-py27_0      conda-forge
#     descartes:       1.1.0-py27_0      conda-forge
#     fiona:           1.7.10-py27_2     conda-forge
#     freexl:          1.0.2-2           conda-forge
#     gdal:            2.1.3-np112py27_0 conda-forge
#     geopandas:       0.3.0-py27_0      conda-forge
#     geos:            3.5.1-1           conda-forge
#     giflib:          5.1.4-0           conda-forge
#     hdf4:            4.2.12-0          conda-forge
#     json-c:          0.12.1-0          conda-forge
#     kealib:          1.4.6-3           conda-forge
#     libdap4:         3.18.3-2          conda-forge
#     libnetcdf:       4.4.1-0           conda-forge
#     libspatialindex: 1.8.5-1           conda-forge
#     libspatialite:   4.3.0a-15         conda-forge
#     munch:           2.2.0-py27_0      conda-forge
#     openjpeg:        2.1.2-2           conda-forge
#     proj4:           4.9.3-5           conda-forge
#     pyproj:          1.9.5.1-py27_0    conda-forge
#     pysal:           1.14.3-py27_0     conda-forge
#     rtree:           0.8.3-py27_0      conda-forge
#     shapely:         1.6.2-py27_0      conda-forge
#     util-linux:      2.21-0
#     xerces-c:        3.1.4-0
#
# The following packages will be UPDATED:
#
#     conda:           4.3.23-py27_0                 --> 4.3.29-py27_0 conda-forge
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#     conda-env:       2.6.0-0                       --> 2.6.0-0       conda-forge
#
# conda-env-2.6. 100% |################################| Time: 0:00:00 673.45 kB/s
# geos-3.5.1-1.t 100% |################################| Time: 0:00:02   7.86 MB/s | Time: 0:00:00   1.05 MB/s                              | Time: 0:00:00   1.39 MB/s MB/s       | Time: 0:00:00   1.79 MB/s5% |#                               | Time: 0:00:00   2.02 MB/s  2.18 MB/s             | Time: 0:00:00   2.43 MB/s1.t   8% |##                              | Time: 0:00:00   2.57 MB/s                   | Time: 0:00:00   2.95 MB/sme: 0:00:00   3.29 MB/s####                           | Time: 0:00:00   3.87 MB/s19% |######                          | Time: 0:00:00   4.31 MB/s   4.27 MB/s              | Time: 0:00:01   4.25 MB/s-1.t  22% |#######                         | Time: 0:00:01   4.25 MB/s                    | Time: 0:00:01   4.39 MB/sime: 0:00:01   4.54 MB/ss#########                       | Time: 0:00:01   4.82 MB/s         | Time: 0:00:01   5.02 MB/s1   5.14 MB/s0:00:01   5.37 MB/sTime: 0:00:01   5.59 MB/s    | Time: 0:00:01   5.78 MB/s.87 MB/s01   6.06 MB/s 0:00:01   6.22 MB/s Time: 0:00:01   6.38 MB/s     | Time: 0:00:01   6.53 MB/s6.59 MB/s:01   6.72 MB/s: 0:00:01   6.85 MB/seos-3.5.1-1.t  67% |#####################           | Time: 0:00:02   6.90 MB/sMB/s% |#######
.10 MB/s####       | Time: 0:00:03   4.09 MB/sp  80% |#########################       | Time: 0:00:03   4.06 MB/s:03   4.05 MB/s###########      | Time: 0:00:03   4.04 MB/s.14.3-p  84% |###########################     | Time: 0:00:03   4.02 MB/s: 0:00:03   4.01 MB/s###################    | Time: 0:00:03   4.00 MB/sysal-1.14.3-p  88% |############################    | Time: 0:00:03   3.98 MB/s| Time: 0:00:03   3.97 MB/s##########################   | Time: 0:00:03   3.97 MB/sMB/s####  | Time: 0:00:03   3.96 MB/s% |##############################  | Time: 0:00:03   3.95 MB/s 3.94 MB/s########### | Time: 0:00:03   3.94 MB/s-p  99% |############################### | Time: 0:00:03   3.94 MB/s
# conda-4.3.29-p 100% |################################| Time: 0:00:00   3.90 MB/s | Time: 0:00:00   3.77 MB/s#######################       | Time: 0:00:00   3.83 MB/s
# descartes-1.1. 100% |################################| Time: 0:00:00   7.30 MB/s
# geopandas-0.3. 100% |################################| Time: 0:00:00   4.92 MB/s | Time: 0:00:00   6.46 MB/s###########                   | Time: 0:00:00   4.93 MB/s MB/s

# %% [markdown]
# ## Download File Templates for 5-year data

# %%
#src = 'https://www2.census.gov/programs-surveys/acs/summary_file/2015/data/2015_1yr_Summary_FileTemplates.zip'
#dest = 'capture/ACS2015_1year/2015_1yr_Summary_FileTemplates.zip'
#download_file(src, dest)
#templates = unzip_file(dest)

def download_file_templates(year):
    src = 'https://www2.census.gov/programs-surveys/acs/summary_file/{year}/data/{year}_5yr_Summary_FileTemplates.zip'.format(**locals())

    # Special-case 2010
    src = src.replace('2010_5yr_Summary_File', '2010_5yr_SummaryFile')
    
    dest = 'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates.zip'.format(**locals())
    download_file(src, dest)
    templates = unzip_file(dest)
    
for year in range(2009, 2016):
    download_file_templates(year)
# Out:
# capture/ACS2009_5year/2009_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2009_5year/2009_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2010_5year/2010_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2010_5year/2010_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2011_5year/2011_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2011_5year/2011_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2012_5year/2012_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2012_5year/2012_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2013_5year/2013_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2013_5year/2013_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2014_5year/2014_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2014_5year/2014_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2015_5year/2015_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2015_5year/2015_5yr_Summary_FileTemplates.zip already unzipped

# %%
# !ls -l capture/ACS2015_1year/2015_1yr_Summary_FileTemplates/Templates | head
# Out:
# total 13192
# -rw-rw-r-- 1 rsargent rsargent  25600 Aug  5  2016 2015_SFGeoFileTemplate.xls
# -rw-rw-r-- 1 rsargent rsargent  92160 Aug  5  2016 Seq100.xls
# -rw-rw-r-- 1 rsargent rsargent  60928 Aug  5  2016 Seq101.xls
# -rw-rw-r-- 1 rsargent rsargent  88064 Aug  5  2016 Seq102.xls
# -rw-rw-r-- 1 rsargent rsargent 115200 Aug  5  2016 Seq103.xls
# -rw-rw-r-- 1 rsargent rsargent  99328 Aug  5  2016 Seq104.xls
# -rw-rw-r-- 1 rsargent rsargent 111104 Aug  5  2016 Seq105.xls
# -rw-rw-r-- 1 rsargent rsargent 107520 Aug  5  2016 Seq106.xls
# -rw-rw-r-- 1 rsargent rsargent  88064 Aug  5  2016 Seq107.xls
# ls: write error: Broken pipe

# %% [markdown]
# ## Download ACS2015 5-year data (tract and block group)

# %%
def download_data(year):
    filename = 'Tracts_Block_Groups_Only'
    if year < 2011:
        filename += '.zip'
    else:
        filename += '.tar.gz'
    src = 'https://www2.census.gov/programs-surveys/acs/summary_file/{year}/data/5_year_entire_sf/{filename}'.format(**locals())
    dest = 'capture/ACS{year}_5year/{filename}'.format(**locals())

    if os.path.exists(dest):
        print '{dest} already exists, skipping'.format(**locals())
    else:
        try:
            os.unlink(filename)
        except OSError:
            pass
        cmd = 'curl'
        cmd += " -H 'User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'"
        cmd += ' {src}'.format(**locals())
        cmd += ' >{dest}'.format(**locals())
        try:
            os.makedirs(os.path.dirname(dest))
        except OSError:
            pass
        print cmd
        subprocess_check(cmd)
        print 'Downloaded to {dest}'.format(**locals())

for year in range(2009, 2016):
    download_data(year)
# Out:
# capture/ACS2009_5year/Tracts_Block_Groups_Only.zip already exists, skipping
# capture/ACS2010_5year/Tracts_Block_Groups_Only.zip already exists, skipping
# capture/ACS2011_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2012_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2013_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2014_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2015_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping

# %%
# !ls -l capture/ACS*/Tracts*
# Out:
# -rw-rw-r-- 1 rsargent rsargent 2806502508 Oct  5 07:52 capture/ACS2009_5year/Tracts_Block_Groups_Only.zip
# -rw-rw-r-- 1 rsargent rsargent 3369803296 Oct  5 07:59 capture/ACS2010_5year/Tracts_Block_Groups_Only.zip
# -rw-rw-r-- 1 rsargent rsargent  749940736 Oct  5 08:02 capture/ACS2011_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3651813394 Oct  5 07:33 capture/ACS2012_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3769295680 Oct  5 07:45 capture/ACS2013_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3757945352 Oct  5 07:59 capture/ACS2014_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3747109902 Dec  2  2016 capture/ACS2015_5year/Tracts_Block_Groups_Only.tar.gz

# %%
    
    
# !mkdir -p capture/ACS2005_5year
# !mv  capture/ACS2005_5year

# !cd capture/ACS2005_5year; tar xvfz Tracts_Block_Groups_Only.tar.gz >/dev/null

# !wget --header="User-Agent: Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.97 Safari/537.11" https://www2.census.gov/programs-surveys/acs/summary_file/2015/data/5_year_entire_sf/2015_ACS_Geography_Files.zip

# !mv 2015_ACS_Geography_Files.zip capture/ACS2005_5year

unzip_file('capture/ACS2005_5year/2015_ACS_Geography_Files.zip')

# %% [markdown]
# ## Read CSV utility functions

# %%
def read_acs2015_5year_template(seqno):
    path = 'capture/ACS2015_5year/2015_5yr_Summary_FileTemplates/2015_5yr_Templates/Seq%d.xls' % seqno
    if not os.path.exists(path):
        return None
    return pandas.read_excel(path)

# Combine template header and data into pandas frame
def read_acs2015_year_data(state, seqno):
    header = read_acs2015_5year_template(seqno)
    data = pandas.read_csv('capture/ACS2015_5year/group2/e20155%s%04d000.txt' % (state, seqno),
                            index_col=False,
                            dtype={'FILEID':numpy.str,
                                   'FILETYPE':numpy.str,
                                   'STUSAB':numpy.str,
                                   'CHARITER':numpy.str,
                                   'SEQUENCE':numpy.str,
                                   'LOGRECNO':numpy.str},
                            header=None,
                            names=header.columns.values)
    return data

# %%
dataset = 'acs2015_5year_tract2010'
column_dir = 'columncache'

# %% [markdown]
# ## Write ACS2015 5-year description.html

# %%
description_path = column_dir + '/' + dataset + '/description.html'
force_regenerate = True

if os.path.exists(description_path) and not force_regenerate:
    print '{description_path} already exists, skipping'.format(**locals())
else:
    table_rows = []

    for seqno in range(1, 1000):
        template = read_acs2015_5year_template(seqno)
        if template is None:
            break
        for col in range(6, template.shape[1]):
            colname = template.columns.values[col]
            description = template.iloc[0,col]
            description = description.replace(':', '')
            description = re.sub(r'\s*%\s*', ' &mdash; ', description)
            table_rows.append(u'<tr><td>{dataset}.{colname}</td><td>{description}</td></tr>\n'.format(**locals()))

    html = '<table>' + ''.join(table_rows) + '</table>'

    open(description_path, 'w').write(html.encode('utf8'))
    print 'Wrote %d column names and descriptions to %s' % (len(table_rows), description_path)

# %% [markdown]
# ## Create ACS2015 block-level population

# %% [markdown]
# ### Read 2010 block geoids and 2010 block populations

# %%
block_populations = numpy.load('columncache/census2010_block2010/p001001.numpy')
print 'block_populations has', sum(block_populations), 'total people'

# %%
block_geoids_2010 = [row[0] for row in query_psql("SELECT geoid2010 FROM sf1_2010_block_p001 order by blockidx2010")]
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-32-4a017443b2f3> in <module>()
# ----> 1 block_geoids_2010 = [row[0] for row in query_psql("SELECT geoid2010 FROM sf1_2010_block_p001 order by blockidx2010")]
#
# <string> in query_psql(query, quiet, database)
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/psycopg2/__init__.pyc in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: No such file or directory
# 	Is the server running locally and accepting
# 	connections on Unix domain socket "/var/run/postgresql/.s.PGSQL.5432"?

# %%
block_geoids_2010 = json.load(open('block_geoids_2010.json'))
print 'There are', len(block_geoids_2010), 'blocks'

assert(len(block_geoids_2010) + 1 == len(block_populations))

# %% [markdown]
# ### Compute 2010 population by tract and block indices from tract

# %%
tract_populations = {}
tract_block_indexes = {}

for block_index_minus_one, block_geoid in enumerate(block_geoids_2010):
    block_index = block_index_minus_one + 1
    tract_name = block_geoid[0:11]
    if tract_name not in tract_populations:
        tract_populations[tract_name] = 0
        tract_block_indexes[tract_name] = []
    tract_populations[tract_name] += block_populations[block_index]
    tract_block_indexes[tract_name].append(block_index)

print 'There are', len(tract_populations), 'tracts'
print 'tract_populations has', sum(tract_populations.values()), 'people'

# %% [markdown]
# ### Map tract identifiers to LOGRECNO using geography file

# %%
tract_to_logrecno = {}

def compute_tract_to_logrecno(state):
    geography = pandas.read_csv('capture/ACS2015_5year/2015_ACS_Geography_Files/g20155{state}.csv'.format(**locals()),
                                dtype=numpy.str,
                                index_col=False,
                                header=None,
                                keep_default_na=False,
                                na_values=[])

    nrows = geography.shape[0]
    print 'State {state} has {nrows} geography rows'.format(**locals())
    
    ntracts = 0
    tract_to_logrecno[state] = {}
    
    for r in range(0, geography.shape[0]):
        aggregation_level = geography.iloc[r, 2]
        if aggregation_level == '140': # census tract
            tract_identifier = geography.iloc[r, 48][7:]
            logrecno = geography.iloc[r, 4]
            tract_to_logrecno[state][tract_identifier] = logrecno
    
    print 'Found %d tracts for state %s' % (len(tract_to_logrecno[state]), state)

for state in state_names:
    compute_tract_to_logrecno(state)

# %% [markdown]
# ### Interpolate and write columns for data file

# %%
# TODO: can we do this with a data frame then write out columns?

def interpolate_acs_file(state, seq):
    print 'Reading %s:%d' % (state, seq)
    data = read_acs2015_year_data(state, seq)

    print 'Mapping locrecno to row'
    logrecnos = data['LOGRECNO']

    logrecno_to_row = {}

    for r, logrecno in enumerate(logrecnos):
        logrecno_to_row[logrecno] = r
    
    col_names = data.columns.values[6:]
    print 'Iterating across %d columns' % len(col_names)
    for col_name in col_names:
        input_col = data[col_name]
        output_col_path = column_dir + '/' + dataset + '/' + col_name + '.float32'
        if os.path.exists(output_col_path):
            print '%s already exists, skipping' % output_col_path
            continue

        output_col = numpy.zeros(block_populations.size, dtype=numpy.float32)

        for tract in sorted(tract_to_logrecno[state].keys()):
            input_pop = input_col[logrecno_to_row[tract_to_logrecno[state][tract]]]
            if not isinstance(input_pop, numbers.Number):
                if input_pop == '.':
                    input_pop = 0
                else:
                    try:
                        input_pop = float(input_pop)
                    except:
                        print 'That population is'
                        print input_pop
                        print type(input_pop)
                        print '>%s<' % input_pop
                        input_pop = 0
            if not tract in tract_block_indexes:
                print 'missing tract {tract} from tract_block_indexes'.format(**locals())
            else:
                for block_index in tract_block_indexes[tract]:
                    if block_populations[block_index]:
                        output_col[block_index] = input_pop * float(block_populations[block_index]) / tract_populations[tract]
            
        output_col.tofile(output_col_path + '.tmp')
        os.rename(output_col_path + '.tmp', output_col_path)
        print 'Created %s' % output_col_path

for seq in range(97, 2000):
    interpolate_acs_file('pa', seq)

# %%
# TODO: can we do this with a data frame then write out columns?

def interpolate_acs_file(seq):
    output_cols = {}
    missing_tracts = {}
    for state in state_names:
        data = read_acs2015_year_data(state, seq)
    
        logrecnos = data['LOGRECNO']

        logrecno_to_row = {}

        col_names = data.columns.values[6:]
        print '%s:%d has %d columns' % (state, seq, len(col_names))
        assert len(col_names) < 500   # sanity check to avoid demanding too much RAM on hal15

        for r, logrecno in enumerate(logrecnos):
            logrecno_to_row[logrecno] = r
    
        for col_name in col_names:
            input_col = data[col_name]
                
            if not col_name in output_cols:
                output_cols[col_name] = numpy.zeros(block_populations.size, dtype=numpy.float32)
            output_col = output_cols[col_name]

            for tract in sorted(tract_to_logrecno[state].keys()):
                input_pop = input_col[logrecno_to_row[tract_to_logrecno[state][tract]]]
                if not isinstance(input_pop, numbers.Number):
                    if input_pop == '.':
                        input_pop = 0
                    else:
                        try:
                            input_pop = float(input_pop)
                        except:
                            print 'That population is'
                            print input_pop
                            print type(input_pop)
                            print '>%s<' % input_pop
                            input_pop = 0
                            
                            
                if not tract in tract_block_indexes:
                    missing_tracts[tract] = True
                else:
                    for block_index in tract_block_indexes[tract]:
                        if block_populations[block_index]:
                            output_col[block_index] = input_pop * float(block_populations[block_index]) / tract_populations[tract]
            
    print 'Missing tracts: %s' % (sorted(missing_tracts.keys()))

    for col_name in sorted(output_cols.keys()):
        output_col_path = column_dir + '/' + dataset + '/' + col_name + '.float32'
        output_cols[col_name].tofile(output_col_path + '.tmp')
        os.rename(output_col_path + '.tmp', output_col_path)
        print 'Created %s with sum %f' % (output_col_path, output_cols[col_name].sum())
    
        
for seq in range(1, 1000):
    interpolate_acs_file(seq)

# %%
len(tract_block_indexes.keys())

# %%
# !ls -l columncache/acs2015_5year_tract2010/B08006_002.float32

# %%
x=numpy.memmap('columncache/acs2015_5year_tract2010/B08006_002.float32', dtype=numpy.float32, mode='r')

# %%
x.sum()

# %% [markdown]
# # Look at eviction data from Jeff Benzing

# %%
jeff_evictions_xls_path = 'evictions/publicsource/AOPC eviction data.xlsx'
je_df = pandas.read_excel(jeff_evictions_xls_path, 'Data', header=1)

# %%
je_df
# Out:
#              DocketType     CaseCategory CountyName CourtOfficeCode  \
# 0       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-0-03
# 1       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-0-03
# 2       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-0-03
# 3       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-0-03
# 4       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 5       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 6       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 7       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 8       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 9       Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 10      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 11      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 12      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 13      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 14      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 15      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 16      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 17      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 18      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 19      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 20      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 21      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 22      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 23      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 24      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 25      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 26      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 27      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 28      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# 29      Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-01
# ...                 ...              ...        ...             ...
# 351377  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351378  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351379  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351380  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351381  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351382  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351383  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351384  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351385  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351386  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351387  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351388  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351389  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351390  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351391  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351392  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351393  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351394  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351395  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351396  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351397  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351398  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351399  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351400  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351401  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351402  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351403  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351404  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351405  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
# 351406  Landlord/Tenant  Landlord/Tenant  Allegheny     MDJ-05-2-31
#
#                     DocketNumber  \
# 0       MJ-05003-LT-0000001-2009
# 1       MJ-05003-LT-0000001-2011
# 2       MJ-05003-LT-0000001-2013
# 3       MJ-05003-LT-0000001-2013
# 4       MJ-05201-LT-0000001-2009
# 5       MJ-05201-LT-0000001-2009
# 6       MJ-05201-LT-0000001-2009
# 7       MJ-05201-LT-0000001-2012
# 8       MJ-05201-LT-0000001-2012
# 9       MJ-05201-LT-0000001-2012
# 10      MJ-05201-LT-0000001-2012
# 11      MJ-05201-LT-0000001-2013
# 12      MJ-05201-LT-0000001-2014
# 13      MJ-05201-LT-0000001-2014
# 14      MJ-05201-LT-0000001-2015
# 15      MJ-05201-LT-0000001-2016
# 16      MJ-05201-LT-0000001-2016
# 17      MJ-05201-LT-0000001-2016
# 2        Inactive      1504.56       Christian, Maureen                    No
# 3        Inactive      1504.56       Christian, Maureen                    No
# 4          Closed      1594.00           Jones, Rob Jr.                    No
# 5          Closed      1594.00           Jones, Rob Jr.                    No
# 6          Closed      1594.00           Jones, Rob Jr.                    No
# 7          Closed      1970.00         Esseller, Joshua                    No
# 8          Closed      1970.00         Esseller, Joshua                    No
# 9          Closed      1970.00         Esseller, Rhonda                    No
# 10         Closed      1970.00         Esseller, Rhonda                    No
# 11         Closed      4194.45            Warr, Barbara                    No
# 12         Closed       959.00      Richard, Ginger Lin                    No
# 13         Closed       959.00      Richard, Ginger Lin                    No
# 14       Inactive      1563.50          Stevens, George                    No
# 15         Closed      2215.00     Puciata, Daniel Ryan                    No
# 16         Closed      2215.00     Puciata, Daniel Ryan                    No
# 17         Closed      2215.00     Puciata, Daniel Ryan                    No
# 18         Closed      1740.00         Frazier, Shariah                    No
# 19         Closed      1740.00         Frazier, Shariah                    No
# 20         Closed      1740.00         Frazier, Shariah                    No
# 21         Closed       700.00             HAY, MICHAEL                    No
# 22         Closed       700.00             HAY, MICHAEL                    No
# 23         Closed      1500.00                Otts, Amy                    No
# 24         Closed      1500.00                Otts, Amy                    No
# 25         Closed      1350.00         Sikorska, Maggie                    No
# 26         Closed      1350.00         Sikorska, Maggie                    No
# 27         Closed         0.00        Ferrara, Kathleen                    No
# 28         Closed      2075.89   Lake, Brent Taylor Jr.                    No
# 29         Closed       544.57    Bryant, Kimberley Ann                    No
# ...           ...          ...                      ...                   ...
# 351377     Closed      1283.94          Keasley, Dorian                    No
# 351378     Closed      1283.94          Keasley, Dorian                    No
# 351379     Closed      1283.94          Keasley, Dorian                    No
# 351380     Closed      1570.00            Seamon, Terri                    No
# 351381     Closed      2062.18        Sinclair, Kristen                    No
# 351382     Closed      2062.18        Sinclair, Kristen                    No
# 351383     Closed      2062.18        Sinclair, Kristen                    No
# 351384     Closed      2555.00          Lannier, Rhonda                    No
# 351385     Closed      2555.00          Lannier, Rhonda                    No
# 351386     Closed      2555.00          Lannier, Rhonda                    No
# 351387     Closed      2400.00    McCall; et al., Gavin                    No
# 351388     Closed      1425.82         Hinton, Victoria                    No
# 351389     Closed      1425.82         Hinton, Victoria                    No
# 351390     Closed      1425.82         Hinton, Victoria                    No
# 351391     Closed      1425.82           Robinson, Joan                    No
# 351392     Closed      1425.82           Robinson, Joan                    No
# 351393     Closed      1425.82           Robinson, Joan                    No
# 351394     Closed      2250.00  McFarland, William Erik                    No
# 351395     Closed      2250.00  McFarland, William Erik                    No
# 351396     Closed      2250.00  McFarland, William Erik                    No
# 351397     Closed      2250.00  McFarland, William Erik                    No
# 351398     Closed      2250.00          Probst, Damisha                    No
# 351399     Closed      2250.00          Probst, Damisha                    No
# 351400     Closed      2250.00          Probst, Damisha                    No
# 351401     Closed      2250.00          Probst, Damisha                    No
# 351402     Closed      3160.00             Gee, William                    No
# 351403     Closed      3160.00             Gee, William                    No
# 351404     Closed      1690.00   Moorefield, Jaquinette                    No
# 351405     Closed      1690.00   Moorefield, Jaquinette                    No
# 351406     Closed      3135.00    Chandrasekhar, Deepak                    No
#
#            FirstName MiddleName        LastName Generation Suffix  \
# 0            Maureen        NaN       Christian        NaN    NaN
# 1            Maureen        NaN       Christian        NaN    NaN
# 2            Maureen        NaN       Christian        NaN    NaN
# 3            Maureen        NaN       Christian        NaN    NaN
# 4                Rob        NaN           Jones        Jr.    NaN
# 5                Rob        NaN           Jones        Jr.    NaN
# 6                Rob        NaN           Jones        Jr.    NaN
# 7             Joshua        NaN        Esseller        NaN    NaN
# 8             Joshua        NaN        Esseller        NaN    NaN
# 9             Rhonda        NaN        Esseller        NaN    NaN
# 10            Rhonda        NaN        Esseller        NaN    NaN
# 11           Barbara        NaN            Warr        NaN    NaN
# 12            Ginger        Lin         Richard        NaN    NaN
# 13            Ginger        Lin         Richard        NaN    NaN
# 14            George        NaN         Stevens        NaN    NaN
# 15            Daniel       Ryan         Puciata        NaN    NaN
# 16            Daniel       Ryan         Puciata        NaN    NaN
# 17            Daniel       Ryan         Puciata        NaN    NaN
# 18           Shariah        NaN         Frazier        NaN    NaN
# 19           Shariah        NaN         Frazier        NaN    NaN
# 20           Shariah        NaN         Frazier        NaN    NaN
# 21           MICHAEL        NaN             HAY        NaN    NaN
# 22           MICHAEL        NaN             HAY        NaN    NaN
# 23               Amy        NaN            Otts        NaN    NaN
# 24               Amy        NaN            Otts        NaN    NaN
# 25            Maggie        NaN        Sikorska        NaN    NaN
# 26            Maggie        NaN        Sikorska        NaN    NaN
# 27          Kathleen        NaN         Ferrara        NaN    NaN
# 28             Brent     Taylor            Lake        Jr.    NaN
# 29         Kimberley        Ann          Bryant        NaN    NaN
# ...              ...        ...             ...        ...    ...
# 351377        Dorian        NaN         Keasley        NaN    NaN
# 351378        Dorian        NaN         Keasley        NaN    NaN
# 351379        Dorian        NaN         Keasley        NaN    NaN
# 351380         Terri        NaN          Seamon        NaN    NaN
# 351381       Kristen        NaN        Sinclair        NaN    NaN
# 351382       Kristen        NaN        Sinclair        NaN    NaN
# 351383       Kristen        NaN        Sinclair        NaN    NaN
# 351384        Rhonda        NaN         Lannier        NaN    NaN
# 351385        Rhonda        NaN         Lannier        NaN    NaN
# 351386        Rhonda        NaN         Lannier        NaN    NaN
# 351387         Gavin        NaN  McCall; et al.        NaN    NaN
# 351388      Victoria        NaN          Hinton        NaN    NaN
# 351389      Victoria        NaN          Hinton        NaN    NaN
# 351390      Victoria        NaN          Hinton        NaN    NaN
# 351391          Joan        NaN        Robinson        NaN    NaN
# 351392          Joan        NaN        Robinson        NaN    NaN
# 351393          Joan        NaN        Robinson        NaN    NaN
# 351394  William Erik        NaN       McFarland        NaN    NaN
# 351395  William Erik        NaN       McFarland        NaN    NaN
# 351396  William Erik        NaN       McFarland        NaN    NaN
# 351397  William Erik        NaN       McFarland        NaN    NaN
# 351398       Damisha        NaN          Probst        NaN    NaN
# 351399       Damisha        NaN          Probst        NaN    NaN
# 351400       Damisha        NaN          Probst        NaN    NaN
# 351401       Damisha        NaN          Probst        NaN    NaN
# 9                           Yes                NaN          Pittsburgh
# 10                          Yes                NaN          Pittsburgh
# 11                           No             Thomas                 NaN
# 12                          Yes                NaN          Pittsburgh
# 13                          Yes                NaN          Pittsburgh
# 14                          Yes                NaN                Mars
# 15                          Yes                NaN          Pittsburgh
# 16                          Yes                NaN          Pittsburgh
# 17                          Yes                NaN          Pittsburgh
# 18                          Yes                NaN          Pittsburgh
# 19                          Yes                NaN          Pittsburgh
# 20                          Yes                NaN          Pittsburgh
# 21                          Yes                NaN                 NaN
# 22                          Yes                NaN                 NaN
# 23                           No            Brandon                 NaN
# 24                           No            Brandon                 NaN
# 25                           No               Paul                 NaN
# 26                           No               Paul                 NaN
# 27                           No               John                 NaN
# 28                           No              Janet                 NaN
# 29                          Yes                NaN          Pittsburgh
# ...                         ...                ...                 ...
# 351377                      Yes                NaN         Monroeville
# 351378                      Yes                NaN         Monroeville
# 351379                      Yes                NaN         Monroeville
# 351380                      Yes                NaN          Pittsburgh
# 351381                      Yes                NaN          Pittsburgh
# 351382                      Yes                NaN          Pittsburgh
# 351383                      Yes                NaN          Pittsburgh
# 351384                       No              James                 NaN
# 351385                       No              James                 NaN
# 351386                       No              James                 NaN
# 351387                      Yes                NaN          Pittsburgh
# 351388                      Yes                NaN          Pittsburgh
# 351389                      Yes                NaN          Pittsburgh
# 351390                      Yes                NaN          Pittsburgh
# 351391                      Yes                NaN          Pittsburgh
# 351392                      Yes                NaN          Pittsburgh
# 351393                      Yes                NaN          Pittsburgh
# 351394                       No              Sally                   A
# 351395                       No              Sally                   A
# 351396                       No              Sally                   A
# 351397                       No              Sally                   A
# 351398                       No              Sally                   A
# 351399                       No              Sally                   A
# 351400                       No              Sally                   A
# 351401                       No              Sally                   A
# 351402                      Yes                NaN          Pittsburgh
# 351403                      Yes                NaN          Pittsburgh
# 351404                       No              James                 NaN
# 351405                       No              James                 NaN
# 351406                      Yes                NaN          Pittsburgh
#
#                          PlaintiffLastName PlaintiffGeneration  \
# 0         Housing Authority Of City Of Pgh                 NaN
# 1       Allegheny County Housing Authority                 NaN
# 2       Allegheny County Housing Authority                 NaN
# 3       Allegheny County Housing Authority                 NaN
# 4                                 Herbinko                 NaN
# 5                                 Herbinko                 NaN
# 6                                 Herbinko                 NaN
# 7                           Gtn Properties                 NaN
# 8                           Gtn Properties                 NaN
# 9                           Gtn Properties                 NaN
# 10                          Gtn Properties                 NaN
# 11                                    Mans                 NaN
# 12                          Freid-El Corp.                 NaN
# 13                          Freid-El Corp.                 NaN
# 14       Keystone Interactive Services Inc                 NaN
# 15           John C R Kelly Realestate Inc                 NaN
# 16           John C R Kelly Realestate Inc                 NaN
# 17           John C R Kelly Realestate Inc                 NaN
# 18                           Freid-El Corp                 NaN
# 19                           Freid-El Corp                 NaN
# 20                           Freid-El Corp                 NaN
# 21                       BCN PROPERTY MGMT                 NaN
# 22                       BCN PROPERTY MGMT                 NaN
# 23                                   Quinn                 NaN
# 24                                   Quinn                 NaN
# 25                                  Miller                 NaN
# 26                                  Miller                 NaN
# 27                              Krebs, Jr.                 NaN
# 28                                   Zubik                 NaN
# 29                          Freid-El Corp.                 NaN
# ...                                    ...                 ...
# 351377             Arbors Management, Inc.                 NaN
# 351378             Arbors Management, Inc.                 NaN
# 351379             Arbors Management, Inc.                 NaN
# 351380                   Alpha Beatty, LLC                 NaN
# 351381     C.A. Properties-Agent For Owner                 NaN
# 351382     C.A. Properties-Agent For Owner                 NaN
# 351383     C.A. Properties-Agent For Owner                 NaN
# 351384                            Wojcicki                 NaN
# 351385                            Wojcicki                 NaN
# 351386                            Wojcicki                 NaN
# 351387                   J.J. Land Company                 NaN
# 351388                   J.J. Land Company                 NaN
# 351389                   J.J. Land Company                 NaN
# 351390                   J.J. Land Company                 NaN
# 351391                   J.J. Land Company                 NaN
# 351392                   J.J. Land Company                 NaN
# 351393                   J.J. Land Company                 NaN
# 351394                             Skarupa                 NaN
# 351395                             Skarupa                 NaN
# 351396                             Skarupa                 NaN
# 351397                             Skarupa                 NaN
# 351398                             Skarupa                 NaN
# 351399                             Skarupa                 NaN
# 351400                             Skarupa                 NaN
# 351401                             Skarupa                 NaN
# 351402                    Negley Neighbors                 NaN
# 351403                    Negley Neighbors                 NaN
# 351404                            Wojcicki                 NaN
# 351405                            Wojcicki                 NaN
# 351406                   J.J. Land Company                 NaN
#
#        PlaintiffSuffix PlaintiffCityName PlaintiffStateCode  \
# 0                  NaN        Pittsburgh                 PA
# 1                  NaN        Pittsburgh                 PA
# 2                  NaN        Pittsburgh                 PA
# 3                  NaN        Pittsburgh                 PA
# 4                  NaN          Bellevue                 PA
# 5                  NaN          Bellevue                 PA
# 6                  NaN          Bellevue                 PA
# 7                  NaN        Pittsburgh                 PA
# 8                  NaN        Pittsburgh                 PA
# 9                  NaN        Pittsburgh                 PA
# 10                 NaN        Pittsburgh                 PA
# 11                 NaN        Pittsburgh                 PA
# 12                 NaN        Pittsburgh                 PA
# 13                 NaN        Pittsburgh                 PA
# 14                 NaN              Mars                 PA
# 15                 NaN        Pittsburgh                 PA
# 16                 NaN        Pittsburgh                 PA
# 17                 NaN        Pittsburgh                 PA
# 18                 NaN        Pittsburgh                 PA
# 19                 NaN        Pittsburgh                 PA
# 20                 NaN        Pittsburgh                 PA
# 21                 NaN        PITTSBURGH                 PA
# 22                 NaN        PITTSBURGH                 PA
# 23                 NaN        Pittsburgh                 PA
# 24                 NaN        Pittsburgh                 PA
# 25                 NaN        Pittsburgh                 PA
# 26                 NaN        Pittsburgh                 PA
# 27                 NaN        Pittsburgh                 PA
# 28                 NaN        Pittsburgh                 PA
# 29                 NaN        Pittsburgh                 PA
# ...                ...               ...                ...
# 351377             NaN       Monroeville                 PA
# 351378             NaN       Monroeville                 PA
# 351379             NaN       Monroeville                 PA
# 351380             NaN        Pittsburgh                 PA
# 351381             NaN        Pittsburgh                 PA
# 351382             NaN        Pittsburgh                 PA
# 351383             NaN        Pittsburgh                 PA
# 351384             NaN        Pittsburgh                 PA
# 351385             NaN        Pittsburgh                 PA
# 351386             NaN        Pittsburgh                 PA
# 25                                          NaN                       NaN
# 26                                          NaN                       NaN
# 27                                          NaN                       NaN
# 28                                          NaN                       NaN
# 29                                          NaN                       NaN
# ...                                         ...                       ...
# 351377                                      NaN                       NaN
# 351378                                      NaN                       NaN
# 351379                                      NaN                       NaN
# 351380                                      NaN                       NaN
# 351381                                      NaN                       NaN
# 351382                                      NaN                       NaN
# 351383                                      NaN                       NaN
# 351384                                      NaN                       NaN
# 351385                                      NaN                       NaN
# 351386                                      NaN                       NaN
# 351387                                      NaN                       NaN
# 351388                                      NaN                       NaN
# 351389                                      NaN                       NaN
# 351390                                      NaN                       NaN
# 351391                                      NaN                       NaN
# 351392                                      NaN                       NaN
# 351393                                      NaN                       NaN
# 351394                                      NaN                       NaN
# 351395                                      NaN                       NaN
# 351396                                      NaN                       NaN
# 351397                                      NaN                       NaN
# 351398                                      NaN                       NaN
# 351399                                      NaN                       NaN
# 351400                                      NaN                       NaN
# 351401                                      NaN                       NaN
# 351402                                      NaN                       NaN
# 351403                                      NaN                       NaN
# 351404                                      NaN                       NaN
# 351405                                      NaN                       NaN
# 351406                                      NaN                       NaN
#
#        Plaintiff Attorney Name  Plaintiff Attorney Supreme Court Number  \
# 0                          NaN                                      NaN
# 1           McPoyle, Thomas J.                                  85811.0
# 2            Lloyd, Bethann R.                                  77385.0
# 3            Lloyd, Bethann R.                                  77385.0
# 4                          NaN                                      NaN
# 5                          NaN                                      NaN
# 6                          NaN                                      NaN
# 7                          NaN                                      NaN
# 8                          NaN                                      NaN
# 9                          NaN                                      NaN
# 10                         NaN                                      NaN
# 11                         NaN                                      NaN
# 12                         NaN                                      NaN
# 13                         NaN                                      NaN
# 14                         NaN                                      NaN
# 15                         NaN                                      NaN
# 16                         NaN                                      NaN
# 17                         NaN                                      NaN
# 18                         NaN                                      NaN
# 19                         NaN                                      NaN
# 20                         NaN                                      NaN
# 21                         NaN                                      NaN
# 22                         NaN                                      NaN
# 23                         NaN                                      NaN
# 24                         NaN                                      NaN
# 25                         NaN                                      NaN
# 26                         NaN                                      NaN
# 27                         NaN                                      NaN
# 28                         NaN                                      NaN
# 29                         NaN                                      NaN
# ...                        ...                                      ...
# 351377                     NaN                                      NaN
# 351378                     NaN                                      NaN
# 351379                     NaN                                      NaN
# 351380       Anderson, Adam G.                                  93538.0
# 351381                     NaN                                      NaN
# 351382                     NaN                                      NaN
# 351383                     NaN                                      NaN
# 351384                     NaN                                      NaN
# 351385                     NaN                                      NaN
# 351386                     NaN                                      NaN
# 351387                     NaN                                      NaN
# 351388                     NaN                                      NaN
# 351389                     NaN                                      NaN
# 351390                     NaN                                      NaN
# 351391                     NaN                                      NaN
# 351392                     NaN                                      NaN
# 351393                     NaN                                      NaN
# 351394                     NaN                                      NaN
# 351395                     NaN                                      NaN
# 351396                     NaN                                      NaN
# 351397                     NaN                                      NaN
# 351398                     NaN                                      NaN
# 351399                     NaN                                      NaN
# 351400                     NaN                                      NaN
# 351401                     NaN                                      NaN
# 351402                     NaN                                      NaN
# 351403                     NaN                                      NaN
# 351404                     NaN                                      NaN
# 351405                     NaN                                      NaN
# 351406                     NaN                                      NaN
#
#         Plaintiff Attorney Phone      Judge Assigned  \
# 0                            NaN    James, Joseph M.
# 1                   4.124023e+09  Ceoffe, Anthony M.
# 2                   4.125536e+09  McDaniel, Donna Jo
# 3                   4.125536e+09  McDaniel, Donna Jo
# 4                            NaN         Smith, Tara
# 5                            NaN         Smith, Tara
# 6                            NaN         Smith, Tara
# 7                            NaN         Smith, Tara
# 8                            NaN         Smith, Tara
# 9                            NaN         Smith, Tara
# 10                           NaN         Smith, Tara
# 11                           NaN         Smith, Tara
# 12                           NaN         Smith, Tara
# 13                           NaN         Smith, Tara
# 14                           NaN         Smith, Tara
# 15                           NaN         Smith, Tara
# 16                           NaN         Smith, Tara
# 17                           NaN         Smith, Tara
# 18                           NaN         Smith, Tara
# 19                           NaN         Smith, Tara
# 20                           NaN         Smith, Tara
# 21                           NaN         Smith, Tara
# 22                           NaN         Smith, Tara
# 23                           NaN         Smith, Tara
# 24                           NaN         Smith, Tara
# 25                           NaN         Smith, Tara
# 26                           NaN         Smith, Tara
# 27                           NaN         Smith, Tara
# 28                           NaN         Smith, Tara
# 29                           NaN         Smith, Tara
# ...                          ...                 ...
# 351377                       NaN      Costa, Ron Sr.
# 351378                       NaN      Costa, Ron Sr.
# 351379                       NaN      Costa, Ron Sr.
# 351380              4.124345e+09      Costa, Ron Sr.
# 351381                       NaN      Costa, Ron Sr.
# 351382                       NaN      Costa, Ron Sr.
# 351383                       NaN      Costa, Ron Sr.
# 351384                       NaN      Costa, Ron Sr.
# 351385                       NaN      Costa, Ron Sr.
# 351386                       NaN      Costa, Ron Sr.
# 351387                       NaN      Costa, Ron Sr.
# 351388                       NaN      Costa, Ron Sr.
# 351389                       NaN      Costa, Ron Sr.
# 351390                       NaN      Costa, Ron Sr.
# 351391                       NaN      Costa, Ron Sr.
# 351392                       NaN      Costa, Ron Sr.
# 351393                       NaN      Costa, Ron Sr.
# 351394                       NaN      Costa, Ron Sr.
# 351395                       NaN      Costa, Ron Sr.
# 351396                       NaN      Costa, Ron Sr.
# 351397                       NaN      Costa, Ron Sr.
# 351398                       NaN      Costa, Ron Sr.
# 351399                       NaN      Costa, Ron Sr.
# 351400                       NaN      Costa, Ron Sr.
# 351401                       NaN      Costa, Ron Sr.
# 351402                       NaN      Costa, Ron Sr.
# 351403                       NaN      Costa, Ron Sr.
# 351404                       NaN      Costa, Ron Sr.
# 351405                       NaN      Costa, Ron Sr.
# 351406                       NaN      Costa, Ron Sr.
#
#        Associated Landlord Tenant Docket Number
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# ...                                         ...
# 351377                                      NaN
# 351378                                      NaN
# 351379                                      NaN
# 351380                                      NaN
# 351381                                      NaN
# 351382                                      NaN
# 351383                                      NaN
# 351384                                      NaN
# 351385                                      NaN
# 351386                                      NaN
# 351387                                      NaN
# 351388                                      NaN
# 351389                                      NaN
# 351390                                      NaN
# 351391                                      NaN
# 351392                                      NaN
# 351393                                      NaN
# 351394                                      NaN
# 351395                                      NaN
# 351396                                      NaN
# 351397                                      NaN
# 351398                                      NaN
# 351399                                      NaN
# 351400                                      NaN
# 351401                                      NaN
# 351402                                      NaN
# 351403                                      NaN
# 351404                                      NaN
# 351405                                      NaN
# 351406                                      NaN
#
# [351407 rows x 48 columns]

# %%
je_df['DocketNumber'].duplicated
# Out:
# <bound method Series.duplicated of 0         MJ-05003-LT-0000001-2009
# 1         MJ-05003-LT-0000001-2011
# 2         MJ-05003-LT-0000001-2013
# 3         MJ-05003-LT-0000001-2013
# 4         MJ-05201-LT-0000001-2009
# 5         MJ-05201-LT-0000001-2009
# 6         MJ-05201-LT-0000001-2009
# 7         MJ-05201-LT-0000001-2012
# 8         MJ-05201-LT-0000001-2012
# 9         MJ-05201-LT-0000001-2012
# 10        MJ-05201-LT-0000001-2012
# 11        MJ-05201-LT-0000001-2013
# 12        MJ-05201-LT-0000001-2014
# 13        MJ-05201-LT-0000001-2014
# 14        MJ-05201-LT-0000001-2015
# 15        MJ-05201-LT-0000001-2016
# 16        MJ-05201-LT-0000001-2016
# 17        MJ-05201-LT-0000001-2016
# 18        MJ-05201-LT-0000001-2017
# 19        MJ-05201-LT-0000001-2017
# 20        MJ-05201-LT-0000001-2017
# 21        MJ-05201-LT-0000001-2018
# 22        MJ-05201-LT-0000001-2018
# 23        MJ-05201-LT-0000002-2009
# 24        MJ-05201-LT-0000002-2009
# 25        MJ-05201-LT-0000002-2011
# 26        MJ-05201-LT-0000002-2011
# 27        MJ-05201-LT-0000002-2012
# 28        MJ-05201-LT-0000002-2013
# 29        MJ-05201-LT-0000002-2014
#                     ...
# 351377    MJ-05231-LT-0000180-2012
# 351378    MJ-05231-LT-0000180-2012
# 351379    MJ-05231-LT-0000180-2012
# 351380    MJ-05231-LT-0000180-2013
# 351381    MJ-05231-LT-0000180-2014
# 351382    MJ-05231-LT-0000180-2014
# 351383    MJ-05231-LT-0000180-2014
# 351384    MJ-05231-LT-0000180-2015
# 351385    MJ-05231-LT-0000180-2015
# 351386    MJ-05231-LT-0000180-2015
# 351387    MJ-05231-LT-0000180-2016
# 351388    MJ-05231-LT-0000180-2017
# 351389    MJ-05231-LT-0000180-2017
# 351390    MJ-05231-LT-0000180-2017
# 351391    MJ-05231-LT-0000180-2017
# 351392    MJ-05231-LT-0000180-2017
# 351393    MJ-05231-LT-0000180-2017
# 351394    MJ-05231-LT-0000181-2009
# 351395    MJ-05231-LT-0000181-2009
# 351396    MJ-05231-LT-0000181-2009
# 351397    MJ-05231-LT-0000181-2009
# 351398    MJ-05231-LT-0000181-2009
# 351399    MJ-05231-LT-0000181-2009
# 351400    MJ-05231-LT-0000181-2009
# 351401    MJ-05231-LT-0000181-2009
# 351402    MJ-05231-LT-0000181-2010
# 351403    MJ-05231-LT-0000181-2010
# 351404    MJ-05231-LT-0000181-2012
# 351405    MJ-05231-LT-0000181-2012
# 351406    MJ-05231-LT-0000181-2013
# Name: DocketNumber, Length: 351407, dtype: object>

# %%
je_xls = pandas.ExcelFile(jeff_evictions_xls_path)
je_xls.sheet_names
# Out:
# [u'Request Summary', u'Data']
