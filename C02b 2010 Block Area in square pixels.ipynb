# %%
import array, csv, fcntl, glob, json, math, multiprocessing, numpy, os, random, re, shutil
import shapely, shapely.wkb, struct, subprocess, sys, threading, urllib2

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

set_default_psql_database('census2010')
# Out:
# set default_psql_database to census2010

# %%
try:
    import pyproj
except:
    # !pip install pyproj
    import pyproj

# %%
try:
    import shapely
except:
    # !pip install shapely==1.6b2
    import shapely

# %%
def LonLatToPixelXY(lonlat, scale = 1.):
    (lon, lat) = lonlat
    x = (lon + 180.0) * 256.0 / 360.0
    y = 128.0 - math.log(math.tan((lat + 90.0) * math.pi / 360.0)) * 128.0 / math.pi
    return [x*scale, y*scale]

# %% [markdown]
# Create census2010_block_idxs mapping each geoid2010 to a sequential integer
# ---------------------------------------------------------------------------

# %%
regenerate_census2010_block_idxs = False

if regenerate_census2010_block_idxs:
    psql("""
DROP TABLE census2010_block_idxs;
CREATE TABLE census2010_block_idxs (blockidx2010 SERIAL PRIMARY KEY,
                                   geoid2010 VARCHAR);

INSERT INTO census2010_block_idxs 
SELECT nextval('census2010_block_idxs_blockidx2010_seq'), geoid10
FROM tiger2010_census2010_blocks
ORDER BY geoid10;
CREATE UNIQUE INDEX ON census2010_block_idxs (geoid2010);
""")
    
psql("\d census2010_block_idxs")
psql("SELECT COUNT(*) FROM census2010_block_idxs")
psql("SELECT * FROM census2010_block_idxs ORDER BY geoid2010 LIMIT 5")
# Out:
# \d census2010_block_idxs
# Finished execution in 0.904316 secs: Table "public.census2010_block_idxs"
#     Column    |       Type        |                                  Modifiers
# --------------+-------------------+------------------------------------------------------------------------------
#  blockidx2010 | integer           | not null default nextval('census2010_block_idxs_blockidx2010_seq'::regclass)
#  geoid2010    | character varying |
# Indexes:
#     "census2010_block_idxs_pkey" PRIMARY KEY, btree (blockidx2010)
#     "census2010_block_idxs_geoid2010_idx" UNIQUE, btree (geoid2010)
# SELECT COUNT(*) FROM census2010_block_idxs
# Finished execution in 1.38568 secs: count
# ----------
#  11078297
# (1 row)
# SELECT * FROM census2010_block_idxs ORDER BY geoid2010 LIMIT 5
# Finished execution in 0.108793 secs: blockidx2010 |    geoid2010
# --------------+-----------------
#             1 | 010010201001000
#             2 | 010010201001001
#             3 | 010010201001002
#             4 | 010010201001003
#             5 | 010010201001004
# (5 rows)

# %%
#psql('SELECT SUM(p001001) FROM sf1_2000_int2010_p001')
#psql('SELECT SUM(p001001) FROM sf1_2010_block_p001')
psql("""
SELECT SUM(GREATEST(a.p001001, b.p001001))
FROM sf1_2010_block_p001 as a
JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
""")
# Out:
# SELECT SUM(GREATEST(a.p001001, b.p001001))
# FROM sf1_2010_block_p001 as a
# JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
# Finished execution in 14.3458 secs: sum
# ------------------
#  341321396.909159
# (1 row)

# %%
#psql("SELECT COUNT(*) FROM census2010_block_idxs")
#psql("SELECT COUNT(*) FROM tiger2010_census2010_blocks")
#psql("SELECT COUNT(*) FROM sf1_2010_block_p001")
#psql("SELECT COUNT(*) FROM sf1_2010_block_p001 WHERE LEFT(geoid2010,2) != '72'")
#psql("SELECT COUNT(*) FROM sf1_2000_int2010_p001")

psql("""
SELECT COUNT(*) FROM census2010_block_idxs as i
JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)
JOIN sf1_2010_block_p001 as a USING (geoid2010)
LEFT JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
""")
# Out:
# SELECT COUNT(*) FROM census2010_block_idxs as i
# JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)
# JOIN sf1_2010_block_p001 as a USING (geoid2010)
# LEFT JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
# Finished execution in 35.8532 secs: count
# ----------
#  11078297
# (1 row)

# %%
psql("""
SELECT SUM(GREATEST(a.p001001, b.p001001))
FROM census2010_block_idxs as i
JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)
JOIN sf1_2010_block_p001 as a USING (geoid2010)
JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
""")
# Out:
# SELECT SUM(GREATEST(a.p001001, b.p001001))
# FROM census2010_block_idxs as i
# JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)
# JOIN sf1_2010_block_p001 as a USING (geoid2010)
# JOIN sf1_2000_int2010_p001 as b USING (geoid2010)
# Finished execution in 38.3241 secs: sum
# ------------------
#  341321396.909154
# (1 row)

# %% [markdown]
# Compute dots for max(2010, 2000 interpolated) block population, by geoid2010
# ----------------------------------------------------------------------------

# %%
max_psql_parallelism = 8
psql_semaphore = multiprocessing.Semaphore(max_psql_parallelism)

def query_psql_throttled(query, quiet=False):
    psql_semaphore.acquire()
    try:
        rows = query_psql(query, quiet=quiet)
    finally:
        psql_semaphore.release()
    return rows

# %%
prototiledir = 'prototiles002'
# !mkdir -p $prototiledir

pops = [numpy.load('columncache/census%d_block2010/P0010001.numpy' % y) for y in [1990, 2000, 2010]]
caps = numpy.ceil(numpy.maximum(numpy.maximum(pops[0], pops[1]), pops[2]) * 2 + 60).astype(numpy.int32)

numpy_atomic_save(prototiledir + '/caps.numpy', caps)

# %%
query_psql("SELECT geoid10, geom FROM tiger2010_census2010_blocks LIMIT 1")
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-7-845506d02149> in <module>()
# ----> 1 query_psql("SELECT geoid10, geom FROM tiger2010_census2010_blocks LIMIT 1")
#
# <string> in query_psql(query, quiet, database)
#
# /home/rsargent/anaconda2/lib/python2.7/site-packages/psycopg2/__init__.pyc in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: No such file or directory
# 	Is the server running locally and accepting
# 	connections on Unix domain socket "/var/run/postgresql/.s.PGSQL.5432"?

# %%
# !ls capture
# Out:
# ACS2009_5year  ACS2014_5year  NHGIS_1990
# ACS2010_5year  ACS2015_1year  NHGIS_block2000_to_block2010
# ACS2011_5year  ACS2015_5year  NHGIS_block2000_to_block2010.zip
# ACS2012_5year  ACS2016_5year  tiger2010_census2010_tracts
# ACS2013_5year  lodes7

# %%
# !grep tiger *.ipynb
# Out:
# 00 Import 2000 Census Block Shapefiles.ipynb:      " public | tiger2010_census2000_blocks         | table    | rsargent\n",
# 00 Import 2000 Census Block Shapefiles.ipynb:      " public | tiger2010_census2000_blocks_gid_seq | sequence | rsargent\n",
# 00 Import 2000 Census Block Shapefiles.ipynb:      " public | tiger2010_census2010_blocks         | table    | rsargent\n",
# 00 Import 2000 Census Block Shapefiles.ipynb:      " public | tiger2010_census2010_blocks_gid_seq | sequence | rsargent\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_table_name(yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    return 'tiger2010_census{yyyy}_blocks'.format(**locals())\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_file_name(state_id, yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_url(state_id, yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    file_name = tiger2010_file_name(state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    return 'http://www2.census.gov/geo/tiger/TIGER2010/TABBLOCK/{yyyy}/{file_name}.zip'.format(**locals())\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_dir(state_id, yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    table_name = tiger2010_table_name(yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    file_name = tiger2010_file_name(state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_shapefile_path(state_id, yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    table_name = tiger2010_table_name(yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    file_name = tiger2010_file_name(state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def tiger2010_id_name(yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "def download_tiger2010_state(state_id, yyyy):\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    src = tiger2010_url(state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    table_name=tiger2010_table_name(yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_01_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_01_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_02_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_02_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_04_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_04_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_05_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_05_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_08_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_06_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_08_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_06_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_09_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_10_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_11_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_10_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_09_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_11_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_12_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_12_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_13_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_16_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_15_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_16_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_13_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_17_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_15_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_17_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_18_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_18_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_19_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_19_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_20_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_21_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_20_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_21_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_22_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_23_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_22_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_24_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_23_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_24_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_25_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_26_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_25_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_28_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_28_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_27_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_27_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_26_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_29_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_30_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_31_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_29_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_30_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_31_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_33_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_32_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_32_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_33_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_35_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_34_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_35_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_36_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_34_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_36_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_37_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_38_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_37_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_38_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_39_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_39_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_40_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_40_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_41_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_42_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_41_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_42_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_44_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_44_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_46_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_45_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_45_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_46_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_47_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_48_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_47_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_48_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_49_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_49_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_50_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_50_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_53_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_51_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_51_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_53_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_54_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_54_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_55_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_55_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_56_tabblock00.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2000_blocks/tl_2010_56_tabblock00.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_01_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_01_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_02_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_02_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_04_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_05_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_05_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_04_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_08_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_08_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_09_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_06_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_09_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_06_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_11_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_11_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_10_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_10_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_12_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_12_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_13_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_13_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_15_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_15_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_16_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_16_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_17_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_18_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_17_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_19_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_18_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_21_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_20_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_19_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_21_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_22_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_22_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_23_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_24_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_24_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_25_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_23_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_20_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_26_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_25_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_26_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_27_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_27_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_28_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_28_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_29_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_30_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_31_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_29_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_31_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_32_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_30_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_32_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_34_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_34_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_36_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_35_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_33_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_37_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_36_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_35_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_37_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_38_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_33_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_39_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_38_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_39_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_40_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_41_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_41_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_40_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_42_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_42_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_44_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_46_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_45_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_47_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_44_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_45_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_46_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_47_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_48_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_48_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_49_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_49_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_50_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_50_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_51_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_53_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_54_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_51_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_54_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_55_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_53_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_55_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_56_tabblock10.zip already downloaded\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "capture/tiger2010_census2010_blocks/tl_2010_56_tabblock10.zip already unzipped\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "        executor.submit(download_tiger2010_state, state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "!shp2pgsql -p capture/tiger2010_census2000_blocks/tl_2010_01_tabblock00/tl_2010_01_tabblock00.shp\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "!shp2pgsql -p capture/tiger2010_census2010_blocks/tl_2010_01_tabblock10/tl_2010_01_tabblock10.shp"
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    table_name = tiger2010_table_name(yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "    shapefile_path = tiger2010_shapefile_path(state_id, yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "        id_name = tiger2010_id_name(yyyy)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "DROP TABLE tiger2010_census2000_blocks;\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Creating tiger2010_census2000_blocks schema using state 01\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      " public.tiger2010_census2000_blocks.geom SRID:4326 TYPE:MULTIPOLYGON DIMS:2 \n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "CREATE INDEX ON tiger2010_census2000_blocks (blkidfp00);\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "CREATE INDEX ON tiger2010_census2000_blocks USING GIST (geom);\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "ALTER TABLE tiger2010_census2000_blocks ADD COLUMN dots text DEFAULT '';\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 01 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 02 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 04 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 05 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 06 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 08 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 09 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 10 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 11 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 12 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "DROP TABLE tiger2010_census2010_blocks;\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Creating tiger2010_census2010_blocks schema using state 01\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      " public.tiger2010_census2010_blocks.geom SRID:4326 TYPE:MULTIPOLYGON DIMS:2 \n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "CREATE INDEX ON tiger2010_census2010_blocks (geoid10);\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "CREATE INDEX ON tiger2010_census2010_blocks USING GIST (geom);\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "ALTER TABLE tiger2010_census2010_blocks ADD COLUMN dots text DEFAULT '';\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 13 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 15 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 16 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 17 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 18 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 19 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 20 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 21 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 22 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 23 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 24 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 25 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 26 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 27 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 28 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 29 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 30 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 31 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 32 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 33 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 34 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 35 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 36 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 37 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 38 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 39 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 40 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 41 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 42 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 44 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 45 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 46 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 47 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 48 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 49 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 50 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 51 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 53 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 54 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 55 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 56 to tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 01 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 02 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 04 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 05 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 06 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 08 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 09 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 10 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 11 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 12 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 13 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 15 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 16 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 17 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 18 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 19 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 20 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 21 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 22 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 23 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 24 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 25 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 26 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 27 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 28 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 29 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 30 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 31 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 32 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 33 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 34 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 35 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 36 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 37 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 38 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 39 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 40 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 41 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 42 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 44 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 45 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 46 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 47 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 48 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 49 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 50 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 51 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 53 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 54 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 55 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Appending state 56 to tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "tiger2010_census2000_blocks and tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "\\d tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Finished execution in 0.155889 secs: Table \"public.tiger2010_census2000_blocks\"\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      " gid        | integer                     | not null default nextval('tiger2010_census2000_blocks_gid_seq'::regclass)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2000_blocks_pkey\" PRIMARY KEY, btree (gid)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2000_blocks_blkidfp00_idx\" btree (blkidfp00)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2000_blocks_geom_idx\" gist (geom)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "\\d tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "Finished execution in 0.157959 secs: Table \"public.tiger2010_census2010_blocks\"\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      " gid        | integer                     | not null default nextval('tiger2010_census2010_blocks_gid_seq'::regclass)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2010_blocks_pkey\" PRIMARY KEY, btree (gid)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2010_blocks_geoid10_idx\" btree (geoid10)\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "    \"tiger2010_census2010_blocks_geom_idx\" gist (geom)\n"
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql('\\d tiger2010_census2000_blocks')\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql('\\d tiger2010_census2010_blocks')"
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql('SELECT COUNT(*) FROM tiger2010_census2000_blocks')\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql('SELECT COUNT(*) FROM tiger2010_census2010_blocks')"
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "!pg_dump -t tiger2010_census2010_blocks timelapse | psql census2010"
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2000_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:      "SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2010_blocks\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql(\"SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2000_blocks\")\n",
# 01 Import 2000-2010 Census Block Shapefiles.ipynb:    "psql(\"SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2010_blocks\")"
# A02 Download 2010 Census Tracts and Block Groups.ipynb:    "    return 'capture/tiger2010_census2010_tracts/{state_id}.geojson'.format(**locals())\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:    "    src_zipfile = 'https://www2.census.gov/geo/tiger/TIGER2010/TRACT/2010/tl_2010_{state_id}_tract10.zip'.format(**locals())\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:    "    local_zipfile = 'capture/tiger2010_census2010_tracts/tl_2010_{state_id}_tract10.zip'.format(**locals())\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/01.geojson already exists, skipping\n",
# ...
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/11.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/13.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/12.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/15.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/16.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/17.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/18.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/19.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/20.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/21.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/22.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/23.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/25.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/24.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/26.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/27.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/28.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/30.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/31.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/32.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/29.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/34.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/33.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/35.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/36.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/37.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/38.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/39.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/40.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/41.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/42.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/44.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/46.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/45.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/48.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/49.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/50.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/47.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/51.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/53.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/54.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/55.geojson already exists, skipping\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/56.geojson already exists, skipping\n"
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/01.geojson has 1181 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/02.geojson has 167 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/04.geojson has 1526 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/05.geojson has 686 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/06.geojson has 8057 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/08.geojson has 1249 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/09.geojson has 833 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/10.geojson has 218 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/11.geojson has 179 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/12.geojson has 4245 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/13.geojson has 1969 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/15.geojson has 351 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/16.geojson has 298 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/17.geojson has 3123 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/18.geojson has 1511 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/19.geojson has 825 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/20.geojson has 770 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/21.geojson has 1115 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/22.geojson has 1148 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/23.geojson has 358 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/24.geojson has 1406 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/25.geojson has 1478 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/26.geojson has 2813 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/27.geojson has 1338 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/28.geojson has 664 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/29.geojson has 1393 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/30.geojson has 271 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/31.geojson has 532 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/32.geojson has 687 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/33.geojson has 295 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/34.geojson has 2010 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/35.geojson has 499 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/36.geojson has 4919 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/37.geojson has 2195 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/38.geojson has 205 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/39.geojson has 2952 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/40.geojson has 1046 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/41.geojson has 834 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/42.geojson has 3218 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/44.geojson has 244 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/45.geojson has 1103 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/46.geojson has 222 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/47.geojson has 1497 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/48.geojson has 5265 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/49.geojson has 588 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/50.geojson has 184 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/51.geojson has 1907 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/53.geojson has 1458 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/54.geojson has 484 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/55.geojson has 1409 tracts\n",
# A02 Download 2010 Census Tracts and Block Groups.ipynb:      "capture/tiger2010_census2010_tracts/56.geojson has 132 tracts\n",
# C02 Generate prototiles.ipynb:    "FROM tiger2010_census2010_blocks\n",
# C02 Generate prototiles.ipynb:      "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02 Generate prototiles.ipynb:    "#psql(\"SELECT COUNT(*) FROM tiger2010_census2010_blocks\")\n",
# C02 Generate prototiles.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02 Generate prototiles.ipynb:      "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02 Generate prototiles.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02 Generate prototiles.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02b 2010 Block Area in square pixels.ipynb:    "FROM tiger2010_census2010_blocks\n",
# C02b 2010 Block Area in square pixels.ipynb:      "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02b 2010 Block Area in square pixels.ipynb:    "#psql(\"SELECT COUNT(*) FROM tiger2010_census2010_blocks\")\n",
# C02b 2010 Block Area in square pixels.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02b 2010 Block Area in square pixels.ipynb:      "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02b 2010 Block Area in square pixels.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# C02b 2010 Block Area in square pixels.ipynb:      "\u001b<ipython-input-7-845506d02149>\u001b in \u001b<module>\u001b()\u001b\n\u001b----> 1\u001b \u001bquery_psql\u001b\u001b(\u001b\u001b\"SELECT geoid10, geom FROM tiger2010_census2010_blocks LIMIT 1\"\u001b\u001b)\u001b\u001b\u001b\u001b\n\u001b",
# C02b 2010 Block Area in square pixels.ipynb:    "query_psql(\"SELECT geoid10, geom FROM tiger2010_census2010_blocks LIMIT 1\")\n"
# C02b 2010 Block Area in square pixels.ipynb:      "ACS2012_5year  ACS2016_5year  tiger2010_census2010_tracts\r\n",
# C02b 2010 Block Area in square pixels.ipynb:      "./capture/tiger2010_census2010_tracts\r\n"
# C02b 2010 Block Area in square pixels.ipynb:    "!find . -name '*tiger*'"
# C02b 2010 Block Area in square pixels.ipynb:    "JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)\n",
# Draw Allegheny County Census Blocks Blockgroups Tracts.ipynb:    "#!wget https://www2.census.gov/geo/tiger/TIGER2010/TRACT/2010/tl_2010_42003_tract10.zip\n",
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "tiger2010_census2000_blocks and tiger2010_census2010_blocks\n",
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql('\\d tiger2010_census2000_blocks')\n",
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql('\\d tiger2010_census2010_blocks')"
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql('SELECT COUNT(*) FROM tiger2010_census2000_blocks')\n",
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql('SELECT COUNT(*) FROM tiger2010_census2010_blocks')"
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "!pg_dump -t tiger2010_census2010_blocks timelapse | psql census2010"
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql(\"SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2000_blocks\")\n",
# V01 Import Allegheny County Precinct Shapefiles.ipynb:    "psql(\"SELECT SUM(ST_AREA(geography(geom))) FROM tiger2010_census2010_blocks\")"

# %%
record_format = '<ffii'
record_len = struct.calcsize(record_format)

def process_shard(start_idx, end_idx_exclusive):
    end_idx_inclusive = end_idx_exclusive - 1
    shard_filename = 'shards/protomaster-%08d' % start_idx
    if os.path.exists(shard_filename):
        sys.stdout.write('%s already exists\n' % shard_filename)
        return shard_filename
    shard_out = open(shard_filename + '.tmp', 'wb')
    query = """
SELECT i.blockidx2010, shapes.geom
FROM (SELECT * FROM census2010_block_idxs WHERE blockidx2010 BETWEEN {start_idx} AND {end_idx_inclusive}) as i
JOIN tiger2010_census2010_blocks as shapes ON (i.geoid2010=shapes.geoid10)
""".format(**locals())
    rows = query_psql_throttled(query, quiet=True)
    begin_time = time.time()

    points = []
    population = 0
    dots = 0
    for (blockIdx, geom) in rows:
        pop = caps[blockIdx]
        population += pop
        polygon = shapely.wkb.loads(geom, hex=True)

        for i in range(pop):
            dots += 1
            point = LonLatToPixelXY(randomPoint(polygon))
            points.append(struct.pack(record_format, 
                                      point[0], point[1],
                                      blockIdx, i))
        if len(points) >= 10000:
            shard_out.write(''.join(points))
            points = []
    shard_out.write(''.join(points))
    shard_out.close()
    sys.stdout.write("Shard {shard_filename} has population {population} and {dots} dots\n".format(**locals()))
    os.rename(shard_filename + '.tmp', shard_filename)
    sys.stdout.write("Finished %s with %d rows in %g seconds\n" % (shard_filename, len(rows), time.time() - begin_time))
    return shard_filename

# %%
max_block_idx = query_psql("SELECT MAX(blockidx2010) FROM census2010_block_idxs")[0][0]

shard_size = 100000
pool = SimpleProcessPoolExecutor(16)

results = []

print "Starting shards with maximum index %d" % max_block_idx

if not os.path.exists('shards'):
    os.mkdir("shards")

for start_idx in range(0, max_block_idx + 1, shard_size):
    pool.submit(process_shard, start_idx, start_idx + shard_size)

shardfiles = pool.shutdown()
# Out:
# Execution of SELECT MAX(blockidx2010) FROM census2010_block_idxs
# took 0.00168085 seconds and returned 1 rows
# Starting shards with maximum index 11078297
# Shard shards/protomaster-00500000 has population 9907490.0 and 9907490 dots
# Finished shards/protomaster-00500000 with 100000 rows in 3227.91 seconds
# Shard shards/protomaster-00600000 has population 9712959.0 and 9712959 dots
# Finished shards/protomaster-00600000 with 100000 rows in 3274.61 seconds
# Shard shards/protomaster-00300000 has population 11030615.0 and 11030615 dots
# Finished shards/protomaster-00300000 with 100000 rows in 3569.9 seconds
# Shard shards/protomaster-00000000 has population 9950570.0 and 9950570 dots
# Finished shards/protomaster-00000000 with 99999 rows in 3633.97 seconds
# Shard shards/protomaster-00100000 has population 11488061.0 and 11488061 dots
# Finished shards/protomaster-00100000 with 100000 rows in 3759.05 seconds
# Shard shards/protomaster-01500000 has population 10780288.0 and 10780288 dots
# Finished shards/protomaster-01500000 with 100000 rows in 3849.36 seconds
# Shard shards/protomaster-00800000 has population 12821192.0 and 12821192 dots
# Finished shards/protomaster-00800000 with 100000 rows in 3860.96 seconds
# Shard shards/protomaster-00400000 has population 14040615.0 and 14040615 dots
# Finished shards/protomaster-00400000 with 100000 rows in 4126.78 seconds
# Shard shards/protomaster-00200000 has population 10014259.0 and 10014259 dots
# Finished shards/protomaster-00200000 with 100000 rows in 4529.14 seconds
# Shard shards/protomaster-01400000 has population 14704593.0 and 14704593 dots
# Finished shards/protomaster-01400000 with 100000 rows in 4590.29 seconds
# Shard shards/protomaster-00700000 has population 15490970.0 and 15490970 dots
# Finished shards/protomaster-00700000 with 100000 rows in 5167.56 seconds
# Shard shards/protomaster-01100000 has population 18307988.0 and 18307988 dots
# Finished shards/protomaster-01100000 with 100000 rows in 5199.45 seconds
# Shard shards/protomaster-01300000 has population 15606497.0 and 15606497 dots
# Finished shards/protomaster-01300000 with 100000 rows in 5516.3 seconds
# Shard shards/protomaster-01000000 has population 16890861.0 and 16890861 dots
# Finished shards/protomaster-01000000 with 100000 rows in 5557.91 seconds
# Shard shards/protomaster-01200000 has population 19202318.0 and 19202318 dots
# Finished shards/protomaster-01200000 with 100000 rows in 5947.64 seconds
# Shard shards/protomaster-00900000 has population 24821261.0 and 24821261 dots
# Finished shards/protomaster-00900000 with 100000 rows in 6554.59 seconds
# Shard shards/protomaster-01900000 has population 13121408.0 and 13121408 dots
# Finished shards/protomaster-01900000 with 100000 rows in 4279.49 seconds
# Shard shards/protomaster-01600000 has population 15003853.0 and 15003853 dots
# Finished shards/protomaster-01600000 with 100000 rows in 4871.33 seconds
# Shard shards/protomaster-01800000 has population 14173408.0 and 14173408 dots
# Finished shards/protomaster-01800000 with 100000 rows in 4601.35 seconds
# Shard shards/protomaster-01700000 has population 16643625.0 and 16643625 dots
# Finished shards/protomaster-01700000 with 100000 rows in 5303.26 seconds
# Shard shards/protomaster-02100000 has population 13837727.0 and 13837727 dots
# Finished shards/protomaster-02100000 with 100000 rows in 4737.12 seconds
# Shard shards/protomaster-02200000 has population 13761978.0 and 13761978 dots
# Finished shards/protomaster-02200000 with 100000 rows in 4835.52 seconds
# Shard shards/protomaster-03000000 has population 10021215.0 and 10021215 dots
# Finished shards/protomaster-03000000 with 100000 rows in 2836.54 seconds
# Shard shards/protomaster-02400000 has population 11553718.0 and 11553718 dots
# Finished shards/protomaster-02400000 with 100000 rows in 4316.58 seconds
# Shard shards/protomaster-02800000 has population 12079682.0 and 12079682 dots
# Finished shards/protomaster-02800000 with 100000 rows in 3379.01 seconds
# Shard shards/protomaster-02600000 has population 7924294.0 and 7924294 dots
# Finished shards/protomaster-02600000 with 100000 rows in 3802.23 seconds
# Shard shards/protomaster-02900000 has population 12421730.0 and 12421730 dots
# Finished shards/protomaster-02900000 with 100000 rows in 3561.68 seconds
# Shard shards/protomaster-02500000 has population 11718798.0 and 11718798 dots
# Finished shards/protomaster-02500000 with 100000 rows in 4553.88 seconds
# Shard shards/protomaster-02700000 has population 17140364.0 and 17140364 dots
# Finished shards/protomaster-02700000 with 100000 rows in 3992.02 seconds
# Shard shards/protomaster-02000000 has population 18509555.0 and 18509555 dots
# Finished shards/protomaster-02000000 with 100000 rows in 5979.29 seconds
# Shard shards/protomaster-02300000 has population 16084453.0 and 16084453 dots
# Finished shards/protomaster-02300000 with 100000 rows in 5682.93 seconds
# Shard shards/protomaster-03100000 has population 12009828.0 and 12009828 dots
# Finished shards/protomaster-03100000 with 100000 rows in 3597 seconds
# Shard shards/protomaster-03400000 has population 8787140.0 and 8787140 dots
# Finished shards/protomaster-03400000 with 100000 rows in 2403.44 seconds
# Shard shards/protomaster-03600000 has population 8229138.0 and 8229138 dots
# Finished shards/protomaster-03600000 with 100000 rows in 2308.76 seconds
# Shard shards/protomaster-03700000 has population 8864031.0 and 8864031 dots
# Finished shards/protomaster-03700000 with 100000 rows in 2385.16 seconds
# Shard shards/protomaster-03500000 has population 10208459.0 and 10208459 dots
# Finished shards/protomaster-03500000 with 100000 rows in 2696.39 seconds
# Shard shards/protomaster-03300000 has population 11114735.0 and 11114735 dots
# Finished shards/protomaster-03300000 with 100000 rows in 3199.46 seconds
# Shard shards/protomaster-03200000 has population 13028226.0 and 13028226 dots
# Finished shards/protomaster-03200000 with 100000 rows in 3705.14 seconds
# Shard shards/protomaster-03800000 has population 11313374.0 and 11313374 dots
# Finished shards/protomaster-03800000 with 100000 rows in 4011.88 seconds
# Shard shards/protomaster-04600000 has population 11298664.0 and 11298664 dots
# Finished shards/protomaster-04600000 with 100000 rows in 3474.09 seconds
# Shard shards/protomaster-04000000 has population 12078958.0 and 12078958 dots
# Finished shards/protomaster-04000000 with 100000 rows in 4477.56 seconds
# Shard shards/protomaster-04200000 has population 10218717.0 and 10218717 dots
# Finished shards/protomaster-04200000 with 100000 rows in 4303.68 seconds
# Shard shards/protomaster-04400000 has population 13397489.0 and 13397489 dots
# Finished shards/protomaster-04400000 with 100000 rows in 4444.34 seconds
# Shard shards/protomaster-04700000 has population 13099151.0 and 13099151 dots
# Finished shards/protomaster-04700000 with 100000 rows in 3875.99 seconds
# Shard shards/protomaster-05000000 has population 10667706.0 and 10667706 dots
# Finished shards/protomaster-05000000 with 100000 rows in 3231.49 seconds
# Shard shards/protomaster-05100000 has population 10739929.0 and 10739929 dots
# Finished shards/protomaster-05100000 with 100000 rows in 3250 seconds
# Shard shards/protomaster-03900000 has population 12335398.0 and 12335398 dots
# Finished shards/protomaster-03900000 with 100000 rows in 5704.39 seconds
# Shard shards/protomaster-04100000 has population 11515664.0 and 11515664 dots
# Finished shards/protomaster-04100000 with 100000 rows in 5586.95 seconds
# Shard shards/protomaster-05300000 has population 9404223.0 and 9404223 dots
# Finished shards/protomaster-05300000 with 100000 rows in 3037.89 seconds
# Shard shards/protomaster-04900000 has population 12759410.0 and 12759410 dots
# Finished shards/protomaster-04900000 with 100000 rows in 3854.59 seconds
# Shard shards/protomaster-04800000 has population 14274036.0 and 14274036 dots
# Finished shards/protomaster-04800000 with 100000 rows in 4248.08 seconds
# Shard shards/protomaster-05200000 has population 10810267.0 and 10810267 dots
# Finished shards/protomaster-05200000 with 100000 rows in 3542.57 seconds
# Shard shards/protomaster-04300000 has population 16365883.0 and 16365883 dots
# Finished shards/protomaster-04300000 with 100000 rows in 5796.83 seconds
# Shard shards/protomaster-04500000 has population 16325898.0 and 16325898 dots
# Finished shards/protomaster-04500000 with 100000 rows in 5231.16 seconds
# Shard shards/protomaster-05400000 has population 10246670.0 and 10246670 dots
# Finished shards/protomaster-05400000 with 100000 rows in 3227.29 seconds
# Shard shards/protomaster-05900000 has population 8324009.0 and 8324009 dots
# Finished shards/protomaster-05900000 with 100000 rows in 2318.5 seconds
# Shard shards/protomaster-05800000 has population 8520811.0 and 8520811 dots
# Finished shards/protomaster-05800000 with 100000 rows in 2803.54 seconds
# Shard shards/protomaster-05500000 has population 9438294.0 and 9438294 dots
# Finished shards/protomaster-05500000 with 100000 rows in 3174.24 seconds
# Shard shards/protomaster-05700000 has population 7728204.0 and 7728204 dots
# Finished shards/protomaster-05700000 with 100000 rows in 3431.63 seconds
# Shard shards/protomaster-05600000 has population 11435537.0 and 11435537 dots
# Finished shards/protomaster-05600000 with 100000 rows in 3792.23 seconds
# Shard shards/protomaster-06400000 has population 8273972.0 and 8273972 dots
# Finished shards/protomaster-06400000 with 100000 rows in 2858.4 seconds
# Shard shards/protomaster-06000000 has population 11784776.0 and 11784776 dots
# Finished shards/protomaster-06000000 with 100000 rows in 3805.28 seconds
# Shard shards/protomaster-06300000 has population 12504522.0 and 12504522 dots
# Finished shards/protomaster-06300000 with 100000 rows in 4051.41 seconds
# Shard shards/protomaster-07200000 has population 7925043.0 and 7925043 dots
# Finished shards/protomaster-07200000 with 100000 rows in 2368.77 seconds
# Shard shards/protomaster-06100000 has population 13720580.0 and 13720580 dots
# Finished shards/protomaster-06100000 with 100000 rows in 4608.73 seconds
# Shard shards/protomaster-06900000 has population 13432899.0 and 13432899 dots
# Finished shards/protomaster-06900000 with 100000 rows in 4624.16 seconds
# Shard shards/protomaster-07100000 has population 10521351.0 and 10521351 dots
# Finished shards/protomaster-07100000 with 100000 rows in 3262.81 seconds
# Shard shards/protomaster-06800000 has population 13107348.0 and 13107348 dots
# Finished shards/protomaster-06800000 with 100000 rows in 4824.19 seconds
# Shard shards/protomaster-06500000 has population 15717021.0 and 15717021 dots
# Finished shards/protomaster-06500000 with 100000 rows in 5128.16 seconds
# Shard shards/protomaster-06700000 has population 18664275.0 and 18664275 dots
# Finished shards/protomaster-06700000 with 100000 rows in 5553.91 seconds
# Shard shards/protomaster-06200000 has population 18479870.0 and 18479870 dots
# Finished shards/protomaster-06200000 with 100000 rows in 5965.53 seconds
# Shard shards/protomaster-07700000 has population 7949515.0 and 7949515 dots
# Finished shards/protomaster-07700000 with 100000 rows in 2591.9 seconds
# Shard shards/protomaster-07600000 has population 9891347.0 and 9891347 dots
# Finished shards/protomaster-07600000 with 100000 rows in 3222.73 seconds
# Shard shards/protomaster-07500000 has population 12824726.0 and 12824726 dots
# Finished shards/protomaster-07500000 with 100000 rows in 3719.26 seconds
# Shard shards/protomaster-07400000 has population 13983376.0 and 13983376 dots
# Finished shards/protomaster-07400000 with 100000 rows in 4124.68 seconds
# Shard shards/protomaster-07000000 has population 13837409.0 and 13837409 dots
# Finished shards/protomaster-07000000 with 100000 rows in 4975.67 seconds
# Shard shards/protomaster-07300000 has population 16017224.0 and 16017224 dots
# Finished shards/protomaster-07300000 with 100000 rows in 4826.53 seconds
# Shard shards/protomaster-06600000 has population 23827330.0 and 23827330 dots
# Finished shards/protomaster-06600000 with 100000 rows in 6886.85 seconds
# Shard shards/protomaster-07800000 has population 10876192.0 and 10876192 dots
# Finished shards/protomaster-07800000 with 100000 rows in 3110.27 seconds
# Shard shards/protomaster-07900000 has population 9065467.0 and 9065467 dots
# Finished shards/protomaster-07900000 with 100000 rows in 3519.9 seconds
# Shard shards/protomaster-08000000 has population 11551121.0 and 11551121 dots
# Finished shards/protomaster-08000000 with 100000 rows in 3712.5 seconds
# Shard shards/protomaster-08700000 has population 9896595.0 and 9896595 dots
# Finished shards/protomaster-08700000 with 100000 rows in 3116.24 seconds
# Shard shards/protomaster-08100000 has population 13693191.0 and 13693191 dots
# Finished shards/protomaster-08100000 with 100000 rows in 4543.58 seconds
# Shard shards/protomaster-08200000 has population 12643307.0 and 12643307 dots
# Finished shards/protomaster-08200000 with 100000 rows in 4568.98 seconds
# Shard shards/protomaster-08300000 has population 12310097.0 and 12310097 dots
# Finished shards/protomaster-08300000 with 100000 rows in 4468.06 seconds
# Shard shards/protomaster-08800000 has population 10798104.0 and 10798104 dots
# Finished shards/protomaster-08800000 with 100000 rows in 3773.52 seconds
# Shard shards/protomaster-08400000 has population 14108434.0 and 14108434 dots
# Finished shards/protomaster-08400000 with 100000 rows in 4837.5 seconds
# Shard shards/protomaster-08600000 has population 12189184.0 and 12189184 dots
# Finished shards/protomaster-08600000 with 100000 rows in 4299.05 seconds
# Shard shards/protomaster-08500000 has population 13000599.0 and 13000599 dots
# Finished shards/protomaster-08500000 with 100000 rows in 4693.7 seconds
# Shard shards/protomaster-08900000 has population 11479867.0 and 11479867 dots
# Finished shards/protomaster-08900000 with 100000 rows in 4223.74 seconds
# Shard shards/protomaster-09000000 has population 12644177.0 and 12644177 dots
# Finished shards/protomaster-09000000 with 100000 rows in 4236.29 seconds
# Shard shards/protomaster-09100000 has population 12934825.0 and 12934825 dots
# Finished shards/protomaster-09100000 with 100000 rows in 4561.21 seconds
# Shard shards/protomaster-09200000 has population 14380246.0 and 14380246 dots
# Finished shards/protomaster-09200000 with 100000 rows in 4325.06 seconds
# Shard shards/protomaster-09300000 has population 12301029.0 and 12301029 dots
# Finished shards/protomaster-09300000 with 100000 rows in 3932.87 seconds
# Shard shards/protomaster-09400000 has population 14656559.0 and 14656559 dots
# Finished shards/protomaster-09400000 with 100000 rows in 4266.95 seconds
# Shard shards/protomaster-09600000 has population 9628870.0 and 9628870 dots
# Finished shards/protomaster-09600000 with 100000 rows in 3453.1 seconds
# Shard shards/protomaster-09500000 has population 12389326.0 and 12389326 dots
# Finished shards/protomaster-09500000 with 100000 rows in 4009.68 seconds
# Shard shards/protomaster-09700000 has population 10213226.0 and 10213226 dots
# Finished shards/protomaster-09700000 with 100000 rows in 3532.85 seconds
# Shard shards/protomaster-09900000 has population 10594451.0 and 10594451 dots
# Finished shards/protomaster-09900000 with 100000 rows in 3733.35 seconds
# Shard shards/protomaster-10000000 has population 11583083.0 and 11583083 dots
# Finished shards/protomaster-10000000 with 100000 rows in 3966.5 seconds
# Shard shards/protomaster-11000000 has population 5924269.0 and 5924269 dots
# Finished shards/protomaster-11000000 with 78298 rows in 2363.48 seconds
# Shard shards/protomaster-09800000 has population 14030478.0 and 14030478 dots
# Finished shards/protomaster-09800000 with 100000 rows in 4313.48 seconds
# Shard shards/protomaster-10500000 has population 13077702.0 and 13077702 dots
# Finished shards/protomaster-10500000 with 100000 rows in 4159.66 seconds
# Shard shards/protomaster-10300000 has population 12833073.0 and 12833073 dots
# Finished shards/protomaster-10300000 with 100000 rows in 4741.71 seconds
# Shard shards/protomaster-10800000 has population 11947132.0 and 11947132 dots
# Finished shards/protomaster-10800000 with 100000 rows in 3951.44 seconds
# Shard shards/protomaster-10400000 has population 14684841.0 and 14684841 dots
# Finished shards/protomaster-10400000 with 100000 rows in 4510.8 seconds
# Shard shards/protomaster-10600000 has population 9585338.0 and 9585338 dots
# Finished shards/protomaster-10600000 with 100000 rows in 4367.98 seconds
# Shard shards/protomaster-10900000 has population 10540844.0 and 10540844 dots
# Finished shards/protomaster-10900000 with 100000 rows in 3995.48 seconds
# Shard shards/protomaster-10100000 has population 12201092.0 and 12201092 dots
# Finished shards/protomaster-10100000 with 100000 rows in 5128.33 seconds
# Shard shards/protomaster-10700000 has population 10125403.0 and 10125403 dots
# Finished shards/protomaster-10700000 with 100000 rows in 4136.75 seconds
# Shard shards/protomaster-10200000 has population 11056913.0 and 11056913 dots
# Finished shards/protomaster-10200000 with 100000 rows in 5017.4 seconds
# SimpleProcessPoolExecutor succeeded: all 111 jobs completed

# %% [markdown]
# Randomize point order and write them to binary file
# ---------------------------------------------------
#
# Binary file will later be converted to tiles, or, if small enough (i.e. a single state like PA or smaller) could be read directly by the web client page.

# %%
master = prototiledir + '/master.bin'

reread_shard_filenames = True

if reread_shard_filenames:
    shardfiles = glob.glob('shards/protomaster-????????')
    print 'Located %d shard files' % len(shardfiles)
# Out:
# Located 111 shard files

# %%
numpy_record_type = [('x','<f4'), ('y','<f4'), ('blockIdx', '<i4'), ('subIdx', '<i4')]

if os.path.exists(master):
    print '%s already exists' % master
else:
    npoints = 0
    for file in sorted(shardfiles):
        nbytes = os.stat(file).st_size
        if nbytes % record_len:
            raise 'File %s has unexpected length %d' % (file, nbytes)
        npoints += nbytes / record_len
    print 'From all shards: %d points (%.1fGB)' % (npoints, npoints * record_len / 1e9)

    for _ in stopwatch('Reading all shards'):
        master_points = numpy.zeros(npoints, dtype=numpy_record_type)
        offset = 0
        for file in sorted(shardfiles):
            shard_points = numpy.fromfile(file, dtype=numpy_record_type)
            master_points[offset:offset + len(shard_points)] = shard_points
            print 'Placed %d points from %s at offset %d' % (
                    len(shard_points), file, offset)
            offset += len(shard_points)
        assert offset == npoints

    for _ in stopwatch('Shuffling points'):
        numpy.random.shuffle(master_points)

    for _ in stopwatch('Writing %d points to %s' % (npoints, master)):
        master_points.tofile(master)
        nbytes = os.stat(master).st_size
        print 'Master is %.1fGB' % (nbytes / 1e9)
        assert npoints * record_len == nbytes
        
    master_points = None   # allow memory to be reclaimed
# Out:
# From all shards: 1384713813 points (22.2GB)
# Placed 9950570 points from shards/protomaster-00000000 at offset 0
# Placed 11488061 points from shards/protomaster-00100000 at offset 9950570
# Placed 10014259 points from shards/protomaster-00200000 at offset 21438631
# Placed 11030615 points from shards/protomaster-00300000 at offset 31452890
# Placed 14040615 points from shards/protomaster-00400000 at offset 42483505
# Placed 9907490 points from shards/protomaster-00500000 at offset 56524120
# Placed 9712959 points from shards/protomaster-00600000 at offset 66431610
# Placed 15490970 points from shards/protomaster-00700000 at offset 76144569
# Placed 12821192 points from shards/protomaster-00800000 at offset 91635539
# Placed 24821261 points from shards/protomaster-00900000 at offset 104456731
# Placed 16890861 points from shards/protomaster-01000000 at offset 129277992
# Placed 18307988 points from shards/protomaster-01100000 at offset 146168853
# Placed 19202318 points from shards/protomaster-01200000 at offset 164476841
# Placed 15606497 points from shards/protomaster-01300000 at offset 183679159
# Placed 14704593 points from shards/protomaster-01400000 at offset 199285656
# Placed 10780288 points from shards/protomaster-01500000 at offset 213990249
# Placed 15003853 points from shards/protomaster-01600000 at offset 224770537
# Placed 16643625 points from shards/protomaster-01700000 at offset 239774390
# Placed 14173408 points from shards/protomaster-01800000 at offset 256418015
# Placed 13121408 points from shards/protomaster-01900000 at offset 270591423
# Placed 18509555 points from shards/protomaster-02000000 at offset 283712831
# Placed 13837727 points from shards/protomaster-02100000 at offset 302222386
# Placed 13761978 points from shards/protomaster-02200000 at offset 316060113
# Placed 16084453 points from shards/protomaster-02300000 at offset 329822091
# Placed 11553718 points from shards/protomaster-02400000 at offset 345906544
# Placed 11718798 points from shards/protomaster-02500000 at offset 357460262
# Placed 7924294 points from shards/protomaster-02600000 at offset 369179060
# Placed 17140364 points from shards/protomaster-02700000 at offset 377103354
# Placed 12079682 points from shards/protomaster-02800000 at offset 394243718
# Placed 12421730 points from shards/protomaster-02900000 at offset 406323400
# Placed 10021215 points from shards/protomaster-03000000 at offset 418745130
# Placed 12009828 points from shards/protomaster-03100000 at offset 428766345
# Placed 13028226 points from shards/protomaster-03200000 at offset 440776173
# Placed 11114735 points from shards/protomaster-03300000 at offset 453804399
# Placed 8787140 points from shards/protomaster-03400000 at offset 464919134
# Placed 10208459 points from shards/protomaster-03500000 at offset 473706274
# Placed 8229138 points from shards/protomaster-03600000 at offset 483914733
# Placed 8864031 points from shards/protomaster-03700000 at offset 492143871
# Placed 11313374 points from shards/protomaster-03800000 at offset 501007902
# Placed 12335398 points from shards/protomaster-03900000 at offset 512321276
# Placed 12078958 points from shards/protomaster-04000000 at offset 524656674
# Placed 11515664 points from shards/protomaster-04100000 at offset 536735632
# Placed 10218717 points from shards/protomaster-04200000 at offset 548251296
# Placed 16365883 points from shards/protomaster-04300000 at offset 558470013
# Placed 13397489 points from shards/protomaster-04400000 at offset 574835896
# Placed 16325898 points from shards/protomaster-04500000 at offset 588233385
# Placed 11298664 points from shards/protomaster-04600000 at offset 604559283
# Placed 13099151 points from shards/protomaster-04700000 at offset 615857947
# Placed 14274036 points from shards/protomaster-04800000 at offset 628957098
# Placed 12759410 points from shards/protomaster-04900000 at offset 643231134
# Placed 10667706 points from shards/protomaster-05000000 at offset 655990544
# Placed 10739929 points from shards/protomaster-05100000 at offset 666658250
# Placed 10810267 points from shards/protomaster-05200000 at offset 677398179
# Placed 9404223 points from shards/protomaster-05300000 at offset 688208446
# Placed 10246670 points from shards/protomaster-05400000 at offset 697612669
# Placed 9438294 points from shards/protomaster-05500000 at offset 707859339
# Placed 11435537 points from shards/protomaster-05600000 at offset 717297633
# Placed 7728204 points from shards/protomaster-05700000 at offset 728733170
# Placed 8520811 points from shards/protomaster-05800000 at offset 736461374
# Placed 8324009 points from shards/protomaster-05900000 at offset 744982185
# Placed 11784776 points from shards/protomaster-06000000 at offset 753306194
# Placed 13720580 points from shards/protomaster-06100000 at offset 765090970
# Placed 18479870 points from shards/protomaster-06200000 at offset 778811550
# Placed 12504522 points from shards/protomaster-06300000 at offset 797291420
# Placed 8273972 points from shards/protomaster-06400000 at offset 809795942
# Placed 15717021 points from shards/protomaster-06500000 at offset 818069914
# Placed 23827330 points from shards/protomaster-06600000 at offset 833786935
# Placed 18664275 points from shards/protomaster-06700000 at offset 857614265
# Placed 13107348 points from shards/protomaster-06800000 at offset 876278540
# Placed 13432899 points from shards/protomaster-06900000 at offset 889385888
# Placed 13837409 points from shards/protomaster-07000000 at offset 902818787
# Placed 10521351 points from shards/protomaster-07100000 at offset 916656196
# Placed 7925043 points from shards/protomaster-07200000 at offset 927177547
# Placed 16017224 points from shards/protomaster-07300000 at offset 935102590
# Placed 13983376 points from shards/protomaster-07400000 at offset 951119814
# Placed 12824726 points from shards/protomaster-07500000 at offset 965103190
# Placed 9891347 points from shards/protomaster-07600000 at offset 977927916
# Placed 7949515 points from shards/protomaster-07700000 at offset 987819263
# Placed 10876192 points from shards/protomaster-07800000 at offset 995768778
# Placed 9065467 points from shards/protomaster-07900000 at offset 1006644970
# Placed 11551121 points from shards/protomaster-08000000 at offset 1015710437
# Placed 13693191 points from shards/protomaster-08100000 at offset 1027261558
# Placed 12643307 points from shards/protomaster-08200000 at offset 1040954749
# Placed 12310097 points from shards/protomaster-08300000 at offset 1053598056
# Placed 14108434 points from shards/protomaster-08400000 at offset 1065908153
# Placed 13000599 points from shards/protomaster-08500000 at offset 1080016587
# Placed 12189184 points from shards/protomaster-08600000 at offset 1093017186
# Placed 9896595 points from shards/protomaster-08700000 at offset 1105206370
# Placed 10798104 points from shards/protomaster-08800000 at offset 1115102965
# Placed 11479867 points from shards/protomaster-08900000 at offset 1125901069
# Placed 12644177 points from shards/protomaster-09000000 at offset 1137380936
# Placed 12934825 points from shards/protomaster-09100000 at offset 1150025113
# Placed 14380246 points from shards/protomaster-09200000 at offset 1162959938
# Placed 12301029 points from shards/protomaster-09300000 at offset 1177340184
# Placed 14656559 points from shards/protomaster-09400000 at offset 1189641213
# Placed 12389326 points from shards/protomaster-09500000 at offset 1204297772
# Placed 9628870 points from shards/protomaster-09600000 at offset 1216687098
# Placed 10213226 points from shards/protomaster-09700000 at offset 1226315968
# Placed 14030478 points from shards/protomaster-09800000 at offset 1236529194
# Placed 10594451 points from shards/protomaster-09900000 at offset 1250559672
# Placed 11583083 points from shards/protomaster-10000000 at offset 1261154123
# Placed 12201092 points from shards/protomaster-10100000 at offset 1272737206
# Placed 11056913 points from shards/protomaster-10200000 at offset 1284938298
# Placed 12833073 points from shards/protomaster-10300000 at offset 1295995211
# Placed 14684841 points from shards/protomaster-10400000 at offset 1308828284
# Placed 13077702 points from shards/protomaster-10500000 at offset 1323513125
# Placed 9585338 points from shards/protomaster-10600000 at offset 1336590827
# Placed 10125403 points from shards/protomaster-10700000 at offset 1346176165
# Placed 11947132 points from shards/protomaster-10800000 at offset 1356301568
# Placed 10540844 points from shards/protomaster-10900000 at offset 1368248700
# Placed 5924269 points from shards/protomaster-11000000 at offset 1378789544
# Reading all shards took 136.9 seconds
# Shuffling points took 116.2 seconds
# Master is 22.2GB
# Writing 1384713813 points to prototiles002/master.bin took 72.8 seconds

# %% [markdown]
# Generate prototiles
# -------------------

# %%
# Too many points to easily fit in RAM;  instead, buffer and write every so often
class PrototileWriter:
    def __init__(self, z, x, y):
        self.filename = "%s/%d/%d/%d.bin" % (prototiledir, z, x, y)
        if not os.path.exists(os.path.dirname(self.filename)):
            os.makedirs(os.path.dirname(self.filename))
        open(self.filename + '.tmp', 'w') # truncate file
        buffer_len = 256
        self.buf = numpy.zeros(buffer_len, dtype=numpy_record_type)
        self.size = 0
    def write(self, point):
        if self.size == len(self.buf):
            self.flush()
        self.buf[self.size] = point
        self.size += 1
    def flush(self):
        if self.size:
            self.buf[0:self.size].tofile(open(self.filename + '.tmp', 'a'))
            self.size = 0
    def close(self):
        self.flush()
        os.rename(self.filename + '.tmp', self.filename)

# %%
def make_prototile_zoom(z, subsample):
    dim = 2 ** z
    with Stopwatch('Building %d prototiles in %s/%d with subsample %g%%' % 
                   (dim * dim, prototiledir, z, subsample * 100.0)):
        tiles = [[PrototileWriter(z, x, y) for y in range(dim)] for x in range(dim)]

        num_records = os.stat(master).st_size / record_len
    
        if subsample < 1:
            num_records = int(round(num_records * subsample))
                              
        with open(master, 'rb') as master_in:
            while num_records > 0:
                records_to_read = min(num_records, 1024)
                bytes = master_in.read(records_to_read * record_len)
                assert len(bytes) == records_to_read * record_len
                records = numpy.frombuffer(bytes, dtype=numpy_record_type)
                assert len(records) == records_to_read
                num_records -= records_to_read
                for record in records:
                    xtile = int(record[0] * dim / 256)
                    ytile = int(record[1] * dim / 256)
                    tiles[xtile][ytile].write(record)
    
        for ytile in range(dim):
            for xtile in range(dim):
                tiles[xtile][ytile].close()

# %%
# Zoom behavior.  bad(1) means brighness step change on level switch.
# bad(2) means low res, or brightnness change if we render more levels

#       0-5    5-10   10+
# PNG   bad(1) good   bad(2)
# BIN   good   bad(1) good

# PNG
#

make_prototile_zoom( 0, 0.001) # fully zoomed out
make_prototile_zoom( 1, 0.001)
make_prototile_zoom( 2, 0.001)
make_prototile_zoom( 3, 0.001)
make_prototile_zoom( 4, 0.001)
make_prototile_zoom( 5, 0.001)
make_prototile_zoom( 6, 0.004)
make_prototile_zoom( 7, 0.016)
make_prototile_zoom( 8, 0.064)
make_prototile_zoom( 9, 0.256)
make_prototile_zoom(10, 1.0)   # zoomed in to metropolitan area
# Out:
# Building 1 prototiles in prototiles002/0 with subsample 0.1% took 17.6 seconds
# Building 4 prototiles in prototiles002/1 with subsample 0.1% took 17.3 seconds
# Building 16 prototiles in prototiles002/2 with subsample 0.1% took 17.8 seconds
# Building 64 prototiles in prototiles002/3 with subsample 0.1% took 17.9 seconds

# %%
# !du -sh prototiles002
# Out:
# 21G	prototiles002

# %%
#def check_point_file(filename):
#    n = 0
#    with open(filename, 'rb') as file_in:
#        print 'Checking %s' % filename
#        while True:
#            rec = file_in.read(record_len)
#            if not rec:
#                return
#            (x, y, blockIdx, seqWithinBlock) = struct.unpack(record_format, rec)
#            if x < 0 or x >= 256:
#                print 'Error at %s:%d' % (filename, n)
#                print (x, y, blockIdx, seqWithinBlock)
#            n += 1
