# %%
import json, os, re, sqlite3, thread, urllib, urllib2
from shapely.geometry import Point
import collections


# Google geocoding API to geocode an address
# Assumes key is in google_api_key.txt
# Use as second level lookup only for those which fail census lookup

re_noalnum = re.compile('^([^\w]+)$')

def geocode_address_google(address):
    if(pandas.isnull(address) or re_noalnum.match(address)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(address)
        return None

    try:
        geocode_address_google.conn
    except:
        geocode_address_google.conn = sqlite3.connect('geocoding_cache')
        geocode_address_google.cur = geocode_address_google.conn.cursor()
        geocode_address_google.cur.execute(('CREATE TABLE IF NOT EXISTS kvs'
                                     ' (key PRIMARY KEY, value)'
                                     ' WITHOUT ROWID;'))
        geocode_address_google.conn.commit()

    geocode_address_google.cur.execute('SELECT value FROM kvs WHERE key=?', (address,))
    rows = geocode_address_google.cur.fetchall()
    if rows:
        #print "Google: Found %r in cache" % (address)
        return json.loads(rows[0][0])
        
    #print "Google: %r not found in cache, fetching" % (address)

    api_key = open('google-api-key-do-not-commit.txt').read()
    payload = {'address':address, 'key':api_key}
    result = json.load(urllib2.urlopen('https://maps.googleapis.com/maps/api/geocode/json?%s' % urllib.urlencode(payload)))
    
    geocode_address_google.cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                                 ' VALUES (?, ?);'),
                                 (address, json.dumps(result)))
    geocode_address_google.conn.commit()
    
    # If the result succeeded and generated a formatted address, cache under that key too
    try:
        if(result['status']=='OK'):
            if(len(result['results'])== 1):
                canonical = result['results'][0]['formatted_address']
                #print "Google: Storing canonical addr of %r for %r" % (canonical, address)
                geocode_address_google.cur.execute(('INSERT OR REPLACE INTO kvs (key, value)'
                                                     ' VALUES (?, ?);'),
                                                     (canonical, json.dumps(result)))
                geocode_address_google.conn.commit()
            else:
                print "Google: Fetch %r seemed to succeed, but results empty or non-unique" % (address)

        else:
            print "Google: Fetch %r failed" % (address)

    except:
        #pass
        raise
    
    return result

def get_canonical_address_google(raw_addr):
    if(pandas.isnull(raw_addr) or re_noalnum.match(raw_addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(raw_addr)
        return None

    try:
        result=geocode_address_google(raw_addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            return(result['results'][0]['formatted_address'])
        else:
            return None
    except:
        return None

def get_canonical_zip_google(addr):
    if(pandas.isnull(addr) or re_noalnum.match(addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None

    try:
        result=geocode_address_google(addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            addr_comps = result['results'][0]['address_components']
            for i in range(0, len(addr_comps)):
                if('postal_code' in addr_comps[i]['types']):
                    return addr_comps[i]['short_name']
        
        return None
    except:
        return None
    
def get_canonical_coords_google(addr):
    if(pandas.isnull(addr) or re_noalnum.match(addr)):
        #print "Skipping address lookup for %r, no alphanumeric characters" %(addr)
        return None

    try:
        result=geocode_address_google(addr)
        if(result['status']=='OK' and len(result['results'])== 1):
            latlon = result['results'][0]['geometry']['location']
            if(latlon):
                return(Point(latlon['lng'], latlon['lat']))
        return None
    except:
        return None

# %%
def canonicalize_string(text):
    # Remove any leading or trailing whitespace, replace any internal whitespace with single spaces, upcase it all
    ret = re.sub("^\s+|\s+$", "", text)
    ret = re.sub("\s+", " ", ret)
    return ret.upper()

# %%
canonicalize_string(" a\t b   ")
# Out:
# 'A B'

# %%
canonicalize_string("  \t\t\t ")
# Out:
# ''

# %%
conn = sqlite3.connect('geocoding_cache')
cur = conn.cursor()
cur.execute('SELECT key, value FROM kvs')
google_rows = cur.fetchall()
len(google_rows)
# Out:
# 614521

# %%
# Key is canonical address, value is a map: {'canonical_in_census_db': True/False,'canonical_in_google_db': True/False, 'other_addr_strings':Set, 'census_value':str, 'google_value':str
canonical_addr_map={}

# %%
# Process google DB
count = 0

for (addr,gval) in google_rows:
    caddr = canonicalize_string(addr)
    
    # If there's nothing there, skip it
    if(caddr==""):
        continue
    if(caddr not in canonical_addr_map):
        canonical_addr_map[caddr]={'canonical_in_census_db':False,'canonical_in_google_db': False, 
                                   'other_addr_strings':set(), 
                                   'census_value':None, 'google_value':None}
    # At this point we know there's a (possibly just created) map for caddr in canonical_addr_map.
    # Update it for this entry
    if(caddr in canonical_addr_map):
        if (addr == caddr):
            # This is the canonical entry
            canonical_addr_map[caddr]['canonical_in_google_db']=True
            canonical_addr_map[caddr]['google_value']=gval
        else:
            # This is not the canonical entry
            canonical_addr_map[caddr]['other_addr_strings'].add(addr)
            if(not canonical_addr_map[caddr]['google_value']):
                canonical_addr_map[caddr]['google_value']=gval
            else:
                # Already have a value.  Do we have a canonical one yet?  If not, is this new one the same as what we have?
                if(not canonical_addr_map[caddr]['canonical_in_google_db'] and canonical_addr_map[caddr]['google_value'] != gval):
                    # Compare status and the length of the results, prefer status 'OK' and results length == 1
                    try:
                        stored_res = json.loads(canonical_addr_map[caddr]['google_value'])
                        new_res = json.loads(gval)
                        if(stored_res['status']!='OK' or len(stored_res['results'])!=1):
                            # The old one isn't good.  Try the new one in case it's better.
                            canonical_addr_map[caddr]['google_value']=gval
                            print "Replacing '%s'->'%s' google values do not match" % (addr,caddr)
                    except Exception as e:
                        print "ERROR processing '%s'->'%s' google values do not match\n%s" % (addr,caddr,e)
# Out:
# Replacing '  ALLEGHENY AVE  '->'ALLEGHENY AVE' google values do not match
# Replacing ' ALLEGHENY AVE  '->'ALLEGHENY AVE' google values do not match

# %%
num_added = 0
num_already_ok=0

# Find out if any of the entries in canonical_addr_map aren't in google db
for caddr in canonical_addr_map:
    if(not canonical_addr_map[caddr]['canonical_in_google_db']):
        #print "Adding %s (%d others)" % (caddr, len(canonical_addr_map[caddr]['other_addr_strings']))
        cur.execute(('INSERT OR REPLACE INTO kvs (key, value) VALUES (?, ?);'),
                    (caddr, canonical_addr_map[caddr]['google_value']))
        canonical_addr_map[caddr]['canonical_in_google_db']=True
        num_added=num_added+1
    else:
        num_already_ok=num_already_ok+1
print "Added %d, %d already ok" % (num_added, num_already_ok)
# Out:
# Added 294594, 317702 already ok

# %%
# Do same processing for census
conn_c = sqlite3.connect('geocoding_cache_census')
cur_c = conn_c.cursor()
cur_c.execute('SELECT key, value FROM kvs')
census_rows = cur_c.fetchall()
len(census_rows)
# Out:
# 3379234

# %%
# Process census DB
count = 0

for (addr,cval) in census_rows:
    caddr = canonicalize_string(addr)
    
    # If there's nothing there, skip it
    if(caddr==""):
        continue
    if(caddr not in canonical_addr_map):
        canonical_addr_map[caddr]={'canonical_in_census_db':False,'canonical_in_google_db': False, 
                                   'other_addr_strings':set(), 
                                   'census_value':None, 'google_value':None}
    # At this point we know there's a (possibly just created) map for caddr in canonical_addr_map.
    # Update it for this entry
    if(caddr in canonical_addr_map):
        if (addr == caddr):
            # This is the canonical entry
            canonical_addr_map[caddr]['canonical_in_census_db']=True
            canonical_addr_map[caddr]['census_value']=cval
        else:
            # This is not the canonical entry
            canonical_addr_map[caddr]['other_addr_strings'].add(addr)
            if(not canonical_addr_map[caddr]['census_value']):
                canonical_addr_map[caddr]['census_value']=cval
            else:
                # Already have a value.  Do we have a canonical one yet?  If not, is this new one the same as what we have?
                if(not canonical_addr_map[caddr]['canonical_in_census_db'] and canonical_addr_map[caddr]['census_value'] != cval):
                    # Compare status and the length of the results, prefer status 'OK' and results length == 1
                    try:
                        stored_res = json.loads(canonical_addr_map[caddr]['census_value'])
                        new_res = json.loads(cval)
                        if(len(stored_res['result']['addressMatches'])!=1):
                            # The old one isn't good.  Try the new one in case it's better.
                            canonical_addr_map[caddr]['census_value']=cval
                            print "Replacing '%s'->'%s' census values do not match" % (addr,caddr)
                    except Exception as e:
                        print "ERROR processing '%s'->'%s' census values do not match\n%s" % (addr,caddr,e)
# Out:
# Replacing '    CLIMAX ST  '->'CLIMAX ST' census values do not match
# Replacing '   CLIMAX ST  '->'CLIMAX ST' census values do not match
# Replacing '   FREELAND ST  '->'FREELAND ST' census values do not match
# Replacing '   INDUSTRY ST  '->'INDUSTRY ST' census values do not match
# Replacing '   IVY RD  '->'IVY RD' census values do not match
# Replacing '   LOYAL WAY  '->'LOYAL WAY' census values do not match
# Replacing '   NORWICH  '->'NORWICH' census values do not match
# Replacing '   PO BOX 11067        PITTSBURGH PA   15237'->'PO BOX 11067 PITTSBURGH PA 15237' census values do not match
# Replacing '   PO BOX 13444        PITTSBURGH PA   15243'->'PO BOX 13444 PITTSBURGH PA 15243' census values do not match
# Replacing '   PO BOX 342        VERONA PA   15147'->'PO BOX 342 VERONA PA 15147' census values do not match
# Replacing '   PO BOX 42265        PITTSBURGH PA   15203'->'PO BOX 42265 PITTSBURGH PA 15203' census values do not match
# Replacing '   PO BOX 801        MONROEVILLE PA   15146'->'PO BOX 801 MONROEVILLE PA 15146' census values do not match
# Replacing '   WAGON WHEEL RD  '->'WAGON WHEEL RD' census values do not match
# Replacing '  CLIMAX ST  '->'CLIMAX ST' census values do not match
# Replacing '  ESTELLA AVE  '->'ESTELLA AVE' census values do not match
# Replacing '  FREELAND ST  '->'FREELAND ST' census values do not match
# Replacing '  GEARING AVE  '->'GEARING AVE' census values do not match
# Replacing '  INDUSTRY ST  '->'INDUSTRY ST' census values do not match
# Replacing '  LOYAL WAY  '->'LOYAL WAY' census values do not match
# Replacing '  MELWOOD AVE  '->'MELWOOD AVE' census values do not match
# Replacing ' 10 AUDLEY PLACE PATRICKS HILL CORK IRELAND T23 W8HT '->'10 AUDLEY PLACE PATRICKS HILL CORK IRELAND T23 W8HT' census values do not match
# Replacing ' 1547 KING JAMES DR Pittsburgh, PA 15237-6711 '->'1547 KING JAMES DR PITTSBURGH, PA 15237-6711' census values do not match
# Replacing ' 178 S Linwood Pittsburgh, PA 15205-3308 '->'178 S LINWOOD PITTSBURGH, PA 15205-3308' census values do not match
# Replacing ' 206 CRIDERS LN Pittsburgh, PA 15237-2642 '->'206 CRIDERS LN PITTSBURGH, PA 15237-2642' census values do not match
# Replacing ' 22 PARK ST MOONER PONDS 3039 AUSTRALIA '->'22 PARK ST MOONER PONDS 3039 AUSTRALIA' census values do not match
# Replacing ' 2ND ST  '->'2ND ST' census values do not match
# Replacing ' 4011 OUTLOOK DR DR West Mifflin, PA 15122-2250 '->'4011 OUTLOOK DR DR WEST MIFFLIN, PA 15122-2250' census values do not match
# Replacing ' 4TH AVE PITTSBURGH, PA 15222 '->'4TH AVE PITTSBURGH, PA 15222' census values do not match
# Replacing ' 509 BLDG 4 XINKEXIANGYUAN ZHONGGUANCUN BEIJIRG ,CHINA '->'509 BLDG 4 XINKEXIANGYUAN ZHONGGUANCUN BEIJIRG ,CHINA' census values do not match
# Replacing ' 514 Nordeen Drive DR West Mifflin, PA 15122-1158 '->'514 NORDEEN DRIVE DR WEST MIFFLIN, PA 15122-1158' census values do not match
# Replacing ' 734 OAKCROSSING RD LONDON ONTARIO N6H 5V9 CANADA '->'734 OAKCROSSING RD LONDON ONTARIO N6H 5V9 CANADA' census values do not match
# Replacing ' 86 S Linwood Pittsburgh, PA 15205-4528 '->'86 S LINWOOD PITTSBURGH, PA 15205-4528' census values do not match
# Replacing ' ALDER DR WEXFORD, PA 15090 '->'ALDER DR WEXFORD, PA 15090' census values do not match
# Replacing ' ALLEGHENY AVE  '->'ALLEGHENY AVE' census values do not match
# Replacing ' ATTICA ST PITTSBURGH, PA 15220 '->'ATTICA ST PITTSBURGH, PA 15220' census values do not match
# Replacing ' BABCOCK BLVD  '->'BABCOCK BLVD' census values do not match
# Replacing ' BEAVER RD  '->'BEAVER RD' census values do not match
# Replacing ' BEAVER ST LEETSDALE, PA 15056 '->'BEAVER ST LEETSDALE, PA 15056' census values do not match
# Replacing ' BOYLE ST PITTSBURGH, PA 15212 '->'BOYLE ST PITTSBURGH, PA 15212' census values do not match
# Replacing ' BRERETON ST PITTSBURGH PA 15219'->'BRERETON ST PITTSBURGH PA 15219' census values do not match
# Replacing ' BRERETON ST PITTSBURGH, PA 15219 '->'BRERETON ST PITTSBURGH, PA 15219' census values do not match
# Replacing ' BRIGHTON PLACE PITTSBURGH, PA 15212 '->'BRIGHTON PLACE PITTSBURGH, PA 15212' census values do not match
# Replacing ' BROWN WAY PITTSBURGH, PA 15224 '->'BROWN WAY PITTSBURGH, PA 15224' census values do not match
# Replacing ' BUENTE ST PITTSBURGH, PA 15212 '->'BUENTE ST PITTSBURGH, PA 15212' census values do not match
# Replacing ' CAMP HORNE RD                PA '->'CAMP HORNE RD PA' census values do not match
# Replacing ' CARRIAGE BLVD  '->'CARRIAGE BLVD' census values do not match
# Replacing ' CATHERINE ST DUQUESNE PA 15110'->'CATHERINE ST DUQUESNE PA 15110' census values do not match
# Replacing ' MICHELLE RD NEW KENSINGTON, PA 15068 '->'MICHELLE RD NEW KENSINGTON, PA 15068' census values do not match
# Replacing ' MONTICELLO ST PITTSBURGH PA 15208'->'MONTICELLO ST PITTSBURGH PA 15208' census values do not match
# Replacing ' MONTICELLO ST PITTSBURGH, PA 15208 '->'MONTICELLO ST PITTSBURGH, PA 15208' census values do not match
# Replacing ' MORTIMER AVE  '->'MORTIMER AVE' census values do not match
# Replacing ' MOUNT VERNON ST PITTSBURGH, PA 15208 '->'MOUNT VERNON ST PITTSBURGH, PA 15208' census values do not match
# Replacing ' MULBERRY AY DUQUESNE       PA 15110'->'MULBERRY AY DUQUESNE PA 15110' census values do not match
# Replacing ' MULBERRY AY DUQUESNE PA 15110'->'MULBERRY AY DUQUESNE PA 15110' census values do not match
# Replacing ' MULBERRY AY DUQUESNE, PA 15110 '->'MULBERRY AY DUQUESNE, PA 15110' census values do not match
# Replacing ' N 3RD ST DUQUESNE, PA 15110 '->'N 3RD ST DUQUESNE, PA 15110' census values do not match
# Replacing ' N CHARLES ST PITTSBURGH, PA 15214 '->'N CHARLES ST PITTSBURGH, PA 15214' census values do not match
# Replacing ' N SHERIDAN AVE PITTSBURGH, PA 15206 '->'N SHERIDAN AVE PITTSBURGH, PA 15206' census values do not match
# Replacing ' NEWTON ST PITTSBURGH, PA 15203 '->'NEWTON ST PITTSBURGH, PA 15203' census values do not match
# Replacing ' NIMICK PLACE PITTSBURGH, PA 15221 '->'NIMICK PLACE PITTSBURGH, PA 15221' census values do not match
# Replacing ' NINA WAY  '->'NINA WAY' census values do not match
# Replacing ' OAKDALE ST PITTSBURGH, PA 15214 '->'OAKDALE ST PITTSBURGH, PA 15214' census values do not match
# Replacing ' OHIO RIVER BLVD LEETSDALE PA 15056'->'OHIO RIVER BLVD LEETSDALE PA 15056' census values do not match
# Replacing ' OHIO RIVER BLVD LEETSDALE, PA 15056 '->'OHIO RIVER BLVD LEETSDALE, PA 15056' census values do not match
# Replacing ' OLD CLAIRTON RD PITTSBURGH PA 15236'->'OLD CLAIRTON RD PITTSBURGH PA 15236' census values do not match
# Replacing ' OLD CLAIRTON RD PITTSBURGH, PA 15236 '->'OLD CLAIRTON RD PITTSBURGH, PA 15236' census values do not match
# Replacing ' OLD RAMSEY RD MONROEVILLE PA 15146'->'OLD RAMSEY RD MONROEVILLE PA 15146' census values do not match
# Replacing ' OLD RAMSEY RD MONROEVILLE, PA 15146 '->'OLD RAMSEY RD MONROEVILLE, PA 15146' census values do not match
# Replacing ' OLIVER ST  '->'OLIVER ST' census values do not match
# Replacing ' ONE PPG PL STE 1640 PITTSBURGH PA 15222'->'ONE PPG PL STE 1640 PITTSBURGH PA 15222' census values do not match
# Replacing ' P O BOX 11067 PITTSBURGH PA 15237'->'P O BOX 11067 PITTSBURGH PA 15237' census values do not match
# Replacing ' P O BOX 13341 PITTSBURGH PA 15243'->'P O BOX 13341 PITTSBURGH PA 15243' census values do not match
# Replacing ' RACE ST PITTSBURGH PA 15208'->'RACE ST PITTSBURGH PA 15208' census values do not match
# Replacing ' RACE ST PITTSBURGH, PA 15208 '->'RACE ST PITTSBURGH, PA 15208' census values do not match
# Replacing ' RICHARD RD  '->'RICHARD RD' census values do not match
# Replacing ' ROCHESTER RD  '->'ROCHESTER RD' census values do not match
# Replacing ' S 1ST ST DUQUESNE, PA 15110 '->'S 1ST ST DUQUESNE, PA 15110' census values do not match
# Replacing ' S 5TH ST DUQUESNE, PA 15110 '->'S 5TH ST DUQUESNE, PA 15110' census values do not match
# Replacing ' S 6TH ST DUQUESNE, PA 15110 '->'S 6TH ST DUQUESNE, PA 15110' census values do not match
# Replacing ' S 7TH ST DUQUESNE, PA 15110 '->'S 7TH ST DUQUESNE, PA 15110' census values do not match
# Replacing ' S LANG AVE PITTSBURGH, PA 15208 '->'S LANG AVE PITTSBURGH, PA 15208' census values do not match
# Replacing ' SAINT PATRICK ST PITTSBURGH, PA 15210 '->'SAINT PATRICK ST PITTSBURGH, PA 15210' census values do not match
# Replacing ' SANDUSKY ST PITTSBURGH, PA 15212 '->'SANDUSKY ST PITTSBURGH, PA 15212' census values do not match
# Replacing ' SCAIFE RD SEWICKLEY PA 15143'->'SCAIFE RD SEWICKLEY PA 15143' census values do not match
# Replacing ' SCAIFE RD SEWICKLEY, PA 15143 '->'SCAIFE RD SEWICKLEY, PA 15143' census values do not match
# Replacing ' SHERMAN AVE DUQUESNE, PA 15110 '->'SHERMAN AVE DUQUESNE, PA 15110' census values do not match
# Replacing ' SHETLAND AVE PITTSBURGH PA 15206'->'SHETLAND AVE PITTSBURGH PA 15206' census values do not match
# Replacing ' SHETLAND AVE PITTSBURGH, PA 15206 '->'SHETLAND AVE PITTSBURGH, PA 15206' census values do not match
# Replacing ' SPRING GARDEN AVE PITTSBURGH PA 15212'->'SPRING GARDEN AVE PITTSBURGH PA 15212' census values do not match
# Replacing ' SPRING GARDEN AVE PITTSBURGH, PA 15212 '->'SPRING GARDEN AVE PITTSBURGH, PA 15212' census values do not match
# Replacing ' STANDARD AVE SPRINGDALE, PA 15144 '->'STANDARD AVE SPRINGDALE, PA 15144' census values do not match
# Replacing ' SUBURBAN AVE PITTSBURGH, PA 15216 '->'SUBURBAN AVE PITTSBURGH, PA 15216' census values do not match
# Replacing ' SUNNYHILL RD  '->'SUNNYHILL RD' census values do not match
# Replacing ' SWEET GUM RD  '->'SWEET GUM RD' census values do not match
# Replacing ' SYGAN RD MCDONALD       PA 15057'->'SYGAN RD MCDONALD PA 15057' census values do not match
# Replacing ' TURRETT ST PITTSBURGH, PA 15206 '->'TURRETT ST PITTSBURGH, PA 15206' census values do not match
# Replacing ' UNIVERSITY AVE PITTSBURGH, PA 15214 '->'UNIVERSITY AVE PITTSBURGH, PA 15214' census values do not match
# Replacing ' UPLAND ST PITTSBURGH PA 15208'->'UPLAND ST PITTSBURGH PA 15208' census values do not match
# Replacing ' UPLAND ST PITTSBURGH, PA 15208 '->'UPLAND ST PITTSBURGH, PA 15208' census values do not match
# Replacing ' VALLEY FIELDS DR PITTSBURGH, PA 15239 '->'VALLEY FIELDS DR PITTSBURGH, PA 15239' census values do not match
# Replacing ' W CARSON ST FRONT PITTSBURGH, PA 15204 '->'W CARSON ST FRONT PITTSBURGH, PA 15204' census values do not match
# Replacing ' WAGON WHEEL RD  '->'WAGON WHEEL RD' census values do not match
# Replacing ' WALTER ST PITTSBURGH, PA 15210 '->'WALTER ST PITTSBURGH, PA 15210' census values do not match
# Replacing ' WARRINGTON AVE  '->'WARRINGTON AVE' census values do not match
# Replacing ' WEBER RD                PA '->'WEBER RD PA' census values do not match
# Replacing ' WICKLOW ST PITTSBURGH PA 15224'->'WICKLOW ST PITTSBURGH PA 15224' census values do not match
# Replacing ' WICKLOW ST PITTSBURGH, PA 15224 '->'WICKLOW ST PITTSBURGH, PA 15224' census values do not match
# Replacing ' WILDWOOD RD  '->'WILDWOOD RD' census values do not match
# Replacing ' WILSON AVE PITTSBURGH, PA 15214 '->'WILSON AVE PITTSBURGH, PA 15214' census values do not match
# Replacing ' WOODLAND RD PITTSBURGH PA 15232'->'WOODLAND RD PITTSBURGH PA 15232' census values do not match
# Replacing ' WYCOFF ST PITTSBURGH, PA 15204 '->'WYCOFF ST PITTSBURGH, PA 15204' census values do not match
# Replacing '0 BLVD OF THE ALLIES  PITTSBURGH PA 15213'->'0 BLVD OF THE ALLIES PITTSBURGH PA 15213' census values do not match
# Replacing '0 LEDGEWAY  PITTSBURGH PA 15213'->'0 LEDGEWAY PITTSBURGH PA 15213' census values do not match
# Replacing '0 PVT R of W PITTSBURGH PA 15238'->'0 PVT R OF W PITTSBURGH PA 15238' census values do not match
# Replacing '0 PVT R of W PITTSBURGH, PA 15238 '->'0 PVT R OF W PITTSBURGH, PA 15238' census values do not match
# Replacing '0 R of W BUENA VISTA, PA 15018 '->'0 R OF W BUENA VISTA, PA 15018' census values do not match
# Replacing '0 R of W GIBSONIA, PA 15044 '->'0 R OF W GIBSONIA, PA 15044' census values do not match
# Replacing '0 R of W MC KEESPORT, PA 15135 '->'0 R OF W MC KEESPORT, PA 15135' census values do not match
# Replacing '0 SYLVANIA DRy PITTSBURGH, PA 15241 '->'0 SYLVANIA DRY PITTSBURGH, PA 15241' census values do not match
# Replacing '1013 ASSOCIATES 1739 E CARSON ST 356 Pittsburgh, PA 15203-1700 '->'1013 ASSOCIATES 1739 E CARSON ST 356 PITTSBURGH, PA 15203-1700' census values do not match
# Replacing '1013 ASSOCIATES 1739 E CARSON ST STE 356 Pittsburgh, PA 15203-1700 '->'1013 ASSOCIATES 1739 E CARSON ST STE 356 PITTSBURGH, PA 15203-1700' census values do not match
# Replacing '105 NANTUCKET DR PITTSBURGH     PA 15238'->'105 NANTUCKET DR PITTSBURGH PA 15238' census values do not match
# Replacing '117 BAKER DR CLAIRTON       PA 15025'->'117 BAKER DR CLAIRTON PA 15025' census values do not match
# Replacing '121 EDGEWOOD AVE PITTSBURGH     PA 15218'->'121 EDGEWOOD AVE PITTSBURGH PA 15218' census values do not match
# Replacing '124 ROAD D APT B TAMUNING GU 96913-3744 '->'124 ROAD D APT B TAMUNING GU 96913-3744' census values do not match
# Replacing '13 ALLEE HENRI MATISSE 77420 CHAMP-SUR-MARNE FRANCE '->'13 ALLEE HENRI MATISSE 77420 CHAMP-SUR-MARNE FRANCE' census values do not match
# Replacing '13 ALLEE HENRI MATISSE CHAMP SUR MARNE FRANCE 77420 '->'13 ALLEE HENRI MATISSE CHAMP SUR MARNE FRANCE 77420' census values do not match
# Replacing '1326 MAIN ST  '->'1326 MAIN ST' census values do not match
# Replacing '1440 WOOD RD '->'1440 WOOD RD' census values do not match
# Replacing '1510 OLIVANT ST PITTSBURGH     PA 15206'->'1510 OLIVANT ST PITTSBURGH PA 15206' census values do not match
# Replacing '1516 ROSEBERRY ST  '->'1516 ROSEBERRY ST' census values do not match
# Replacing '1530 OLD STATE RD GIBSONIA       PA 15044'->'1530 OLD STATE RD GIBSONIA PA 15044' census values do not match
# Replacing '16   ELLERS ST   PITTSBURGH PA 15213'->'16 ELLERS ST PITTSBURGH PA 15213' census values do not match
# Replacing '16 JANELAINE COURT SPRINGDALE SOUTH MELBOURNE AUSTRALIA 3172 '->'16 JANELAINE COURT SPRINGDALE SOUTH MELBOURNE AUSTRALIA 3172' census values do not match
# Replacing '1770 FERGUSON RD  '->'1770 FERGUSON RD' census values do not match
# Replacing '18 ELLERS ST PITTSBURGH     PA 15213'->'18 ELLERS ST PITTSBURGH PA 15213' census values do not match
# Replacing '2 REPUBLIC AVE  '->'2 REPUBLIC AVE' census values do not match
# Replacing '200 WAVERLY AVE  '->'200 WAVERLY AVE' census values do not match
# Replacing '206 FREEDOM LANE NATRONA HGTS   PA 15065'->'206 FREEDOM LANE NATRONA HGTS PA 15065' census values do not match
# Replacing '225 INDIANOLA RD  '->'225 INDIANOLA RD' census values do not match
# Replacing '248 BREWER RD '->'248 BREWER RD' census values do not match
# Replacing '266 BATES ST PITTSBURGH     PA 15213'->'266 BATES ST PITTSBURGH PA 15213' census values do not match
# Replacing '2668 PANGBURN HOLLOW RD  '->'2668 PANGBURN HOLLOW RD' census values do not match
# Replacing '28 ELLERS ST PITTSBURGH     PA 15213'->'28 ELLERS ST PITTSBURGH PA 15213' census values do not match
# Replacing '2932 CROCKETT ST PITTSBURGH     PA 15213'->'2932 CROCKETT ST PITTSBURGH PA 15213' census values do not match
# Replacing '299 SHERMAN ST '->'299 SHERMAN ST' census values do not match
# Replacing '30 CHILDS ST PITTSBURGH     PA 15213'->'30 CHILDS ST PITTSBURGH PA 15213' census values do not match
# Replacing '303 YORK WAY PITTSBURGH     PA 15213'->'303 YORK WAY PITTSBURGH PA 15213' census values do not match
# Replacing '309 MEYRAN AVE PITTSBURGH     PA 15213'->'309 MEYRAN AVE PITTSBURGH PA 15213' census values do not match
# Replacing '3220 HARDIE WAY PITTSBURGH     PA 15213'->'3220 HARDIE WAY PITTSBURGH PA 15213' census values do not match
# Replacing '825 PALE SAN VITORES RD APT 410 TAMUNING GU 96913 '->'825 PALE SAN VITORES RD APT 410 TAMUNING GU 96913' census values do not match
# Replacing '9165 CLARK ST MONTREAL QUEBEC QUEBEC H2N1S1 '->'9165 CLARK ST MONTREAL QUEBEC QUEBEC H2N1S1' census values do not match
# Replacing '9A KAWAU RD GREENLANE AUCKLAND 1061 NEW ZEALAND '->'9A KAWAU RD GREENLANE AUCKLAND 1061 NEW ZEALAND' census values do not match
# Replacing 'AM KAISERKAI 46 HAMBURG GERMANY 20457 '->'AM KAISERKAI 46 HAMBURG GERMANY 20457' census values do not match
# Replacing 'BOX 329 BONOLA  RIVER RD  '->'BOX 329 BONOLA RIVER RD' census values do not match
# Replacing 'DPT 25-158 20 STANWIX ST PITTSBURGH, PA 15222-4802 '->'DPT 25-158 20 STANWIX ST PITTSBURGH, PA 15222-4802' census values do not match
# Replacing 'JAN DETROCHSTRAAT 188 1703 DILBEEK BELGIUM '->'JAN DETROCHSTRAAT 188 1703 DILBEEK BELGIUM' census values do not match
# Replacing 'N7746 COUNTY ROAD O WHITEWATER WI 53190-4427 '->'N7746 COUNTY ROAD O WHITEWATER WI 53190-4427' census values do not match
# Replacing 'ODOS DEMOKRATIAS 85 70100 AGIOS NIKOLAOS CRETE GREECE '->'ODOS DEMOKRATIAS 85 70100 AGIOS NIKOLAOS CRETE GREECE' census values do not match
# Replacing 'ODOS DEMOKRATIAS 85 70100 AGIOS NIKOLAOS CRETE, GREECE '->'ODOS DEMOKRATIAS 85 70100 AGIOS NIKOLAOS CRETE, GREECE' census values do not match
# Replacing 'PO BOX 757 MYLOR SOUTH AUSTRALIA 5153 '->'PO BOX 757 MYLOR SOUTH AUSTRALIA 5153' census values do not match
# Replacing 'PO BOX RKM LIGONIER, PA 15658-0780 '->'PO BOX RKM LIGONIER, PA 15658-0780' census values do not match

# %%
num_added = 0
num_already_ok=0

# Find out if any of the entries in canonical_addr_map aren't in census db
for caddr in canonical_addr_map:
    if(canonical_addr_map[caddr]['census_value']):
        if(not canonical_addr_map[caddr]['canonical_in_census_db']):
            #print "Adding %s (%d others)" % (caddr, len(canonical_addr_map[caddr]['other_addr_strings']))
            cur_c.execute(('INSERT OR REPLACE INTO kvs (key, value) VALUES (?, ?);'),
                          (caddr, canonical_addr_map[caddr]['census_value']))
            canonical_addr_map[caddr]['canonical_in_census_db']=True
            num_added=num_added+1
        else:
            num_already_ok=num_already_ok+1
print "Added %d, %d already ok" % (num_added, num_already_ok)
# Out:
# Added 676576, 2030685 already ok

# %%
# Try to save out canonical_addr_map
import pickle
pickle_file_path = 'assessments/canonical_addr_map.pickle'

# %%
# Load in canonical_addr_map
with open(pickle_file_path, 'rb') as handle:
    canonical_addr_map = pickle.load(handle)

# %%
# Save out canonical_addr_map
with open(pickle_file_path, 'wb') as handle:
    pickle.dump(canonical_addr_map, handle, protocol=pickle.HIGHEST_PROTOCOL)
